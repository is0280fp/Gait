# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_only_3DGRF_LSTM_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# # Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# # StratifiedGroupKFoldの分割結果をpickle
import pickle

# test
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# trainig and validation
with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
   COP_ML = pickle.load(f)
f.close()

# label
with open("/content/drive/MyDrive/test_data/train_idx_list.pickle", mode="rb") as f:
   train_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   label = pickle.load(f)
f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    test_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    test_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()

# # trainig and validation
# with open("V_val_train.pickle", mode="rb") as f:
#    V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    COP_ML = pickle.load(f)
# f.close()

# # label
# with open("train_idx_list.pickle", mode="rb") as f:
#    train_index_list = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("label_val_train.pickle", mode="rb") as f:
#    label = pickle.load(f)
# f.close()

# with open("test_sub_ID.pickle", mode="rb") as f:
#    sub_ID=pickle.load(f)
# f.close()

# import pandas as pd

# with open("test_data_index.pickle", mode="rb") as f:
#    test_index = pickle.load(f)
# f.close()

# %%
import numpy as np
print(np.where(label==0)[0].shape)
print(np.where(label==1)[0].shape)
print(np.where(label==2)[0].shape)
print(np.where(label==3)[0].shape)
print(np.where(label==4)[0].shape)
# Out:
# (13756,)
# (11862,)
# (17630,)
# (18557,)
# (14341,)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(V)
V = mmscaler_LSTM.transform(V)
V = V.reshape(V.shape[0], V.shape[1], 1)

mmscaler_LSTM.fit(AP)
AP = mmscaler_LSTM.transform(AP)
AP = AP.reshape(AP.shape[0], AP.shape[1], 1)

mmscaler_LSTM.fit(ML)
ML = mmscaler_LSTM.transform(ML)
ML = ML.reshape(ML.shape[0], ML.shape[1], 1)

mmscaler_LSTM.fit(COP_AP)
COP_AP = mmscaler_LSTM.transform(COP_AP)
COP_AP = COP_AP.reshape(COP_AP.shape[0], COP_AP.shape[1], 1)

mmscaler_LSTM.fit(COP_ML)
COP_ML = mmscaler_LSTM.transform(COP_ML)
COP_ML = COP_ML.reshape(COP_ML.shape[0], COP_ML.shape[1], 1)

# %%
# !pip install keras-layer-normalization
# !pip install keras-self-attention
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=1061aeab32dfe9a3dc2f7e0fcdd97576f2c66e442e0e739b70a1ceef215bfae8
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_3DGRF_LSTM_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )

initializer = he_normal()

classes_main = 5

#LSTM-----------------------------------------------------------------------------------------------------------------------
def build_model():
  # LSTM
  # 最初これだけだった
  model = Sequential()
  model.add(InputLayer(input_shape=(101, 3)))

  model.add(Bidirectional(LSTM(512, return_sequences=True)))
  # model.add(LSTM(256, return_sequences=True))
  model.add(LayerNormalization())
  model.add(Activation('tanh'))
  model.add(Dropout(0.5))
  
  model.add(Flatten())

  model.add(Dense(512, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#------------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

EPOCHS = 500

val_label_list = []
train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(7):
  train_index = train_index_list[i]
  train_LSTM_data = np.concatenate([V[train_index], AP[train_index], ML[train_index]], axis=2)
  val_index = val_index_list[i]
  val_LSTM_data = np.concatenate([V[val_index], AP[val_index], ML[val_index]], axis=2)
  
  # label
  train_label = label[train_index] 
  val_label= label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  MAX = len(train_LSTM_data)

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)
# train_data (65268, 101, 3)
# val_data (10878, 101, 3)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11952,)
# H (10373,)
# K (15152,)
# A (15736,)
# C (12055,)
# Epoch 1/400
# 1036/1036 [==============================] - 132s 96ms/step - loss: 1.6473 - acc: 0.3060 - val_loss: 1.4401 - val_acc: 0.3963
#
# Epoch 00001: val_loss improved from inf to 1.44013, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 1.3747 - acc: 0.4240 - val_loss: 1.3464 - val_acc: 0.4408
#
# Epoch 00002: val_loss improved from 1.44013 to 1.34641, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 1.2464 - acc: 0.5000 - val_loss: 1.2765 - val_acc: 0.4706
#
# Epoch 00003: val_loss improved from 1.34641 to 1.27654, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 1.1597 - acc: 0.5482 - val_loss: 1.1887 - val_acc: 0.5300
#
# Epoch 00004: val_loss improved from 1.27654 to 1.18871, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 1.0945 - acc: 0.5879 - val_loss: 1.1464 - val_acc: 0.5359
#
# Epoch 00005: val_loss improved from 1.18871 to 1.14643, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 1.0316 - acc: 0.6249 - val_loss: 1.0857 - val_acc: 0.5782
#
# Epoch 00006: val_loss improved from 1.14643 to 1.08574, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.9749 - acc: 0.6582 - val_loss: 1.0590 - val_acc: 0.5974
#
# Epoch 00007: val_loss improved from 1.08574 to 1.05903, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.9289 - acc: 0.6837 - val_loss: 1.0267 - val_acc: 0.6213
#
# Epoch 00008: val_loss improved from 1.05903 to 1.02674, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.8883 - acc: 0.7075 - val_loss: 0.9898 - val_acc: 0.6330
#
# Epoch 00009: val_loss improved from 1.02674 to 0.98980, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.8554 - acc: 0.7247 - val_loss: 0.9587 - val_acc: 0.6391
#
# Epoch 00010: val_loss improved from 0.98980 to 0.95874, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.8184 - acc: 0.7444 - val_loss: 0.9274 - val_acc: 0.6716
#
# Epoch 00011: val_loss improved from 0.95874 to 0.92736, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.7860 - acc: 0.7666 - val_loss: 0.9116 - val_acc: 0.6750
#
# Epoch 00012: val_loss improved from 0.92736 to 0.91160, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.7626 - acc: 0.7782 - val_loss: 0.8841 - val_acc: 0.6839
#
# Epoch 00013: val_loss improved from 0.91160 to 0.88406, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.7353 - acc: 0.7904 - val_loss: 0.8742 - val_acc: 0.6996
#
# Epoch 00014: val_loss improved from 0.88406 to 0.87423, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.7055 - acc: 0.8070 - val_loss: 0.8638 - val_acc: 0.6934
#
# Epoch 00015: val_loss improved from 0.87423 to 0.86383, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.6880 - acc: 0.8159 - val_loss: 0.8295 - val_acc: 0.7191
#
# Epoch 00016: val_loss improved from 0.86383 to 0.82954, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.6652 - acc: 0.8245 - val_loss: 0.8062 - val_acc: 0.7325
#
# Epoch 00017: val_loss improved from 0.82954 to 0.80618, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.6448 - acc: 0.8331 - val_loss: 0.7995 - val_acc: 0.7294
#
# Epoch 00018: val_loss improved from 0.80618 to 0.79953, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.6201 - acc: 0.8472 - val_loss: 0.8007 - val_acc: 0.7236
#
# Epoch 00019: val_loss did not improve from 0.79953
# Epoch 20/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.5991 - acc: 0.8583 - val_loss: 0.7752 - val_acc: 0.7423
#
# Epoch 00020: val_loss improved from 0.79953 to 0.77521, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.5847 - acc: 0.8649 - val_loss: 0.7673 - val_acc: 0.7462
#
# Epoch 00021: val_loss improved from 0.77521 to 0.76734, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.5669 - acc: 0.8718 - val_loss: 0.7542 - val_acc: 0.7519
#
# Epoch 00022: val_loss improved from 0.76734 to 0.75418, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.5510 - acc: 0.8775 - val_loss: 0.7421 - val_acc: 0.7577
#
# Epoch 00023: val_loss improved from 0.75418 to 0.74213, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.5336 - acc: 0.8882 - val_loss: 0.7382 - val_acc: 0.7578
#
# Epoch 00024: val_loss improved from 0.74213 to 0.73821, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.5175 - acc: 0.8937 - val_loss: 0.7306 - val_acc: 0.7599
#
# Epoch 00025: val_loss improved from 0.73821 to 0.73057, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.5034 - acc: 0.9021 - val_loss: 0.7205 - val_acc: 0.7743
#
# Epoch 00026: val_loss improved from 0.73057 to 0.72046, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4917 - acc: 0.9046 - val_loss: 0.7028 - val_acc: 0.7810
#
# Epoch 00027: val_loss improved from 0.72046 to 0.70276, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4784 - acc: 0.9083 - val_loss: 0.7017 - val_acc: 0.7705
#
# Epoch 00028: val_loss improved from 0.70276 to 0.70166, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4699 - acc: 0.9124 - val_loss: 0.6950 - val_acc: 0.7743
#
# Epoch 00029: val_loss improved from 0.70166 to 0.69504, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4525 - acc: 0.9195 - val_loss: 0.6928 - val_acc: 0.7772
#
# Epoch 00030: val_loss improved from 0.69504 to 0.69280, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4416 - acc: 0.9215 - val_loss: 0.6778 - val_acc: 0.7844
#
# Epoch 00031: val_loss improved from 0.69280 to 0.67783, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4301 - acc: 0.9267 - val_loss: 0.6747 - val_acc: 0.7787
#
# Epoch 00032: val_loss improved from 0.67783 to 0.67467, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4191 - acc: 0.9291 - val_loss: 0.6636 - val_acc: 0.7847
#
# Epoch 00033: val_loss improved from 0.67467 to 0.66360, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.4050 - acc: 0.9361 - val_loss: 0.6593 - val_acc: 0.7913
#
# Epoch 00034: val_loss improved from 0.66360 to 0.65926, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3952 - acc: 0.9391 - val_loss: 0.6610 - val_acc: 0.7878
#
# Epoch 00035: val_loss did not improve from 0.65926
# Epoch 36/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3847 - acc: 0.9431 - val_loss: 0.6528 - val_acc: 0.7831
#
# Epoch 00036: val_loss improved from 0.65926 to 0.65282, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3736 - acc: 0.9474 - val_loss: 0.6484 - val_acc: 0.7862
#
# Epoch 00037: val_loss improved from 0.65282 to 0.64840, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3669 - acc: 0.9472 - val_loss: 0.6326 - val_acc: 0.7925
#
# Epoch 00038: val_loss improved from 0.64840 to 0.63262, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 99s 96ms/step - loss: 0.3610 - acc: 0.9491 - val_loss: 0.6267 - val_acc: 0.7955
#
# Epoch 00039: val_loss improved from 0.63262 to 0.62666, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3518 - acc: 0.9512 - val_loss: 0.6302 - val_acc: 0.7962
#
# Epoch 00040: val_loss did not improve from 0.62666
# Epoch 41/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3423 - acc: 0.9537 - val_loss: 0.6198 - val_acc: 0.8033
#
# Epoch 00041: val_loss improved from 0.62666 to 0.61975, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3329 - acc: 0.9556 - val_loss: 0.6139 - val_acc: 0.8036
#
# Epoch 00042: val_loss improved from 0.61975 to 0.61388, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3247 - acc: 0.9596 - val_loss: 0.6172 - val_acc: 0.8104
#
# Epoch 00043: val_loss did not improve from 0.61388
# Epoch 44/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3207 - acc: 0.9585 - val_loss: 0.6234 - val_acc: 0.8024
#
# Epoch 00044: val_loss did not improve from 0.61388
# Epoch 45/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3107 - acc: 0.9627 - val_loss: 0.6253 - val_acc: 0.7972
#
# Epoch 00045: val_loss did not improve from 0.61388
# Epoch 46/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.3033 - acc: 0.9650 - val_loss: 0.6074 - val_acc: 0.7971
#
# Epoch 00046: val_loss improved from 0.61388 to 0.60741, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.2944 - acc: 0.9657 - val_loss: 0.5999 - val_acc: 0.8059
#
# Epoch 00047: val_loss improved from 0.60741 to 0.59992, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.2862 - acc: 0.9672 - val_loss: 0.6103 - val_acc: 0.8073
#
# Epoch 00048: val_loss did not improve from 0.59992
# Epoch 49/400
# 1036/1036 [==============================] - 99s 95ms/step - loss: 0.2820 - acc: 0.9690 - val_loss: 0.6072 - val_acc: 0.8020
#
# Epoch 00049: val_loss did not improve from 0.59992
# Epoch 50/400
#  970/1036 [===========================>..] - ETA: 5s - loss: 0.2795 - acc: 0.9690

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 31 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

i=0
# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5')

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# # save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11952,)
# H (10373,)
# K (15152,)
# A (15736,)
# C (12055,)
# Epoch 1/400
# 1036/1036 [==============================] - 101s 65ms/step - loss: 0.2917 - acc: 0.9669 - val_loss: 0.5930 - val_acc: 0.8065
#
# Epoch 00001: val_loss improved from inf to 0.59304, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 67s 64ms/step - loss: 0.2814 - acc: 0.9700 - val_loss: 0.6041 - val_acc: 0.8094
#
# Epoch 00002: val_loss did not improve from 0.59304
# Epoch 3/400
# 1036/1036 [==============================] - 67s 65ms/step - loss: 0.2733 - acc: 0.9714 - val_loss: 0.6088 - val_acc: 0.8000
#
# Epoch 00003: val_loss did not improve from 0.59304
# Epoch 4/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.2696 - acc: 0.9722 - val_loss: 0.5900 - val_acc: 0.8113
#
# Epoch 00004: val_loss improved from 0.59304 to 0.59004, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2632 - acc: 0.9736 - val_loss: 0.5906 - val_acc: 0.8151
#
# Epoch 00005: val_loss did not improve from 0.59004
# Epoch 6/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2598 - acc: 0.9737 - val_loss: 0.5943 - val_acc: 0.8107
#
# Epoch 00006: val_loss did not improve from 0.59004
# Epoch 7/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2539 - acc: 0.9737 - val_loss: 0.5872 - val_acc: 0.8151
#
# Epoch 00007: val_loss improved from 0.59004 to 0.58722, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2439 - acc: 0.9770 - val_loss: 0.5957 - val_acc: 0.8029
#
# Epoch 00008: val_loss did not improve from 0.58722
# Epoch 9/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2405 - acc: 0.9773 - val_loss: 0.5689 - val_acc: 0.8170
#
# Epoch 00009: val_loss improved from 0.58722 to 0.56895, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2364 - acc: 0.9787 - val_loss: 0.5831 - val_acc: 0.8149
#
# Epoch 00010: val_loss did not improve from 0.56895
# Epoch 11/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2300 - acc: 0.9797 - val_loss: 0.5762 - val_acc: 0.8205
#
# Epoch 00011: val_loss did not improve from 0.56895
# Epoch 12/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2255 - acc: 0.9807 - val_loss: 0.5704 - val_acc: 0.8200
#
# Epoch 00012: val_loss did not improve from 0.56895
# Epoch 13/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2193 - acc: 0.9807 - val_loss: 0.5700 - val_acc: 0.8127
#
# Epoch 00013: val_loss did not improve from 0.56895
# Epoch 14/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2152 - acc: 0.9820 - val_loss: 0.5659 - val_acc: 0.8147
#
# Epoch 00014: val_loss improved from 0.56895 to 0.56594, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.2113 - acc: 0.9820 - val_loss: 0.5786 - val_acc: 0.8088
#
# Epoch 00015: val_loss did not improve from 0.56594
# Epoch 16/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.2088 - acc: 0.9819 - val_loss: 0.5658 - val_acc: 0.8188
#
# Epoch 00016: val_loss improved from 0.56594 to 0.56579, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.2036 - acc: 0.9825 - val_loss: 0.5626 - val_acc: 0.8164
#
# Epoch 00017: val_loss improved from 0.56579 to 0.56262, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1977 - acc: 0.9838 - val_loss: 0.5741 - val_acc: 0.8179
#
# Epoch 00018: val_loss did not improve from 0.56262
# Epoch 19/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1934 - acc: 0.9845 - val_loss: 0.5692 - val_acc: 0.8183
#
# Epoch 00019: val_loss did not improve from 0.56262
# Epoch 20/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1883 - acc: 0.9861 - val_loss: 0.5535 - val_acc: 0.8156
#
# Epoch 00020: val_loss improved from 0.56262 to 0.55346, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1864 - acc: 0.9858 - val_loss: 0.5582 - val_acc: 0.8278
#
# Epoch 00021: val_loss did not improve from 0.55346
# Epoch 22/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1814 - acc: 0.9869 - val_loss: 0.5580 - val_acc: 0.8188
#
# Epoch 00022: val_loss did not improve from 0.55346
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1786 - acc: 0.9859 - val_loss: 0.5657 - val_acc: 0.8207
#
# Epoch 00023: val_loss did not improve from 0.55346
# Epoch 24/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1725 - acc: 0.9873 - val_loss: 0.5518 - val_acc: 0.8228
#
# Epoch 00024: val_loss improved from 0.55346 to 0.55181, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1719 - acc: 0.9866 - val_loss: 0.5520 - val_acc: 0.8219
#
# Epoch 00025: val_loss did not improve from 0.55181
# Epoch 26/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1679 - acc: 0.9875 - val_loss: 0.5509 - val_acc: 0.8215
#
# Epoch 00026: val_loss improved from 0.55181 to 0.55087, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1644 - acc: 0.9885 - val_loss: 0.5528 - val_acc: 0.8228
#
# Epoch 00027: val_loss did not improve from 0.55087
# Epoch 28/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1615 - acc: 0.9876 - val_loss: 0.5452 - val_acc: 0.8225
#
# Epoch 00028: val_loss improved from 0.55087 to 0.54516, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1588 - acc: 0.9893 - val_loss: 0.5516 - val_acc: 0.8246
#
# Epoch 00029: val_loss did not improve from 0.54516
# Epoch 30/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1542 - acc: 0.9900 - val_loss: 0.5397 - val_acc: 0.8262
#
# Epoch 00030: val_loss improved from 0.54516 to 0.53970, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1495 - acc: 0.9901 - val_loss: 0.5610 - val_acc: 0.8184
#
# Epoch 00031: val_loss did not improve from 0.53970
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1455 - acc: 0.9909 - val_loss: 0.5375 - val_acc: 0.8291
#
# Epoch 00032: val_loss improved from 0.53970 to 0.53746, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1416 - acc: 0.9923 - val_loss: 0.5358 - val_acc: 0.8298
#
# Epoch 00033: val_loss improved from 0.53746 to 0.53576, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1405 - acc: 0.9925 - val_loss: 0.5308 - val_acc: 0.8307
#
# Epoch 00034: val_loss improved from 0.53576 to 0.53082, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1382 - acc: 0.9929 - val_loss: 0.5303 - val_acc: 0.8316
#
# Epoch 00035: val_loss improved from 0.53082 to 0.53032, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1376 - acc: 0.9931 - val_loss: 0.5312 - val_acc: 0.8297
#
# Epoch 00036: val_loss did not improve from 0.53032
# Epoch 37/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1374 - acc: 0.9927 - val_loss: 0.5304 - val_acc: 0.8330
#
# Epoch 00037: val_loss did not improve from 0.53032
# Epoch 38/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1366 - acc: 0.9938 - val_loss: 0.5256 - val_acc: 0.8313
#
# Epoch 00038: val_loss improved from 0.53032 to 0.52561, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1358 - acc: 0.9929 - val_loss: 0.5286 - val_acc: 0.8333
#
# Epoch 00039: val_loss did not improve from 0.52561
# Epoch 40/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1349 - acc: 0.9933 - val_loss: 0.5282 - val_acc: 0.8331
#
# Epoch 00040: val_loss did not improve from 0.52561
# Epoch 41/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1350 - acc: 0.9932 - val_loss: 0.5297 - val_acc: 0.8299
#
# Epoch 00041: val_loss did not improve from 0.52561
# Epoch 42/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1334 - acc: 0.9936 - val_loss: 0.5298 - val_acc: 0.8320
#
# Epoch 00042: val_loss did not improve from 0.52561
# Epoch 43/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1345 - acc: 0.9936 - val_loss: 0.5294 - val_acc: 0.8296
#
# Epoch 00043: val_loss did not improve from 0.52561
# Epoch 44/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1343 - acc: 0.9935 - val_loss: 0.5277 - val_acc: 0.8338
#
# Epoch 00044: val_loss did not improve from 0.52561
# Epoch 45/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1328 - acc: 0.9940 - val_loss: 0.5291 - val_acc: 0.8309
#
# Epoch 00045: val_loss did not improve from 0.52561
# Epoch 46/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1318 - acc: 0.9941 - val_loss: 0.5262 - val_acc: 0.8369
#
# Epoch 00046: val_loss did not improve from 0.52561
# Epoch 47/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1324 - acc: 0.9940 - val_loss: 0.5285 - val_acc: 0.8341
#
# Epoch 00047: val_loss did not improve from 0.52561
# Epoch 48/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1310 - acc: 0.9939 - val_loss: 0.5256 - val_acc: 0.8354
#
# Epoch 00048: val_loss improved from 0.52561 to 0.52555, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1320 - acc: 0.9935 - val_loss: 0.5271 - val_acc: 0.8320
#
# Epoch 00049: val_loss did not improve from 0.52555
# Epoch 50/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1310 - acc: 0.9940 - val_loss: 0.5272 - val_acc: 0.8327
#
# Epoch 00050: val_loss did not improve from 0.52555
# Epoch 51/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1288 - acc: 0.9953 - val_loss: 0.5239 - val_acc: 0.8332
#
# Epoch 00051: val_loss improved from 0.52555 to 0.52390, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1314 - acc: 0.9943 - val_loss: 0.5224 - val_acc: 0.8328
#
# Epoch 00052: val_loss improved from 0.52390 to 0.52239, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1279 - acc: 0.9944 - val_loss: 0.5277 - val_acc: 0.8286
#
# Epoch 00053: val_loss did not improve from 0.52239
# Epoch 54/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1289 - acc: 0.9942 - val_loss: 0.5284 - val_acc: 0.8325
#
# Epoch 00054: val_loss did not improve from 0.52239
# Epoch 55/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1296 - acc: 0.9944 - val_loss: 0.5296 - val_acc: 0.8264
#
# Epoch 00055: val_loss did not improve from 0.52239
# Epoch 56/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1269 - acc: 0.9952 - val_loss: 0.5245 - val_acc: 0.8348
#
# Epoch 00056: val_loss did not improve from 0.52239
# Epoch 57/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1294 - acc: 0.9938 - val_loss: 0.5247 - val_acc: 0.8308
#
# Epoch 00057: val_loss did not improve from 0.52239
# Epoch 58/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1279 - acc: 0.9938 - val_loss: 0.5277 - val_acc: 0.8294
#
# Epoch 00058: val_loss did not improve from 0.52239
# Epoch 59/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1279 - acc: 0.9947 - val_loss: 0.5271 - val_acc: 0.8334
#
# Epoch 00059: val_loss did not improve from 0.52239
# Epoch 60/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1273 - acc: 0.9952 - val_loss: 0.5264 - val_acc: 0.8377
#
# Epoch 00060: val_loss did not improve from 0.52239
# Epoch 61/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1294 - acc: 0.9939 - val_loss: 0.5239 - val_acc: 0.8349
#
# Epoch 00061: val_loss did not improve from 0.52239
# Epoch 62/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1283 - acc: 0.9936 - val_loss: 0.5272 - val_acc: 0.8345
#
# Epoch 00062: val_loss did not improve from 0.52239
# results per 0-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5272 - acc: 0.8345
# [[1601   40   69   39   55]
#  [  15 1236  152   36   50]
#  [  39   44 2005  208  182]
#  [  43  150  188 2373   67]
#  [  27   93  148  155 1863]]
#               precision    recall  f1-score   support
#
#           HC       0.93      0.89      0.91      1804
#          a_H       0.79      0.83      0.81      1489
#          a_K       0.78      0.81      0.80      2478
#          a_A       0.84      0.84      0.84      2821
#          a_C       0.84      0.81      0.83      2286
#
#     accuracy                           0.83     10878
#    macro avg       0.84      0.84      0.84     10878
# weighted avg       0.84      0.83      0.84     10878

# %%
for i in range(1, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11644,)
# H (9971,)
# K (15293,)
# A (16092,)
# C (12268,)
# Epoch 1/400
# 1036/1036 [==============================] - 69s 64ms/step - loss: 1.6336 - acc: 0.2946 - val_loss: 1.4719 - val_acc: 0.3548
#
# Epoch 00001: val_loss improved from inf to 1.47192, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 67s 64ms/step - loss: 1.3708 - acc: 0.4194 - val_loss: 1.3844 - val_acc: 0.4349
#
# Epoch 00002: val_loss improved from 1.47192 to 1.38443, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 67s 64ms/step - loss: 1.2558 - acc: 0.4917 - val_loss: 1.3302 - val_acc: 0.4580
#
# Epoch 00003: val_loss improved from 1.38443 to 1.33023, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 68s 65ms/step - loss: 1.1741 - acc: 0.5415 - val_loss: 1.2494 - val_acc: 0.4848
#
# Epoch 00004: val_loss improved from 1.33023 to 1.24940, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 68s 65ms/step - loss: 1.0967 - acc: 0.5848 - val_loss: 1.1839 - val_acc: 0.5365
#
# Epoch 00005: val_loss improved from 1.24940 to 1.18389, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 1.0412 - acc: 0.6181 - val_loss: 1.1466 - val_acc: 0.5584
#
# Epoch 00006: val_loss improved from 1.18389 to 1.14664, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.9866 - acc: 0.6459 - val_loss: 1.1077 - val_acc: 0.5878
#
# Epoch 00007: val_loss improved from 1.14664 to 1.10768, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.9370 - acc: 0.6780 - val_loss: 1.0700 - val_acc: 0.6182
#
# Epoch 00008: val_loss improved from 1.10768 to 1.07003, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.8996 - acc: 0.6998 - val_loss: 1.0334 - val_acc: 0.6241
#
# Epoch 00009: val_loss improved from 1.07003 to 1.03345, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.8560 - acc: 0.7235 - val_loss: 0.9951 - val_acc: 0.6545
#
# Epoch 00010: val_loss improved from 1.03345 to 0.99511, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.8311 - acc: 0.7382 - val_loss: 0.9805 - val_acc: 0.6545
#
# Epoch 00011: val_loss improved from 0.99511 to 0.98055, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7925 - acc: 0.7561 - val_loss: 0.9474 - val_acc: 0.6708
#
# Epoch 00012: val_loss improved from 0.98055 to 0.94741, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7667 - acc: 0.7729 - val_loss: 0.9232 - val_acc: 0.7026
#
# Epoch 00013: val_loss improved from 0.94741 to 0.92323, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7311 - acc: 0.7907 - val_loss: 0.9177 - val_acc: 0.6942
#
# Epoch 00014: val_loss improved from 0.92323 to 0.91771, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7093 - acc: 0.8039 - val_loss: 0.8898 - val_acc: 0.7090
#
# Epoch 00015: val_loss improved from 0.91771 to 0.88982, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6912 - acc: 0.8102 - val_loss: 0.8695 - val_acc: 0.7085
#
# Epoch 00016: val_loss improved from 0.88982 to 0.86946, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6639 - acc: 0.8264 - val_loss: 0.8428 - val_acc: 0.7189
#
# Epoch 00017: val_loss improved from 0.86946 to 0.84281, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6379 - acc: 0.8395 - val_loss: 0.8378 - val_acc: 0.7316
#
# Epoch 00018: val_loss improved from 0.84281 to 0.83783, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6215 - acc: 0.8488 - val_loss: 0.8132 - val_acc: 0.7364
#
# Epoch 00019: val_loss improved from 0.83783 to 0.81317, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6012 - acc: 0.8565 - val_loss: 0.8098 - val_acc: 0.7304
#
# Epoch 00020: val_loss improved from 0.81317 to 0.80984, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5823 - acc: 0.8659 - val_loss: 0.7847 - val_acc: 0.7513
#
# Epoch 00021: val_loss improved from 0.80984 to 0.78470, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5601 - acc: 0.8748 - val_loss: 0.7757 - val_acc: 0.7584
#
# Epoch 00022: val_loss improved from 0.78470 to 0.77567, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5461 - acc: 0.8834 - val_loss: 0.7714 - val_acc: 0.7581
#
# Epoch 00023: val_loss improved from 0.77567 to 0.77139, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5318 - acc: 0.8859 - val_loss: 0.7650 - val_acc: 0.7576
#
# Epoch 00024: val_loss improved from 0.77139 to 0.76501, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5180 - acc: 0.8913 - val_loss: 0.7506 - val_acc: 0.7619
#
# Epoch 00025: val_loss improved from 0.76501 to 0.75060, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.5028 - acc: 0.8988 - val_loss: 0.7455 - val_acc: 0.7568
#
# Epoch 00026: val_loss improved from 0.75060 to 0.74547, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4895 - acc: 0.9020 - val_loss: 0.7351 - val_acc: 0.7738
#
# Epoch 00027: val_loss improved from 0.74547 to 0.73513, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.4765 - acc: 0.9078 - val_loss: 0.7414 - val_acc: 0.7614
#
# Epoch 00028: val_loss did not improve from 0.73513
# Epoch 29/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.4647 - acc: 0.9127 - val_loss: 0.7400 - val_acc: 0.7632
#
# Epoch 00029: val_loss did not improve from 0.73513
# Epoch 30/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4509 - acc: 0.9170 - val_loss: 0.6973 - val_acc: 0.7849
#
# Epoch 00030: val_loss improved from 0.73513 to 0.69731, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.4338 - acc: 0.9260 - val_loss: 0.7082 - val_acc: 0.7813
#
# Epoch 00031: val_loss did not improve from 0.69731
# Epoch 32/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.4237 - acc: 0.9283 - val_loss: 0.6966 - val_acc: 0.7837
#
# Epoch 00032: val_loss improved from 0.69731 to 0.69656, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.4141 - acc: 0.9340 - val_loss: 0.6943 - val_acc: 0.7867
#
# Epoch 00033: val_loss improved from 0.69656 to 0.69434, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4047 - acc: 0.9401 - val_loss: 0.6900 - val_acc: 0.7933
#
# Epoch 00034: val_loss improved from 0.69434 to 0.68997, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4021 - acc: 0.9409 - val_loss: 0.6883 - val_acc: 0.7922
#
# Epoch 00035: val_loss improved from 0.68997 to 0.68834, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4031 - acc: 0.9400 - val_loss: 0.6864 - val_acc: 0.7973
#
# Epoch 00036: val_loss improved from 0.68834 to 0.68643, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4025 - acc: 0.9384 - val_loss: 0.6856 - val_acc: 0.7909
#
# Epoch 00037: val_loss improved from 0.68643 to 0.68561, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4005 - acc: 0.9402 - val_loss: 0.6813 - val_acc: 0.7928
#
# Epoch 00038: val_loss improved from 0.68561 to 0.68128, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3979 - acc: 0.9410 - val_loss: 0.6837 - val_acc: 0.7936
#
# Epoch 00039: val_loss did not improve from 0.68128
# Epoch 40/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3960 - acc: 0.9423 - val_loss: 0.6824 - val_acc: 0.7976
#
# Epoch 00040: val_loss did not improve from 0.68128
# Epoch 41/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3923 - acc: 0.9445 - val_loss: 0.6829 - val_acc: 0.7963
#
# Epoch 00041: val_loss did not improve from 0.68128
# Epoch 42/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3909 - acc: 0.9447 - val_loss: 0.6789 - val_acc: 0.7943
#
# Epoch 00042: val_loss improved from 0.68128 to 0.67892, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3920 - acc: 0.9443 - val_loss: 0.6797 - val_acc: 0.7943
#
# Epoch 00043: val_loss did not improve from 0.67892
# Epoch 44/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3890 - acc: 0.9443 - val_loss: 0.6792 - val_acc: 0.7933
#
# Epoch 00044: val_loss did not improve from 0.67892
# Epoch 45/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3867 - acc: 0.9462 - val_loss: 0.6769 - val_acc: 0.7983
#
# Epoch 00045: val_loss improved from 0.67892 to 0.67687, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3884 - acc: 0.9447 - val_loss: 0.6758 - val_acc: 0.7992
#
# Epoch 00046: val_loss improved from 0.67687 to 0.67580, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3860 - acc: 0.9466 - val_loss: 0.6765 - val_acc: 0.7906
#
# Epoch 00047: val_loss did not improve from 0.67580
# Epoch 48/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3835 - acc: 0.9467 - val_loss: 0.6758 - val_acc: 0.7944
#
# Epoch 00048: val_loss improved from 0.67580 to 0.67579, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3832 - acc: 0.9481 - val_loss: 0.6750 - val_acc: 0.7951
#
# Epoch 00049: val_loss improved from 0.67579 to 0.67504, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3817 - acc: 0.9454 - val_loss: 0.6718 - val_acc: 0.7997
#
# Epoch 00050: val_loss improved from 0.67504 to 0.67177, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 51/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3826 - acc: 0.9471 - val_loss: 0.6698 - val_acc: 0.8019
#
# Epoch 00051: val_loss improved from 0.67177 to 0.66978, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3798 - acc: 0.9474 - val_loss: 0.6701 - val_acc: 0.7989
#
# Epoch 00052: val_loss did not improve from 0.66978
# Epoch 53/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3797 - acc: 0.9493 - val_loss: 0.6692 - val_acc: 0.7978
#
# Epoch 00053: val_loss improved from 0.66978 to 0.66922, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 54/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3775 - acc: 0.9480 - val_loss: 0.6683 - val_acc: 0.7950
#
# Epoch 00054: val_loss improved from 0.66922 to 0.66827, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 55/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3738 - acc: 0.9504 - val_loss: 0.6681 - val_acc: 0.7978
#
# Epoch 00055: val_loss improved from 0.66827 to 0.66808, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3744 - acc: 0.9498 - val_loss: 0.6666 - val_acc: 0.7951
#
# Epoch 00056: val_loss improved from 0.66808 to 0.66656, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 57/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3727 - acc: 0.9497 - val_loss: 0.6660 - val_acc: 0.7999
#
# Epoch 00057: val_loss improved from 0.66656 to 0.66604, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3730 - acc: 0.9491 - val_loss: 0.6666 - val_acc: 0.7964
#
# Epoch 00058: val_loss did not improve from 0.66604
# Epoch 59/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3692 - acc: 0.9541 - val_loss: 0.6669 - val_acc: 0.7955
#
# Epoch 00059: val_loss did not improve from 0.66604
# Epoch 60/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3697 - acc: 0.9510 - val_loss: 0.6621 - val_acc: 0.7981
#
# Epoch 00060: val_loss improved from 0.66604 to 0.66212, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3717 - acc: 0.9490 - val_loss: 0.6664 - val_acc: 0.8003
#
# Epoch 00061: val_loss did not improve from 0.66212
# Epoch 62/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3666 - acc: 0.9512 - val_loss: 0.6651 - val_acc: 0.7982
#
# Epoch 00062: val_loss did not improve from 0.66212
# Epoch 63/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3681 - acc: 0.9508 - val_loss: 0.6682 - val_acc: 0.7970
#
# Epoch 00063: val_loss did not improve from 0.66212
# Epoch 64/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3648 - acc: 0.9528 - val_loss: 0.6648 - val_acc: 0.7992
#
# Epoch 00064: val_loss did not improve from 0.66212
# Epoch 65/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3648 - acc: 0.9540 - val_loss: 0.6659 - val_acc: 0.8017
#
# Epoch 00065: val_loss did not improve from 0.66212
# Epoch 66/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3677 - acc: 0.9517 - val_loss: 0.6643 - val_acc: 0.7985
#
# Epoch 00066: val_loss did not improve from 0.66212
# Epoch 67/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3650 - acc: 0.9529 - val_loss: 0.6640 - val_acc: 0.7993
#
# Epoch 00067: val_loss did not improve from 0.66212
# Epoch 68/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3637 - acc: 0.9532 - val_loss: 0.6645 - val_acc: 0.7975
#
# Epoch 00068: val_loss did not improve from 0.66212
# Epoch 69/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.3678 - acc: 0.9518 - val_loss: 0.6637 - val_acc: 0.7974
#
# Epoch 00069: val_loss did not improve from 0.66212
# Epoch 70/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3647 - acc: 0.9533 - val_loss: 0.6636 - val_acc: 0.8000
#
# Epoch 00070: val_loss did not improve from 0.66212
# results per 1-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.6636 - acc: 0.8000
# [[1777   25   49   60  201]
#  [  52 1571  124   60   84]
#  [  74  127 1914  143   79]
#  [  55  120  183 2023   84]
#  [ 318   24  137  177 1417]]
#               precision    recall  f1-score   support
#
#           HC       0.78      0.84      0.81      2112
#          a_H       0.84      0.83      0.84      1891
#          a_K       0.80      0.82      0.81      2337
#          a_A       0.82      0.82      0.82      2465
#          a_C       0.76      0.68      0.72      2073
#
#     accuracy                           0.80     10878
#    macro avg       0.80      0.80      0.80     10878
# weighted avg       0.80      0.80      0.80     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11736,)
# H (9990,)
# K (15491,)
# A (15652,)
# C (12399,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 67ms/step - loss: 1.6432 - acc: 0.3035 - val_loss: 1.4066 - val_acc: 0.4151
#
# Epoch 00001: val_loss improved from inf to 1.40655, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.3720 - acc: 0.4256 - val_loss: 1.2834 - val_acc: 0.4891
#
# Epoch 00002: val_loss improved from 1.40655 to 1.28343, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.2562 - acc: 0.4895 - val_loss: 1.2340 - val_acc: 0.5136
#
# Epoch 00003: val_loss improved from 1.28343 to 1.23398, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.1705 - acc: 0.5441 - val_loss: 1.1427 - val_acc: 0.5496
#
# Epoch 00004: val_loss improved from 1.23398 to 1.14267, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0937 - acc: 0.5863 - val_loss: 1.1035 - val_acc: 0.5972
#
# Epoch 00005: val_loss improved from 1.14267 to 1.10355, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0372 - acc: 0.6207 - val_loss: 1.0596 - val_acc: 0.6087
#
# Epoch 00006: val_loss improved from 1.10355 to 1.05960, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9828 - acc: 0.6532 - val_loss: 1.0108 - val_acc: 0.6450
#
# Epoch 00007: val_loss improved from 1.05960 to 1.01084, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9387 - acc: 0.6774 - val_loss: 0.9873 - val_acc: 0.6537
#
# Epoch 00008: val_loss improved from 1.01084 to 0.98733, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8948 - acc: 0.7012 - val_loss: 0.9441 - val_acc: 0.6681
#
# Epoch 00009: val_loss improved from 0.98733 to 0.94414, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8623 - acc: 0.7216 - val_loss: 0.9351 - val_acc: 0.6793
#
# Epoch 00010: val_loss improved from 0.94414 to 0.93513, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8245 - acc: 0.7411 - val_loss: 0.9104 - val_acc: 0.6877
#
# Epoch 00011: val_loss improved from 0.93513 to 0.91043, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7929 - acc: 0.7580 - val_loss: 0.8854 - val_acc: 0.6958
#
# Epoch 00012: val_loss improved from 0.91043 to 0.88537, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7630 - acc: 0.7768 - val_loss: 0.8468 - val_acc: 0.7166
#
# Epoch 00013: val_loss improved from 0.88537 to 0.84676, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7379 - acc: 0.7900 - val_loss: 0.8378 - val_acc: 0.7162
#
# Epoch 00014: val_loss improved from 0.84676 to 0.83777, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7090 - acc: 0.8038 - val_loss: 0.8206 - val_acc: 0.7265
#
# Epoch 00015: val_loss improved from 0.83777 to 0.82064, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6896 - acc: 0.8117 - val_loss: 0.8068 - val_acc: 0.7215
#
# Epoch 00016: val_loss improved from 0.82064 to 0.80680, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6596 - acc: 0.8297 - val_loss: 0.7890 - val_acc: 0.7375
#
# Epoch 00017: val_loss improved from 0.80680 to 0.78900, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6432 - acc: 0.8363 - val_loss: 0.7850 - val_acc: 0.7330
#
# Epoch 00018: val_loss improved from 0.78900 to 0.78495, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6194 - acc: 0.8501 - val_loss: 0.7730 - val_acc: 0.7382
#
# Epoch 00019: val_loss improved from 0.78495 to 0.77300, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5999 - acc: 0.8575 - val_loss: 0.7609 - val_acc: 0.7403
#
# Epoch 00020: val_loss improved from 0.77300 to 0.76094, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5808 - acc: 0.8662 - val_loss: 0.7422 - val_acc: 0.7510
#
# Epoch 00021: val_loss improved from 0.76094 to 0.74217, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5659 - acc: 0.8742 - val_loss: 0.7286 - val_acc: 0.7708
#
# Epoch 00022: val_loss improved from 0.74217 to 0.72862, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5502 - acc: 0.8787 - val_loss: 0.7173 - val_acc: 0.7625
#
# Epoch 00023: val_loss improved from 0.72862 to 0.71730, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5317 - acc: 0.8883 - val_loss: 0.7095 - val_acc: 0.7651
#
# Epoch 00024: val_loss improved from 0.71730 to 0.70946, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5166 - acc: 0.8942 - val_loss: 0.7142 - val_acc: 0.7636
#
# Epoch 00025: val_loss did not improve from 0.70946
# Epoch 26/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5032 - acc: 0.8978 - val_loss: 0.7003 - val_acc: 0.7666
#
# Epoch 00026: val_loss improved from 0.70946 to 0.70027, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4901 - acc: 0.9046 - val_loss: 0.6890 - val_acc: 0.7728
#
# Epoch 00027: val_loss improved from 0.70027 to 0.68896, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4790 - acc: 0.9084 - val_loss: 0.6762 - val_acc: 0.7709
#
# Epoch 00028: val_loss improved from 0.68896 to 0.67623, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4633 - acc: 0.9150 - val_loss: 0.6625 - val_acc: 0.7762
#
# Epoch 00029: val_loss improved from 0.67623 to 0.66254, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4516 - acc: 0.9170 - val_loss: 0.6644 - val_acc: 0.7773
#
# Epoch 00030: val_loss did not improve from 0.66254
# Epoch 31/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4385 - acc: 0.9232 - val_loss: 0.6634 - val_acc: 0.7835
#
# Epoch 00031: val_loss did not improve from 0.66254
# Epoch 32/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4229 - acc: 0.9307 - val_loss: 0.6408 - val_acc: 0.7865
#
# Epoch 00032: val_loss improved from 0.66254 to 0.64077, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4113 - acc: 0.9374 - val_loss: 0.6387 - val_acc: 0.7934
#
# Epoch 00033: val_loss improved from 0.64077 to 0.63865, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4088 - acc: 0.9375 - val_loss: 0.6325 - val_acc: 0.7935
#
# Epoch 00034: val_loss improved from 0.63865 to 0.63248, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4079 - acc: 0.9388 - val_loss: 0.6362 - val_acc: 0.7933
#
# Epoch 00035: val_loss did not improve from 0.63248
# Epoch 36/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4032 - acc: 0.9401 - val_loss: 0.6344 - val_acc: 0.7957
#
# Epoch 00036: val_loss did not improve from 0.63248
# Epoch 37/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4002 - acc: 0.9426 - val_loss: 0.6376 - val_acc: 0.7937
#
# Epoch 00037: val_loss did not improve from 0.63248
# Epoch 38/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4016 - acc: 0.9406 - val_loss: 0.6294 - val_acc: 0.7940
#
# Epoch 00038: val_loss improved from 0.63248 to 0.62937, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3978 - acc: 0.9430 - val_loss: 0.6292 - val_acc: 0.7936
#
# Epoch 00039: val_loss improved from 0.62937 to 0.62920, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3943 - acc: 0.9439 - val_loss: 0.6313 - val_acc: 0.7971
#
# Epoch 00040: val_loss did not improve from 0.62920
# Epoch 41/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3949 - acc: 0.9431 - val_loss: 0.6269 - val_acc: 0.7972
#
# Epoch 00041: val_loss improved from 0.62920 to 0.62689, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3940 - acc: 0.9442 - val_loss: 0.6266 - val_acc: 0.7972
#
# Epoch 00042: val_loss improved from 0.62689 to 0.62658, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3905 - acc: 0.9454 - val_loss: 0.6290 - val_acc: 0.7966
#
# Epoch 00043: val_loss did not improve from 0.62658
# Epoch 44/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3907 - acc: 0.9445 - val_loss: 0.6260 - val_acc: 0.7983
#
# Epoch 00044: val_loss improved from 0.62658 to 0.62605, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3852 - acc: 0.9478 - val_loss: 0.6264 - val_acc: 0.7970
#
# Epoch 00045: val_loss did not improve from 0.62605
# Epoch 46/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3872 - acc: 0.9466 - val_loss: 0.6253 - val_acc: 0.8000
#
# Epoch 00046: val_loss improved from 0.62605 to 0.62531, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3907 - acc: 0.9447 - val_loss: 0.6209 - val_acc: 0.8009
#
# Epoch 00047: val_loss improved from 0.62531 to 0.62089, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3856 - acc: 0.9468 - val_loss: 0.6254 - val_acc: 0.7969
#
# Epoch 00048: val_loss did not improve from 0.62089
# Epoch 49/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3846 - acc: 0.9478 - val_loss: 0.6248 - val_acc: 0.7955
#
# Epoch 00049: val_loss did not improve from 0.62089
# Epoch 50/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3857 - acc: 0.9455 - val_loss: 0.6285 - val_acc: 0.7877
#
# Epoch 00050: val_loss did not improve from 0.62089
# Epoch 51/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3831 - acc: 0.9470 - val_loss: 0.6203 - val_acc: 0.7989
#
# Epoch 00051: val_loss improved from 0.62089 to 0.62025, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3800 - acc: 0.9493 - val_loss: 0.6209 - val_acc: 0.7944
#
# Epoch 00052: val_loss did not improve from 0.62025
# Epoch 53/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3802 - acc: 0.9479 - val_loss: 0.6202 - val_acc: 0.7947
#
# Epoch 00053: val_loss improved from 0.62025 to 0.62022, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 54/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3773 - acc: 0.9508 - val_loss: 0.6178 - val_acc: 0.7987
#
# Epoch 00054: val_loss improved from 0.62022 to 0.61779, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 55/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3780 - acc: 0.9481 - val_loss: 0.6194 - val_acc: 0.8031
#
# Epoch 00055: val_loss did not improve from 0.61779
# Epoch 56/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3767 - acc: 0.9490 - val_loss: 0.6164 - val_acc: 0.8023
#
# Epoch 00056: val_loss improved from 0.61779 to 0.61643, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 57/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3750 - acc: 0.9501 - val_loss: 0.6168 - val_acc: 0.8008
#
# Epoch 00057: val_loss did not improve from 0.61643
# Epoch 58/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3739 - acc: 0.9502 - val_loss: 0.6152 - val_acc: 0.8035
#
# Epoch 00058: val_loss improved from 0.61643 to 0.61524, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 59/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3702 - acc: 0.9516 - val_loss: 0.6176 - val_acc: 0.7992
#
# Epoch 00059: val_loss did not improve from 0.61524
# Epoch 60/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3708 - acc: 0.9528 - val_loss: 0.6176 - val_acc: 0.7998
#
# Epoch 00060: val_loss did not improve from 0.61524
# Epoch 61/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3737 - acc: 0.9483 - val_loss: 0.6166 - val_acc: 0.7982
#
# Epoch 00061: val_loss did not improve from 0.61524
# Epoch 62/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3716 - acc: 0.9502 - val_loss: 0.6114 - val_acc: 0.8036
#
# Epoch 00062: val_loss improved from 0.61524 to 0.61136, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 63/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3673 - acc: 0.9530 - val_loss: 0.6133 - val_acc: 0.7987
#
# Epoch 00063: val_loss did not improve from 0.61136
# Epoch 64/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3657 - acc: 0.9541 - val_loss: 0.6138 - val_acc: 0.8015
#
# Epoch 00064: val_loss did not improve from 0.61136
# Epoch 65/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3653 - acc: 0.9535 - val_loss: 0.6122 - val_acc: 0.7989
#
# Epoch 00065: val_loss did not improve from 0.61136
# Epoch 66/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3678 - acc: 0.9513 - val_loss: 0.6110 - val_acc: 0.7986
#
# Epoch 00066: val_loss improved from 0.61136 to 0.61101, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 67/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3648 - acc: 0.9531 - val_loss: 0.6127 - val_acc: 0.7994
#
# Epoch 00067: val_loss did not improve from 0.61101
# Epoch 68/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3672 - acc: 0.9534 - val_loss: 0.6116 - val_acc: 0.8000
#
# Epoch 00068: val_loss did not improve from 0.61101
# Epoch 69/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3663 - acc: 0.9546 - val_loss: 0.6111 - val_acc: 0.8024
#
# Epoch 00069: val_loss did not improve from 0.61101
# Epoch 70/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3658 - acc: 0.9544 - val_loss: 0.6117 - val_acc: 0.8011
#
# Epoch 00070: val_loss did not improve from 0.61101
# Epoch 71/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3678 - acc: 0.9521 - val_loss: 0.6110 - val_acc: 0.8001
#
# Epoch 00071: val_loss did not improve from 0.61101
# Epoch 72/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3660 - acc: 0.9525 - val_loss: 0.6140 - val_acc: 0.7981
#
# Epoch 00072: val_loss did not improve from 0.61101
# Epoch 73/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3646 - acc: 0.9529 - val_loss: 0.6106 - val_acc: 0.8023
#
# Epoch 00073: val_loss improved from 0.61101 to 0.61055, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 74/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3639 - acc: 0.9544 - val_loss: 0.6103 - val_acc: 0.8043
#
# Epoch 00074: val_loss improved from 0.61055 to 0.61032, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 75/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3672 - acc: 0.9516 - val_loss: 0.6117 - val_acc: 0.7998
#
# Epoch 00075: val_loss did not improve from 0.61032
# Epoch 76/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3642 - acc: 0.9534 - val_loss: 0.6117 - val_acc: 0.8035
#
# Epoch 00076: val_loss did not improve from 0.61032
# Epoch 77/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3634 - acc: 0.9549 - val_loss: 0.6143 - val_acc: 0.7977
#
# Epoch 00077: val_loss did not improve from 0.61032
# Epoch 78/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3627 - acc: 0.9539 - val_loss: 0.6150 - val_acc: 0.8004
#
# Epoch 00078: val_loss did not improve from 0.61032
# Epoch 79/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3668 - acc: 0.9517 - val_loss: 0.6117 - val_acc: 0.8026
#
# Epoch 00079: val_loss did not improve from 0.61032
# Epoch 80/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3610 - acc: 0.9569 - val_loss: 0.6120 - val_acc: 0.8032
#
# Epoch 00080: val_loss did not improve from 0.61032
# Epoch 81/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3668 - acc: 0.9521 - val_loss: 0.6097 - val_acc: 0.8009
#
# Epoch 00081: val_loss improved from 0.61032 to 0.60972, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 82/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3648 - acc: 0.9527 - val_loss: 0.6109 - val_acc: 0.8043
#
# Epoch 00082: val_loss did not improve from 0.60972
# Epoch 83/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3642 - acc: 0.9545 - val_loss: 0.6130 - val_acc: 0.8013
#
# Epoch 00083: val_loss did not improve from 0.60972
# Epoch 84/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3632 - acc: 0.9532 - val_loss: 0.6083 - val_acc: 0.8035
#
# Epoch 00084: val_loss improved from 0.60972 to 0.60826, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 85/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3638 - acc: 0.9550 - val_loss: 0.6111 - val_acc: 0.8028
#
# Epoch 00085: val_loss did not improve from 0.60826
# Epoch 86/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3635 - acc: 0.9540 - val_loss: 0.6098 - val_acc: 0.8020
#
# Epoch 00086: val_loss did not improve from 0.60826
# Epoch 87/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3615 - acc: 0.9550 - val_loss: 0.6100 - val_acc: 0.8024
#
# Epoch 00087: val_loss did not improve from 0.60826
# Epoch 88/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3600 - acc: 0.9554 - val_loss: 0.6121 - val_acc: 0.8034
#
# Epoch 00088: val_loss did not improve from 0.60826
# Epoch 89/400
# ...
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (12396,)
# H (10200,)
# K (14405,)
# A (16112,)
# C (12155,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 67ms/step - loss: 1.6562 - acc: 0.3020 - val_loss: 1.3987 - val_acc: 0.4239
#
# Epoch 00001: val_loss improved from inf to 1.39871, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.3579 - acc: 0.4366 - val_loss: 1.3280 - val_acc: 0.4759
#
# Epoch 00002: val_loss improved from 1.39871 to 1.32801, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.2400 - acc: 0.5026 - val_loss: 1.2779 - val_acc: 0.5001
#
# Epoch 00003: val_loss improved from 1.32801 to 1.27793, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.1451 - acc: 0.5567 - val_loss: 1.2252 - val_acc: 0.5465
#
# Epoch 00004: val_loss improved from 1.27793 to 1.22517, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0743 - acc: 0.5953 - val_loss: 1.1631 - val_acc: 0.5713
#
# Epoch 00005: val_loss improved from 1.22517 to 1.16312, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0101 - acc: 0.6386 - val_loss: 1.1180 - val_acc: 0.5961
#
# Epoch 00006: val_loss improved from 1.16312 to 1.11805, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9621 - acc: 0.6624 - val_loss: 1.0762 - val_acc: 0.6021
#
# Epoch 00007: val_loss improved from 1.11805 to 1.07617, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9209 - acc: 0.6877 - val_loss: 1.0410 - val_acc: 0.6242
#
# Epoch 00008: val_loss improved from 1.07617 to 1.04097, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.8761 - acc: 0.7130 - val_loss: 1.0110 - val_acc: 0.6385
#
# Epoch 00009: val_loss improved from 1.04097 to 1.01096, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.8362 - acc: 0.7353 - val_loss: 0.9953 - val_acc: 0.6458
#
# Epoch 00010: val_loss improved from 1.01096 to 0.99526, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.8071 - acc: 0.7518 - val_loss: 0.9624 - val_acc: 0.6637
#
# Epoch 00011: val_loss improved from 0.99526 to 0.96244, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7715 - acc: 0.7700 - val_loss: 0.9524 - val_acc: 0.6547
#
# Epoch 00012: val_loss improved from 0.96244 to 0.95237, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7477 - acc: 0.7847 - val_loss: 0.9405 - val_acc: 0.6581
#
# Epoch 00013: val_loss improved from 0.95237 to 0.94055, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7171 - acc: 0.7993 - val_loss: 0.9049 - val_acc: 0.6817
#
# Epoch 00014: val_loss improved from 0.94055 to 0.90492, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6970 - acc: 0.8115 - val_loss: 0.8980 - val_acc: 0.6881
#
# Epoch 00015: val_loss improved from 0.90492 to 0.89798, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6772 - acc: 0.8181 - val_loss: 0.8742 - val_acc: 0.6919
#
# Epoch 00016: val_loss improved from 0.89798 to 0.87422, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6513 - acc: 0.8328 - val_loss: 0.8446 - val_acc: 0.7083
#
# Epoch 00017: val_loss improved from 0.87422 to 0.84460, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6271 - acc: 0.8453 - val_loss: 0.8468 - val_acc: 0.7134
#
# Epoch 00018: val_loss did not improve from 0.84460
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6053 - acc: 0.8592 - val_loss: 0.8438 - val_acc: 0.7144
#
# Epoch 00019: val_loss improved from 0.84460 to 0.84376, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5912 - acc: 0.8601 - val_loss: 0.8269 - val_acc: 0.7151
#
# Epoch 00020: val_loss improved from 0.84376 to 0.82691, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5701 - acc: 0.8738 - val_loss: 0.8125 - val_acc: 0.7251
#
# Epoch 00021: val_loss improved from 0.82691 to 0.81248, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5534 - acc: 0.8784 - val_loss: 0.7990 - val_acc: 0.7354
#
# Epoch 00022: val_loss improved from 0.81248 to 0.79897, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5371 - acc: 0.8860 - val_loss: 0.8019 - val_acc: 0.7250
#
# Epoch 00023: val_loss did not improve from 0.79897
# Epoch 24/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5212 - acc: 0.8906 - val_loss: 0.7877 - val_acc: 0.7386
#
# Epoch 00024: val_loss improved from 0.79897 to 0.78769, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5058 - acc: 0.8981 - val_loss: 0.7703 - val_acc: 0.7435
#
# Epoch 00025: val_loss improved from 0.78769 to 0.77031, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4917 - acc: 0.9050 - val_loss: 0.7701 - val_acc: 0.7377
#
# Epoch 00026: val_loss improved from 0.77031 to 0.77015, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4794 - acc: 0.9083 - val_loss: 0.7600 - val_acc: 0.7407
#
# Epoch 00027: val_loss improved from 0.77015 to 0.76004, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.4662 - acc: 0.9127 - val_loss: 0.7441 - val_acc: 0.7473
#
# Epoch 00028: val_loss improved from 0.76004 to 0.74410, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4512 - acc: 0.9198 - val_loss: 0.7432 - val_acc: 0.7614
#
# Epoch 00029: val_loss improved from 0.74410 to 0.74317, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4375 - acc: 0.9249 - val_loss: 0.7290 - val_acc: 0.7611
#
# Epoch 00030: val_loss improved from 0.74317 to 0.72897, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4296 - acc: 0.9269 - val_loss: 0.7216 - val_acc: 0.7610
#
# Epoch 00031: val_loss improved from 0.72897 to 0.72156, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4146 - acc: 0.9335 - val_loss: 0.7064 - val_acc: 0.7722
#
# Epoch 00032: val_loss improved from 0.72156 to 0.70639, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4048 - acc: 0.9380 - val_loss: 0.7070 - val_acc: 0.7733
#
# Epoch 00033: val_loss did not improve from 0.70639
# Epoch 34/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3992 - acc: 0.9420 - val_loss: 0.7049 - val_acc: 0.7707
#
# Epoch 00034: val_loss improved from 0.70639 to 0.70491, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3980 - acc: 0.9418 - val_loss: 0.7044 - val_acc: 0.7810
#
# Epoch 00035: val_loss improved from 0.70491 to 0.70442, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3970 - acc: 0.9423 - val_loss: 0.7019 - val_acc: 0.7808
#
# Epoch 00036: val_loss improved from 0.70442 to 0.70186, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3929 - acc: 0.9437 - val_loss: 0.7005 - val_acc: 0.7817
#
# Epoch 00037: val_loss improved from 0.70186 to 0.70046, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3896 - acc: 0.9460 - val_loss: 0.6988 - val_acc: 0.7838
#
# Epoch 00038: val_loss improved from 0.70046 to 0.69884, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3878 - acc: 0.9471 - val_loss: 0.6979 - val_acc: 0.7808
#
# Epoch 00039: val_loss improved from 0.69884 to 0.69789, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3872 - acc: 0.9457 - val_loss: 0.7009 - val_acc: 0.7785
#
# Epoch 00040: val_loss did not improve from 0.69789
# Epoch 41/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3865 - acc: 0.9470 - val_loss: 0.7004 - val_acc: 0.7841
#
# Epoch 00041: val_loss did not improve from 0.69789
# Epoch 42/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3884 - acc: 0.9444 - val_loss: 0.7016 - val_acc: 0.7848
#
# Epoch 00042: val_loss did not improve from 0.69789
# Epoch 43/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3811 - acc: 0.9481 - val_loss: 0.6957 - val_acc: 0.7821
#
# Epoch 00043: val_loss improved from 0.69789 to 0.69567, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3810 - acc: 0.9493 - val_loss: 0.6997 - val_acc: 0.7800
#
# Epoch 00044: val_loss did not improve from 0.69567
# Epoch 45/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3792 - acc: 0.9490 - val_loss: 0.6978 - val_acc: 0.7813
#
# Epoch 00045: val_loss did not improve from 0.69567
# Epoch 46/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3800 - acc: 0.9484 - val_loss: 0.6974 - val_acc: 0.7742
#
# Epoch 00046: val_loss did not improve from 0.69567
# Epoch 47/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3772 - acc: 0.9501 - val_loss: 0.6983 - val_acc: 0.7821
#
# Epoch 00047: val_loss did not improve from 0.69567
# Epoch 48/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3751 - acc: 0.9507 - val_loss: 0.6973 - val_acc: 0.7799
#
# Epoch 00048: val_loss did not improve from 0.69567
# Epoch 49/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3774 - acc: 0.9473 - val_loss: 0.6938 - val_acc: 0.7830
#
# Epoch 00049: val_loss improved from 0.69567 to 0.69377, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3731 - acc: 0.9499 - val_loss: 0.6940 - val_acc: 0.7816
#
# Epoch 00050: val_loss did not improve from 0.69377
# Epoch 51/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3745 - acc: 0.9512 - val_loss: 0.6906 - val_acc: 0.7841
#
# Epoch 00051: val_loss improved from 0.69377 to 0.69065, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3709 - acc: 0.9525 - val_loss: 0.6955 - val_acc: 0.7835
#
# Epoch 00052: val_loss did not improve from 0.69065
# Epoch 53/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3715 - acc: 0.9504 - val_loss: 0.6920 - val_acc: 0.7896
#
# Epoch 00053: val_loss did not improve from 0.69065
# Epoch 54/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3708 - acc: 0.9519 - val_loss: 0.6932 - val_acc: 0.7870
#
# Epoch 00054: val_loss did not improve from 0.69065
# Epoch 55/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3695 - acc: 0.9506 - val_loss: 0.6863 - val_acc: 0.7855
#
# Epoch 00055: val_loss improved from 0.69065 to 0.68630, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 56/400
#  876/1036 [========================>.....] - ETA: 10s - loss: 0.3677 - acc: 0.9513

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 25 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

i=3
# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5')

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# # save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (12396,)
# H (10200,)
# K (14405,)
# A (16112,)
# C (12155,)
# Epoch 1/400
# 1036/1036 [==============================] - 134s 98ms/step - loss: 0.3779 - acc: 0.9459 - val_loss: 0.6976 - val_acc: 0.7734
#
# Epoch 00001: val_loss improved from inf to 0.69756, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.3812 - acc: 0.9422 - val_loss: 0.7032 - val_acc: 0.7764
#
# Epoch 00002: val_loss did not improve from 0.69756
# Epoch 3/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.3719 - acc: 0.9465 - val_loss: 0.7064 - val_acc: 0.7662
#
# Epoch 00003: val_loss did not improve from 0.69756
# Epoch 4/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.3646 - acc: 0.9483 - val_loss: 0.6896 - val_acc: 0.7804
#
# Epoch 00004: val_loss improved from 0.69756 to 0.68957, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3526 - acc: 0.9528 - val_loss: 0.6901 - val_acc: 0.7655
#
# Epoch 00005: val_loss did not improve from 0.68957
# Epoch 6/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3458 - acc: 0.9525 - val_loss: 0.6796 - val_acc: 0.7790
#
# Epoch 00006: val_loss improved from 0.68957 to 0.67964, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.3345 - acc: 0.9564 - val_loss: 0.6674 - val_acc: 0.7811
#
# Epoch 00007: val_loss improved from 0.67964 to 0.66740, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3290 - acc: 0.9577 - val_loss: 0.6652 - val_acc: 0.7841
#
# Epoch 00008: val_loss improved from 0.66740 to 0.66517, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3215 - acc: 0.9586 - val_loss: 0.6738 - val_acc: 0.7735
#
# Epoch 00009: val_loss did not improve from 0.66517
# Epoch 10/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3084 - acc: 0.9638 - val_loss: 0.6619 - val_acc: 0.7811
#
# Epoch 00010: val_loss improved from 0.66517 to 0.66195, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.3044 - acc: 0.9639 - val_loss: 0.6581 - val_acc: 0.7885
#
# Epoch 00011: val_loss improved from 0.66195 to 0.65809, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2939 - acc: 0.9672 - val_loss: 0.6603 - val_acc: 0.7773
#
# Epoch 00012: val_loss did not improve from 0.65809
# Epoch 13/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.2915 - acc: 0.9667 - val_loss: 0.6537 - val_acc: 0.7812
#
# Epoch 00013: val_loss improved from 0.65809 to 0.65367, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.2826 - acc: 0.9687 - val_loss: 0.6506 - val_acc: 0.7892
#
# Epoch 00014: val_loss improved from 0.65367 to 0.65062, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.2754 - acc: 0.9709 - val_loss: 0.6477 - val_acc: 0.7949
#
# Epoch 00015: val_loss improved from 0.65062 to 0.64775, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2714 - acc: 0.9697 - val_loss: 0.6536 - val_acc: 0.7906
#
# Epoch 00016: val_loss did not improve from 0.64775
# Epoch 17/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.2646 - acc: 0.9721 - val_loss: 0.6333 - val_acc: 0.7945
#
# Epoch 00017: val_loss improved from 0.64775 to 0.63332, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2575 - acc: 0.9745 - val_loss: 0.6430 - val_acc: 0.7870
#
# Epoch 00018: val_loss did not improve from 0.63332
# Epoch 19/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2518 - acc: 0.9754 - val_loss: 0.6431 - val_acc: 0.7801
#
# Epoch 00019: val_loss did not improve from 0.63332
# Epoch 20/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2486 - acc: 0.9760 - val_loss: 0.6347 - val_acc: 0.7853
#
# Epoch 00020: val_loss did not improve from 0.63332
# Epoch 21/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2395 - acc: 0.9793 - val_loss: 0.6406 - val_acc: 0.7840
#
# Epoch 00021: val_loss did not improve from 0.63332
# Epoch 22/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2380 - acc: 0.9768 - val_loss: 0.6364 - val_acc: 0.7977
#
# Epoch 00022: val_loss did not improve from 0.63332
# Epoch 23/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2303 - acc: 0.9805 - val_loss: 0.6272 - val_acc: 0.7936
#
# Epoch 00023: val_loss improved from 0.63332 to 0.62718, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2261 - acc: 0.9803 - val_loss: 0.6246 - val_acc: 0.7954
#
# Epoch 00024: val_loss improved from 0.62718 to 0.62464, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2204 - acc: 0.9818 - val_loss: 0.6222 - val_acc: 0.7980
#
# Epoch 00025: val_loss improved from 0.62464 to 0.62219, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2146 - acc: 0.9837 - val_loss: 0.6178 - val_acc: 0.7992
#
# Epoch 00026: val_loss improved from 0.62219 to 0.61781, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2081 - acc: 0.9843 - val_loss: 0.6123 - val_acc: 0.7979
#
# Epoch 00027: val_loss improved from 0.61781 to 0.61232, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2033 - acc: 0.9855 - val_loss: 0.6117 - val_acc: 0.8020
#
# Epoch 00028: val_loss improved from 0.61232 to 0.61174, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1989 - acc: 0.9875 - val_loss: 0.6146 - val_acc: 0.8001
#
# Epoch 00029: val_loss did not improve from 0.61174
# Epoch 30/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2018 - acc: 0.9861 - val_loss: 0.6141 - val_acc: 0.7961
#
# Epoch 00030: val_loss did not improve from 0.61174
# Epoch 31/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2018 - acc: 0.9867 - val_loss: 0.6172 - val_acc: 0.7995
#
# Epoch 00031: val_loss did not improve from 0.61174
# Epoch 32/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.1993 - acc: 0.9876 - val_loss: 0.6115 - val_acc: 0.7940
#
# Epoch 00032: val_loss improved from 0.61174 to 0.61153, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1976 - acc: 0.9874 - val_loss: 0.6103 - val_acc: 0.7996
#
# Epoch 00033: val_loss improved from 0.61153 to 0.61033, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.2000 - acc: 0.9878 - val_loss: 0.6112 - val_acc: 0.7990
#
# Epoch 00034: val_loss did not improve from 0.61033
# Epoch 35/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1977 - acc: 0.9869 - val_loss: 0.6102 - val_acc: 0.8018
#
# Epoch 00035: val_loss improved from 0.61033 to 0.61023, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1973 - acc: 0.9868 - val_loss: 0.6103 - val_acc: 0.7956
#
# Epoch 00036: val_loss did not improve from 0.61023
# Epoch 37/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1943 - acc: 0.9879 - val_loss: 0.6114 - val_acc: 0.8027
#
# Epoch 00037: val_loss did not improve from 0.61023
# Epoch 38/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1945 - acc: 0.9884 - val_loss: 0.6089 - val_acc: 0.8001
#
# Epoch 00038: val_loss improved from 0.61023 to 0.60892, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1960 - acc: 0.9874 - val_loss: 0.6111 - val_acc: 0.7983
#
# Epoch 00039: val_loss did not improve from 0.60892
# Epoch 40/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.1930 - acc: 0.9882 - val_loss: 0.6131 - val_acc: 0.7980
#
# Epoch 00040: val_loss did not improve from 0.60892
# Epoch 41/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1960 - acc: 0.9868 - val_loss: 0.6137 - val_acc: 0.7980
#
# Epoch 00041: val_loss did not improve from 0.60892
# Epoch 42/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1935 - acc: 0.9882 - val_loss: 0.6102 - val_acc: 0.7964
#
# Epoch 00042: val_loss did not improve from 0.60892
# Epoch 43/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1962 - acc: 0.9868 - val_loss: 0.6078 - val_acc: 0.7999
#
# Epoch 00043: val_loss improved from 0.60892 to 0.60777, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1922 - acc: 0.9881 - val_loss: 0.6108 - val_acc: 0.7994
#
# Epoch 00044: val_loss did not improve from 0.60777
# Epoch 45/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.1919 - acc: 0.9885 - val_loss: 0.6060 - val_acc: 0.7999
#
# Epoch 00045: val_loss improved from 0.60777 to 0.60598, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1916 - acc: 0.9883 - val_loss: 0.6083 - val_acc: 0.7978
#
# Epoch 00046: val_loss did not improve from 0.60598
# Epoch 47/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.1909 - acc: 0.9883 - val_loss: 0.6085 - val_acc: 0.8053
#
# Epoch 00047: val_loss did not improve from 0.60598
# Epoch 48/400
# 1036/1036 [==============================] - 100s 96ms/step - loss: 0.1900 - acc: 0.9887 - val_loss: 0.6083 - val_acc: 0.8046
#
# Epoch 00048: val_loss did not improve from 0.60598
# Epoch 49/400
# 1036/1036 [==============================] - 100s 97ms/step - loss: 0.1882 - acc: 0.9895 - val_loss: 0.6117 - val_acc: 0.7984
#
# Epoch 00049: val_loss did not improve from 0.60598
# Epoch 50/400
#  645/1036 [=================>............] - ETA: 36s - loss: 0.1901 - acc: 0.9872

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 56 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

i=3
# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5')

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# # save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (12396,)
# H (10200,)
# K (14405,)
# A (16112,)
# C (12155,)
# Epoch 1/400
# 1036/1036 [==============================] - 101s 65ms/step - loss: 0.1933 - acc: 0.9872 - val_loss: 0.6105 - val_acc: 0.8031
#
# Epoch 00001: val_loss improved from inf to 0.61045, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 68s 65ms/step - loss: 0.1919 - acc: 0.9875 - val_loss: 0.6075 - val_acc: 0.8010
#
# Epoch 00002: val_loss improved from 0.61045 to 0.60745, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1901 - acc: 0.9887 - val_loss: 0.6089 - val_acc: 0.7989
#
# Epoch 00003: val_loss did not improve from 0.60745
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1903 - acc: 0.9890 - val_loss: 0.6086 - val_acc: 0.8000
#
# Epoch 00004: val_loss did not improve from 0.60745
# Epoch 5/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1902 - acc: 0.9883 - val_loss: 0.6057 - val_acc: 0.8053
#
# Epoch 00005: val_loss improved from 0.60745 to 0.60569, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1885 - acc: 0.9878 - val_loss: 0.6057 - val_acc: 0.8013
#
# Epoch 00006: val_loss improved from 0.60569 to 0.60568, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1884 - acc: 0.9887 - val_loss: 0.6063 - val_acc: 0.7998
#
# Epoch 00007: val_loss did not improve from 0.60568
# Epoch 8/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1857 - acc: 0.9898 - val_loss: 0.6113 - val_acc: 0.7978
#
# Epoch 00008: val_loss did not improve from 0.60568
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1878 - acc: 0.9881 - val_loss: 0.6098 - val_acc: 0.7971
#
# Epoch 00009: val_loss did not improve from 0.60568
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1858 - acc: 0.9894 - val_loss: 0.6042 - val_acc: 0.8049
#
# Epoch 00010: val_loss improved from 0.60568 to 0.60423, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1856 - acc: 0.9893 - val_loss: 0.6038 - val_acc: 0.8006
#
# Epoch 00011: val_loss improved from 0.60423 to 0.60380, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1851 - acc: 0.9889 - val_loss: 0.6063 - val_acc: 0.8009
#
# Epoch 00012: val_loss did not improve from 0.60380
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1866 - acc: 0.9896 - val_loss: 0.6064 - val_acc: 0.8012
#
# Epoch 00013: val_loss did not improve from 0.60380
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1847 - acc: 0.9898 - val_loss: 0.6075 - val_acc: 0.7990
#
# Epoch 00014: val_loss did not improve from 0.60380
# Epoch 15/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1844 - acc: 0.9888 - val_loss: 0.6030 - val_acc: 0.8028
#
# Epoch 00015: val_loss improved from 0.60380 to 0.60295, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1848 - acc: 0.9892 - val_loss: 0.6067 - val_acc: 0.8011
#
# Epoch 00016: val_loss did not improve from 0.60295
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1845 - acc: 0.9889 - val_loss: 0.6022 - val_acc: 0.7996
#
# Epoch 00017: val_loss improved from 0.60295 to 0.60223, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1841 - acc: 0.9901 - val_loss: 0.6055 - val_acc: 0.8045
#
# Epoch 00018: val_loss did not improve from 0.60223
# Epoch 19/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1826 - acc: 0.9891 - val_loss: 0.6043 - val_acc: 0.8025
#
# Epoch 00019: val_loss did not improve from 0.60223
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1843 - acc: 0.9886 - val_loss: 0.6025 - val_acc: 0.8041
#
# Epoch 00020: val_loss did not improve from 0.60223
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1834 - acc: 0.9882 - val_loss: 0.6010 - val_acc: 0.8046
#
# Epoch 00021: val_loss improved from 0.60223 to 0.60103, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1806 - acc: 0.9894 - val_loss: 0.5966 - val_acc: 0.8042
#
# Epoch 00022: val_loss improved from 0.60103 to 0.59663, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1790 - acc: 0.9903 - val_loss: 0.6021 - val_acc: 0.8064
#
# Epoch 00023: val_loss did not improve from 0.59663
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1815 - acc: 0.9878 - val_loss: 0.6039 - val_acc: 0.8057
#
# Epoch 00024: val_loss did not improve from 0.59663
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1806 - acc: 0.9893 - val_loss: 0.6018 - val_acc: 0.8081
#
# Epoch 00025: val_loss did not improve from 0.59663
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1781 - acc: 0.9899 - val_loss: 0.6042 - val_acc: 0.8076
#
# Epoch 00026: val_loss did not improve from 0.59663
# Epoch 27/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1788 - acc: 0.9903 - val_loss: 0.6015 - val_acc: 0.8013
#
# Epoch 00027: val_loss did not improve from 0.59663
# Epoch 28/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1786 - acc: 0.9905 - val_loss: 0.6022 - val_acc: 0.8020
#
# Epoch 00028: val_loss did not improve from 0.59663
# Epoch 29/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1781 - acc: 0.9910 - val_loss: 0.6017 - val_acc: 0.8030
#
# Epoch 00029: val_loss did not improve from 0.59663
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1783 - acc: 0.9894 - val_loss: 0.6042 - val_acc: 0.8050
#
# Epoch 00030: val_loss did not improve from 0.59663
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1770 - acc: 0.9907 - val_loss: 0.6021 - val_acc: 0.8034
#
# Epoch 00031: val_loss did not improve from 0.59663
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1757 - acc: 0.9905 - val_loss: 0.5983 - val_acc: 0.8097
#
# Epoch 00032: val_loss did not improve from 0.59663
# results per 3-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5983 - acc: 0.8097
# [[1183   11   42   56   68]
#  [  29 1363  146   75   49]
#  [  71  173 2696  168  117]
#  [  90   56  297 1808  194]
#  [  17  121  149  141 1758]]
#               precision    recall  f1-score   support
#
#           HC       0.85      0.87      0.86      1360
#          a_H       0.79      0.82      0.81      1662
#          a_K       0.81      0.84      0.82      3225
#          a_A       0.80      0.74      0.77      2445
#          a_C       0.80      0.80      0.80      2186
#
#     accuracy                           0.81     10878
#    macro avg       0.81      0.81      0.81     10878
# weighted avg       0.81      0.81      0.81     10878

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

for i in range(4, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11732,)
# H (10284,)
# K (15374,)
# A (15728,)
# C (12150,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 68ms/step - loss: 1.6665 - acc: 0.3023 - val_loss: 1.5050 - val_acc: 0.3595
#
# Epoch 00001: val_loss improved from inf to 1.50496, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3746 - acc: 0.4275 - val_loss: 1.3618 - val_acc: 0.4493
#
# Epoch 00002: val_loss improved from 1.50496 to 1.36181, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2582 - acc: 0.4933 - val_loss: 1.2831 - val_acc: 0.4890
#
# Epoch 00003: val_loss improved from 1.36181 to 1.28314, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1612 - acc: 0.5448 - val_loss: 1.2171 - val_acc: 0.5319
#
# Epoch 00004: val_loss improved from 1.28314 to 1.21710, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.0871 - acc: 0.5911 - val_loss: 1.1620 - val_acc: 0.5582
#
# Epoch 00005: val_loss improved from 1.21710 to 1.16200, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0335 - acc: 0.6220 - val_loss: 1.1332 - val_acc: 0.5817
#
# Epoch 00006: val_loss improved from 1.16200 to 1.13318, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9778 - acc: 0.6567 - val_loss: 1.0876 - val_acc: 0.6081
#
# Epoch 00007: val_loss improved from 1.13318 to 1.08760, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9318 - acc: 0.6812 - val_loss: 1.0438 - val_acc: 0.6259
#
# Epoch 00008: val_loss improved from 1.08760 to 1.04375, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8840 - acc: 0.7102 - val_loss: 1.0166 - val_acc: 0.6410
#
# Epoch 00009: val_loss improved from 1.04375 to 1.01664, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8525 - acc: 0.7267 - val_loss: 1.0035 - val_acc: 0.6446
#
# Epoch 00010: val_loss improved from 1.01664 to 1.00348, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8200 - acc: 0.7445 - val_loss: 0.9656 - val_acc: 0.6628
#
# Epoch 00011: val_loss improved from 1.00348 to 0.96564, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7814 - acc: 0.7659 - val_loss: 0.9393 - val_acc: 0.6749
#
# Epoch 00012: val_loss improved from 0.96564 to 0.93929, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7602 - acc: 0.7773 - val_loss: 0.9369 - val_acc: 0.6742
#
# Epoch 00013: val_loss improved from 0.93929 to 0.93687, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7303 - acc: 0.7930 - val_loss: 0.9104 - val_acc: 0.6913
#
# Epoch 00014: val_loss improved from 0.93687 to 0.91044, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7084 - acc: 0.8053 - val_loss: 0.8851 - val_acc: 0.7064
#
# Epoch 00015: val_loss improved from 0.91044 to 0.88508, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6818 - acc: 0.8174 - val_loss: 0.8732 - val_acc: 0.7046
#
# Epoch 00016: val_loss improved from 0.88508 to 0.87319, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6601 - acc: 0.8284 - val_loss: 0.8309 - val_acc: 0.7285
#
# Epoch 00017: val_loss improved from 0.87319 to 0.83086, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6400 - acc: 0.8366 - val_loss: 0.8430 - val_acc: 0.7222
#
# Epoch 00018: val_loss did not improve from 0.83086
# Epoch 19/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6190 - acc: 0.8486 - val_loss: 0.8255 - val_acc: 0.7304
#
# Epoch 00019: val_loss improved from 0.83086 to 0.82554, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6013 - acc: 0.8569 - val_loss: 0.8301 - val_acc: 0.7284
#
# Epoch 00020: val_loss did not improve from 0.82554
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5811 - acc: 0.8663 - val_loss: 0.8023 - val_acc: 0.7377
#
# Epoch 00021: val_loss improved from 0.82554 to 0.80232, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5652 - acc: 0.8750 - val_loss: 0.7892 - val_acc: 0.7493
#
# Epoch 00022: val_loss improved from 0.80232 to 0.78918, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5493 - acc: 0.8784 - val_loss: 0.7866 - val_acc: 0.7473
#
# Epoch 00023: val_loss improved from 0.78918 to 0.78659, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5345 - acc: 0.8854 - val_loss: 0.7735 - val_acc: 0.7600
#
# Epoch 00024: val_loss improved from 0.78659 to 0.77353, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5210 - acc: 0.8911 - val_loss: 0.7767 - val_acc: 0.7494
#
# Epoch 00025: val_loss did not improve from 0.77353
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5057 - acc: 0.8969 - val_loss: 0.7515 - val_acc: 0.7663
#
# Epoch 00026: val_loss improved from 0.77353 to 0.75146, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4907 - acc: 0.9040 - val_loss: 0.7401 - val_acc: 0.7622
#
# Epoch 00027: val_loss improved from 0.75146 to 0.74006, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4752 - acc: 0.9088 - val_loss: 0.7304 - val_acc: 0.7798
#
# Epoch 00028: val_loss improved from 0.74006 to 0.73036, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4677 - acc: 0.9110 - val_loss: 0.7277 - val_acc: 0.7737
#
# Epoch 00029: val_loss improved from 0.73036 to 0.72773, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4544 - acc: 0.9176 - val_loss: 0.7252 - val_acc: 0.7682
#
# Epoch 00030: val_loss improved from 0.72773 to 0.72517, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4356 - acc: 0.9252 - val_loss: 0.7113 - val_acc: 0.7832
#
# Epoch 00031: val_loss improved from 0.72517 to 0.71127, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4278 - acc: 0.9278 - val_loss: 0.7044 - val_acc: 0.7837
#
# Epoch 00032: val_loss improved from 0.71127 to 0.70437, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4172 - acc: 0.9305 - val_loss: 0.6865 - val_acc: 0.7819
#
# Epoch 00033: val_loss improved from 0.70437 to 0.68648, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4078 - acc: 0.9318 - val_loss: 0.6953 - val_acc: 0.7905
#
# Epoch 00034: val_loss did not improve from 0.68648
# Epoch 35/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3959 - acc: 0.9382 - val_loss: 0.6813 - val_acc: 0.7942
#
# Epoch 00035: val_loss improved from 0.68648 to 0.68126, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3865 - acc: 0.9405 - val_loss: 0.6883 - val_acc: 0.7832
#
# Epoch 00036: val_loss did not improve from 0.68126
# Epoch 37/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3757 - acc: 0.9443 - val_loss: 0.6677 - val_acc: 0.7917
#
# Epoch 00037: val_loss improved from 0.68126 to 0.66775, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3673 - acc: 0.9461 - val_loss: 0.6726 - val_acc: 0.7867
#
# Epoch 00038: val_loss did not improve from 0.66775
# Epoch 39/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3600 - acc: 0.9484 - val_loss: 0.6674 - val_acc: 0.7945
#
# Epoch 00039: val_loss improved from 0.66775 to 0.66738, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3493 - acc: 0.9517 - val_loss: 0.6659 - val_acc: 0.7943
#
# Epoch 00040: val_loss improved from 0.66738 to 0.66590, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3419 - acc: 0.9548 - val_loss: 0.6493 - val_acc: 0.7989
#
# Epoch 00041: val_loss improved from 0.66590 to 0.64928, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3325 - acc: 0.9574 - val_loss: 0.6502 - val_acc: 0.7936
#
# Epoch 00042: val_loss did not improve from 0.64928
# Epoch 43/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3251 - acc: 0.9579 - val_loss: 0.6571 - val_acc: 0.7993
#
# Epoch 00043: val_loss did not improve from 0.64928
# Epoch 44/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3154 - acc: 0.9614 - val_loss: 0.6495 - val_acc: 0.7978
#
# Epoch 00044: val_loss did not improve from 0.64928
# Epoch 45/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3108 - acc: 0.9612 - val_loss: 0.6515 - val_acc: 0.7950
#
# Epoch 00045: val_loss did not improve from 0.64928
# Epoch 46/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3028 - acc: 0.9625 - val_loss: 0.6201 - val_acc: 0.8034
#
# Epoch 00046: val_loss improved from 0.64928 to 0.62008, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2981 - acc: 0.9625 - val_loss: 0.6210 - val_acc: 0.8019
#
# Epoch 00047: val_loss did not improve from 0.62008
# Epoch 48/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2901 - acc: 0.9662 - val_loss: 0.6312 - val_acc: 0.7992
#
# Epoch 00048: val_loss did not improve from 0.62008
# Epoch 49/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2818 - acc: 0.9689 - val_loss: 0.6319 - val_acc: 0.8023
#
# Epoch 00049: val_loss did not improve from 0.62008
# Epoch 50/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2771 - acc: 0.9689 - val_loss: 0.6317 - val_acc: 0.8053
#
# Epoch 00050: val_loss did not improve from 0.62008
# Epoch 51/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2682 - acc: 0.9716 - val_loss: 0.6163 - val_acc: 0.8052
#
# Epoch 00051: val_loss improved from 0.62008 to 0.61630, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2621 - acc: 0.9719 - val_loss: 0.6112 - val_acc: 0.8080
#
# Epoch 00052: val_loss improved from 0.61630 to 0.61120, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2558 - acc: 0.9744 - val_loss: 0.6140 - val_acc: 0.8123
#
# Epoch 00053: val_loss did not improve from 0.61120
# Epoch 54/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2500 - acc: 0.9757 - val_loss: 0.6190 - val_acc: 0.8109
#
# Epoch 00054: val_loss did not improve from 0.61120
# Epoch 55/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2471 - acc: 0.9756 - val_loss: 0.6040 - val_acc: 0.8126
#
# Epoch 00055: val_loss improved from 0.61120 to 0.60401, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2408 - acc: 0.9764 - val_loss: 0.6070 - val_acc: 0.8116
#
# Epoch 00056: val_loss did not improve from 0.60401
# Epoch 57/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2336 - acc: 0.9788 - val_loss: 0.5966 - val_acc: 0.8130
#
# Epoch 00057: val_loss improved from 0.60401 to 0.59664, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2302 - acc: 0.9787 - val_loss: 0.5921 - val_acc: 0.8137
#
# Epoch 00058: val_loss improved from 0.59664 to 0.59211, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 59/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2231 - acc: 0.9806 - val_loss: 0.5996 - val_acc: 0.8046
#
# Epoch 00059: val_loss did not improve from 0.59211
# Epoch 60/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2189 - acc: 0.9800 - val_loss: 0.5886 - val_acc: 0.8142
#
# Epoch 00060: val_loss improved from 0.59211 to 0.58864, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2156 - acc: 0.9807 - val_loss: 0.5916 - val_acc: 0.8093
#
# Epoch 00061: val_loss did not improve from 0.58864
# Epoch 62/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2098 - acc: 0.9826 - val_loss: 0.5756 - val_acc: 0.8204
#
# Epoch 00062: val_loss improved from 0.58864 to 0.57561, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 63/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2051 - acc: 0.9830 - val_loss: 0.5885 - val_acc: 0.8104
#
# Epoch 00063: val_loss did not improve from 0.57561
# Epoch 64/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2004 - acc: 0.9832 - val_loss: 0.5849 - val_acc: 0.8120
#
# Epoch 00064: val_loss did not improve from 0.57561
# Epoch 65/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1988 - acc: 0.9827 - val_loss: 0.5701 - val_acc: 0.8187
#
# Epoch 00065: val_loss improved from 0.57561 to 0.57013, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 66/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1929 - acc: 0.9840 - val_loss: 0.5785 - val_acc: 0.8086
#
# Epoch 00066: val_loss did not improve from 0.57013
# Epoch 67/400
#  754/1036 [====================>.........] - ETA: 18s - loss: 0.1910 - acc: 0.9843

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 14 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

i=4
# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5')

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# # save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11732,)
# H (10284,)
# K (15374,)
# A (15728,)
# C (12150,)
# Epoch 1/400
# 1036/1036 [==============================] - 104s 67ms/step - loss: 0.1831 - acc: 0.9862 - val_loss: 0.5769 - val_acc: 0.8113
#
# Epoch 00001: val_loss improved from inf to 0.57694, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1805 - acc: 0.9870 - val_loss: 0.5749 - val_acc: 0.8161
#
# Epoch 00002: val_loss improved from 0.57694 to 0.57489, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1773 - acc: 0.9867 - val_loss: 0.5757 - val_acc: 0.8115
#
# Epoch 00003: val_loss did not improve from 0.57489
# Epoch 4/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1745 - acc: 0.9867 - val_loss: 0.5746 - val_acc: 0.8158
#
# Epoch 00004: val_loss improved from 0.57489 to 0.57458, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1682 - acc: 0.9872 - val_loss: 0.5894 - val_acc: 0.8041
#
# Epoch 00005: val_loss did not improve from 0.57458
# Epoch 6/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1653 - acc: 0.9884 - val_loss: 0.5689 - val_acc: 0.8131
#
# Epoch 00006: val_loss improved from 0.57458 to 0.56886, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1618 - acc: 0.9888 - val_loss: 0.5796 - val_acc: 0.8136
#
# Epoch 00007: val_loss did not improve from 0.56886
# Epoch 8/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1587 - acc: 0.9891 - val_loss: 0.5618 - val_acc: 0.8206
#
# Epoch 00008: val_loss improved from 0.56886 to 0.56178, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1561 - acc: 0.9883 - val_loss: 0.5703 - val_acc: 0.8136
#
# Epoch 00009: val_loss did not improve from 0.56178
# Epoch 10/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1547 - acc: 0.9887 - val_loss: 0.5727 - val_acc: 0.8122
#
# Epoch 00010: val_loss did not improve from 0.56178
# Epoch 11/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1488 - acc: 0.9901 - val_loss: 0.5654 - val_acc: 0.8205
#
# Epoch 00011: val_loss did not improve from 0.56178
# Epoch 12/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1473 - acc: 0.9901 - val_loss: 0.5402 - val_acc: 0.8265
#
# Epoch 00012: val_loss improved from 0.56178 to 0.54019, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1433 - acc: 0.9914 - val_loss: 0.5518 - val_acc: 0.8176
#
# Epoch 00013: val_loss did not improve from 0.54019
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1432 - acc: 0.9897 - val_loss: 0.5499 - val_acc: 0.8230
#
# Epoch 00014: val_loss did not improve from 0.54019
# Epoch 15/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1356 - acc: 0.9919 - val_loss: 0.5436 - val_acc: 0.8228
#
# Epoch 00015: val_loss did not improve from 0.54019
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1320 - acc: 0.9936 - val_loss: 0.5378 - val_acc: 0.8243
#
# Epoch 00016: val_loss improved from 0.54019 to 0.53782, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1306 - acc: 0.9927 - val_loss: 0.5428 - val_acc: 0.8262
#
# Epoch 00017: val_loss did not improve from 0.53782
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1301 - acc: 0.9928 - val_loss: 0.5438 - val_acc: 0.8277
#
# Epoch 00018: val_loss did not improve from 0.53782
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1294 - acc: 0.9932 - val_loss: 0.5391 - val_acc: 0.8263
#
# Epoch 00019: val_loss did not improve from 0.53782
# Epoch 20/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1281 - acc: 0.9932 - val_loss: 0.5375 - val_acc: 0.8252
#
# Epoch 00020: val_loss improved from 0.53782 to 0.53749, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1280 - acc: 0.9940 - val_loss: 0.5357 - val_acc: 0.8274
#
# Epoch 00021: val_loss improved from 0.53749 to 0.53574, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1254 - acc: 0.9945 - val_loss: 0.5336 - val_acc: 0.8345
#
# Epoch 00022: val_loss improved from 0.53574 to 0.53362, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1257 - acc: 0.9945 - val_loss: 0.5349 - val_acc: 0.8292
#
# Epoch 00023: val_loss did not improve from 0.53362
# Epoch 24/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1267 - acc: 0.9939 - val_loss: 0.5369 - val_acc: 0.8285
#
# Epoch 00024: val_loss did not improve from 0.53362
# Epoch 25/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1251 - acc: 0.9944 - val_loss: 0.5361 - val_acc: 0.8285
#
# Epoch 00025: val_loss did not improve from 0.53362
# Epoch 26/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1252 - acc: 0.9946 - val_loss: 0.5343 - val_acc: 0.8292
#
# Epoch 00026: val_loss did not improve from 0.53362
# Epoch 27/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1260 - acc: 0.9936 - val_loss: 0.5361 - val_acc: 0.8321
#
# Epoch 00027: val_loss did not improve from 0.53362
# Epoch 28/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1248 - acc: 0.9938 - val_loss: 0.5332 - val_acc: 0.8303
#
# Epoch 00028: val_loss improved from 0.53362 to 0.53325, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1237 - acc: 0.9941 - val_loss: 0.5321 - val_acc: 0.8307
#
# Epoch 00029: val_loss improved from 0.53325 to 0.53207, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1233 - acc: 0.9943 - val_loss: 0.5353 - val_acc: 0.8295
#
# Epoch 00030: val_loss did not improve from 0.53207
# Epoch 31/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1220 - acc: 0.9949 - val_loss: 0.5301 - val_acc: 0.8307
#
# Epoch 00031: val_loss improved from 0.53207 to 0.53005, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1230 - acc: 0.9946 - val_loss: 0.5325 - val_acc: 0.8318
#
# Epoch 00032: val_loss did not improve from 0.53005
# Epoch 33/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1223 - acc: 0.9947 - val_loss: 0.5335 - val_acc: 0.8303
#
# Epoch 00033: val_loss did not improve from 0.53005
# Epoch 34/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1235 - acc: 0.9942 - val_loss: 0.5335 - val_acc: 0.8308
#
# Epoch 00034: val_loss did not improve from 0.53005
# Epoch 35/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.1222 - acc: 0.9945 - val_loss: 0.5373 - val_acc: 0.8301
#
# Epoch 00035: val_loss did not improve from 0.53005
# Epoch 36/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1223 - acc: 0.9948 - val_loss: 0.5282 - val_acc: 0.8352
#
# Epoch 00036: val_loss improved from 0.53005 to 0.52823, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1233 - acc: 0.9940 - val_loss: 0.5317 - val_acc: 0.8333
#
# Epoch 00037: val_loss did not improve from 0.52823
# Epoch 38/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1232 - acc: 0.9945 - val_loss: 0.5315 - val_acc: 0.8324
#
# Epoch 00038: val_loss did not improve from 0.52823
# Epoch 39/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1220 - acc: 0.9945 - val_loss: 0.5342 - val_acc: 0.8302
#
# Epoch 00039: val_loss did not improve from 0.52823
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1239 - acc: 0.9937 - val_loss: 0.5342 - val_acc: 0.8320
#
# Epoch 00040: val_loss did not improve from 0.52823
# Epoch 41/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1222 - acc: 0.9940 - val_loss: 0.5324 - val_acc: 0.8319
#
# Epoch 00041: val_loss did not improve from 0.52823
# Epoch 42/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1229 - acc: 0.9946 - val_loss: 0.5336 - val_acc: 0.8320
#
# Epoch 00042: val_loss did not improve from 0.52823
# Epoch 43/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1223 - acc: 0.9943 - val_loss: 0.5312 - val_acc: 0.8325
#
# Epoch 00043: val_loss did not improve from 0.52823
# Epoch 44/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1212 - acc: 0.9952 - val_loss: 0.5334 - val_acc: 0.8304
#
# Epoch 00044: val_loss did not improve from 0.52823
# Epoch 45/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1239 - acc: 0.9942 - val_loss: 0.5318 - val_acc: 0.8306
#
# Epoch 00045: val_loss did not improve from 0.52823
# Epoch 46/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1228 - acc: 0.9947 - val_loss: 0.5329 - val_acc: 0.8262
#
# Epoch 00046: val_loss did not improve from 0.52823
# results per 4-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5329 - acc: 0.8262
# [[1820   39   71   51   43]
#  [  12 1189  247   90   40]
#  [  31   82 1957   96   90]
#  [  60   57  181 2360  171]
#  [  49  110  246  125 1661]]
#               precision    recall  f1-score   support
#
#           HC       0.92      0.90      0.91      2024
#          a_H       0.81      0.75      0.78      1578
#          a_K       0.72      0.87      0.79      2256
#          a_A       0.87      0.83      0.85      2829
#          a_C       0.83      0.76      0.79      2191
#
#     accuracy                           0.83     10878
#    macro avg       0.83      0.82      0.82     10878
# weighted avg       0.83      0.83      0.83     10878

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

for i in range(5, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11496,)
# H (10032,)
# K (15224,)
# A (15958,)
# C (12558,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 68ms/step - loss: 1.6794 - acc: 0.3049 - val_loss: 1.3827 - val_acc: 0.4072
#
# Epoch 00001: val_loss improved from inf to 1.38275, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3709 - acc: 0.4289 - val_loss: 1.2672 - val_acc: 0.4969
#
# Epoch 00002: val_loss improved from 1.38275 to 1.26724, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2436 - acc: 0.4972 - val_loss: 1.1931 - val_acc: 0.5300
#
# Epoch 00003: val_loss improved from 1.26724 to 1.19310, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1580 - acc: 0.5474 - val_loss: 1.1673 - val_acc: 0.5431
#
# Epoch 00004: val_loss improved from 1.19310 to 1.16729, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0790 - acc: 0.5943 - val_loss: 1.1157 - val_acc: 0.5759
#
# Epoch 00005: val_loss improved from 1.16729 to 1.11568, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.0208 - acc: 0.6273 - val_loss: 1.0811 - val_acc: 0.5933
#
# Epoch 00006: val_loss improved from 1.11568 to 1.08108, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9716 - acc: 0.6579 - val_loss: 1.0603 - val_acc: 0.6074
#
# Epoch 00007: val_loss improved from 1.08108 to 1.06034, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9229 - acc: 0.6858 - val_loss: 1.0280 - val_acc: 0.6215
#
# Epoch 00008: val_loss improved from 1.06034 to 1.02798, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.8831 - acc: 0.7083 - val_loss: 0.9893 - val_acc: 0.6324
#
# Epoch 00009: val_loss improved from 1.02798 to 0.98932, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.8503 - acc: 0.7245 - val_loss: 0.9788 - val_acc: 0.6510
#
# Epoch 00010: val_loss improved from 0.98932 to 0.97880, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 69s 66ms/step - loss: 0.8127 - acc: 0.7464 - val_loss: 0.9496 - val_acc: 0.6648
#
# Epoch 00011: val_loss improved from 0.97880 to 0.94964, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7833 - acc: 0.7640 - val_loss: 0.9388 - val_acc: 0.6605
#
# Epoch 00012: val_loss improved from 0.94964 to 0.93880, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7522 - acc: 0.7796 - val_loss: 0.9200 - val_acc: 0.6790
#
# Epoch 00013: val_loss improved from 0.93880 to 0.91995, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7301 - acc: 0.7918 - val_loss: 0.8985 - val_acc: 0.6773
#
# Epoch 00014: val_loss improved from 0.91995 to 0.89847, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7027 - acc: 0.8084 - val_loss: 0.8901 - val_acc: 0.6886
#
# Epoch 00015: val_loss improved from 0.89847 to 0.89012, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6831 - acc: 0.8203 - val_loss: 0.8670 - val_acc: 0.7010
#
# Epoch 00016: val_loss improved from 0.89012 to 0.86700, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6586 - acc: 0.8283 - val_loss: 0.8511 - val_acc: 0.6965
#
# Epoch 00017: val_loss improved from 0.86700 to 0.85112, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6378 - acc: 0.8380 - val_loss: 0.8527 - val_acc: 0.6924
#
# Epoch 00018: val_loss did not improve from 0.85112
# Epoch 19/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6216 - acc: 0.8460 - val_loss: 0.8328 - val_acc: 0.7083
#
# Epoch 00019: val_loss improved from 0.85112 to 0.83278, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5973 - acc: 0.8575 - val_loss: 0.8214 - val_acc: 0.7214
#
# Epoch 00020: val_loss improved from 0.83278 to 0.82144, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5829 - acc: 0.8625 - val_loss: 0.8209 - val_acc: 0.7161
#
# Epoch 00021: val_loss improved from 0.82144 to 0.82087, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5636 - acc: 0.8720 - val_loss: 0.8030 - val_acc: 0.7233
#
# Epoch 00022: val_loss improved from 0.82087 to 0.80298, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5508 - acc: 0.8771 - val_loss: 0.8001 - val_acc: 0.7205
#
# Epoch 00023: val_loss improved from 0.80298 to 0.80012, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5335 - acc: 0.8862 - val_loss: 0.7855 - val_acc: 0.7261
#
# Epoch 00024: val_loss improved from 0.80012 to 0.78549, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5154 - acc: 0.8950 - val_loss: 0.7613 - val_acc: 0.7409
#
# Epoch 00025: val_loss improved from 0.78549 to 0.76135, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5018 - acc: 0.8999 - val_loss: 0.7559 - val_acc: 0.7432
#
# Epoch 00026: val_loss improved from 0.76135 to 0.75586, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4879 - acc: 0.9050 - val_loss: 0.7545 - val_acc: 0.7355
#
# Epoch 00027: val_loss improved from 0.75586 to 0.75448, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4717 - acc: 0.9116 - val_loss: 0.7462 - val_acc: 0.7424
#
# Epoch 00028: val_loss improved from 0.75448 to 0.74619, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4642 - acc: 0.9139 - val_loss: 0.7530 - val_acc: 0.7439
#
# Epoch 00029: val_loss did not improve from 0.74619
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4476 - acc: 0.9195 - val_loss: 0.7354 - val_acc: 0.7352
#
# Epoch 00030: val_loss improved from 0.74619 to 0.73540, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4408 - acc: 0.9218 - val_loss: 0.7389 - val_acc: 0.7524
#
# Epoch 00031: val_loss did not improve from 0.73540
# Epoch 32/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4244 - acc: 0.9295 - val_loss: 0.7102 - val_acc: 0.7598
#
# Epoch 00032: val_loss improved from 0.73540 to 0.71022, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4123 - acc: 0.9331 - val_loss: 0.7145 - val_acc: 0.7513
#
# Epoch 00033: val_loss did not improve from 0.71022
# Epoch 34/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4026 - acc: 0.9372 - val_loss: 0.7124 - val_acc: 0.7589
#
# Epoch 00034: val_loss did not improve from 0.71022
# Epoch 35/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3965 - acc: 0.9373 - val_loss: 0.7156 - val_acc: 0.7559
#
# Epoch 00035: val_loss did not improve from 0.71022
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3853 - acc: 0.9397 - val_loss: 0.7053 - val_acc: 0.7571
#
# Epoch 00036: val_loss improved from 0.71022 to 0.70527, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3792 - acc: 0.9410 - val_loss: 0.6811 - val_acc: 0.7660
#
# Epoch 00037: val_loss improved from 0.70527 to 0.68115, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3681 - acc: 0.9453 - val_loss: 0.6909 - val_acc: 0.7732
#
# Epoch 00038: val_loss did not improve from 0.68115
# Epoch 39/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3571 - acc: 0.9501 - val_loss: 0.6827 - val_acc: 0.7678
#
# Epoch 00039: val_loss did not improve from 0.68115
# Epoch 40/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3491 - acc: 0.9526 - val_loss: 0.6709 - val_acc: 0.7719
#
# Epoch 00040: val_loss improved from 0.68115 to 0.67086, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3384 - acc: 0.9559 - val_loss: 0.6683 - val_acc: 0.7670
#
# Epoch 00041: val_loss improved from 0.67086 to 0.66826, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3300 - acc: 0.9575 - val_loss: 0.6553 - val_acc: 0.7768
#
# Epoch 00042: val_loss improved from 0.66826 to 0.65527, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3230 - acc: 0.9598 - val_loss: 0.6652 - val_acc: 0.7774
#
# Epoch 00043: val_loss did not improve from 0.65527
# Epoch 44/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3170 - acc: 0.9580 - val_loss: 0.6574 - val_acc: 0.7738
#
# Epoch 00044: val_loss did not improve from 0.65527
# Epoch 45/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3066 - acc: 0.9637 - val_loss: 0.6698 - val_acc: 0.7712
#
# Epoch 00045: val_loss did not improve from 0.65527
# Epoch 46/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3015 - acc: 0.9627 - val_loss: 0.6449 - val_acc: 0.7819
#
# Epoch 00046: val_loss improved from 0.65527 to 0.64493, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2936 - acc: 0.9656 - val_loss: 0.6503 - val_acc: 0.7819
#
# Epoch 00047: val_loss did not improve from 0.64493
# Epoch 48/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2848 - acc: 0.9695 - val_loss: 0.6420 - val_acc: 0.7819
#
# Epoch 00048: val_loss improved from 0.64493 to 0.64199, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2779 - acc: 0.9693 - val_loss: 0.6346 - val_acc: 0.7813
#
# Epoch 00049: val_loss improved from 0.64199 to 0.63460, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2716 - acc: 0.9715 - val_loss: 0.6450 - val_acc: 0.7777
#
# Epoch 00050: val_loss did not improve from 0.63460
# Epoch 51/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2658 - acc: 0.9734 - val_loss: 0.6363 - val_acc: 0.7944
#
# Epoch 00051: val_loss did not improve from 0.63460
# Epoch 52/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2598 - acc: 0.9734 - val_loss: 0.6156 - val_acc: 0.7880
#
# Epoch 00052: val_loss improved from 0.63460 to 0.61555, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2548 - acc: 0.9738 - val_loss: 0.6228 - val_acc: 0.7954
#
# Epoch 00053: val_loss did not improve from 0.61555
# Epoch 54/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2491 - acc: 0.9747 - val_loss: 0.6226 - val_acc: 0.7920
#
# Epoch 00054: val_loss did not improve from 0.61555
# Epoch 55/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2428 - acc: 0.9768 - val_loss: 0.6217 - val_acc: 0.7885
#
# Epoch 00055: val_loss did not improve from 0.61555
# Epoch 56/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2392 - acc: 0.9771 - val_loss: 0.6322 - val_acc: 0.7869
#
# Epoch 00056: val_loss did not improve from 0.61555
# Epoch 57/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2320 - acc: 0.9782 - val_loss: 0.6068 - val_acc: 0.7905
#
# Epoch 00057: val_loss improved from 0.61555 to 0.60678, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2273 - acc: 0.9791 - val_loss: 0.6081 - val_acc: 0.7943
#
# Epoch 00058: val_loss did not improve from 0.60678
# Epoch 59/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2221 - acc: 0.9806 - val_loss: 0.5950 - val_acc: 0.7947
#
# Epoch 00059: val_loss improved from 0.60678 to 0.59504, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 60/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2167 - acc: 0.9820 - val_loss: 0.5934 - val_acc: 0.7977
#
# Epoch 00060: val_loss improved from 0.59504 to 0.59337, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2114 - acc: 0.9820 - val_loss: 0.5899 - val_acc: 0.8014
#
# Epoch 00061: val_loss improved from 0.59337 to 0.58986, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 62/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2089 - acc: 0.9818 - val_loss: 0.6058 - val_acc: 0.8006
#
# Epoch 00062: val_loss did not improve from 0.58986
# Epoch 63/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2067 - acc: 0.9821 - val_loss: 0.5848 - val_acc: 0.8127
#
# Epoch 00063: val_loss improved from 0.58986 to 0.58482, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 64/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1991 - acc: 0.9838 - val_loss: 0.6134 - val_acc: 0.7888
#
# Epoch 00064: val_loss did not improve from 0.58482
# Epoch 65/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1948 - acc: 0.9850 - val_loss: 0.5919 - val_acc: 0.8043
#
# Epoch 00065: val_loss did not improve from 0.58482
# Epoch 66/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1928 - acc: 0.9847 - val_loss: 0.6018 - val_acc: 0.7917
#
# Epoch 00066: val_loss did not improve from 0.58482
# Epoch 67/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1864 - acc: 0.9856 - val_loss: 0.5999 - val_acc: 0.7964
#
# Epoch 00067: val_loss did not improve from 0.58482
# Epoch 68/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1836 - acc: 0.9860 - val_loss: 0.5897 - val_acc: 0.8001
#
# Epoch 00068: val_loss did not improve from 0.58482
# Epoch 69/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1805 - acc: 0.9865 - val_loss: 0.5860 - val_acc: 0.8057
#
# Epoch 00069: val_loss did not improve from 0.58482
# Epoch 70/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1755 - acc: 0.9862 - val_loss: 0.5960 - val_acc: 0.7981
#
# Epoch 00070: val_loss did not improve from 0.58482
# Epoch 71/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1728 - acc: 0.9868 - val_loss: 0.5951 - val_acc: 0.8084
#
# Epoch 00071: val_loss did not improve from 0.58482
# Epoch 72/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1692 - acc: 0.9883 - val_loss: 0.5904 - val_acc: 0.8017
#
# Epoch 00072: val_loss did not improve from 0.58482
# Epoch 73/400
# 1036/1036 [==============================] - 72s 69ms/step - loss: 0.1626 - acc: 0.9900 - val_loss: 0.5750 - val_acc: 0.8078
#
# Epoch 00073: val_loss improved from 0.58482 to 0.57501, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 74/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1627 - acc: 0.9886 - val_loss: 0.5766 - val_acc: 0.8120
#
# Epoch 00074: val_loss did not improve from 0.57501
# Epoch 75/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1585 - acc: 0.9886 - val_loss: 0.5870 - val_acc: 0.8065
#
# Epoch 00075: val_loss did not improve from 0.57501
# Epoch 76/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1549 - acc: 0.9890 - val_loss: 0.5757 - val_acc: 0.8123
#
# Epoch 00076: val_loss did not improve from 0.57501
# Epoch 77/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1495 - acc: 0.9909 - val_loss: 0.5658 - val_acc: 0.8018
#
# Epoch 00077: val_loss improved from 0.57501 to 0.56582, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 78/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1478 - acc: 0.9903 - val_loss: 0.5618 - val_acc: 0.8149
#
# Epoch 00078: val_loss improved from 0.56582 to 0.56177, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 79/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1462 - acc: 0.9911 - val_loss: 0.5736 - val_acc: 0.8095
#
# Epoch 00079: val_loss did not improve from 0.56177
# Epoch 80/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1413 - acc: 0.9915 - val_loss: 0.5803 - val_acc: 0.7973
#
# Epoch 00080: val_loss did not improve from 0.56177
# Epoch 81/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1377 - acc: 0.9915 - val_loss: 0.5649 - val_acc: 0.8046
#
# Epoch 00081: val_loss did not improve from 0.56177
# Epoch 82/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1335 - acc: 0.9934 - val_loss: 0.5633 - val_acc: 0.8075
#
# Epoch 00082: val_loss did not improve from 0.56177
# Epoch 83/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1319 - acc: 0.9936 - val_loss: 0.5603 - val_acc: 0.8123
#
# Epoch 00083: val_loss improved from 0.56177 to 0.56032, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 84/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1317 - acc: 0.9938 - val_loss: 0.5584 - val_acc: 0.8138
#
# Epoch 00084: val_loss improved from 0.56032 to 0.55839, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 85/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1312 - acc: 0.9935 - val_loss: 0.5580 - val_acc: 0.8144
#
# Epoch 00085: val_loss improved from 0.55839 to 0.55801, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 86/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1308 - acc: 0.9938 - val_loss: 0.5582 - val_acc: 0.8122
#
# Epoch 00086: val_loss did not improve from 0.55801
# Epoch 87/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1302 - acc: 0.9932 - val_loss: 0.5562 - val_acc: 0.8120
#
# Epoch 00087: val_loss improved from 0.55801 to 0.55620, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 88/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1275 - acc: 0.9945 - val_loss: 0.5605 - val_acc: 0.8109
#
# Epoch 00088: val_loss did not improve from 0.55620
# Epoch 89/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1278 - acc: 0.9940 - val_loss: 0.5534 - val_acc: 0.8157
#
# Epoch 00089: val_loss improved from 0.55620 to 0.55338, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 90/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1274 - acc: 0.9945 - val_loss: 0.5552 - val_acc: 0.8218
#
# Epoch 00090: val_loss did not improve from 0.55338
# Epoch 91/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1283 - acc: 0.9941 - val_loss: 0.5564 - val_acc: 0.8146
#
# Epoch 00091: val_loss did not improve from 0.55338
# Epoch 92/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1257 - acc: 0.9945 - val_loss: 0.5529 - val_acc: 0.8115
#
# Epoch 00092: val_loss improved from 0.55338 to 0.55285, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 93/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1261 - acc: 0.9940 - val_loss: 0.5552 - val_acc: 0.8135
#
# Epoch 00093: val_loss did not improve from 0.55285
# Epoch 94/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1237 - acc: 0.9943 - val_loss: 0.5567 - val_acc: 0.8117
#
# Epoch 00094: val_loss did not improve from 0.55285
# Epoch 95/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1241 - acc: 0.9948 - val_loss: 0.5580 - val_acc: 0.8115
#
# Epoch 00095: val_loss did not improve from 0.55285
# Epoch 96/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1236 - acc: 0.9952 - val_loss: 0.5562 - val_acc: 0.8133
#
# Epoch 00096: val_loss did not improve from 0.55285
# Epoch 97/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1224 - acc: 0.9948 - val_loss: 0.5545 - val_acc: 0.8131
#
# Epoch 00097: val_loss did not improve from 0.55285
# Epoch 98/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1241 - acc: 0.9948 - val_loss: 0.5571 - val_acc: 0.8105
#
# Epoch 00098: val_loss did not improve from 0.55285
# Epoch 99/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1235 - acc: 0.9948 - val_loss: 0.5535 - val_acc: 0.8114
#
# Epoch 00099: val_loss did not improve from 0.55285
# Epoch 100/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1232 - acc: 0.9951 - val_loss: 0.5489 - val_acc: 0.8171
#
# Epoch 00100: val_loss improved from 0.55285 to 0.54885, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 101/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1235 - acc: 0.9944 - val_loss: 0.5541 - val_acc: 0.8133
#
# Epoch 00101: val_loss did not improve from 0.54885
# Epoch 102/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1228 - acc: 0.9943 - val_loss: 0.5521 - val_acc: 0.8153
#
# Epoch 00102: val_loss did not improve from 0.54885
# Epoch 103/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1220 - acc: 0.9949 - val_loss: 0.5550 - val_acc: 0.8131
#
# Epoch 00103: val_loss did not improve from 0.54885
# Epoch 104/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1231 - acc: 0.9944 - val_loss: 0.5537 - val_acc: 0.8195
#
# Epoch 00104: val_loss did not improve from 0.54885
# Epoch 105/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1206 - acc: 0.9946 - val_loss: 0.5518 - val_acc: 0.8146
#
# Epoch 00105: val_loss did not improve from 0.54885
# Epoch 106/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1191 - acc: 0.9951 - val_loss: 0.5560 - val_acc: 0.8129
#
# Epoch 00106: val_loss did not improve from 0.54885
# Epoch 107/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1224 - acc: 0.9948 - val_loss: 0.5550 - val_acc: 0.8142
#
# Epoch 00107: val_loss did not improve from 0.54885
# Epoch 108/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1221 - acc: 0.9947 - val_loss: 0.5519 - val_acc: 0.8149
#
# Epoch 00108: val_loss did not improve from 0.54885
# Epoch 109/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1199 - acc: 0.9947 - val_loss: 0.5551 - val_acc: 0.8149
#
# Epoch 00109: val_loss did not improve from 0.54885
# Epoch 110/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1198 - acc: 0.9949 - val_loss: 0.5573 - val_acc: 0.8121
#
# Epoch 00110: val_loss did not improve from 0.54885
# results per 5-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5573 - acc: 0.8121
# [[1999   12  116   54   79]
#  [  15 1430  166  121   98]
#  [  41   14 2002  170  179]
#  [  24   33  218 2246   78]
#  [ 118   31  250  227 1157]]
#               precision    recall  f1-score   support
#
#           HC       0.91      0.88      0.90      2260
#          a_H       0.94      0.78      0.85      1830
#          a_K       0.73      0.83      0.78      2406
#          a_A       0.80      0.86      0.83      2599
#          a_C       0.73      0.65      0.69      1783
#
#     accuracy                           0.81     10878
#    macro avg       0.82      0.80      0.81     10878
# weighted avg       0.82      0.81      0.81     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11580,)
# H (10322,)
# K (14841,)
# A (16064,)
# C (12461,)
# Epoch 1/400
# 1036/1036 [==============================] - 74s 69ms/step - loss: 1.6693 - acc: 0.2979 - val_loss: 1.3968 - val_acc: 0.4155
#
# Epoch 00001: val_loss improved from inf to 1.39678, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.3772 - acc: 0.4272 - val_loss: 1.2993 - val_acc: 0.4542
#
# Epoch 00002: val_loss improved from 1.39678 to 1.29931, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2509 - acc: 0.4997 - val_loss: 1.2290 - val_acc: 0.5145
#
# Epoch 00003: val_loss improved from 1.29931 to 1.22900, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1591 - acc: 0.5493 - val_loss: 1.1635 - val_acc: 0.5513
#
# Epoch 00004: val_loss improved from 1.22900 to 1.16349, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.0880 - acc: 0.5923 - val_loss: 1.0967 - val_acc: 0.5839
#
# Epoch 00005: val_loss improved from 1.16349 to 1.09668, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.0286 - acc: 0.6258 - val_loss: 1.0759 - val_acc: 0.5994
#
# Epoch 00006: val_loss improved from 1.09668 to 1.07591, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9751 - acc: 0.6589 - val_loss: 1.0176 - val_acc: 0.6346
#
# Epoch 00007: val_loss improved from 1.07591 to 1.01756, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9277 - acc: 0.6838 - val_loss: 0.9743 - val_acc: 0.6523
#
# Epoch 00008: val_loss improved from 1.01756 to 0.97434, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8933 - acc: 0.7007 - val_loss: 0.9498 - val_acc: 0.6630
#
# Epoch 00009: val_loss improved from 0.97434 to 0.94980, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8564 - acc: 0.7205 - val_loss: 0.9315 - val_acc: 0.6779
#
# Epoch 00010: val_loss improved from 0.94980 to 0.93147, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8254 - acc: 0.7409 - val_loss: 0.8996 - val_acc: 0.7093
#
# Epoch 00011: val_loss improved from 0.93147 to 0.89956, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7924 - acc: 0.7574 - val_loss: 0.8794 - val_acc: 0.7000
#
# Epoch 00012: val_loss improved from 0.89956 to 0.87936, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7658 - acc: 0.7731 - val_loss: 0.8527 - val_acc: 0.7255
#
# Epoch 00013: val_loss improved from 0.87936 to 0.85271, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7346 - acc: 0.7920 - val_loss: 0.8352 - val_acc: 0.7334
#
# Epoch 00014: val_loss improved from 0.85271 to 0.83520, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7136 - acc: 0.7994 - val_loss: 0.8206 - val_acc: 0.7344
#
# Epoch 00015: val_loss improved from 0.83520 to 0.82058, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6883 - acc: 0.8178 - val_loss: 0.7900 - val_acc: 0.7523
#
# Epoch 00016: val_loss improved from 0.82058 to 0.79004, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6670 - acc: 0.8242 - val_loss: 0.7829 - val_acc: 0.7429
#
# Epoch 00017: val_loss improved from 0.79004 to 0.78287, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6475 - acc: 0.8331 - val_loss: 0.7697 - val_acc: 0.7466
#
# Epoch 00018: val_loss improved from 0.78287 to 0.76970, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6268 - acc: 0.8444 - val_loss: 0.7512 - val_acc: 0.7581
#
# Epoch 00019: val_loss improved from 0.76970 to 0.75124, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6070 - acc: 0.8525 - val_loss: 0.7176 - val_acc: 0.7767
#
# Epoch 00020: val_loss improved from 0.75124 to 0.71758, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5902 - acc: 0.8607 - val_loss: 0.7108 - val_acc: 0.7796
#
# Epoch 00021: val_loss improved from 0.71758 to 0.71075, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5728 - acc: 0.8687 - val_loss: 0.7041 - val_acc: 0.7684
#
# Epoch 00022: val_loss improved from 0.71075 to 0.70408, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5574 - acc: 0.8752 - val_loss: 0.7004 - val_acc: 0.7822
#
# Epoch 00023: val_loss improved from 0.70408 to 0.70039, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5416 - acc: 0.8809 - val_loss: 0.6857 - val_acc: 0.7844
#
# Epoch 00024: val_loss improved from 0.70039 to 0.68573, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5231 - acc: 0.8892 - val_loss: 0.6799 - val_acc: 0.7843
#
# Epoch 00025: val_loss improved from 0.68573 to 0.67992, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5123 - acc: 0.8924 - val_loss: 0.6664 - val_acc: 0.7836
#
# Epoch 00026: val_loss improved from 0.67992 to 0.66642, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5007 - acc: 0.8990 - val_loss: 0.6487 - val_acc: 0.7994
#
# Epoch 00027: val_loss improved from 0.66642 to 0.64873, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4808 - acc: 0.9071 - val_loss: 0.6466 - val_acc: 0.7975
#
# Epoch 00028: val_loss improved from 0.64873 to 0.64659, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4700 - acc: 0.9116 - val_loss: 0.6301 - val_acc: 0.8023
#
# Epoch 00029: val_loss improved from 0.64659 to 0.63006, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4574 - acc: 0.9150 - val_loss: 0.6282 - val_acc: 0.8002
#
# Epoch 00030: val_loss improved from 0.63006 to 0.62824, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4466 - acc: 0.9183 - val_loss: 0.6225 - val_acc: 0.8079
#
# Epoch 00031: val_loss improved from 0.62824 to 0.62248, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4344 - acc: 0.9234 - val_loss: 0.6061 - val_acc: 0.8004
#
# Epoch 00032: val_loss improved from 0.62248 to 0.60608, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4184 - acc: 0.9290 - val_loss: 0.6021 - val_acc: 0.8019
#
# Epoch 00033: val_loss improved from 0.60608 to 0.60206, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4126 - acc: 0.9311 - val_loss: 0.5988 - val_acc: 0.7995
#
# Epoch 00034: val_loss improved from 0.60206 to 0.59877, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3993 - acc: 0.9358 - val_loss: 0.5862 - val_acc: 0.8056
#
# Epoch 00035: val_loss improved from 0.59877 to 0.58617, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3910 - acc: 0.9382 - val_loss: 0.5752 - val_acc: 0.8142
#
# Epoch 00036: val_loss improved from 0.58617 to 0.57520, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3841 - acc: 0.9396 - val_loss: 0.5777 - val_acc: 0.8093
#
# Epoch 00037: val_loss did not improve from 0.57520
# Epoch 38/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3752 - acc: 0.9421 - val_loss: 0.5740 - val_acc: 0.8176
#
# Epoch 00038: val_loss improved from 0.57520 to 0.57402, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3616 - acc: 0.9462 - val_loss: 0.5631 - val_acc: 0.8203
#
# Epoch 00039: val_loss improved from 0.57402 to 0.56310, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3536 - acc: 0.9491 - val_loss: 0.5536 - val_acc: 0.8211
#
# Epoch 00040: val_loss improved from 0.56310 to 0.55358, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3470 - acc: 0.9517 - val_loss: 0.5560 - val_acc: 0.8195
#
# Epoch 00041: val_loss did not improve from 0.55358
# Epoch 42/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3379 - acc: 0.9537 - val_loss: 0.5490 - val_acc: 0.8212
#
# Epoch 00042: val_loss improved from 0.55358 to 0.54895, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3275 - acc: 0.9565 - val_loss: 0.5430 - val_acc: 0.8265
#
# Epoch 00043: val_loss improved from 0.54895 to 0.54300, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3186 - acc: 0.9597 - val_loss: 0.5375 - val_acc: 0.8267
#
# Epoch 00044: val_loss improved from 0.54300 to 0.53746, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3144 - acc: 0.9590 - val_loss: 0.5399 - val_acc: 0.8252
#
# Epoch 00045: val_loss did not improve from 0.53746
# Epoch 46/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3064 - acc: 0.9624 - val_loss: 0.5389 - val_acc: 0.8263
#
# Epoch 00046: val_loss did not improve from 0.53746
# Epoch 47/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2993 - acc: 0.9628 - val_loss: 0.5337 - val_acc: 0.8297
#
# Epoch 00047: val_loss improved from 0.53746 to 0.53369, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2920 - acc: 0.9658 - val_loss: 0.5219 - val_acc: 0.8269
#
# Epoch 00048: val_loss improved from 0.53369 to 0.52190, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2886 - acc: 0.9655 - val_loss: 0.5185 - val_acc: 0.8323
#
# Epoch 00049: val_loss improved from 0.52190 to 0.51855, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2805 - acc: 0.9680 - val_loss: 0.5123 - val_acc: 0.8309
#
# Epoch 00050: val_loss improved from 0.51855 to 0.51232, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 51/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2730 - acc: 0.9679 - val_loss: 0.5164 - val_acc: 0.8326
#
# Epoch 00051: val_loss did not improve from 0.51232
# Epoch 52/400
#  912/1036 [=========================>....] - ETA: 8s - loss: 0.2682 - acc: 0.9704

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 29 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

i=6
# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5')

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# # save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11580,)
# H (10322,)
# K (14841,)
# A (16064,)
# C (12461,)
# Epoch 1/400
# 1036/1036 [==============================] - 102s 65ms/step - loss: 0.2621 - acc: 0.9715 - val_loss: 0.5059 - val_acc: 0.8384
#
# Epoch 00001: val_loss improved from inf to 0.50587, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 68s 66ms/step - loss: 0.2558 - acc: 0.9722 - val_loss: 0.5032 - val_acc: 0.8363
#
# Epoch 00002: val_loss improved from 0.50587 to 0.50315, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.2491 - acc: 0.9755 - val_loss: 0.4846 - val_acc: 0.8346
#
# Epoch 00003: val_loss improved from 0.50315 to 0.48462, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2462 - acc: 0.9745 - val_loss: 0.4964 - val_acc: 0.8408
#
# Epoch 00004: val_loss did not improve from 0.48462
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.2385 - acc: 0.9753 - val_loss: 0.4893 - val_acc: 0.8394
#
# Epoch 00005: val_loss did not improve from 0.48462
# Epoch 6/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2301 - acc: 0.9783 - val_loss: 0.4891 - val_acc: 0.8410
#
# Epoch 00006: val_loss did not improve from 0.48462
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2259 - acc: 0.9787 - val_loss: 0.4785 - val_acc: 0.8472
#
# Epoch 00007: val_loss improved from 0.48462 to 0.47848, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2203 - acc: 0.9802 - val_loss: 0.4955 - val_acc: 0.8294
#
# Epoch 00008: val_loss did not improve from 0.47848
# Epoch 9/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2192 - acc: 0.9785 - val_loss: 0.4817 - val_acc: 0.8423
#
# Epoch 00009: val_loss did not improve from 0.47848
# Epoch 10/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2105 - acc: 0.9824 - val_loss: 0.4769 - val_acc: 0.8458
#
# Epoch 00010: val_loss improved from 0.47848 to 0.47686, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2092 - acc: 0.9809 - val_loss: 0.4709 - val_acc: 0.8435
#
# Epoch 00011: val_loss improved from 0.47686 to 0.47092, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2056 - acc: 0.9816 - val_loss: 0.4837 - val_acc: 0.8471
#
# Epoch 00012: val_loss did not improve from 0.47092
# Epoch 13/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2007 - acc: 0.9830 - val_loss: 0.4788 - val_acc: 0.8398
#
# Epoch 00013: val_loss did not improve from 0.47092
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1953 - acc: 0.9827 - val_loss: 0.4733 - val_acc: 0.8492
#
# Epoch 00014: val_loss did not improve from 0.47092
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1921 - acc: 0.9836 - val_loss: 0.4692 - val_acc: 0.8472
#
# Epoch 00015: val_loss improved from 0.47092 to 0.46924, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1848 - acc: 0.9856 - val_loss: 0.4684 - val_acc: 0.8540
#
# Epoch 00016: val_loss improved from 0.46924 to 0.46837, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1815 - acc: 0.9852 - val_loss: 0.4592 - val_acc: 0.8520
#
# Epoch 00017: val_loss improved from 0.46837 to 0.45918, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1811 - acc: 0.9856 - val_loss: 0.4551 - val_acc: 0.8514
#
# Epoch 00018: val_loss improved from 0.45918 to 0.45507, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1764 - acc: 0.9863 - val_loss: 0.4527 - val_acc: 0.8528
#
# Epoch 00019: val_loss improved from 0.45507 to 0.45265, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1719 - acc: 0.9874 - val_loss: 0.4576 - val_acc: 0.8429
#
# Epoch 00020: val_loss did not improve from 0.45265
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1693 - acc: 0.9871 - val_loss: 0.4591 - val_acc: 0.8416
#
# Epoch 00021: val_loss did not improve from 0.45265
# Epoch 22/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1663 - acc: 0.9869 - val_loss: 0.4495 - val_acc: 0.8470
#
# Epoch 00022: val_loss improved from 0.45265 to 0.44946, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1613 - acc: 0.9883 - val_loss: 0.4467 - val_acc: 0.8480
#
# Epoch 00023: val_loss improved from 0.44946 to 0.44671, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1584 - acc: 0.9886 - val_loss: 0.4647 - val_acc: 0.8446
#
# Epoch 00024: val_loss did not improve from 0.44671
# Epoch 25/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1569 - acc: 0.9883 - val_loss: 0.4466 - val_acc: 0.8514
#
# Epoch 00025: val_loss improved from 0.44671 to 0.44661, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1516 - acc: 0.9895 - val_loss: 0.4615 - val_acc: 0.8447
#
# Epoch 00026: val_loss did not improve from 0.44661
# Epoch 27/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1500 - acc: 0.9890 - val_loss: 0.4544 - val_acc: 0.8519
#
# Epoch 00027: val_loss did not improve from 0.44661
# Epoch 28/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1478 - acc: 0.9889 - val_loss: 0.4461 - val_acc: 0.8496
#
# Epoch 00028: val_loss improved from 0.44661 to 0.44612, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1428 - acc: 0.9902 - val_loss: 0.4486 - val_acc: 0.8533
#
# Epoch 00029: val_loss did not improve from 0.44612
# Epoch 30/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.1385 - acc: 0.9911 - val_loss: 0.4433 - val_acc: 0.8539
#
# Epoch 00030: val_loss improved from 0.44612 to 0.44334, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1338 - acc: 0.9926 - val_loss: 0.4402 - val_acc: 0.8547
#
# Epoch 00031: val_loss improved from 0.44334 to 0.44016, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1324 - acc: 0.9929 - val_loss: 0.4408 - val_acc: 0.8507
#
# Epoch 00032: val_loss did not improve from 0.44016
# Epoch 33/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1307 - acc: 0.9930 - val_loss: 0.4368 - val_acc: 0.8568
#
# Epoch 00033: val_loss improved from 0.44016 to 0.43682, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1301 - acc: 0.9929 - val_loss: 0.4412 - val_acc: 0.8567
#
# Epoch 00034: val_loss did not improve from 0.43682
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1294 - acc: 0.9942 - val_loss: 0.4429 - val_acc: 0.8567
#
# Epoch 00035: val_loss did not improve from 0.43682
# Epoch 36/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1280 - acc: 0.9934 - val_loss: 0.4395 - val_acc: 0.8563
#
# Epoch 00036: val_loss did not improve from 0.43682
# Epoch 37/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1289 - acc: 0.9936 - val_loss: 0.4402 - val_acc: 0.8556
#
# Epoch 00037: val_loss did not improve from 0.43682
# Epoch 38/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1254 - acc: 0.9942 - val_loss: 0.4437 - val_acc: 0.8561
#
# Epoch 00038: val_loss did not improve from 0.43682
# Epoch 39/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1284 - acc: 0.9927 - val_loss: 0.4415 - val_acc: 0.8594
#
# Epoch 00039: val_loss did not improve from 0.43682
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1284 - acc: 0.9926 - val_loss: 0.4404 - val_acc: 0.8582
#
# Epoch 00040: val_loss did not improve from 0.43682
# Epoch 41/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1249 - acc: 0.9942 - val_loss: 0.4410 - val_acc: 0.8525
#
# Epoch 00041: val_loss did not improve from 0.43682
# Epoch 42/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1264 - acc: 0.9939 - val_loss: 0.4412 - val_acc: 0.8505
#
# Epoch 00042: val_loss did not improve from 0.43682
# Epoch 43/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1242 - acc: 0.9943 - val_loss: 0.4409 - val_acc: 0.8525
#
# Epoch 00043: val_loss did not improve from 0.43682
# results per 6-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4409 - acc: 0.8525
# [[1981   29   90   26   50]
#  [  66 1191  100  141   42]
#  [   8   92 2456  130  103]
#  [   9  114  249 1980  141]
#  [  75   61   41   37 1666]]
#               precision    recall  f1-score   support
#
#           HC       0.93      0.91      0.92      2176
#          a_H       0.80      0.77      0.79      1540
#          a_K       0.84      0.88      0.86      2789
#          a_A       0.86      0.79      0.82      2493
#          a_C       0.83      0.89      0.86      1880
#
#     accuracy                           0.85     10878
#    macro avg       0.85      0.85      0.85     10878
# weighted avg       0.85      0.85      0.85     10878

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

mmscaler_LSTM.fit(test_COP_ML)
test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

# %%
import numpy as np
test_x = np.concatenate([test_V[test_index], test_AP[test_index], test_ML[test_index]], axis=2)
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1649   30    0   18   57]
#  [  37 1120  149   13  132]
#  [ 110   97 1967  134  211]
#  [  51   75  237 2481  145]
#  [  37   91   82  166 1789]]
#               precision    recall  f1-score   support
#
#           HC    0.87527   0.94014   0.90654      1754
#          a_H    0.79264   0.77188   0.78212      1451
#          a_K    0.80780   0.78087   0.79411      2519
#          a_A    0.88229   0.83004   0.85537      2989
#          a_C    0.76650   0.82633   0.79529      2165
#
#     accuracy                        0.82791     10878
#    macro avg    0.82490   0.82985   0.82669     10878
# weighted avg    0.82890   0.82791   0.82771     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1547   17   39   29  122]
#  [  67 1002  169   59  154]
#  [ 129  192 1812  175  211]
#  [ 116  125  248 2245  255]
#  [ 105  139  137  145 1639]]
#               precision    recall  f1-score   support
#
#           HC    0.78768   0.88198   0.83217      1754
#          a_H    0.67932   0.69056   0.68489      1451
#          a_K    0.75343   0.71933   0.73599      2519
#          a_A    0.84621   0.75109   0.79582      2989
#          a_C    0.68837   0.75704   0.72107      2165
#
#     accuracy                        0.75795     10878
#    macro avg    0.75100   0.76000   0.75399     10878
# weighted avg    0.76161   0.75795   0.75815     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1638   10   31   19   56]
#  [  48  998  196   86  123]
#  [  72  146 1893  199  209]
#  [ 131   84  285 2321  168]
#  [  81   81  145  178 1680]]
#               precision    recall  f1-score   support
#
#           HC    0.83147   0.93387   0.87970      1754
#          a_H    0.75663   0.68780   0.72058      1451
#          a_K    0.74235   0.75149   0.74689      2519
#          a_A    0.82804   0.77651   0.80145      2989
#          a_C    0.75134   0.77598   0.76346      2165
#
#     accuracy                        0.78415     10878
#    macro avg    0.78197   0.78513   0.78242     10878
# weighted avg    0.78396   0.78415   0.78309     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_24 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_25 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# activation_27 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# activation_28 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_29 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1608    0   50   38   58]
#  [  33 1164   97   35  122]
#  [  48  106 1969  147  249]
#  [  79  167  232 2349  162]
#  [  42  173  110  112 1728]]
#               precision    recall  f1-score   support
#
#           HC    0.88840   0.91676   0.90236      1754
#          a_H    0.72298   0.80221   0.76054      1451
#          a_K    0.80106   0.78166   0.79124      2519
#          a_A    0.87617   0.78588   0.82857      2989
#          a_C    0.74515   0.79815   0.77074      2165
#
#     accuracy                        0.81063     10878
#    macro avg    0.80675   0.81693   0.81069     10878
# weighted avg    0.81424   0.81063   0.81124     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_30 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_31 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# activation_33 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# activation_34 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_35 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1687    0   10    0   57]
#  [  43 1098  204   27   79]
#  [  41  133 1980  171  194]
#  [ 115   92  318 2315  149]
#  [  35  111   77  151 1791]]
#               precision    recall  f1-score   support
#
#           HC    0.87819   0.96180   0.91810      1754
#          a_H    0.76569   0.75672   0.76118      1451
#          a_K    0.76477   0.78603   0.77525      2519
#          a_A    0.86899   0.77451   0.81903      2989
#          a_C    0.78899   0.82725   0.80767      2165
#
#     accuracy                        0.81550     10878
#    macro avg    0.81333   0.82126   0.81625     10878
# weighted avg    0.81664   0.81550   0.81489     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1591    0   55   30   78]
#  [  45  986  207  100  113]
#  [  32   79 2017  160  231]
#  [  79   82  304 2415  109]
#  [  73  102  112   67 1811]]
#               precision    recall  f1-score   support
#
#           HC    0.87418   0.90707   0.89032      1754
#          a_H    0.78943   0.67953   0.73037      1451
#          a_K    0.74842   0.80071   0.77369      2519
#          a_A    0.87121   0.80796   0.83840      2989
#          a_C    0.77327   0.83649   0.80364      2165
#
#     accuracy                        0.81081     10878
#    macro avg    0.81130   0.80635   0.80728     10878
# weighted avg    0.81285   0.81081   0.81046     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 101, 1024)         2113536
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_42 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_43 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 128)               512
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 64)                256
# _________________________________________________________________
# activation_46 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_47 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,245,849
# Trainable params: 55,243,919
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1656   20   29   30   19]
#  [  35 1148  147   34   87]
#  [  30  138 2023  151  177]
#  [  31  106  308 2411  133]
#  [  43   93  143   95 1791]]
#               precision    recall  f1-score   support
#
#           HC    0.92256   0.94413   0.93322      1754
#          a_H    0.76279   0.79118   0.77673      1451
#          a_K    0.76340   0.80310   0.78274      2519
#          a_A    0.88607   0.80662   0.84448      2989
#          a_C    0.81151   0.82725   0.81930      2165
#
#     accuracy                        0.83002     10878
#    macro avg    0.82927   0.83446   0.83130     10878
# weighted avg    0.83226   0.83002   0.83045     10878
