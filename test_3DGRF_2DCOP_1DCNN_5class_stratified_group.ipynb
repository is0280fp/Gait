# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_3DGRF_2DCOP_1DCNN_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# # Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# # StratifiedGroupKFoldの分割結果をpickle
import pickle

# test
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# trainig and validation
with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
   COP_ML = pickle.load(f)
f.close()

# label
with open("/content/drive/MyDrive/test_data/train_idx_list.pickle", mode="rb") as f:
   train_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   label = pickle.load(f)
f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    test_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    test_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()

# # trainig and validation
# with open("V_val_train.pickle", mode="rb") as f:
#    V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    COP_ML = pickle.load(f)
# f.close()

# # label
# with open("train_idx_list.pickle", mode="rb") as f:
#    train_index_list = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("label_val_train.pickle", mode="rb") as f:
#    label = pickle.load(f)
# f.close()

# with open("test_sub_ID.pickle", mode="rb") as f:
#    sub_ID=pickle.load(f)
# f.close()

# import pandas as pd

# with open("test_data_index.pickle", mode="rb") as f:
#    test_index = pickle.load(f)
# f.close()

# %%
import numpy as np
print(np.where(label==0)[0].shape)
print(np.where(label==1)[0].shape)
print(np.where(label==2)[0].shape)
print(np.where(label==3)[0].shape)
print(np.where(label==4)[0].shape)
# Out:
# (13756,)
# (11862,)
# (17630,)
# (18557,)
# (14341,)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# CNN
mmscaler_CNN.fit(V)
V = mmscaler_CNN.transform(V)
V = V.reshape(V.shape[0], V.shape[1], 1)

mmscaler_CNN.fit(AP)
AP = mmscaler_CNN.transform(AP)
AP = AP.reshape(AP.shape[0], AP.shape[1], 1)

mmscaler_CNN.fit(ML)
ML = mmscaler_CNN.transform(ML)
ML = ML.reshape(ML.shape[0], ML.shape[1], 1)

mmscaler_CNN.fit(COP_AP)
COP_AP = mmscaler_CNN.transform(COP_AP)
COP_AP = COP_AP.reshape(COP_AP.shape[0], COP_AP.shape[1], 1)

mmscaler_CNN.fit(COP_ML)
COP_ML = mmscaler_CNN.transform(COP_ML)
COP_ML = COP_ML.reshape(COP_ML.shape[0], COP_ML.shape[1], 1)

# %%
# !pip install keras-layer-normalization
# !pip install keras-self-attention
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=29657d2bb70bb3b3c52936e614f61d7e4562f6bc36e7d8d289a14b43bf09b28f
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_3DGRF_2DCOP_1DCNN_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr

lr_scheduler = LearningRateScheduler(decay_schedule)

initializer = he_normal()

classes_main = 5

def build_model():
  # CNN
  # 最初これだけだった
  model = Sequential()
  model.add(Conv1D(128, padding = "same", kernel_size=3, strides=1, kernel_initializer=initializer, input_shape=(101, 5)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(MaxPooling1D(2))

  model.add(Conv1D(256, padding = "same", kernel_size=3, strides=1, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))

  model.add(MaxPooling1D(2))

  model.add(Flatten())

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#-------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

val_label_list = []
train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(7):
  train_index = train_index_list[i]
  train_LSTM_data = np.concatenate([V[train_index], AP[train_index], ML[train_index], COP_AP[train_index], COP_ML[train_index]], axis=2)
  val_index = val_index_list[i]
  val_LSTM_data = np.concatenate([V[val_index], AP[val_index], ML[val_index], COP_AP[val_index], COP_ML[val_index]], axis=2)
  
  # label
  train_label = label[train_index] 
  val_label= label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  MAX = len(train_LSTM_data)

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)
# train_data (65268, 101, 5)
# val_data (10878, 101, 5)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=600, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

now = datetime.datetime.now()
with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(cmx_list, f)
f.close()

with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(report_list, f)
f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization (BatchNo (None, 101, 128)          512
# _________________________________________________________________
# activation (Activation)      (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 50, 128)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 256)           1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# HC (11952,)
# H (10373,)
# K (15152,)
# A (15736,)
# C (12055,)
# Epoch 1/600
# 1036/1036 [==============================] - 40s 6ms/step - loss: 1.6276 - acc: 0.3134 - val_loss: 1.2575 - val_acc: 0.4902
#
# Epoch 00001: val_loss improved from inf to 1.25748, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 2/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 1.2272 - acc: 0.5031 - val_loss: 1.1659 - val_acc: 0.5427
#
# Epoch 00002: val_loss improved from 1.25748 to 1.16592, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 3/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 1.0942 - acc: 0.5888 - val_loss: 1.0938 - val_acc: 0.5864
#
# Epoch 00003: val_loss improved from 1.16592 to 1.09383, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 4/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.9904 - acc: 0.6522 - val_loss: 1.0479 - val_acc: 0.6145
#
# Epoch 00004: val_loss improved from 1.09383 to 1.04793, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 5/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.9102 - acc: 0.7002 - val_loss: 0.9914 - val_acc: 0.6469
#
# Epoch 00005: val_loss improved from 1.04793 to 0.99143, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 6/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.8472 - acc: 0.7395 - val_loss: 0.9510 - val_acc: 0.6767
#
# Epoch 00006: val_loss improved from 0.99143 to 0.95098, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 7/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7929 - acc: 0.7725 - val_loss: 0.9121 - val_acc: 0.7022
#
# Epoch 00007: val_loss improved from 0.95098 to 0.91210, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 8/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7469 - acc: 0.7958 - val_loss: 0.8752 - val_acc: 0.7173
#
# Epoch 00008: val_loss improved from 0.91210 to 0.87521, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 9/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7083 - acc: 0.8159 - val_loss: 0.8571 - val_acc: 0.7209
#
# Epoch 00009: val_loss improved from 0.87521 to 0.85711, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 10/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6730 - acc: 0.8337 - val_loss: 0.8308 - val_acc: 0.7440
#
# Epoch 00010: val_loss improved from 0.85711 to 0.83081, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 11/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6415 - acc: 0.8513 - val_loss: 0.8064 - val_acc: 0.7468
#
# Epoch 00011: val_loss improved from 0.83081 to 0.80641, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 12/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6068 - acc: 0.8694 - val_loss: 0.7964 - val_acc: 0.7526
#
# Epoch 00012: val_loss improved from 0.80641 to 0.79643, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 13/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5834 - acc: 0.8813 - val_loss: 0.7808 - val_acc: 0.7677
#
# Epoch 00013: val_loss improved from 0.79643 to 0.78080, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 14/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5606 - acc: 0.8912 - val_loss: 0.7691 - val_acc: 0.7614
#
# Epoch 00014: val_loss improved from 0.78080 to 0.76913, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 15/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5336 - acc: 0.9031 - val_loss: 0.7507 - val_acc: 0.7680
#
# Epoch 00015: val_loss improved from 0.76913 to 0.75070, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 16/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5136 - acc: 0.9120 - val_loss: 0.7356 - val_acc: 0.7738
#
# Epoch 00016: val_loss improved from 0.75070 to 0.73557, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 17/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4942 - acc: 0.9197 - val_loss: 0.7223 - val_acc: 0.7809
#
# Epoch 00017: val_loss improved from 0.73557 to 0.72235, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 18/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4752 - acc: 0.9274 - val_loss: 0.7132 - val_acc: 0.7897
#
# Epoch 00018: val_loss improved from 0.72235 to 0.71320, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 19/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4564 - acc: 0.9361 - val_loss: 0.6991 - val_acc: 0.7897
#
# Epoch 00019: val_loss improved from 0.71320 to 0.69909, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 20/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4393 - acc: 0.9394 - val_loss: 0.6940 - val_acc: 0.7933
#
# Epoch 00020: val_loss improved from 0.69909 to 0.69399, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 21/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4282 - acc: 0.9439 - val_loss: 0.6843 - val_acc: 0.7961
#
# Epoch 00021: val_loss improved from 0.69399 to 0.68432, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 22/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4114 - acc: 0.9498 - val_loss: 0.6638 - val_acc: 0.8047
#
# Epoch 00022: val_loss improved from 0.68432 to 0.66377, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 23/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3984 - acc: 0.9531 - val_loss: 0.6630 - val_acc: 0.8088
#
# Epoch 00023: val_loss improved from 0.66377 to 0.66302, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 24/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3814 - acc: 0.9595 - val_loss: 0.6665 - val_acc: 0.7975
#
# Epoch 00024: val_loss did not improve from 0.66302
# Epoch 25/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3714 - acc: 0.9615 - val_loss: 0.6508 - val_acc: 0.8041
#
# Epoch 00025: val_loss improved from 0.66302 to 0.65083, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 26/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3601 - acc: 0.9647 - val_loss: 0.6451 - val_acc: 0.8145
#
# Epoch 00026: val_loss improved from 0.65083 to 0.64513, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 27/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3448 - acc: 0.9694 - val_loss: 0.6454 - val_acc: 0.8017
#
# Epoch 00027: val_loss did not improve from 0.64513
# Epoch 28/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3382 - acc: 0.9691 - val_loss: 0.6352 - val_acc: 0.8176
#
# Epoch 00028: val_loss improved from 0.64513 to 0.63522, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 29/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3222 - acc: 0.9742 - val_loss: 0.6242 - val_acc: 0.8127
#
# Epoch 00029: val_loss improved from 0.63522 to 0.62419, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 30/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3150 - acc: 0.9753 - val_loss: 0.6307 - val_acc: 0.8095
#
# Epoch 00030: val_loss did not improve from 0.62419
# Epoch 31/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3053 - acc: 0.9772 - val_loss: 0.6182 - val_acc: 0.8139
#
# Epoch 00031: val_loss improved from 0.62419 to 0.61819, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 32/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2965 - acc: 0.9778 - val_loss: 0.6148 - val_acc: 0.8162
#
# Epoch 00032: val_loss improved from 0.61819 to 0.61483, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 33/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2862 - acc: 0.9807 - val_loss: 0.6077 - val_acc: 0.8120
#
# Epoch 00033: val_loss improved from 0.61483 to 0.60767, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 34/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2784 - acc: 0.9825 - val_loss: 0.6102 - val_acc: 0.8198
#
# Epoch 00034: val_loss did not improve from 0.60767
# Epoch 35/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2699 - acc: 0.9835 - val_loss: 0.6007 - val_acc: 0.8169
#
# Epoch 00035: val_loss improved from 0.60767 to 0.60071, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 36/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2640 - acc: 0.9856 - val_loss: 0.6048 - val_acc: 0.8145
#
# Epoch 00036: val_loss did not improve from 0.60071
# Epoch 37/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2550 - acc: 0.9862 - val_loss: 0.6021 - val_acc: 0.8125
#
# Epoch 00037: val_loss did not improve from 0.60071
# Epoch 38/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2467 - acc: 0.9878 - val_loss: 0.5923 - val_acc: 0.8143
#
# Epoch 00038: val_loss improved from 0.60071 to 0.59226, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 39/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2447 - acc: 0.9861 - val_loss: 0.5896 - val_acc: 0.8168
#
# Epoch 00039: val_loss improved from 0.59226 to 0.58957, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 40/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2336 - acc: 0.9886 - val_loss: 0.5900 - val_acc: 0.8104
#
# Epoch 00040: val_loss did not improve from 0.58957
# Epoch 41/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2279 - acc: 0.9896 - val_loss: 0.5830 - val_acc: 0.8212
#
# Epoch 00041: val_loss improved from 0.58957 to 0.58303, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 42/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2237 - acc: 0.9883 - val_loss: 0.5794 - val_acc: 0.8164
#
# Epoch 00042: val_loss improved from 0.58303 to 0.57939, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2160 - acc: 0.9910 - val_loss: 0.5808 - val_acc: 0.8195
#
# Epoch 00043: val_loss did not improve from 0.57939
# Epoch 44/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2098 - acc: 0.9913 - val_loss: 0.5888 - val_acc: 0.8125
#
# Epoch 00044: val_loss did not improve from 0.57939
# Epoch 45/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2091 - acc: 0.9904 - val_loss: 0.5767 - val_acc: 0.8127
#
# Epoch 00045: val_loss improved from 0.57939 to 0.57673, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 46/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2003 - acc: 0.9917 - val_loss: 0.5798 - val_acc: 0.8214
#
# Epoch 00046: val_loss did not improve from 0.57673
# Epoch 47/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1953 - acc: 0.9920 - val_loss: 0.5691 - val_acc: 0.8195
#
# Epoch 00047: val_loss improved from 0.57673 to 0.56908, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 48/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1900 - acc: 0.9933 - val_loss: 0.5801 - val_acc: 0.8133
#
# Epoch 00048: val_loss did not improve from 0.56908
# Epoch 49/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1853 - acc: 0.9930 - val_loss: 0.5737 - val_acc: 0.8198
#
# Epoch 00049: val_loss did not improve from 0.56908
# Epoch 50/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1801 - acc: 0.9945 - val_loss: 0.5637 - val_acc: 0.8188
#
# Epoch 00050: val_loss improved from 0.56908 to 0.56367, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 51/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1767 - acc: 0.9942 - val_loss: 0.5676 - val_acc: 0.8223
#
# Epoch 00051: val_loss did not improve from 0.56367
# Epoch 52/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1712 - acc: 0.9949 - val_loss: 0.5626 - val_acc: 0.8228
#
# Epoch 00052: val_loss improved from 0.56367 to 0.56263, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 53/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1687 - acc: 0.9940 - val_loss: 0.5631 - val_acc: 0.8228
#
# Epoch 00053: val_loss did not improve from 0.56263
# Epoch 54/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1616 - acc: 0.9951 - val_loss: 0.5618 - val_acc: 0.8216
#
# Epoch 00054: val_loss improved from 0.56263 to 0.56184, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 55/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1589 - acc: 0.9956 - val_loss: 0.5696 - val_acc: 0.8198
#
# Epoch 00055: val_loss did not improve from 0.56184
# Epoch 56/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1560 - acc: 0.9953 - val_loss: 0.5637 - val_acc: 0.8171
#
# Epoch 00056: val_loss did not improve from 0.56184
# Epoch 57/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1518 - acc: 0.9960 - val_loss: 0.5628 - val_acc: 0.8195
#
# Epoch 00057: val_loss did not improve from 0.56184
# Epoch 58/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1481 - acc: 0.9957 - val_loss: 0.5506 - val_acc: 0.8183
#
# Epoch 00058: val_loss improved from 0.56184 to 0.55062, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 59/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1434 - acc: 0.9963 - val_loss: 0.5662 - val_acc: 0.8173
#
# Epoch 00059: val_loss did not improve from 0.55062
# Epoch 60/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1400 - acc: 0.9965 - val_loss: 0.5561 - val_acc: 0.8194
#
# Epoch 00060: val_loss did not improve from 0.55062
# Epoch 61/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1366 - acc: 0.9966 - val_loss: 0.5543 - val_acc: 0.8216
#
# Epoch 00061: val_loss did not improve from 0.55062
# Epoch 62/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1356 - acc: 0.9966 - val_loss: 0.5470 - val_acc: 0.8263
#
# Epoch 00062: val_loss improved from 0.55062 to 0.54702, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 63/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1304 - acc: 0.9968 - val_loss: 0.5585 - val_acc: 0.8195
#
# Epoch 00063: val_loss did not improve from 0.54702
# Epoch 64/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1275 - acc: 0.9973 - val_loss: 0.5448 - val_acc: 0.8223
#
# Epoch 00064: val_loss improved from 0.54702 to 0.54475, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 65/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1243 - acc: 0.9971 - val_loss: 0.5524 - val_acc: 0.8260
#
# Epoch 00065: val_loss did not improve from 0.54475
# Epoch 66/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1211 - acc: 0.9973 - val_loss: 0.5545 - val_acc: 0.8229
#
# Epoch 00066: val_loss did not improve from 0.54475
# Epoch 67/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1204 - acc: 0.9971 - val_loss: 0.5478 - val_acc: 0.8241
#
# Epoch 00067: val_loss did not improve from 0.54475
# Epoch 68/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1152 - acc: 0.9979 - val_loss: 0.5526 - val_acc: 0.8246
#
# Epoch 00068: val_loss did not improve from 0.54475
# Epoch 69/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1133 - acc: 0.9979 - val_loss: 0.5569 - val_acc: 0.8149
#
# Epoch 00069: val_loss did not improve from 0.54475
# Epoch 70/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1123 - acc: 0.9972 - val_loss: 0.5549 - val_acc: 0.8182
#
# Epoch 00070: val_loss did not improve from 0.54475
# Epoch 71/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1108 - acc: 0.9970 - val_loss: 0.5487 - val_acc: 0.8223
#
# Epoch 00071: val_loss did not improve from 0.54475
# Epoch 72/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1061 - acc: 0.9978 - val_loss: 0.5511 - val_acc: 0.8188
#
# Epoch 00072: val_loss did not improve from 0.54475
# Epoch 73/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1043 - acc: 0.9979 - val_loss: 0.5437 - val_acc: 0.8214
#
# Epoch 00073: val_loss improved from 0.54475 to 0.54374, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 74/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1002 - acc: 0.9981 - val_loss: 0.5451 - val_acc: 0.8190
#
# Epoch 00074: val_loss did not improve from 0.54374
# Epoch 75/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0992 - acc: 0.9977 - val_loss: 0.5553 - val_acc: 0.8138
#
# Epoch 00075: val_loss did not improve from 0.54374
# Epoch 76/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0967 - acc: 0.9978 - val_loss: 0.5474 - val_acc: 0.8142
#
# Epoch 00076: val_loss did not improve from 0.54374
# Epoch 77/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0948 - acc: 0.9978 - val_loss: 0.5508 - val_acc: 0.8240
#
# Epoch 00077: val_loss did not improve from 0.54374
# Epoch 78/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0924 - acc: 0.9985 - val_loss: 0.5449 - val_acc: 0.8164
#
# Epoch 00078: val_loss did not improve from 0.54374
# Epoch 79/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0893 - acc: 0.9987 - val_loss: 0.5506 - val_acc: 0.8148
#
# Epoch 00079: val_loss did not improve from 0.54374
# Epoch 80/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0887 - acc: 0.9981 - val_loss: 0.5457 - val_acc: 0.8220
#
# Epoch 00080: val_loss did not improve from 0.54374
# Epoch 81/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0853 - acc: 0.9990 - val_loss: 0.5399 - val_acc: 0.8185
#
# Epoch 00081: val_loss improved from 0.54374 to 0.53988, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 82/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0850 - acc: 0.9989 - val_loss: 0.5399 - val_acc: 0.8220
#
# Epoch 00082: val_loss improved from 0.53988 to 0.53986, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 83/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0841 - acc: 0.9987 - val_loss: 0.5419 - val_acc: 0.8171
#
# Epoch 00083: val_loss did not improve from 0.53986
# Epoch 84/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0836 - acc: 0.9992 - val_loss: 0.5416 - val_acc: 0.8157
#
# Epoch 00084: val_loss did not improve from 0.53986
# Epoch 85/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0831 - acc: 0.9987 - val_loss: 0.5407 - val_acc: 0.8172
#
# Epoch 00085: val_loss did not improve from 0.53986
# Epoch 86/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0825 - acc: 0.9987 - val_loss: 0.5405 - val_acc: 0.8189
#
# Epoch 00086: val_loss did not improve from 0.53986
# Epoch 87/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0834 - acc: 0.9988 - val_loss: 0.5420 - val_acc: 0.8235
#
# Epoch 00087: val_loss did not improve from 0.53986
# Epoch 88/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0819 - acc: 0.9990 - val_loss: 0.5403 - val_acc: 0.8209
#
# Epoch 00088: val_loss did not improve from 0.53986
# Epoch 89/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0825 - acc: 0.9983 - val_loss: 0.5420 - val_acc: 0.8160
#
# Epoch 00089: val_loss did not improve from 0.53986
# Epoch 90/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0823 - acc: 0.9990 - val_loss: 0.5427 - val_acc: 0.8211
#
# Epoch 00090: val_loss did not improve from 0.53986
# Epoch 91/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0829 - acc: 0.9988 - val_loss: 0.5441 - val_acc: 0.8176
#
# Epoch 00091: val_loss did not improve from 0.53986
# Epoch 92/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0821 - acc: 0.9989 - val_loss: 0.5432 - val_acc: 0.8216
#
# Epoch 00092: val_loss did not improve from 0.53986
# results per 0-fold
# 340/340 [==============================] - 1s 3ms/step - loss: 0.5432 - acc: 0.8216
# [[1408   44   62   87  203]
#  [  16 1147  143   47  136]
#  [  61   37 2182  123   75]
#  [  81  131   72 2390  147]
#  [  49  166  130  131 1810]]
#               precision    recall  f1-score   support
#
#           HC       0.87      0.78      0.82      1804
#          a_H       0.75      0.77      0.76      1489
#          a_K       0.84      0.88      0.86      2478
#          a_A       0.86      0.85      0.85      2821
#          a_C       0.76      0.79      0.78      2286
#
#     accuracy                           0.82     10878
#    macro avg       0.82      0.81      0.82     10878
# weighted avg       0.82      0.82      0.82     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 101, 128)          512
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 50, 256)           1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# HC (11644,)
# H (9971,)
# K (15293,)
# A (16092,)
# C (12268,)
# Epoch 1/600
# 1036/1036 [==============================] - 8s 6ms/step - loss: 1.6032 - acc: 0.3303 - val_loss: 1.2520 - val_acc: 0.5053
#
# Epoch 00001: val_loss improved from inf to 1.25200, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 2/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 1.2002 - acc: 0.5226 - val_loss: 1.1493 - val_acc: 0.5547
#
# Epoch 00002: val_loss improved from 1.25200 to 1.14929, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 3/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 1.0627 - acc: 0.6059 - val_loss: 1.0735 - val_acc: 0.6090
#
# Epoch 00003: val_loss improved from 1.14929 to 1.07349, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 4/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.9657 - acc: 0.6656 - val_loss: 1.0279 - val_acc: 0.6358
#
# Epoch 00004: val_loss improved from 1.07349 to 1.02787, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 5/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.8958 - acc: 0.7068 - val_loss: 0.9840 - val_acc: 0.6532
#
# Epoch 00005: val_loss improved from 1.02787 to 0.98398, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 6/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.8321 - acc: 0.7450 - val_loss: 0.9499 - val_acc: 0.6705
#
# Epoch 00006: val_loss improved from 0.98398 to 0.94986, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 7/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7826 - acc: 0.7748 - val_loss: 0.9281 - val_acc: 0.6945
#
# Epoch 00007: val_loss improved from 0.94986 to 0.92809, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 8/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7362 - acc: 0.8017 - val_loss: 0.9046 - val_acc: 0.7002
#
# Epoch 00008: val_loss improved from 0.92809 to 0.90462, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 9/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7057 - acc: 0.8170 - val_loss: 0.8731 - val_acc: 0.7169
#
# Epoch 00009: val_loss improved from 0.90462 to 0.87307, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 10/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6689 - acc: 0.8350 - val_loss: 0.8507 - val_acc: 0.7204
#
# Epoch 00010: val_loss improved from 0.87307 to 0.85068, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 11/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6343 - acc: 0.8541 - val_loss: 0.8359 - val_acc: 0.7353
#
# Epoch 00011: val_loss improved from 0.85068 to 0.83593, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 12/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6107 - acc: 0.8651 - val_loss: 0.8133 - val_acc: 0.7450
#
# Epoch 00012: val_loss improved from 0.83593 to 0.81331, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 13/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5776 - acc: 0.8824 - val_loss: 0.7941 - val_acc: 0.7466
#
# Epoch 00013: val_loss improved from 0.81331 to 0.79411, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 14/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5580 - acc: 0.8906 - val_loss: 0.7873 - val_acc: 0.7505
#
# Epoch 00014: val_loss improved from 0.79411 to 0.78728, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 15/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5353 - acc: 0.9025 - val_loss: 0.7731 - val_acc: 0.7592
#
# Epoch 00015: val_loss improved from 0.78728 to 0.77314, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 16/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5132 - acc: 0.9108 - val_loss: 0.7575 - val_acc: 0.7594
#
# Epoch 00016: val_loss improved from 0.77314 to 0.75751, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 17/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4945 - acc: 0.9188 - val_loss: 0.7486 - val_acc: 0.7681
#
# Epoch 00017: val_loss improved from 0.75751 to 0.74862, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 18/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4778 - acc: 0.9251 - val_loss: 0.7390 - val_acc: 0.7711
#
# Epoch 00018: val_loss improved from 0.74862 to 0.73897, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 19/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4560 - acc: 0.9347 - val_loss: 0.7275 - val_acc: 0.7716
#
# Epoch 00019: val_loss improved from 0.73897 to 0.72753, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 20/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4425 - acc: 0.9380 - val_loss: 0.7271 - val_acc: 0.7706
#
# Epoch 00020: val_loss improved from 0.72753 to 0.72712, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 21/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4262 - acc: 0.9443 - val_loss: 0.7115 - val_acc: 0.7765
#
# Epoch 00021: val_loss improved from 0.72712 to 0.71147, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 22/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4123 - acc: 0.9494 - val_loss: 0.6962 - val_acc: 0.7935
#
# Epoch 00022: val_loss improved from 0.71147 to 0.69623, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 23/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3969 - acc: 0.9530 - val_loss: 0.6908 - val_acc: 0.7954
#
# Epoch 00023: val_loss improved from 0.69623 to 0.69083, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 24/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3853 - acc: 0.9560 - val_loss: 0.6952 - val_acc: 0.7918
#
# Epoch 00024: val_loss did not improve from 0.69083
# Epoch 25/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3723 - acc: 0.9595 - val_loss: 0.6809 - val_acc: 0.7884
#
# Epoch 00025: val_loss improved from 0.69083 to 0.68089, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 26/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3591 - acc: 0.9632 - val_loss: 0.6734 - val_acc: 0.7927
#
# Epoch 00026: val_loss improved from 0.68089 to 0.67336, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 27/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3477 - acc: 0.9679 - val_loss: 0.6772 - val_acc: 0.7923
#
# Epoch 00027: val_loss did not improve from 0.67336
# Epoch 28/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3390 - acc: 0.9674 - val_loss: 0.6649 - val_acc: 0.7916
#
# Epoch 00028: val_loss improved from 0.67336 to 0.66493, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 29/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3269 - acc: 0.9707 - val_loss: 0.6622 - val_acc: 0.7904
#
# Epoch 00029: val_loss improved from 0.66493 to 0.66218, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 30/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3160 - acc: 0.9745 - val_loss: 0.6561 - val_acc: 0.8034
#
# Epoch 00030: val_loss improved from 0.66218 to 0.65610, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 31/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3086 - acc: 0.9754 - val_loss: 0.6516 - val_acc: 0.7983
#
# Epoch 00031: val_loss improved from 0.65610 to 0.65157, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 32/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2998 - acc: 0.9764 - val_loss: 0.6515 - val_acc: 0.7949
#
# Epoch 00032: val_loss improved from 0.65157 to 0.65145, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 33/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2894 - acc: 0.9792 - val_loss: 0.6540 - val_acc: 0.7922
#
# Epoch 00033: val_loss did not improve from 0.65145
# Epoch 34/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2800 - acc: 0.9813 - val_loss: 0.6456 - val_acc: 0.7975
#
# Epoch 00034: val_loss improved from 0.65145 to 0.64555, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 35/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2745 - acc: 0.9810 - val_loss: 0.6422 - val_acc: 0.7984
#
# Epoch 00035: val_loss improved from 0.64555 to 0.64217, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 36/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2638 - acc: 0.9844 - val_loss: 0.6291 - val_acc: 0.8013
#
# Epoch 00036: val_loss improved from 0.64217 to 0.62908, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 37/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2581 - acc: 0.9840 - val_loss: 0.6315 - val_acc: 0.8016
#
# Epoch 00037: val_loss did not improve from 0.62908
# Epoch 38/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2496 - acc: 0.9861 - val_loss: 0.6277 - val_acc: 0.8058
#
# Epoch 00038: val_loss improved from 0.62908 to 0.62766, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 39/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2435 - acc: 0.9865 - val_loss: 0.6228 - val_acc: 0.8110
#
# Epoch 00039: val_loss improved from 0.62766 to 0.62280, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 40/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2375 - acc: 0.9870 - val_loss: 0.6263 - val_acc: 0.8067
#
# Epoch 00040: val_loss did not improve from 0.62280
# Epoch 41/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2300 - acc: 0.9888 - val_loss: 0.6239 - val_acc: 0.8082
#
# Epoch 00041: val_loss did not improve from 0.62280
# Epoch 42/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2220 - acc: 0.9898 - val_loss: 0.6102 - val_acc: 0.8138
#
# Epoch 00042: val_loss improved from 0.62280 to 0.61017, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2182 - acc: 0.9898 - val_loss: 0.6076 - val_acc: 0.8105
#
# Epoch 00043: val_loss improved from 0.61017 to 0.60762, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 44/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2104 - acc: 0.9908 - val_loss: 0.6141 - val_acc: 0.8039
#
# Epoch 00044: val_loss did not improve from 0.60762
# Epoch 45/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2055 - acc: 0.9904 - val_loss: 0.6090 - val_acc: 0.8073
#
# Epoch 00045: val_loss did not improve from 0.60762
# Epoch 46/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2015 - acc: 0.9907 - val_loss: 0.6013 - val_acc: 0.8107
#
# Epoch 00046: val_loss improved from 0.60762 to 0.60128, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 47/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1981 - acc: 0.9905 - val_loss: 0.6024 - val_acc: 0.8135
#
# Epoch 00047: val_loss did not improve from 0.60128
# Epoch 48/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1893 - acc: 0.9932 - val_loss: 0.6055 - val_acc: 0.8086
#
# Epoch 00048: val_loss did not improve from 0.60128
# Epoch 49/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1867 - acc: 0.9922 - val_loss: 0.6101 - val_acc: 0.8090
#
# Epoch 00049: val_loss did not improve from 0.60128
# Epoch 50/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1814 - acc: 0.9931 - val_loss: 0.6139 - val_acc: 0.8035
#
# Epoch 00050: val_loss did not improve from 0.60128
# Epoch 51/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1753 - acc: 0.9930 - val_loss: 0.6000 - val_acc: 0.8118
#
# Epoch 00051: val_loss improved from 0.60128 to 0.59999, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 52/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1724 - acc: 0.9936 - val_loss: 0.6078 - val_acc: 0.8039
#
# Epoch 00052: val_loss did not improve from 0.59999
# Epoch 53/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1669 - acc: 0.9941 - val_loss: 0.6051 - val_acc: 0.8044
#
# Epoch 00053: val_loss did not improve from 0.59999
# Epoch 54/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1636 - acc: 0.9943 - val_loss: 0.6004 - val_acc: 0.8093
#
# Epoch 00054: val_loss did not improve from 0.59999
# Epoch 55/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1589 - acc: 0.9956 - val_loss: 0.5960 - val_acc: 0.8075
#
# Epoch 00055: val_loss improved from 0.59999 to 0.59601, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 56/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1541 - acc: 0.9956 - val_loss: 0.6011 - val_acc: 0.8064
#
# Epoch 00056: val_loss did not improve from 0.59601
# Epoch 57/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1499 - acc: 0.9960 - val_loss: 0.5944 - val_acc: 0.8088
#
# Epoch 00057: val_loss improved from 0.59601 to 0.59444, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 58/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1467 - acc: 0.9961 - val_loss: 0.5987 - val_acc: 0.8085
#
# Epoch 00058: val_loss did not improve from 0.59444
# Epoch 59/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1441 - acc: 0.9960 - val_loss: 0.6007 - val_acc: 0.8080
#
# Epoch 00059: val_loss did not improve from 0.59444
# Epoch 60/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1383 - acc: 0.9968 - val_loss: 0.6014 - val_acc: 0.8069
#
# Epoch 00060: val_loss did not improve from 0.59444
# Epoch 61/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1366 - acc: 0.9967 - val_loss: 0.5864 - val_acc: 0.8128
#
# Epoch 00061: val_loss improved from 0.59444 to 0.58638, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 62/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1332 - acc: 0.9967 - val_loss: 0.5944 - val_acc: 0.8069
#
# Epoch 00062: val_loss did not improve from 0.58638
# Epoch 63/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1315 - acc: 0.9966 - val_loss: 0.5939 - val_acc: 0.8102
#
# Epoch 00063: val_loss did not improve from 0.58638
# Epoch 64/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1281 - acc: 0.9970 - val_loss: 0.6002 - val_acc: 0.8033
#
# Epoch 00064: val_loss did not improve from 0.58638
# Epoch 65/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1243 - acc: 0.9970 - val_loss: 0.5854 - val_acc: 0.8093
#
# Epoch 00065: val_loss improved from 0.58638 to 0.58537, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 66/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1228 - acc: 0.9966 - val_loss: 0.5817 - val_acc: 0.8149
#
# Epoch 00066: val_loss improved from 0.58537 to 0.58170, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 67/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1193 - acc: 0.9969 - val_loss: 0.5936 - val_acc: 0.8068
#
# Epoch 00067: val_loss did not improve from 0.58170
# Epoch 68/600
# ...
# Epoch 21/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.4246 - acc: 0.9452 - val_loss: 0.6506 - val_acc: 0.8088
#
# Epoch 00021: val_loss improved from 0.66227 to 0.65056, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 22/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.4084 - acc: 0.9496 - val_loss: 0.6485 - val_acc: 0.8071
#
# Epoch 00022: val_loss improved from 0.65056 to 0.64849, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 23/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3937 - acc: 0.9565 - val_loss: 0.6323 - val_acc: 0.8082
#
# Epoch 00023: val_loss improved from 0.64849 to 0.63229, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 24/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3812 - acc: 0.9566 - val_loss: 0.6290 - val_acc: 0.8055
#
# Epoch 00024: val_loss improved from 0.63229 to 0.62897, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 25/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.3681 - acc: 0.9627 - val_loss: 0.6210 - val_acc: 0.8139
#
# Epoch 00025: val_loss improved from 0.62897 to 0.62100, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 26/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3570 - acc: 0.9656 - val_loss: 0.6133 - val_acc: 0.8106
#
# Epoch 00026: val_loss improved from 0.62100 to 0.61329, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 27/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3436 - acc: 0.9681 - val_loss: 0.6021 - val_acc: 0.8159
#
# Epoch 00027: val_loss improved from 0.61329 to 0.60208, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 28/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3336 - acc: 0.9707 - val_loss: 0.6045 - val_acc: 0.8196
#
# Epoch 00028: val_loss did not improve from 0.60208
# Epoch 29/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3215 - acc: 0.9745 - val_loss: 0.5968 - val_acc: 0.8242
#
# Epoch 00029: val_loss improved from 0.60208 to 0.59684, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 30/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3128 - acc: 0.9754 - val_loss: 0.5836 - val_acc: 0.8202
#
# Epoch 00030: val_loss improved from 0.59684 to 0.58359, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 31/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.3039 - acc: 0.9781 - val_loss: 0.5780 - val_acc: 0.8198
#
# Epoch 00031: val_loss improved from 0.58359 to 0.57801, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 32/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2943 - acc: 0.9789 - val_loss: 0.5683 - val_acc: 0.8300
#
# Epoch 00032: val_loss improved from 0.57801 to 0.56825, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 33/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2855 - acc: 0.9809 - val_loss: 0.5723 - val_acc: 0.8239
#
# Epoch 00033: val_loss did not improve from 0.56825
# Epoch 34/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2769 - acc: 0.9818 - val_loss: 0.5592 - val_acc: 0.8271
#
# Epoch 00034: val_loss improved from 0.56825 to 0.55915, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 35/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2692 - acc: 0.9836 - val_loss: 0.5586 - val_acc: 0.8309
#
# Epoch 00035: val_loss improved from 0.55915 to 0.55856, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 36/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2611 - acc: 0.9837 - val_loss: 0.5452 - val_acc: 0.8316
#
# Epoch 00036: val_loss improved from 0.55856 to 0.54524, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 37/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2539 - acc: 0.9849 - val_loss: 0.5447 - val_acc: 0.8342
#
# Epoch 00037: val_loss improved from 0.54524 to 0.54472, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 38/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2475 - acc: 0.9862 - val_loss: 0.5482 - val_acc: 0.8268
#
# Epoch 00038: val_loss did not improve from 0.54472
# Epoch 39/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2411 - acc: 0.9875 - val_loss: 0.5472 - val_acc: 0.8240
#
# Epoch 00039: val_loss did not improve from 0.54472
# Epoch 40/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2350 - acc: 0.9884 - val_loss: 0.5268 - val_acc: 0.8392
#
# Epoch 00040: val_loss improved from 0.54472 to 0.52683, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 41/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2270 - acc: 0.9897 - val_loss: 0.5364 - val_acc: 0.8286
#
# Epoch 00041: val_loss did not improve from 0.52683
# Epoch 42/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2210 - acc: 0.9894 - val_loss: 0.5250 - val_acc: 0.8369
#
# Epoch 00042: val_loss improved from 0.52683 to 0.52504, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2155 - acc: 0.9909 - val_loss: 0.5186 - val_acc: 0.8363
#
# Epoch 00043: val_loss improved from 0.52504 to 0.51857, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 44/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2096 - acc: 0.9912 - val_loss: 0.5176 - val_acc: 0.8388
#
# Epoch 00044: val_loss improved from 0.51857 to 0.51756, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 45/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.2044 - acc: 0.9913 - val_loss: 0.5129 - val_acc: 0.8418
#
# Epoch 00045: val_loss improved from 0.51756 to 0.51290, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 46/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1991 - acc: 0.9911 - val_loss: 0.5066 - val_acc: 0.8418
#
# Epoch 00046: val_loss improved from 0.51290 to 0.50657, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 47/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1968 - acc: 0.9911 - val_loss: 0.5080 - val_acc: 0.8400
#
# Epoch 00047: val_loss did not improve from 0.50657
# Epoch 48/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1864 - acc: 0.9935 - val_loss: 0.5127 - val_acc: 0.8338
#
# Epoch 00048: val_loss did not improve from 0.50657
# Epoch 49/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1823 - acc: 0.9943 - val_loss: 0.5157 - val_acc: 0.8311
#
# Epoch 00049: val_loss did not improve from 0.50657
# Epoch 50/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1794 - acc: 0.9932 - val_loss: 0.5063 - val_acc: 0.8431
#
# Epoch 00050: val_loss improved from 0.50657 to 0.50634, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 51/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1741 - acc: 0.9939 - val_loss: 0.4989 - val_acc: 0.8422
#
# Epoch 00051: val_loss improved from 0.50634 to 0.49893, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 52/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1696 - acc: 0.9944 - val_loss: 0.5041 - val_acc: 0.8367
#
# Epoch 00052: val_loss did not improve from 0.49893
# Epoch 53/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1659 - acc: 0.9953 - val_loss: 0.4898 - val_acc: 0.8493
#
# Epoch 00053: val_loss improved from 0.49893 to 0.48983, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 54/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1599 - acc: 0.9959 - val_loss: 0.5053 - val_acc: 0.8368
#
# Epoch 00054: val_loss did not improve from 0.48983
# Epoch 55/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1587 - acc: 0.9946 - val_loss: 0.4878 - val_acc: 0.8468
#
# Epoch 00055: val_loss improved from 0.48983 to 0.48781, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 56/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1537 - acc: 0.9956 - val_loss: 0.4955 - val_acc: 0.8326
#
# Epoch 00056: val_loss did not improve from 0.48781
# Epoch 57/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1497 - acc: 0.9955 - val_loss: 0.4865 - val_acc: 0.8432
#
# Epoch 00057: val_loss improved from 0.48781 to 0.48650, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 58/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1449 - acc: 0.9960 - val_loss: 0.4937 - val_acc: 0.8335
#
# Epoch 00058: val_loss did not improve from 0.48650
# Epoch 59/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1416 - acc: 0.9960 - val_loss: 0.4871 - val_acc: 0.8408
#
# Epoch 00059: val_loss did not improve from 0.48650
# Epoch 60/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1405 - acc: 0.9964 - val_loss: 0.4878 - val_acc: 0.8354
#
# Epoch 00060: val_loss did not improve from 0.48650
# Epoch 61/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1353 - acc: 0.9966 - val_loss: 0.4881 - val_acc: 0.8406
#
# Epoch 00061: val_loss did not improve from 0.48650
# Epoch 62/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1312 - acc: 0.9970 - val_loss: 0.4881 - val_acc: 0.8310
#
# Epoch 00062: val_loss did not improve from 0.48650
# Epoch 63/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1296 - acc: 0.9967 - val_loss: 0.4899 - val_acc: 0.8429
#
# Epoch 00063: val_loss did not improve from 0.48650
# Epoch 64/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1253 - acc: 0.9970 - val_loss: 0.4880 - val_acc: 0.8450
#
# Epoch 00064: val_loss did not improve from 0.48650
# Epoch 65/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1218 - acc: 0.9972 - val_loss: 0.4890 - val_acc: 0.8396
#
# Epoch 00065: val_loss did not improve from 0.48650
# Epoch 66/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1201 - acc: 0.9972 - val_loss: 0.4909 - val_acc: 0.8304
#
# Epoch 00066: val_loss did not improve from 0.48650
# Epoch 67/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1177 - acc: 0.9976 - val_loss: 0.4790 - val_acc: 0.8394
#
# Epoch 00067: val_loss improved from 0.48650 to 0.47902, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 68/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1147 - acc: 0.9971 - val_loss: 0.4821 - val_acc: 0.8413
#
# Epoch 00068: val_loss did not improve from 0.47902
# Epoch 69/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1121 - acc: 0.9973 - val_loss: 0.4754 - val_acc: 0.8448
#
# Epoch 00069: val_loss improved from 0.47902 to 0.47537, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 70/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1080 - acc: 0.9981 - val_loss: 0.4743 - val_acc: 0.8429
#
# Epoch 00070: val_loss improved from 0.47537 to 0.47430, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 71/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1066 - acc: 0.9983 - val_loss: 0.4749 - val_acc: 0.8472
#
# Epoch 00071: val_loss did not improve from 0.47430
# Epoch 72/600
# 1036/1036 [==============================] - 7s 7ms/step - loss: 0.1063 - acc: 0.9977 - val_loss: 0.4668 - val_acc: 0.8474
#
# Epoch 00072: val_loss improved from 0.47430 to 0.46676, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5
# Epoch 73/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.1026 - acc: 0.9975 - val_loss: 0.4695 - val_acc: 0.8469
#
# Epoch 00073: val_loss did not improve from 0.46676
# Epoch 74/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0992 - acc: 0.9983 - val_loss: 0.4713 - val_acc: 0.8475
#
# Epoch 00074: val_loss did not improve from 0.46676
# Epoch 75/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0973 - acc: 0.9977 - val_loss: 0.4726 - val_acc: 0.8415
#
# Epoch 00075: val_loss did not improve from 0.46676
# Epoch 76/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0941 - acc: 0.9984 - val_loss: 0.4706 - val_acc: 0.8463
#
# Epoch 00076: val_loss did not improve from 0.46676
# Epoch 77/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0938 - acc: 0.9980 - val_loss: 0.4795 - val_acc: 0.8393
#
# Epoch 00077: val_loss did not improve from 0.46676
# Epoch 78/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0908 - acc: 0.9983 - val_loss: 0.4813 - val_acc: 0.8479
#
# Epoch 00078: val_loss did not improve from 0.46676
# Epoch 79/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0880 - acc: 0.9986 - val_loss: 0.4824 - val_acc: 0.8462
#
# Epoch 00079: val_loss did not improve from 0.46676
# Epoch 80/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0865 - acc: 0.9981 - val_loss: 0.4796 - val_acc: 0.8398
#
# Epoch 00080: val_loss did not improve from 0.46676
# Epoch 81/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0842 - acc: 0.9989 - val_loss: 0.4735 - val_acc: 0.8416
#
# Epoch 00081: val_loss did not improve from 0.46676
# Epoch 82/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 0.0818 - acc: 0.9988 - val_loss: 0.4706 - val_acc: 0.8456
#
# Epoch 00082: val_loss did not improve from 0.46676
# results per 6-fold
# 340/340 [==============================] - 1s 3ms/step - loss: 0.4706 - acc: 0.8456
# [[1847   50   43  126  110]
#  [  48 1084   74  224  110]
#  [  11   74 2579   91   34]
#  [   0   93   78 2100  222]
#  [ 115   50   18  109 1588]]
#               precision    recall  f1-score   support
#
#           HC       0.91      0.85      0.88      2176
#          a_H       0.80      0.70      0.75      1540
#          a_K       0.92      0.92      0.92      2789
#          a_A       0.79      0.84      0.82      2493
#          a_C       0.77      0.84      0.81      1880
#
#     accuracy                           0.85     10878
#    macro avg       0.84      0.83      0.84     10878
# weighted avg       0.85      0.85      0.85     10878

# %%
# min_max normalizationする場合
import numpy as np

from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

mmscaler_LSTM.fit(test_COP_ML)
test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

# %%
test_x = np.concatenate([test_V[test_index], test_AP[test_index], test_ML[test_index], test_COP_AP[test_index], test_COP_ML[test_index]], axis=2)
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1502   55   88   11   98]
#  [  30  867  340   19  195]
#  [  10   90 2289   55   75]
#  [  92   77  234 2170  416]
#  [  36   85   78   66 1900]]
#               precision    recall  f1-score   support
#
#           HC    0.89940   0.85633   0.87734      1754
#          a_H    0.73850   0.59752   0.66057      1451
#          a_K    0.75569   0.90869   0.82516      2519
#          a_A    0.93494   0.72600   0.81733      2989
#          a_C    0.70790   0.87760   0.78367      2165
#
#     accuracy                        0.80235     10878
#    macro avg    0.80729   0.79323   0.79281     10878
# weighted avg    0.81631   0.80235   0.80121     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_19 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1506    0   25   59  164]
#  [  27  828  284  117  195]
#  [  29  101 2238   91   60]
#  [  31   58  125 2491  284]
#  [ 139   86  100  121 1719]]
#               precision    recall  f1-score   support
#
#           HC    0.86952   0.85861   0.86403      1754
#          a_H    0.77167   0.57064   0.65610      1451
#          a_K    0.80736   0.88845   0.84596      2519
#          a_A    0.86523   0.83339   0.84901      2989
#          a_C    0.70974   0.79400   0.74951      2165
#
#     accuracy                        0.80732     10878
#    macro avg    0.80470   0.78902   0.79292     10878
# weighted avg    0.80909   0.80732   0.80519     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_24 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_25 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# activation_27 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# activation_28 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_29 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1585    0   29   28  112]
#  [  21  905  333   35  157]
#  [  10  129 2308   19   53]
#  [ 125   91  122 2284  367]
#  [  76   93   84   57 1855]]
#               precision    recall  f1-score   support
#
#           HC    0.87232   0.90365   0.88771      1754
#          a_H    0.74302   0.62371   0.67816      1451
#          a_K    0.80250   0.91624   0.85561      2519
#          a_A    0.94263   0.76414   0.84405      2989
#          a_C    0.72917   0.85681   0.78785      2165
#
#     accuracy                        0.82157     10878
#    macro avg    0.81793   0.81291   0.81067     10878
# weighted avg    0.82973   0.82157   0.82045     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_30 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_31 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 128)               512
# _________________________________________________________________
# activation_33 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 64)                256
# _________________________________________________________________
# activation_34 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_35 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1530   17   29   74  104]
#  [  42  825  350   73  161]
#  [  37   91 2270   58   63]
#  [  64  114  129 2478  204]
#  [  89  139   96  100 1741]]
#               precision    recall  f1-score   support
#
#           HC    0.86833   0.87229   0.87031      1754
#          a_H    0.69562   0.56857   0.62571      1451
#          a_K    0.78984   0.90115   0.84183      2519
#          a_A    0.89041   0.82904   0.85863      2989
#          a_C    0.76595   0.80416   0.78459      2165
#
#     accuracy                        0.81302     10878
#    macro avg    0.80203   0.79504   0.79621     10878
# weighted avg    0.81281   0.81302   0.81082     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_37 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1537   25   47   20  125]
#  [  19  842  373   67  150]
#  [   9  101 2278   75   56]
#  [  34   81  197 2378  299]
#  [  90   97  100  160 1718]]
#               precision    recall  f1-score   support
#
#           HC    0.91001   0.87628   0.89283      1754
#          a_H    0.73473   0.58029   0.64844      1451
#          a_K    0.76060   0.90433   0.82626      2519
#          a_A    0.88074   0.79558   0.83600      2989
#          a_C    0.73169   0.79353   0.76136      2165
#
#     accuracy                        0.80465     10878
#    macro avg    0.80355   0.79000   0.79298     10878
# weighted avg    0.80850   0.80465   0.80303     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_42 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_43 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 128)               512
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 64)                256
# _________________________________________________________________
# activation_46 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_47 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1555   17   54   29   99]
#  [  31  965  326   22  107]
#  [  41  139 2244   39   56]
#  [  48  120   85 2469  267]
#  [  74  145   65  129 1752]]
#               precision    recall  f1-score   support
#
#           HC    0.88908   0.88655   0.88781      1754
#          a_H    0.69625   0.66506   0.68030      1451
#          a_K    0.80894   0.89083   0.84791      2519
#          a_A    0.91853   0.82603   0.86983      2989
#          a_C    0.76808   0.80924   0.78812      2165
#
#     accuracy                        0.82598     10878
#    macro avg    0.81618   0.81554   0.81479     10878
# weighted avg    0.82881   0.82598   0.82611     10878

# %%
# test 
model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/0fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/1fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/2fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/3fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/4fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/5fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3DGRF_2DCOP_1DCNN/6fold_test_3DGRF_2DCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_16 (Conv1D)           (None, 101, 128)          2048
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_48 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_49 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_50 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 128)               512
# _________________________________________________________________
# activation_51 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 64)                256
# _________________________________________________________________
# activation_52 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_53 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,784,089
# Trainable params: 1,782,415
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1550   26   17  100   61]
#  [  55  813  309   83  191]
#  [  18  104 2268   51   78]
#  [  16  102  107 2512  252]
#  [ 101   79   87  165 1733]]
#               precision    recall  f1-score   support
#
#           HC    0.89080   0.88369   0.88724      1754
#          a_H    0.72331   0.56030   0.63146      1451
#          a_K    0.81349   0.90036   0.85472      2519
#          a_A    0.86293   0.84041   0.85153      2989
#          a_C    0.74860   0.80046   0.77366      2165
#
#     accuracy                        0.81596     10878
#    macro avg    0.80783   0.79705   0.79972     10878
# weighted avg    0.81460   0.81596   0.81317     10878
