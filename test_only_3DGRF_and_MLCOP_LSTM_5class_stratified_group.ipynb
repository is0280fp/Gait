# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_only_3DGRF_and_MLCOP_LSTM_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# # Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# # StratifiedGroupKFoldの分割結果をpickle
import pickle

# test
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# trainig and validation
with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
   COP_ML = pickle.load(f)
f.close()

# label
with open("/content/drive/MyDrive/test_data/train_idx_list.pickle", mode="rb") as f:
   train_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   label = pickle.load(f)
f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    test_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    test_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()

# # trainig and validation
# with open("V_val_train.pickle", mode="rb") as f:
#    V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    COP_ML = pickle.load(f)
# f.close()

# # label
# with open("train_idx_list.pickle", mode="rb") as f:
#    train_index_list = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("label_val_train.pickle", mode="rb") as f:
#    label = pickle.load(f)
# f.close()

# with open("test_sub_ID.pickle", mode="rb") as f:
#    sub_ID=pickle.load(f)
# f.close()

# import pandas as pd

# with open("test_data_index.pickle", mode="rb") as f:
#    test_index = pickle.load(f)
# f.close()

# %%
import numpy as np
print(np.where(label==0)[0].shape)
print(np.where(label==1)[0].shape)
print(np.where(label==2)[0].shape)
print(np.where(label==3)[0].shape)
print(np.where(label==4)[0].shape)
# Out:
# (13756,)
# (11862,)
# (17630,)
# (18557,)
# (14341,)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(V)
V = mmscaler_LSTM.transform(V)
V = V.reshape(V.shape[0], V.shape[1], 1)

mmscaler_LSTM.fit(AP)
AP = mmscaler_LSTM.transform(AP)
AP = AP.reshape(AP.shape[0], AP.shape[1], 1)

mmscaler_LSTM.fit(ML)
ML = mmscaler_LSTM.transform(ML)
ML = ML.reshape(ML.shape[0], ML.shape[1], 1)

mmscaler_LSTM.fit(COP_AP)
COP_AP = mmscaler_LSTM.transform(COP_AP)
COP_AP = COP_AP.reshape(COP_AP.shape[0], COP_AP.shape[1], 1)

mmscaler_LSTM.fit(COP_ML)
COP_ML = mmscaler_LSTM.transform(COP_ML)
COP_ML = COP_ML.reshape(COP_ML.shape[0], COP_ML.shape[1], 1)

# %%
# !pip install keras-layer-normalization
# !pip install keras-self-attention
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=03a5d8892f3bb6c877e8de4eb9719e8633eb9a97fc5f040428d2d6b494a1c39e
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_LSTM_3DGRF_and_MLCOP_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )


def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

initializer = he_normal()

classes_main = 5

#LSTM-----------------------------------------------------------------------------------------------------------------------
def build_model():
  # LSTM
  # 最初これだけだった
  model = Sequential()
  model.add(InputLayer(input_shape=(101, 4)))

  model.add(Bidirectional(LSTM(512, return_sequences=True)))
  # model.add(LSTM(256, return_sequences=True))
  model.add(LayerNormalization())
  model.add(Activation('tanh'))
  model.add(Dropout(0.5))
  
  model.add(Flatten())

  model.add(Dense(512, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#------------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

EPOCHS = 500

val_label_list = []
train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(0, 7):
  train_index = train_index_list[i]
  train_LSTM_data = np.concatenate([V[train_index], AP[train_index], ML[train_index], COP_ML[train_index]], axis=2)
  val_index = val_index_list[i]
  val_LSTM_data = np.concatenate([V[val_index], AP[val_index], ML[val_index], COP_ML[val_index]], axis=2)
  
  # label
  train_label = label[train_index] 
  val_label= label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  MAX = len(train_LSTM_data)

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )

  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11952,)
# H (10373,)
# K (15152,)
# A (15736,)
# C (12055,)
# Epoch 1/400
# 1036/1036 [==============================] - 93s 59ms/step - loss: 1.6079 - acc: 0.3260 - val_loss: 1.3522 - val_acc: 0.4445
#
# Epoch 00001: val_loss improved from inf to 1.35223, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.3144 - acc: 0.4621 - val_loss: 1.2589 - val_acc: 0.5048
#
# Epoch 00002: val_loss improved from 1.35223 to 1.25895, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.1900 - acc: 0.5298 - val_loss: 1.1784 - val_acc: 0.5493
#
# Epoch 00003: val_loss improved from 1.25895 to 1.17838, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.0963 - acc: 0.5821 - val_loss: 1.1005 - val_acc: 0.5914
#
# Epoch 00004: val_loss improved from 1.17838 to 1.10050, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.0202 - acc: 0.6288 - val_loss: 1.0541 - val_acc: 0.6332
#
# Epoch 00005: val_loss improved from 1.10050 to 1.05406, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.9583 - acc: 0.6679 - val_loss: 1.0176 - val_acc: 0.6521
#
# Epoch 00006: val_loss improved from 1.05406 to 1.01758, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.8988 - acc: 0.7021 - val_loss: 0.9678 - val_acc: 0.6689
#
# Epoch 00007: val_loss improved from 1.01758 to 0.96778, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.8576 - acc: 0.7233 - val_loss: 0.9522 - val_acc: 0.6819
#
# Epoch 00008: val_loss improved from 0.96778 to 0.95222, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.8118 - acc: 0.7475 - val_loss: 0.9128 - val_acc: 0.7044
#
# Epoch 00009: val_loss improved from 0.95222 to 0.91285, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.7825 - acc: 0.7656 - val_loss: 0.8734 - val_acc: 0.7241
#
# Epoch 00010: val_loss improved from 0.91285 to 0.87337, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.7462 - acc: 0.7863 - val_loss: 0.8351 - val_acc: 0.7350
#
# Epoch 00011: val_loss improved from 0.87337 to 0.83513, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.7136 - acc: 0.8036 - val_loss: 0.8237 - val_acc: 0.7467
#
# Epoch 00012: val_loss improved from 0.83513 to 0.82368, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6821 - acc: 0.8208 - val_loss: 0.7904 - val_acc: 0.7554
#
# Epoch 00013: val_loss improved from 0.82368 to 0.79041, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6581 - acc: 0.8327 - val_loss: 0.7796 - val_acc: 0.7565
#
# Epoch 00014: val_loss improved from 0.79041 to 0.77963, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6334 - acc: 0.8424 - val_loss: 0.7578 - val_acc: 0.7555
#
# Epoch 00015: val_loss improved from 0.77963 to 0.75777, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6144 - acc: 0.8499 - val_loss: 0.7393 - val_acc: 0.7711
#
# Epoch 00016: val_loss improved from 0.75777 to 0.73934, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5871 - acc: 0.8637 - val_loss: 0.7342 - val_acc: 0.7708
#
# Epoch 00017: val_loss improved from 0.73934 to 0.73416, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5662 - acc: 0.8750 - val_loss: 0.7177 - val_acc: 0.7762
#
# Epoch 00018: val_loss improved from 0.73416 to 0.71774, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5470 - acc: 0.8824 - val_loss: 0.7082 - val_acc: 0.7793
#
# Epoch 00019: val_loss improved from 0.71774 to 0.70823, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5327 - acc: 0.8885 - val_loss: 0.6936 - val_acc: 0.7806
#
# Epoch 00020: val_loss improved from 0.70823 to 0.69362, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5109 - acc: 0.8991 - val_loss: 0.6775 - val_acc: 0.7811
#
# Epoch 00021: val_loss improved from 0.69362 to 0.67754, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4979 - acc: 0.9036 - val_loss: 0.6686 - val_acc: 0.7972
#
# Epoch 00022: val_loss improved from 0.67754 to 0.66855, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4809 - acc: 0.9104 - val_loss: 0.6604 - val_acc: 0.7886
#
# Epoch 00023: val_loss improved from 0.66855 to 0.66040, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4649 - acc: 0.9178 - val_loss: 0.6504 - val_acc: 0.7979
#
# Epoch 00024: val_loss improved from 0.66040 to 0.65045, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4549 - acc: 0.9216 - val_loss: 0.6375 - val_acc: 0.7975
#
# Epoch 00025: val_loss improved from 0.65045 to 0.63747, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4390 - acc: 0.9262 - val_loss: 0.6265 - val_acc: 0.7971
#
# Epoch 00026: val_loss improved from 0.63747 to 0.62648, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4234 - acc: 0.9318 - val_loss: 0.6176 - val_acc: 0.8069
#
# Epoch 00027: val_loss improved from 0.62648 to 0.61761, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4107 - acc: 0.9361 - val_loss: 0.6058 - val_acc: 0.8048
#
# Epoch 00028: val_loss improved from 0.61761 to 0.60579, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4003 - acc: 0.9401 - val_loss: 0.6051 - val_acc: 0.8129
#
# Epoch 00029: val_loss improved from 0.60579 to 0.60512, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3891 - acc: 0.9420 - val_loss: 0.5942 - val_acc: 0.8110
#
# Epoch 00030: val_loss improved from 0.60512 to 0.59415, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3768 - acc: 0.9479 - val_loss: 0.5973 - val_acc: 0.8094
#
# Epoch 00031: val_loss did not improve from 0.59415
# Epoch 32/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3680 - acc: 0.9496 - val_loss: 0.5850 - val_acc: 0.8158
#
# Epoch 00032: val_loss improved from 0.59415 to 0.58500, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3610 - acc: 0.9502 - val_loss: 0.5741 - val_acc: 0.8161
#
# Epoch 00033: val_loss improved from 0.58500 to 0.57414, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3491 - acc: 0.9556 - val_loss: 0.5764 - val_acc: 0.8204
#
# Epoch 00034: val_loss did not improve from 0.57414
# Epoch 35/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3374 - acc: 0.9597 - val_loss: 0.5628 - val_acc: 0.8174
#
# Epoch 00035: val_loss improved from 0.57414 to 0.56277, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3318 - acc: 0.9594 - val_loss: 0.5591 - val_acc: 0.8255
#
# Epoch 00036: val_loss improved from 0.56277 to 0.55910, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.3221 - acc: 0.9621 - val_loss: 0.5542 - val_acc: 0.8285
#
# Epoch 00037: val_loss improved from 0.55910 to 0.55416, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3117 - acc: 0.9668 - val_loss: 0.5380 - val_acc: 0.8279
#
# Epoch 00038: val_loss improved from 0.55416 to 0.53803, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3037 - acc: 0.9676 - val_loss: 0.5449 - val_acc: 0.8318
#
# Epoch 00039: val_loss did not improve from 0.53803
# Epoch 40/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2964 - acc: 0.9678 - val_loss: 0.5295 - val_acc: 0.8291
#
# Epoch 00040: val_loss improved from 0.53803 to 0.52951, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2867 - acc: 0.9717 - val_loss: 0.5319 - val_acc: 0.8345
#
# Epoch 00041: val_loss did not improve from 0.52951
# Epoch 42/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2838 - acc: 0.9714 - val_loss: 0.5275 - val_acc: 0.8370
#
# Epoch 00042: val_loss improved from 0.52951 to 0.52750, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2741 - acc: 0.9725 - val_loss: 0.5251 - val_acc: 0.8355
#
# Epoch 00043: val_loss improved from 0.52750 to 0.52511, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2707 - acc: 0.9724 - val_loss: 0.5196 - val_acc: 0.8371
#
# Epoch 00044: val_loss improved from 0.52511 to 0.51959, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 45/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2641 - acc: 0.9735 - val_loss: 0.5048 - val_acc: 0.8470
#
# Epoch 00045: val_loss improved from 0.51959 to 0.50476, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2585 - acc: 0.9757 - val_loss: 0.5183 - val_acc: 0.8340
#
# Epoch 00046: val_loss did not improve from 0.50476
# Epoch 47/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2498 - acc: 0.9775 - val_loss: 0.5181 - val_acc: 0.8340
#
# Epoch 00047: val_loss did not improve from 0.50476
# Epoch 48/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2426 - acc: 0.9786 - val_loss: 0.5146 - val_acc: 0.8430
#
# Epoch 00048: val_loss did not improve from 0.50476
# Epoch 49/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2402 - acc: 0.9789 - val_loss: 0.5042 - val_acc: 0.8407
#
# Epoch 00049: val_loss improved from 0.50476 to 0.50417, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.2340 - acc: 0.9798 - val_loss: 0.4924 - val_acc: 0.8493
#
# Epoch 00050: val_loss improved from 0.50417 to 0.49243, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 51/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2268 - acc: 0.9820 - val_loss: 0.4996 - val_acc: 0.8387
#
# Epoch 00051: val_loss did not improve from 0.49243
# Epoch 52/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.2225 - acc: 0.9825 - val_loss: 0.5024 - val_acc: 0.8331
#
# Epoch 00052: val_loss did not improve from 0.49243
# Epoch 53/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2139 - acc: 0.9831 - val_loss: 0.4985 - val_acc: 0.8455
#
# Epoch 00053: val_loss did not improve from 0.49243
# Epoch 54/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2109 - acc: 0.9835 - val_loss: 0.4936 - val_acc: 0.8449
#
# Epoch 00054: val_loss did not improve from 0.49243
# Epoch 55/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2061 - acc: 0.9842 - val_loss: 0.4911 - val_acc: 0.8423
#
# Epoch 00055: val_loss improved from 0.49243 to 0.49107, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 56/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2004 - acc: 0.9858 - val_loss: 0.4810 - val_acc: 0.8486
#
# Epoch 00056: val_loss improved from 0.49107 to 0.48099, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 57/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1952 - acc: 0.9864 - val_loss: 0.4838 - val_acc: 0.8507
#
# Epoch 00057: val_loss did not improve from 0.48099
# Epoch 58/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1938 - acc: 0.9863 - val_loss: 0.4809 - val_acc: 0.8423
#
# Epoch 00058: val_loss improved from 0.48099 to 0.48092, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 59/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1882 - acc: 0.9866 - val_loss: 0.4864 - val_acc: 0.8425
#
# Epoch 00059: val_loss did not improve from 0.48092
# Epoch 60/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1870 - acc: 0.9856 - val_loss: 0.4824 - val_acc: 0.8491
#
# Epoch 00060: val_loss did not improve from 0.48092
# Epoch 61/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1799 - acc: 0.9871 - val_loss: 0.4741 - val_acc: 0.8486
#
# Epoch 00061: val_loss improved from 0.48092 to 0.47410, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 62/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1766 - acc: 0.9876 - val_loss: 0.4845 - val_acc: 0.8423
#
# Epoch 00062: val_loss did not improve from 0.47410
# Epoch 63/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1715 - acc: 0.9887 - val_loss: 0.4731 - val_acc: 0.8458
#
# Epoch 00063: val_loss improved from 0.47410 to 0.47306, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 64/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1690 - acc: 0.9892 - val_loss: 0.4531 - val_acc: 0.8553
#
# Epoch 00064: val_loss improved from 0.47306 to 0.45314, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 65/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1641 - acc: 0.9898 - val_loss: 0.4726 - val_acc: 0.8508
#
# Epoch 00065: val_loss did not improve from 0.45314
# Epoch 66/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1605 - acc: 0.9901 - val_loss: 0.4602 - val_acc: 0.8557
#
# Epoch 00066: val_loss did not improve from 0.45314
# Epoch 67/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1566 - acc: 0.9912 - val_loss: 0.4688 - val_acc: 0.8501
#
# Epoch 00067: val_loss did not improve from 0.45314
# Epoch 68/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1549 - acc: 0.9905 - val_loss: 0.4686 - val_acc: 0.8452
#
# Epoch 00068: val_loss did not improve from 0.45314
# Epoch 69/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1495 - acc: 0.9915 - val_loss: 0.4672 - val_acc: 0.8503
#
# Epoch 00069: val_loss did not improve from 0.45314
# Epoch 70/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1468 - acc: 0.9918 - val_loss: 0.4631 - val_acc: 0.8543
#
# Epoch 00070: val_loss did not improve from 0.45314
# Epoch 71/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1435 - acc: 0.9919 - val_loss: 0.4409 - val_acc: 0.8554
#
# Epoch 00071: val_loss improved from 0.45314 to 0.44085, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 72/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1398 - acc: 0.9922 - val_loss: 0.4519 - val_acc: 0.8550
#
# Epoch 00072: val_loss did not improve from 0.44085
# Epoch 73/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1378 - acc: 0.9922 - val_loss: 0.4653 - val_acc: 0.8520
#
# Epoch 00073: val_loss did not improve from 0.44085
# Epoch 74/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1352 - acc: 0.9917 - val_loss: 0.4603 - val_acc: 0.8542
#
# Epoch 00074: val_loss did not improve from 0.44085
# Epoch 75/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1340 - acc: 0.9927 - val_loss: 0.4587 - val_acc: 0.8550
#
# Epoch 00075: val_loss did not improve from 0.44085
# Epoch 76/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1311 - acc: 0.9923 - val_loss: 0.4591 - val_acc: 0.8434
#
# Epoch 00076: val_loss did not improve from 0.44085
# Epoch 77/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1277 - acc: 0.9930 - val_loss: 0.4557 - val_acc: 0.8533
#
# Epoch 00077: val_loss did not improve from 0.44085
# Epoch 78/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1247 - acc: 0.9926 - val_loss: 0.4546 - val_acc: 0.8539
#
# Epoch 00078: val_loss did not improve from 0.44085
# Epoch 79/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1222 - acc: 0.9934 - val_loss: 0.4506 - val_acc: 0.8507
#
# Epoch 00079: val_loss did not improve from 0.44085
# Epoch 80/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1195 - acc: 0.9935 - val_loss: 0.4442 - val_acc: 0.8625
#
# Epoch 00080: val_loss did not improve from 0.44085
# Epoch 81/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1146 - acc: 0.9949 - val_loss: 0.4354 - val_acc: 0.8628
#
# Epoch 00081: val_loss improved from 0.44085 to 0.43539, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 82/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1132 - acc: 0.9945 - val_loss: 0.4375 - val_acc: 0.8671
#
# Epoch 00082: val_loss did not improve from 0.43539
# Epoch 83/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1109 - acc: 0.9955 - val_loss: 0.4390 - val_acc: 0.8616
#
# Epoch 00083: val_loss did not improve from 0.43539
# Epoch 84/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1107 - acc: 0.9951 - val_loss: 0.4353 - val_acc: 0.8645
#
# Epoch 00084: val_loss improved from 0.43539 to 0.43531, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 85/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1085 - acc: 0.9958 - val_loss: 0.4370 - val_acc: 0.8599
#
# Epoch 00085: val_loss did not improve from 0.43531
# Epoch 86/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1093 - acc: 0.9953 - val_loss: 0.4392 - val_acc: 0.8574
#
# Epoch 00086: val_loss did not improve from 0.43531
# Epoch 87/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1048 - acc: 0.9967 - val_loss: 0.4321 - val_acc: 0.8643
#
# Epoch 00087: val_loss improved from 0.43531 to 0.43212, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 88/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1075 - acc: 0.9964 - val_loss: 0.4365 - val_acc: 0.8632
#
# Epoch 00088: val_loss did not improve from 0.43212
# Epoch 89/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1066 - acc: 0.9964 - val_loss: 0.4331 - val_acc: 0.8614
#
# Epoch 00089: val_loss did not improve from 0.43212
# Epoch 90/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1054 - acc: 0.9965 - val_loss: 0.4331 - val_acc: 0.8592
#
# Epoch 00090: val_loss did not improve from 0.43212
# Epoch 91/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1058 - acc: 0.9960 - val_loss: 0.4339 - val_acc: 0.8623
#
# Epoch 00091: val_loss did not improve from 0.43212
# Epoch 92/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1046 - acc: 0.9964 - val_loss: 0.4351 - val_acc: 0.8586
#
# Epoch 00092: val_loss did not improve from 0.43212
# Epoch 93/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1049 - acc: 0.9964 - val_loss: 0.4347 - val_acc: 0.8592
#
# Epoch 00093: val_loss did not improve from 0.43212
# Epoch 94/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1046 - acc: 0.9960 - val_loss: 0.4315 - val_acc: 0.8632
#
# Epoch 00094: val_loss improved from 0.43212 to 0.43150, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 95/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1056 - acc: 0.9961 - val_loss: 0.4353 - val_acc: 0.8574
#
# Epoch 00095: val_loss did not improve from 0.43150
# Epoch 96/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1053 - acc: 0.9968 - val_loss: 0.4351 - val_acc: 0.8610
#
# Epoch 00096: val_loss did not improve from 0.43150
# Epoch 97/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1046 - acc: 0.9963 - val_loss: 0.4327 - val_acc: 0.8599
#
# Epoch 00097: val_loss did not improve from 0.43150
# Epoch 98/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1048 - acc: 0.9962 - val_loss: 0.4342 - val_acc: 0.8580
#
# Epoch 00098: val_loss did not improve from 0.43150
# Epoch 99/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1032 - acc: 0.9964 - val_loss: 0.4356 - val_acc: 0.8605
#
# Epoch 00099: val_loss did not improve from 0.43150
# Epoch 100/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1024 - acc: 0.9968 - val_loss: 0.4406 - val_acc: 0.8619
#
# Epoch 00100: val_loss did not improve from 0.43150
# Epoch 101/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1041 - acc: 0.9963 - val_loss: 0.4363 - val_acc: 0.8616
#
# Epoch 00101: val_loss did not improve from 0.43150
# Epoch 102/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1012 - acc: 0.9972 - val_loss: 0.4343 - val_acc: 0.8611
#
# Epoch 00102: val_loss did not improve from 0.43150
# Epoch 103/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1001 - acc: 0.9968 - val_loss: 0.4349 - val_acc: 0.8657
#
# Epoch 00103: val_loss did not improve from 0.43150
# Epoch 104/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1018 - acc: 0.9966 - val_loss: 0.4365 - val_acc: 0.8598
#
# Epoch 00104: val_loss did not improve from 0.43150
# results per 0-fold
# 340/340 [==============================] - 5s 13ms/step - loss: 0.4365 - acc: 0.8598
# [[1573   30   51   61   89]
#  [  17 1242  116   30   84]
#  [  17   60 1988  222  191]
#  [   3   76  126 2514  102]
#  [   0   82   37  131 2036]]
#               precision    recall  f1-score   support
#
#           HC       0.98      0.87      0.92      1804
#          a_H       0.83      0.83      0.83      1489
#          a_K       0.86      0.80      0.83      2478
#          a_A       0.85      0.89      0.87      2821
#          a_C       0.81      0.89      0.85      2286
#
#     accuracy                           0.86     10878
#    macro avg       0.87      0.86      0.86     10878
# weighted avg       0.86      0.86      0.86     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11644,)
# H (9971,)
# K (15293,)
# A (16092,)
# C (12268,)
# Epoch 1/400
# 1036/1036 [==============================] - 65s 60ms/step - loss: 1.6159 - acc: 0.3231 - val_loss: 1.3778 - val_acc: 0.4231
#
# Epoch 00001: val_loss improved from inf to 1.37777, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.3146 - acc: 0.4587 - val_loss: 1.2569 - val_acc: 0.5076
#
# Epoch 00002: val_loss improved from 1.37777 to 1.25690, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 1.1854 - acc: 0.5327 - val_loss: 1.1706 - val_acc: 0.5536
#
# Epoch 00003: val_loss improved from 1.25690 to 1.17064, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.0873 - acc: 0.5903 - val_loss: 1.1268 - val_acc: 0.5741
#
# Epoch 00004: val_loss improved from 1.17064 to 1.12679, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 1.0074 - acc: 0.6412 - val_loss: 1.0587 - val_acc: 0.6226
#
# Epoch 00005: val_loss improved from 1.12679 to 1.05869, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.9510 - acc: 0.6714 - val_loss: 1.0221 - val_acc: 0.6305
#
# Epoch 00006: val_loss improved from 1.05869 to 1.02214, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 62s 60ms/step - loss: 0.8966 - acc: 0.7066 - val_loss: 0.9748 - val_acc: 0.6666
#
# Epoch 00007: val_loss improved from 1.02214 to 0.97480, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.8489 - acc: 0.7311 - val_loss: 0.9465 - val_acc: 0.6758
#
# Epoch 00008: val_loss improved from 0.97480 to 0.94651, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.8106 - acc: 0.7518 - val_loss: 0.9275 - val_acc: 0.6895
#
# Epoch 00009: val_loss improved from 0.94651 to 0.92749, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.7719 - acc: 0.7724 - val_loss: 0.8913 - val_acc: 0.7006
#
# Epoch 00010: val_loss improved from 0.92749 to 0.89135, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.7405 - acc: 0.7899 - val_loss: 0.8766 - val_acc: 0.7113
#
# Epoch 00011: val_loss improved from 0.89135 to 0.87658, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.7117 - acc: 0.8069 - val_loss: 0.8488 - val_acc: 0.7319
#
# Epoch 00012: val_loss improved from 0.87658 to 0.84884, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6743 - acc: 0.8261 - val_loss: 0.8255 - val_acc: 0.7381
#
# Epoch 00013: val_loss improved from 0.84884 to 0.82550, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.6524 - acc: 0.8363 - val_loss: 0.8053 - val_acc: 0.7434
#
# Epoch 00014: val_loss improved from 0.82550 to 0.80528, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6233 - acc: 0.8523 - val_loss: 0.8036 - val_acc: 0.7347
#
# Epoch 00015: val_loss improved from 0.80528 to 0.80357, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.6032 - acc: 0.8601 - val_loss: 0.7647 - val_acc: 0.7657
#
# Epoch 00016: val_loss improved from 0.80357 to 0.76466, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5801 - acc: 0.8738 - val_loss: 0.7635 - val_acc: 0.7663
#
# Epoch 00017: val_loss improved from 0.76466 to 0.76349, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5627 - acc: 0.8805 - val_loss: 0.7443 - val_acc: 0.7663
#
# Epoch 00018: val_loss improved from 0.76349 to 0.74426, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5429 - acc: 0.8884 - val_loss: 0.7443 - val_acc: 0.7696
#
# Epoch 00019: val_loss did not improve from 0.74426
# Epoch 20/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5283 - acc: 0.8947 - val_loss: 0.7348 - val_acc: 0.7648
#
# Epoch 00020: val_loss improved from 0.74426 to 0.73480, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.5094 - acc: 0.9007 - val_loss: 0.7114 - val_acc: 0.7801
#
# Epoch 00021: val_loss improved from 0.73480 to 0.71145, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4905 - acc: 0.9109 - val_loss: 0.7079 - val_acc: 0.7814
#
# Epoch 00022: val_loss improved from 0.71145 to 0.70786, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4785 - acc: 0.9148 - val_loss: 0.6827 - val_acc: 0.7934
#
# Epoch 00023: val_loss improved from 0.70786 to 0.68272, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4635 - acc: 0.9195 - val_loss: 0.6817 - val_acc: 0.7957
#
# Epoch 00024: val_loss improved from 0.68272 to 0.68171, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4468 - acc: 0.9255 - val_loss: 0.6649 - val_acc: 0.7978
#
# Epoch 00025: val_loss improved from 0.68171 to 0.66492, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4329 - acc: 0.9325 - val_loss: 0.6724 - val_acc: 0.7937
#
# Epoch 00026: val_loss did not improve from 0.66492
# Epoch 27/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4251 - acc: 0.9329 - val_loss: 0.6467 - val_acc: 0.7932
#
# Epoch 00027: val_loss improved from 0.66492 to 0.64669, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.4125 - acc: 0.9385 - val_loss: 0.6457 - val_acc: 0.7987
#
# Epoch 00028: val_loss improved from 0.64669 to 0.64573, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3971 - acc: 0.9433 - val_loss: 0.6333 - val_acc: 0.7991
#
# Epoch 00029: val_loss improved from 0.64573 to 0.63331, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3859 - acc: 0.9462 - val_loss: 0.6296 - val_acc: 0.8013
#
# Epoch 00030: val_loss improved from 0.63331 to 0.62955, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3749 - acc: 0.9495 - val_loss: 0.6234 - val_acc: 0.8179
#
# Epoch 00031: val_loss improved from 0.62955 to 0.62343, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3641 - acc: 0.9544 - val_loss: 0.6172 - val_acc: 0.8144
#
# Epoch 00032: val_loss improved from 0.62343 to 0.61719, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3557 - acc: 0.9540 - val_loss: 0.6064 - val_acc: 0.8092
#
# Epoch 00033: val_loss improved from 0.61719 to 0.60639, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3441 - acc: 0.9574 - val_loss: 0.6066 - val_acc: 0.8131
#
# Epoch 00034: val_loss did not improve from 0.60639
# Epoch 35/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3367 - acc: 0.9583 - val_loss: 0.6015 - val_acc: 0.8168
#
# Epoch 00035: val_loss improved from 0.60639 to 0.60155, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3244 - acc: 0.9627 - val_loss: 0.5937 - val_acc: 0.8212
#
# Epoch 00036: val_loss improved from 0.60155 to 0.59368, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.3185 - acc: 0.9645 - val_loss: 0.5924 - val_acc: 0.8155
#
# Epoch 00037: val_loss improved from 0.59368 to 0.59243, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3093 - acc: 0.9664 - val_loss: 0.5850 - val_acc: 0.8140
#
# Epoch 00038: val_loss improved from 0.59243 to 0.58499, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.3040 - acc: 0.9668 - val_loss: 0.5804 - val_acc: 0.8197
#
# Epoch 00039: val_loss improved from 0.58499 to 0.58036, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2933 - acc: 0.9701 - val_loss: 0.5720 - val_acc: 0.8168
#
# Epoch 00040: val_loss improved from 0.58036 to 0.57198, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2864 - acc: 0.9705 - val_loss: 0.5673 - val_acc: 0.8247
#
# Epoch 00041: val_loss improved from 0.57198 to 0.56729, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2815 - acc: 0.9708 - val_loss: 0.5701 - val_acc: 0.8230
#
# Epoch 00042: val_loss did not improve from 0.56729
# Epoch 43/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2733 - acc: 0.9743 - val_loss: 0.5650 - val_acc: 0.8217
#
# Epoch 00043: val_loss improved from 0.56729 to 0.56499, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2665 - acc: 0.9752 - val_loss: 0.5725 - val_acc: 0.8151
#
# Epoch 00044: val_loss did not improve from 0.56499
# Epoch 45/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2592 - acc: 0.9764 - val_loss: 0.5585 - val_acc: 0.8220
#
# Epoch 00045: val_loss improved from 0.56499 to 0.55851, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2542 - acc: 0.9773 - val_loss: 0.5550 - val_acc: 0.8201
#
# Epoch 00046: val_loss improved from 0.55851 to 0.55503, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2450 - acc: 0.9802 - val_loss: 0.5499 - val_acc: 0.8200
#
# Epoch 00047: val_loss improved from 0.55503 to 0.54986, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 48/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2405 - acc: 0.9794 - val_loss: 0.5423 - val_acc: 0.8325
#
# Epoch 00048: val_loss improved from 0.54986 to 0.54226, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.2357 - acc: 0.9812 - val_loss: 0.5488 - val_acc: 0.8268
#
# Epoch 00049: val_loss did not improve from 0.54226
# Epoch 50/400
# ...
# Epoch 79/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1206 - acc: 0.9935 - val_loss: 0.4785 - val_acc: 0.8480
#
# Epoch 00079: val_loss improved from 0.48084 to 0.47848, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 80/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1179 - acc: 0.9938 - val_loss: 0.4997 - val_acc: 0.8358
#
# Epoch 00080: val_loss did not improve from 0.47848
# Epoch 81/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1150 - acc: 0.9940 - val_loss: 0.4727 - val_acc: 0.8523
#
# Epoch 00081: val_loss improved from 0.47848 to 0.47268, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 82/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1098 - acc: 0.9952 - val_loss: 0.4747 - val_acc: 0.8502
#
# Epoch 00082: val_loss did not improve from 0.47268
# Epoch 83/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1092 - acc: 0.9951 - val_loss: 0.4715 - val_acc: 0.8485
#
# Epoch 00083: val_loss improved from 0.47268 to 0.47146, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 84/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1077 - acc: 0.9961 - val_loss: 0.4726 - val_acc: 0.8513
#
# Epoch 00084: val_loss did not improve from 0.47146
# Epoch 85/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1067 - acc: 0.9961 - val_loss: 0.4715 - val_acc: 0.8517
#
# Epoch 00085: val_loss improved from 0.47146 to 0.47146, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 86/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1050 - acc: 0.9965 - val_loss: 0.4699 - val_acc: 0.8525
#
# Epoch 00086: val_loss improved from 0.47146 to 0.46991, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 87/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1045 - acc: 0.9967 - val_loss: 0.4685 - val_acc: 0.8522
#
# Epoch 00087: val_loss improved from 0.46991 to 0.46851, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 88/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1045 - acc: 0.9964 - val_loss: 0.4753 - val_acc: 0.8488
#
# Epoch 00088: val_loss did not improve from 0.46851
# Epoch 89/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1042 - acc: 0.9967 - val_loss: 0.4702 - val_acc: 0.8518
#
# Epoch 00089: val_loss did not improve from 0.46851
# Epoch 90/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1044 - acc: 0.9966 - val_loss: 0.4725 - val_acc: 0.8517
#
# Epoch 00090: val_loss did not improve from 0.46851
# Epoch 91/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1038 - acc: 0.9960 - val_loss: 0.4710 - val_acc: 0.8529
#
# Epoch 00091: val_loss did not improve from 0.46851
# Epoch 92/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1040 - acc: 0.9963 - val_loss: 0.4718 - val_acc: 0.8536
#
# Epoch 00092: val_loss did not improve from 0.46851
# Epoch 93/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 0.1020 - acc: 0.9972 - val_loss: 0.4743 - val_acc: 0.8542
#
# Epoch 00093: val_loss did not improve from 0.46851
# Epoch 94/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1031 - acc: 0.9964 - val_loss: 0.4756 - val_acc: 0.8485
#
# Epoch 00094: val_loss did not improve from 0.46851
# Epoch 95/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.1032 - acc: 0.9960 - val_loss: 0.4772 - val_acc: 0.8531
#
# Epoch 00095: val_loss did not improve from 0.46851
# Epoch 96/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1022 - acc: 0.9969 - val_loss: 0.4732 - val_acc: 0.8511
#
# Epoch 00096: val_loss did not improve from 0.46851
# Epoch 97/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.1025 - acc: 0.9967 - val_loss: 0.4755 - val_acc: 0.8484
#
# Epoch 00097: val_loss did not improve from 0.46851
# results per 5-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4755 - acc: 0.8484
# [[2040    0   40   98   82]
#  [  18 1438  143  131  100]
#  [  32   15 2078  182   99]
#  [  19   25   80 2387   88]
#  [ 114  105   62  216 1286]]
#               precision    recall  f1-score   support
#
#           HC       0.92      0.90      0.91      2260
#          a_H       0.91      0.79      0.84      1830
#          a_K       0.86      0.86      0.86      2406
#          a_A       0.79      0.92      0.85      2599
#          a_C       0.78      0.72      0.75      1783
#
#     accuracy                           0.85     10878
#    macro avg       0.85      0.84      0.84     10878
# weighted avg       0.85      0.85      0.85     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11580,)
# H (10322,)
# K (14841,)
# A (16064,)
# C (12461,)
# Epoch 1/400
# 1036/1036 [==============================] - 64s 59ms/step - loss: 1.5854 - acc: 0.3251 - val_loss: 1.3847 - val_acc: 0.4040
#
# Epoch 00001: val_loss improved from inf to 1.38466, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 1.3033 - acc: 0.4684 - val_loss: 1.2738 - val_acc: 0.4846
#
# Epoch 00002: val_loss improved from 1.38466 to 1.27377, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 1.1842 - acc: 0.5371 - val_loss: 1.1988 - val_acc: 0.5387
#
# Epoch 00003: val_loss improved from 1.27377 to 1.19880, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 1.0889 - acc: 0.5926 - val_loss: 1.1320 - val_acc: 0.5522
#
# Epoch 00004: val_loss improved from 1.19880 to 1.13204, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 60s 58ms/step - loss: 1.0158 - acc: 0.6353 - val_loss: 1.0599 - val_acc: 0.6008
#
# Epoch 00005: val_loss improved from 1.13204 to 1.05988, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.9512 - acc: 0.6717 - val_loss: 1.0125 - val_acc: 0.6229
#
# Epoch 00006: val_loss improved from 1.05988 to 1.01248, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.9036 - acc: 0.6986 - val_loss: 0.9692 - val_acc: 0.6595
#
# Epoch 00007: val_loss improved from 1.01248 to 0.96916, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.8549 - acc: 0.7296 - val_loss: 0.9293 - val_acc: 0.6661
#
# Epoch 00008: val_loss improved from 0.96916 to 0.92929, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.8144 - acc: 0.7535 - val_loss: 0.8874 - val_acc: 0.6945
#
# Epoch 00009: val_loss improved from 0.92929 to 0.88744, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.7795 - acc: 0.7696 - val_loss: 0.8543 - val_acc: 0.7212
#
# Epoch 00010: val_loss improved from 0.88744 to 0.85428, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.7438 - acc: 0.7906 - val_loss: 0.8216 - val_acc: 0.7374
#
# Epoch 00011: val_loss improved from 0.85428 to 0.82159, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.7171 - acc: 0.8024 - val_loss: 0.7998 - val_acc: 0.7463
#
# Epoch 00012: val_loss improved from 0.82159 to 0.79978, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.6861 - acc: 0.8169 - val_loss: 0.7735 - val_acc: 0.7554
#
# Epoch 00013: val_loss improved from 0.79978 to 0.77352, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.6552 - acc: 0.8343 - val_loss: 0.7547 - val_acc: 0.7642
#
# Epoch 00014: val_loss improved from 0.77352 to 0.75472, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.6319 - acc: 0.8492 - val_loss: 0.7277 - val_acc: 0.7738
#
# Epoch 00015: val_loss improved from 0.75472 to 0.72768, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.6089 - acc: 0.8573 - val_loss: 0.7120 - val_acc: 0.7761
#
# Epoch 00016: val_loss improved from 0.72768 to 0.71204, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.5845 - acc: 0.8663 - val_loss: 0.6873 - val_acc: 0.7809
#
# Epoch 00017: val_loss improved from 0.71204 to 0.68734, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.5667 - acc: 0.8772 - val_loss: 0.6848 - val_acc: 0.7889
#
# Epoch 00018: val_loss improved from 0.68734 to 0.68476, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 61s 58ms/step - loss: 0.5448 - acc: 0.8880 - val_loss: 0.6478 - val_acc: 0.8059
#
# Epoch 00019: val_loss improved from 0.68476 to 0.64784, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.5284 - acc: 0.8922 - val_loss: 0.6419 - val_acc: 0.8024
#
# Epoch 00020: val_loss improved from 0.64784 to 0.64194, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.5117 - acc: 0.9009 - val_loss: 0.6288 - val_acc: 0.8084
#
# Epoch 00021: val_loss improved from 0.64194 to 0.62881, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4921 - acc: 0.9086 - val_loss: 0.6095 - val_acc: 0.8120
#
# Epoch 00022: val_loss improved from 0.62881 to 0.60952, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4744 - acc: 0.9164 - val_loss: 0.5961 - val_acc: 0.8215
#
# Epoch 00023: val_loss improved from 0.60952 to 0.59614, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 61s 59ms/step - loss: 0.4645 - acc: 0.9184 - val_loss: 0.5922 - val_acc: 0.8205
#
# Epoch 00024: val_loss improved from 0.59614 to 0.59222, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 25/400
#  941/1036 [==========================>...] - ETA: 5s - loss: 0.4496 - acc: 0.9223

# %%
#  続き
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 56 == 0) and (epoch != 0) and (epoch % 136 == 0):
      lr = lr * 0.1
  return lr

i = 6
print("HC", np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H", np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K", np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A", np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C", np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

# checkpointの設定
checkpoint = ModelCheckpoint(
                  filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(
    loss= "categorical_crossentropy",
    # loss = custom_cross_entropy,
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc'],
    # class_weight=class_weight
          )

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

# i = i + 1



# plt.plot(result.history['acc'])
# plt.plot(result.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# plt.plot(result.history['loss'])
# plt.plot(result.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# now = datetime.datetime.now()
# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# HC (11580,)
# H (10322,)
# K (14841,)
# A (16064,)
# C (12461,)
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# Epoch 1/400
# 1036/1036 [==============================] - 103s 67ms/step - loss: 0.4342 - acc: 0.9287 - val_loss: 0.5629 - val_acc: 0.8399
#
# Epoch 00001: val_loss improved from inf to 0.56288, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4226 - acc: 0.9345 - val_loss: 0.5593 - val_acc: 0.8352
#
# Epoch 00002: val_loss improved from 0.56288 to 0.55935, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.4116 - acc: 0.9366 - val_loss: 0.5416 - val_acc: 0.8339
#
# Epoch 00003: val_loss improved from 0.55935 to 0.54158, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3976 - acc: 0.9431 - val_loss: 0.5415 - val_acc: 0.8425
#
# Epoch 00004: val_loss improved from 0.54158 to 0.54152, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3851 - acc: 0.9461 - val_loss: 0.5376 - val_acc: 0.8427
#
# Epoch 00005: val_loss improved from 0.54152 to 0.53761, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3750 - acc: 0.9504 - val_loss: 0.5252 - val_acc: 0.8415
#
# Epoch 00006: val_loss improved from 0.53761 to 0.52517, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3677 - acc: 0.9500 - val_loss: 0.5164 - val_acc: 0.8462
#
# Epoch 00007: val_loss improved from 0.52517 to 0.51635, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3582 - acc: 0.9540 - val_loss: 0.5109 - val_acc: 0.8469
#
# Epoch 00008: val_loss improved from 0.51635 to 0.51090, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3426 - acc: 0.9577 - val_loss: 0.5047 - val_acc: 0.8501
#
# Epoch 00009: val_loss improved from 0.51090 to 0.50474, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3342 - acc: 0.9603 - val_loss: 0.5034 - val_acc: 0.8473
#
# Epoch 00010: val_loss improved from 0.50474 to 0.50343, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3289 - acc: 0.9610 - val_loss: 0.4980 - val_acc: 0.8520
#
# Epoch 00011: val_loss improved from 0.50343 to 0.49795, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3178 - acc: 0.9642 - val_loss: 0.4875 - val_acc: 0.8554
#
# Epoch 00012: val_loss improved from 0.49795 to 0.48751, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3100 - acc: 0.9651 - val_loss: 0.4767 - val_acc: 0.8551
#
# Epoch 00013: val_loss improved from 0.48751 to 0.47673, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3011 - acc: 0.9680 - val_loss: 0.4749 - val_acc: 0.8593
#
# Epoch 00014: val_loss improved from 0.47673 to 0.47486, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.2934 - acc: 0.9699 - val_loss: 0.4786 - val_acc: 0.8501
#
# Epoch 00015: val_loss did not improve from 0.47486
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.2864 - acc: 0.9708 - val_loss: 0.4749 - val_acc: 0.8554
#
# Epoch 00016: val_loss improved from 0.47486 to 0.47486, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2785 - acc: 0.9724 - val_loss: 0.4728 - val_acc: 0.8471
#
# Epoch 00017: val_loss improved from 0.47486 to 0.47280, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2724 - acc: 0.9739 - val_loss: 0.4704 - val_acc: 0.8575
#
# Epoch 00018: val_loss improved from 0.47280 to 0.47041, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2648 - acc: 0.9767 - val_loss: 0.4536 - val_acc: 0.8619
#
# Epoch 00019: val_loss improved from 0.47041 to 0.45364, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2580 - acc: 0.9763 - val_loss: 0.4537 - val_acc: 0.8594
#
# Epoch 00020: val_loss did not improve from 0.45364
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2497 - acc: 0.9802 - val_loss: 0.4480 - val_acc: 0.8663
#
# Epoch 00021: val_loss improved from 0.45364 to 0.44801, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.2462 - acc: 0.9796 - val_loss: 0.4599 - val_acc: 0.8573
#
# Epoch 00022: val_loss did not improve from 0.44801
# Epoch 23/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.2424 - acc: 0.9790 - val_loss: 0.4429 - val_acc: 0.8673
#
# Epoch 00023: val_loss improved from 0.44801 to 0.44286, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2343 - acc: 0.9813 - val_loss: 0.4448 - val_acc: 0.8666
#
# Epoch 00024: val_loss did not improve from 0.44286
# Epoch 25/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2276 - acc: 0.9821 - val_loss: 0.4423 - val_acc: 0.8650
#
# Epoch 00025: val_loss improved from 0.44286 to 0.44234, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2235 - acc: 0.9829 - val_loss: 0.4325 - val_acc: 0.8681
#
# Epoch 00026: val_loss improved from 0.44234 to 0.43247, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2180 - acc: 0.9834 - val_loss: 0.4273 - val_acc: 0.8685
#
# Epoch 00027: val_loss improved from 0.43247 to 0.42731, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2154 - acc: 0.9820 - val_loss: 0.4287 - val_acc: 0.8706
#
# Epoch 00028: val_loss did not improve from 0.42731
# Epoch 29/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2078 - acc: 0.9848 - val_loss: 0.4240 - val_acc: 0.8676
#
# Epoch 00029: val_loss improved from 0.42731 to 0.42404, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.2036 - acc: 0.9848 - val_loss: 0.4273 - val_acc: 0.8649
#
# Epoch 00030: val_loss did not improve from 0.42404
# Epoch 31/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1996 - acc: 0.9853 - val_loss: 0.4190 - val_acc: 0.8713
#
# Epoch 00031: val_loss improved from 0.42404 to 0.41899, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1961 - acc: 0.9852 - val_loss: 0.4220 - val_acc: 0.8654
#
# Epoch 00032: val_loss did not improve from 0.41899
# Epoch 33/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1911 - acc: 0.9861 - val_loss: 0.4218 - val_acc: 0.8748
#
# Epoch 00033: val_loss did not improve from 0.41899
# Epoch 34/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1851 - acc: 0.9871 - val_loss: 0.4258 - val_acc: 0.8702
#
# Epoch 00034: val_loss did not improve from 0.41899
# Epoch 35/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1806 - acc: 0.9878 - val_loss: 0.4202 - val_acc: 0.8708
#
# Epoch 00035: val_loss did not improve from 0.41899
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.1796 - acc: 0.9875 - val_loss: 0.4128 - val_acc: 0.8712
#
# Epoch 00036: val_loss improved from 0.41899 to 0.41280, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1730 - acc: 0.9899 - val_loss: 0.4144 - val_acc: 0.8759
#
# Epoch 00037: val_loss did not improve from 0.41280
# Epoch 38/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1692 - acc: 0.9891 - val_loss: 0.4095 - val_acc: 0.8717
#
# Epoch 00038: val_loss improved from 0.41280 to 0.40951, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1659 - acc: 0.9899 - val_loss: 0.4030 - val_acc: 0.8754
#
# Epoch 00039: val_loss improved from 0.40951 to 0.40302, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1618 - acc: 0.9888 - val_loss: 0.4077 - val_acc: 0.8724
#
# Epoch 00040: val_loss did not improve from 0.40302
# Epoch 41/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.1585 - acc: 0.9908 - val_loss: 0.4078 - val_acc: 0.8757
#
# Epoch 00041: val_loss did not improve from 0.40302
# Epoch 42/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1561 - acc: 0.9900 - val_loss: 0.3882 - val_acc: 0.8793
#
# Epoch 00042: val_loss improved from 0.40302 to 0.38824, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1521 - acc: 0.9904 - val_loss: 0.4103 - val_acc: 0.8724
#
# Epoch 00043: val_loss did not improve from 0.38824
# Epoch 44/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1484 - acc: 0.9913 - val_loss: 0.3993 - val_acc: 0.8777
#
# Epoch 00044: val_loss did not improve from 0.38824
# Epoch 45/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1435 - acc: 0.9916 - val_loss: 0.4015 - val_acc: 0.8727
#
# Epoch 00045: val_loss did not improve from 0.38824
# Epoch 46/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1422 - acc: 0.9918 - val_loss: 0.4193 - val_acc: 0.8650
#
# Epoch 00046: val_loss did not improve from 0.38824
# Epoch 47/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1401 - acc: 0.9909 - val_loss: 0.3975 - val_acc: 0.8707
#
# Epoch 00047: val_loss did not improve from 0.38824
# Epoch 48/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1373 - acc: 0.9916 - val_loss: 0.3953 - val_acc: 0.8820
#
# Epoch 00048: val_loss did not improve from 0.38824
# Epoch 49/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1339 - acc: 0.9921 - val_loss: 0.4046 - val_acc: 0.8736
#
# Epoch 00049: val_loss did not improve from 0.38824
# Epoch 50/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.1305 - acc: 0.9929 - val_loss: 0.3912 - val_acc: 0.8850
#
# Epoch 00050: val_loss did not improve from 0.38824
# Epoch 51/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1290 - acc: 0.9925 - val_loss: 0.4090 - val_acc: 0.8728
#
# Epoch 00051: val_loss did not improve from 0.38824
# Epoch 52/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.1252 - acc: 0.9929 - val_loss: 0.4032 - val_acc: 0.8749
#
# Epoch 00052: val_loss did not improve from 0.38824
# results per 6-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4032 - acc: 0.8749
# [[2124    9    0    0   43]
#  [ 128 1220   40   61   91]
#  [  61   66 2492  129   41]
#  [  57   96  118 1999  223]
#  [  67   23   35   73 1682]]
#               precision    recall  f1-score   support
#
#           HC       0.87      0.98      0.92      2176
#          a_H       0.86      0.79      0.83      1540
#          a_K       0.93      0.89      0.91      2789
#          a_A       0.88      0.80      0.84      2493
#          a_C       0.81      0.89      0.85      1880
#
#     accuracy                           0.87     10878
#    macro avg       0.87      0.87      0.87     10878
# weighted avg       0.88      0.87      0.87     10878

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

mmscaler_LSTM.fit(test_COP_ML)
test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

# %%
test_x = np.concatenate([test_V[test_index], test_AP[test_index], test_ML[test_index], test_COP_ML[test_index]], axis=2)
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_24 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_25 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# activation_27 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# activation_28 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_29 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1581   30   17   33   93]
#  [  10 1089  206   42  104]
#  [  33   76 2110  143  157]
#  [  21   63  107 2465  333]
#  [  34   88   47  124 1872]]
#               precision    recall  f1-score   support
#
#           HC   0.941632  0.901368  0.921060      1754
#          a_H   0.809064  0.750517  0.778691      1451
#          a_K   0.848412  0.837634  0.842988      2519
#          a_A   0.878162  0.824691  0.850587      2989
#          a_C   0.731536  0.864665  0.792549      2165
#
#     accuracy                       0.838114     10878
#    macro avg   0.841761  0.835775  0.837175     10878
# weighted avg   0.843108  0.838114  0.839049     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/1fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_30 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_31 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# activation_33 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# activation_34 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_35 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1595    0   21   31  107]
#  [  11  998  262   52  128]
#  [  10  114 2208   88   99]
#  [  63   97  272 2381  176]
#  [  83  124   98  153 1707]]
#               precision    recall  f1-score   support
#
#           HC   0.905221  0.909350  0.907281      1754
#          a_H   0.748687  0.687802  0.716954      1451
#          a_K   0.771758  0.876538  0.820818      2519
#          a_A   0.880222  0.796587  0.836319      2989
#          a_C   0.769959  0.788453  0.779096      2165
#
#     accuracy                       0.817154     10878
#    macro avg   0.815170  0.811746  0.812094     10878
# weighted avg   0.819646  0.817154  0.816861     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1706    0    0   20   28]
#  [   0 1016  202  107  126]
#  [   0  101 2197  131   90]
#  [  89   64   97 2527  212]
#  [  84  125   83  107 1766]]
#               precision    recall  f1-score   support
#
#           HC   0.907930  0.972634  0.939169      1754
#          a_H   0.777948  0.700207  0.737033      1451
#          a_K   0.851881  0.872171  0.861907      2519
#          a_A   0.873790  0.845433  0.859378      2989
#          a_C   0.794779  0.815704  0.805106      2165
#
#     accuracy                       0.846847     10878
#    macro avg   0.841265  0.841230  0.840518     10878
# weighted avg   0.845712  0.846847  0.845708     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_42 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_43 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 128)               512
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 64)                256
# _________________________________________________________________
# activation_46 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_47 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1656    0    0   51   47]
#  [  23 1011  261   65   91]
#  [  19  132 2126  169   73]
#  [  38   85  195 2572   99]
#  [  65  127   97  130 1746]]
#               precision    recall  f1-score   support
#
#           HC   0.919489  0.944128  0.931646      1754
#          a_H   0.746125  0.696761  0.720599      1451
#          a_K   0.793580  0.843986  0.818007      2519
#          a_A   0.861065  0.860488  0.860776      2989
#          a_C   0.849222  0.806467  0.827292      2165
#
#     accuracy                       0.837562     10878
#    macro avg   0.833896  0.830366  0.831664     10878
# weighted avg   0.837169  0.837562  0.836937     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_8 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_48 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_49 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_50 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 128)               512
# _________________________________________________________________
# activation_51 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 64)                256
# _________________________________________________________________
# activation_52 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_53 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1691   10    8    0   45]
#  [  52  964  239   62  134]
#  [  29  101 2151  154   84]
#  [ 143   42  171 2504  129]
#  [  74  104   76  105 1806]]
#               precision    recall  f1-score   support
#
#           HC   0.850176  0.964082  0.903553      1754
#          a_H   0.789517  0.664369  0.721557      1451
#          a_K   0.813233  0.853910  0.833075      2519
#          a_A   0.886372  0.837738  0.861369      2989
#          a_C   0.821656  0.834180  0.827871      2165
#
#     accuracy                       0.838022     10878
#    macro avg   0.832191  0.830856  0.829485     10878
# weighted avg   0.837799  0.838022  0.836303     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_9 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_54 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_45 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_55 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 128)               512
# _________________________________________________________________
# activation_57 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 64)                256
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_59 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1661    0   56   10   27]
#  [  24 1012  282   67   66]
#  [   9   45 2180  174  111]
#  [  69  107  220 2448  145]
#  [  56  128   81  105 1795]]
#               precision    recall  f1-score   support
#
#           HC   0.913139  0.946978  0.929751      1754
#          a_H   0.783282  0.697450  0.737878      1451
#          a_K   0.773324  0.865423  0.816785      2519
#          a_A   0.873039  0.819003  0.845158      2989
#          a_C   0.837220  0.829099  0.833140      2165
#
#     accuracy                       0.836183     10878
#    macro avg   0.836001  0.831591  0.832542     10878
# weighted avg   0.837312  0.836183  0.835526     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_LSTM_3DGRF_and_MLCOP_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_10 (Bidirectio (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_10 (Laye (None, 101, 1024)         2048
# _________________________________________________________________
# activation_60 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 103424)            0
# _________________________________________________________________
# dense_50 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_61 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_51 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_62 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_52 (Batc (None, 128)               512
# _________________________________________________________________
# activation_63 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_53 (Batc (None, 64)                256
# _________________________________________________________________
# activation_64 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_65 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1668    0   17   58   11]
#  [  72 1030  195   27  127]
#  [  20  164 2108  104  123]
#  [  92   96  130 2472  199]
#  [  82  139   98   89 1757]]
#               precision    recall  f1-score   support
#
#           HC   0.862461  0.950969  0.904555      1754
#          a_H   0.720784  0.709855  0.715278      1451
#          a_K   0.827316  0.836840  0.832051      2519
#          a_A   0.898909  0.827032  0.861474      2989
#          a_C   0.792512  0.811547  0.801917      2165
#
#     accuracy                       0.830575     10878
#    macro avg   0.820396  0.827249  0.823055     10878
# weighted avg   0.831518  0.830575  0.830253     10878
