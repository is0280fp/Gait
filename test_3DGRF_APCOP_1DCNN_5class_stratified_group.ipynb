# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_3DGRF_APCOP_1DCNN_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# # Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# # StratifiedGroupKFoldの分割結果をpickle
import pickle

# test
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# trainig and validation
with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
   COP_ML = pickle.load(f)
f.close()

# label
with open("/content/drive/MyDrive/test_data/train_idx_list.pickle", mode="rb") as f:
   train_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   label = pickle.load(f)
f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    test_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    test_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()

# # trainig and validation
# with open("V_val_train.pickle", mode="rb") as f:
#    V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    COP_ML = pickle.load(f)
# f.close()

# # label
# with open("train_idx_list.pickle", mode="rb") as f:
#    train_index_list = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("label_val_train.pickle", mode="rb") as f:
#    label = pickle.load(f)
# f.close()

# with open("test_sub_ID.pickle", mode="rb") as f:
#    sub_ID=pickle.load(f)
# f.close()

# import pandas as pd

# with open("test_data_index.pickle", mode="rb") as f:
#    test_index = pickle.load(f)
# f.close()

# %%
import numpy as np
print(np.where(label==0)[0].shape)
print(np.where(label==1)[0].shape)
print(np.where(label==2)[0].shape)
print(np.where(label==3)[0].shape)
print(np.where(label==4)[0].shape)
# Out:
# (13756,)
# (11862,)
# (17630,)
# (18557,)
# (14341,)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# CNN
mmscaler_CNN.fit(V)
V = mmscaler_CNN.transform(V)
V = V.reshape(V.shape[0], V.shape[1], 1)

mmscaler_CNN.fit(AP)
AP = mmscaler_CNN.transform(AP)
AP = AP.reshape(AP.shape[0], AP.shape[1], 1)

mmscaler_CNN.fit(ML)
ML = mmscaler_CNN.transform(ML)
ML = ML.reshape(ML.shape[0], ML.shape[1], 1)

mmscaler_CNN.fit(COP_AP)
COP_AP = mmscaler_CNN.transform(COP_AP)
COP_AP = COP_AP.reshape(COP_AP.shape[0], COP_AP.shape[1], 1)

mmscaler_CNN.fit(COP_ML)
COP_ML = mmscaler_CNN.transform(COP_ML)
COP_ML = COP_ML.reshape(COP_ML.shape[0], COP_ML.shape[1], 1)

# %%
# !pip install keras-layer-normalization
# !pip install keras-self-attention
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=b1811668ff50b4185ef5365838c10e4d21e3d6b3124395cccef32bd9754ceefc
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_3DGRF_APCOP_1DCNN_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr

lr_scheduler = LearningRateScheduler(decay_schedule)

initializer = he_normal()

classes_main = 5

def build_model():
  # CNN
  # 最初これだけだった
  model = Sequential()
  model.add(Conv1D(128, padding = "same", kernel_size=3, strides=1, kernel_initializer=initializer, input_shape=(101, 4)))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(MaxPooling1D(2))

  model.add(Conv1D(256, padding = "same", kernel_size=3, strides=1, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))

  model.add(MaxPooling1D(2))

  model.add(Flatten())

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#-------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

val_label_list = []
train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(7):
  train_index = train_index_list[i]
  train_LSTM_data = np.concatenate([V[train_index], AP[train_index], ML[train_index], COP_AP[train_index]], axis=2)
  val_index = val_index_list[i]
  val_LSTM_data = np.concatenate([V[val_index], AP[val_index], ML[val_index], COP_AP[val_index]], axis=2)
  
  # label
  train_label = label[train_index] 
  val_label= label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  MAX = len(train_LSTM_data)

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)
# train_data (65268, 101, 4)
# val_data (10878, 101, 4)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="/content/drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )

  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=600, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

now = datetime.datetime.now()
with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(cmx_list, f)
f.close()

with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(report_list, f)
f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 101, 128)          512
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 50, 256)           1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# HC (11952,)
# H (10373,)
# K (15152,)
# A (15736,)
# C (12055,)
# Epoch 1/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 1.6333 - acc: 0.3124 - val_loss: 1.3040 - val_acc: 0.4881
#
# Epoch 00001: val_loss improved from inf to 1.30395, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 2/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 1.2373 - acc: 0.5021 - val_loss: 1.1736 - val_acc: 0.5585
#
# Epoch 00002: val_loss improved from 1.30395 to 1.17356, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 3/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 1.0859 - acc: 0.5916 - val_loss: 1.0959 - val_acc: 0.5845
#
# Epoch 00003: val_loss improved from 1.17356 to 1.09588, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 4/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.9936 - acc: 0.6508 - val_loss: 1.0357 - val_acc: 0.6235
#
# Epoch 00004: val_loss improved from 1.09588 to 1.03569, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 5/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.9154 - acc: 0.6949 - val_loss: 0.9927 - val_acc: 0.6501
#
# Epoch 00005: val_loss improved from 1.03569 to 0.99266, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 6/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.8524 - acc: 0.7339 - val_loss: 0.9411 - val_acc: 0.6754
#
# Epoch 00006: val_loss improved from 0.99266 to 0.94114, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 7/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.8011 - acc: 0.7644 - val_loss: 0.9103 - val_acc: 0.6962
#
# Epoch 00007: val_loss improved from 0.94114 to 0.91030, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 8/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.7511 - acc: 0.7929 - val_loss: 0.8831 - val_acc: 0.7073
#
# Epoch 00008: val_loss improved from 0.91030 to 0.88309, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 9/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.7133 - acc: 0.8139 - val_loss: 0.8662 - val_acc: 0.7123
#
# Epoch 00009: val_loss improved from 0.88309 to 0.86616, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 10/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6841 - acc: 0.8271 - val_loss: 0.8362 - val_acc: 0.7315
#
# Epoch 00010: val_loss improved from 0.86616 to 0.83623, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 11/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.6474 - acc: 0.8497 - val_loss: 0.8148 - val_acc: 0.7404
#
# Epoch 00011: val_loss improved from 0.83623 to 0.81478, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 12/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.6234 - acc: 0.8604 - val_loss: 0.7874 - val_acc: 0.7544
#
# Epoch 00012: val_loss improved from 0.81478 to 0.78740, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 13/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5952 - acc: 0.8717 - val_loss: 0.7827 - val_acc: 0.7544
#
# Epoch 00013: val_loss improved from 0.78740 to 0.78268, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 14/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5741 - acc: 0.8821 - val_loss: 0.7557 - val_acc: 0.7781
#
# Epoch 00014: val_loss improved from 0.78268 to 0.75571, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 15/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5521 - acc: 0.8914 - val_loss: 0.7473 - val_acc: 0.7736
#
# Epoch 00015: val_loss improved from 0.75571 to 0.74726, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 16/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5263 - acc: 0.9034 - val_loss: 0.7318 - val_acc: 0.7774
#
# Epoch 00016: val_loss improved from 0.74726 to 0.73178, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 17/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5060 - acc: 0.9134 - val_loss: 0.7222 - val_acc: 0.7933
#
# Epoch 00017: val_loss improved from 0.73178 to 0.72217, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 18/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4872 - acc: 0.9195 - val_loss: 0.7084 - val_acc: 0.7869
#
# Epoch 00018: val_loss improved from 0.72217 to 0.70839, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 19/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4692 - acc: 0.9249 - val_loss: 0.7028 - val_acc: 0.7921
#
# Epoch 00019: val_loss improved from 0.70839 to 0.70279, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 20/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4536 - acc: 0.9329 - val_loss: 0.6973 - val_acc: 0.7944
#
# Epoch 00020: val_loss improved from 0.70279 to 0.69731, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 21/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4438 - acc: 0.9342 - val_loss: 0.6834 - val_acc: 0.7943
#
# Epoch 00021: val_loss improved from 0.69731 to 0.68343, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 22/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4256 - acc: 0.9419 - val_loss: 0.6728 - val_acc: 0.8013
#
# Epoch 00022: val_loss improved from 0.68343 to 0.67276, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 23/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.4128 - acc: 0.9442 - val_loss: 0.6641 - val_acc: 0.8086
#
# Epoch 00023: val_loss improved from 0.67276 to 0.66412, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 24/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3963 - acc: 0.9511 - val_loss: 0.6578 - val_acc: 0.8079
#
# Epoch 00024: val_loss improved from 0.66412 to 0.65780, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 25/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3849 - acc: 0.9531 - val_loss: 0.6504 - val_acc: 0.8088
#
# Epoch 00025: val_loss improved from 0.65780 to 0.65037, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 26/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3733 - acc: 0.9568 - val_loss: 0.6463 - val_acc: 0.8081
#
# Epoch 00026: val_loss improved from 0.65037 to 0.64625, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 27/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3617 - acc: 0.9602 - val_loss: 0.6411 - val_acc: 0.8062
#
# Epoch 00027: val_loss improved from 0.64625 to 0.64107, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 28/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3496 - acc: 0.9629 - val_loss: 0.6317 - val_acc: 0.8221
#
# Epoch 00028: val_loss improved from 0.64107 to 0.63169, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 29/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3365 - acc: 0.9680 - val_loss: 0.6306 - val_acc: 0.8114
#
# Epoch 00029: val_loss improved from 0.63169 to 0.63063, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 30/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3277 - acc: 0.9694 - val_loss: 0.6246 - val_acc: 0.8073
#
# Epoch 00030: val_loss improved from 0.63063 to 0.62457, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 31/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3204 - acc: 0.9702 - val_loss: 0.6197 - val_acc: 0.8107
#
# Epoch 00031: val_loss improved from 0.62457 to 0.61969, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 32/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3081 - acc: 0.9741 - val_loss: 0.6139 - val_acc: 0.8121
#
# Epoch 00032: val_loss improved from 0.61969 to 0.61388, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 33/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.3016 - acc: 0.9756 - val_loss: 0.6086 - val_acc: 0.8238
#
# Epoch 00033: val_loss improved from 0.61388 to 0.60856, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 34/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2920 - acc: 0.9772 - val_loss: 0.6086 - val_acc: 0.8177
#
# Epoch 00034: val_loss did not improve from 0.60856
# Epoch 35/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2850 - acc: 0.9777 - val_loss: 0.6010 - val_acc: 0.8157
#
# Epoch 00035: val_loss improved from 0.60856 to 0.60101, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 36/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2766 - acc: 0.9803 - val_loss: 0.6060 - val_acc: 0.8068
#
# Epoch 00036: val_loss did not improve from 0.60101
# Epoch 37/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2675 - acc: 0.9806 - val_loss: 0.5931 - val_acc: 0.8161
#
# Epoch 00037: val_loss improved from 0.60101 to 0.59308, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 38/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2618 - acc: 0.9823 - val_loss: 0.5989 - val_acc: 0.8140
#
# Epoch 00038: val_loss did not improve from 0.59308
# Epoch 39/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2533 - acc: 0.9832 - val_loss: 0.5924 - val_acc: 0.8179
#
# Epoch 00039: val_loss improved from 0.59308 to 0.59241, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 40/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2470 - acc: 0.9853 - val_loss: 0.5936 - val_acc: 0.8149
#
# Epoch 00040: val_loss did not improve from 0.59241
# Epoch 41/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2403 - acc: 0.9857 - val_loss: 0.5868 - val_acc: 0.8198
#
# Epoch 00041: val_loss improved from 0.59241 to 0.58682, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 42/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2344 - acc: 0.9863 - val_loss: 0.5817 - val_acc: 0.8149
#
# Epoch 00042: val_loss improved from 0.58682 to 0.58173, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2266 - acc: 0.9883 - val_loss: 0.5744 - val_acc: 0.8193
#
# Epoch 00043: val_loss improved from 0.58173 to 0.57444, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 44/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2209 - acc: 0.9888 - val_loss: 0.5776 - val_acc: 0.8229
#
# Epoch 00044: val_loss did not improve from 0.57444
# Epoch 45/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2155 - acc: 0.9878 - val_loss: 0.5764 - val_acc: 0.8206
#
# Epoch 00045: val_loss did not improve from 0.57444
# Epoch 46/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.2115 - acc: 0.9887 - val_loss: 0.5721 - val_acc: 0.8159
#
# Epoch 00046: val_loss improved from 0.57444 to 0.57211, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 47/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2051 - acc: 0.9899 - val_loss: 0.5727 - val_acc: 0.8241
#
# Epoch 00047: val_loss did not improve from 0.57211
# Epoch 48/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2004 - acc: 0.9907 - val_loss: 0.5788 - val_acc: 0.8192
#
# Epoch 00048: val_loss did not improve from 0.57211
# Epoch 49/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.1954 - acc: 0.9909 - val_loss: 0.5790 - val_acc: 0.8108
#
# Epoch 00049: val_loss did not improve from 0.57211
# Epoch 50/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.1917 - acc: 0.9909 - val_loss: 0.5633 - val_acc: 0.8197
#
# Epoch 00050: val_loss improved from 0.57211 to 0.56325, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 51/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.1846 - acc: 0.9919 - val_loss: 0.5749 - val_acc: 0.8104
#
# Epoch 00051: val_loss did not improve from 0.56325
# Epoch 52/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1802 - acc: 0.9917 - val_loss: 0.5611 - val_acc: 0.8204
#
# Epoch 00052: val_loss improved from 0.56325 to 0.56109, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 53/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1753 - acc: 0.9926 - val_loss: 0.5575 - val_acc: 0.8210
#
# Epoch 00053: val_loss improved from 0.56109 to 0.55752, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 54/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.1701 - acc: 0.9935 - val_loss: 0.5566 - val_acc: 0.8233
#
# Epoch 00054: val_loss improved from 0.55752 to 0.55662, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 55/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1683 - acc: 0.9927 - val_loss: 0.5556 - val_acc: 0.8183
#
# Epoch 00055: val_loss improved from 0.55662 to 0.55560, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 56/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1622 - acc: 0.9937 - val_loss: 0.5574 - val_acc: 0.8244
#
# Epoch 00056: val_loss did not improve from 0.55560
# Epoch 57/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1574 - acc: 0.9940 - val_loss: 0.5623 - val_acc: 0.8117
#
# Epoch 00057: val_loss did not improve from 0.55560
# Epoch 58/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1549 - acc: 0.9944 - val_loss: 0.5566 - val_acc: 0.8112
#
# Epoch 00058: val_loss did not improve from 0.55560
# Epoch 59/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.1540 - acc: 0.9938 - val_loss: 0.5500 - val_acc: 0.8219
#
# Epoch 00059: val_loss improved from 0.55560 to 0.54996, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 60/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1473 - acc: 0.9948 - val_loss: 0.5429 - val_acc: 0.8297
#
# Epoch 00060: val_loss improved from 0.54996 to 0.54291, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 61/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1440 - acc: 0.9950 - val_loss: 0.5467 - val_acc: 0.8250
#
# Epoch 00061: val_loss did not improve from 0.54291
# Epoch 62/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1408 - acc: 0.9959 - val_loss: 0.5493 - val_acc: 0.8142
#
# Epoch 00062: val_loss did not improve from 0.54291
# Epoch 63/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1374 - acc: 0.9959 - val_loss: 0.5484 - val_acc: 0.8163
#
# Epoch 00063: val_loss did not improve from 0.54291
# Epoch 64/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1343 - acc: 0.9956 - val_loss: 0.5525 - val_acc: 0.8148
#
# Epoch 00064: val_loss did not improve from 0.54291
# Epoch 65/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1313 - acc: 0.9954 - val_loss: 0.5416 - val_acc: 0.8229
#
# Epoch 00065: val_loss improved from 0.54291 to 0.54165, saving model to /content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 66/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1306 - acc: 0.9954 - val_loss: 0.5506 - val_acc: 0.8218
#
# Epoch 00066: val_loss did not improve from 0.54165
# Epoch 67/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1254 - acc: 0.9960 - val_loss: 0.5468 - val_acc: 0.8159
#
# Epoch 00067: val_loss did not improve from 0.54165
# Epoch 68/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1217 - acc: 0.9963 - val_loss: 0.5437 - val_acc: 0.8229
#
# Epoch 00068: val_loss did not improve from 0.54165
# Epoch 69/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1214 - acc: 0.9956 - val_loss: 0.5501 - val_acc: 0.8169
#
# Epoch 00069: val_loss did not improve from 0.54165
# Epoch 70/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1168 - acc: 0.9971 - val_loss: 0.5500 - val_acc: 0.8174
#
# Epoch 00070: val_loss did not improve from 0.54165
# Epoch 71/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1156 - acc: 0.9967 - val_loss: 0.5540 - val_acc: 0.8137
#
# Epoch 00071: val_loss did not improve from 0.54165
# Epoch 72/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1129 - acc: 0.9970 - val_loss: 0.5457 - val_acc: 0.8203
#
# Epoch 00072: val_loss did not improve from 0.54165
# Epoch 73/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1092 - acc: 0.9974 - val_loss: 0.5455 - val_acc: 0.8164
#
# Epoch 00073: val_loss did not improve from 0.54165
# Epoch 74/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1064 - acc: 0.9970 - val_loss: 0.5455 - val_acc: 0.8252
#
# Epoch 00074: val_loss did not improve from 0.54165
# Epoch 75/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1037 - acc: 0.9972 - val_loss: 0.5450 - val_acc: 0.8179
#
# Epoch 00075: val_loss did not improve from 0.54165
# results per 0-fold
# 340/340 [==============================] - 1s 3ms/step - loss: 0.5450 - acc: 0.8179
# [[1442   33  138   69  122]
#  [  34 1135  149  114   57]
#  [  49   31 2196  130   72]
#  [  66   96   87 2420  152]
#  [  26  129  164  263 1704]]
#               precision    recall  f1-score   support
#
#           HC       0.89      0.80      0.84      1804
#          a_H       0.80      0.76      0.78      1489
#          a_K       0.80      0.89      0.84      2478
#          a_A       0.81      0.86      0.83      2821
#          a_C       0.81      0.75      0.78      2286
#
#     accuracy                           0.82     10878
#    macro avg       0.82      0.81      0.81     10878
# weighted avg       0.82      0.82      0.82     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 50, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 25, 256)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# HC (11644,)
# H (9971,)
# K (15293,)
# A (16092,)
# C (12268,)
# Epoch 1/600
# 1036/1036 [==============================] - 7s 6ms/step - loss: 1.6163 - acc: 0.3200 - val_loss: 1.3118 - val_acc: 0.4541
#
# Epoch 00001: val_loss improved from inf to 1.31180, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 2/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 1.2283 - acc: 0.5097 - val_loss: 1.1977 - val_acc: 0.5156
#
# Epoch 00002: val_loss improved from 1.31180 to 1.19770, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 3/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 1.0884 - acc: 0.5893 - val_loss: 1.1202 - val_acc: 0.5723
#
# Epoch 00003: val_loss improved from 1.19770 to 1.12021, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 4/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.9904 - acc: 0.6509 - val_loss: 1.0688 - val_acc: 0.6049
#
# Epoch 00004: val_loss improved from 1.12021 to 1.06879, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 5/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.9184 - acc: 0.6960 - val_loss: 1.0219 - val_acc: 0.6498
#
# Epoch 00005: val_loss improved from 1.06879 to 1.02189, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 6/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.8582 - acc: 0.7321 - val_loss: 0.9793 - val_acc: 0.6706
#
# Epoch 00006: val_loss improved from 1.02189 to 0.97932, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 7/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.8067 - acc: 0.7606 - val_loss: 0.9408 - val_acc: 0.6812
#
# Epoch 00007: val_loss improved from 0.97932 to 0.94081, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 8/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.7642 - acc: 0.7865 - val_loss: 0.9225 - val_acc: 0.7022
#
# Epoch 00008: val_loss improved from 0.94081 to 0.92253, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 9/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.7260 - acc: 0.8071 - val_loss: 0.8922 - val_acc: 0.7111
#
# Epoch 00009: val_loss improved from 0.92253 to 0.89222, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 10/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.6943 - acc: 0.8243 - val_loss: 0.8756 - val_acc: 0.7069
#
# Epoch 00010: val_loss improved from 0.89222 to 0.87558, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 11/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6632 - acc: 0.8393 - val_loss: 0.8554 - val_acc: 0.7232
#
# Epoch 00011: val_loss improved from 0.87558 to 0.85544, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 12/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.6358 - acc: 0.8526 - val_loss: 0.8318 - val_acc: 0.7297
#
# Epoch 00012: val_loss improved from 0.85544 to 0.83185, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 13/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.6071 - acc: 0.8678 - val_loss: 0.8194 - val_acc: 0.7316
#
# Epoch 00013: val_loss improved from 0.83185 to 0.81944, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 14/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5822 - acc: 0.8801 - val_loss: 0.7984 - val_acc: 0.7501
#
# Epoch 00014: val_loss improved from 0.81944 to 0.79844, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 15/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5618 - acc: 0.8899 - val_loss: 0.7837 - val_acc: 0.7498
#
# Epoch 00015: val_loss improved from 0.79844 to 0.78371, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 16/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5419 - acc: 0.8960 - val_loss: 0.7726 - val_acc: 0.7563
#
# Epoch 00016: val_loss improved from 0.78371 to 0.77260, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 17/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.5222 - acc: 0.9029 - val_loss: 0.7673 - val_acc: 0.7661
#
# Epoch 00017: val_loss improved from 0.77260 to 0.76734, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 18/600
# 1036/1036 [==============================] - 6s 5ms/step - loss: 0.5009 - acc: 0.9142 - val_loss: 0.7489 - val_acc: 0.7705
#
# Epoch 00018: val_loss improved from 0.76734 to 0.74888, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 19/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4830 - acc: 0.9204 - val_loss: 0.7452 - val_acc: 0.7674
#
# Epoch 00019: val_loss improved from 0.74888 to 0.74523, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 20/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4691 - acc: 0.9270 - val_loss: 0.7343 - val_acc: 0.7721
#
# Epoch 00020: val_loss improved from 0.74523 to 0.73425, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 21/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4536 - acc: 0.9325 - val_loss: 0.7222 - val_acc: 0.7796
#
# Epoch 00021: val_loss improved from 0.73425 to 0.72221, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 22/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4376 - acc: 0.9373 - val_loss: 0.7199 - val_acc: 0.7783
#
# Epoch 00022: val_loss improved from 0.72221 to 0.71988, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 23/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4230 - acc: 0.9431 - val_loss: 0.7116 - val_acc: 0.7822
#
# Epoch 00023: val_loss improved from 0.71988 to 0.71156, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 24/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.4084 - acc: 0.9477 - val_loss: 0.7049 - val_acc: 0.7753
#
# Epoch 00024: val_loss improved from 0.71156 to 0.70489, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 25/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3970 - acc: 0.9486 - val_loss: 0.6972 - val_acc: 0.7849
#
# Epoch 00025: val_loss improved from 0.70489 to 0.69724, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 26/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3842 - acc: 0.9544 - val_loss: 0.6919 - val_acc: 0.7873
#
# Epoch 00026: val_loss improved from 0.69724 to 0.69188, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 27/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3723 - acc: 0.9571 - val_loss: 0.6840 - val_acc: 0.7805
#
# Epoch 00027: val_loss improved from 0.69188 to 0.68400, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 28/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3606 - acc: 0.9614 - val_loss: 0.6783 - val_acc: 0.7896
#
# Epoch 00028: val_loss improved from 0.68400 to 0.67833, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 29/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3490 - acc: 0.9634 - val_loss: 0.6641 - val_acc: 0.7926
#
# Epoch 00029: val_loss improved from 0.67833 to 0.66407, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 30/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3401 - acc: 0.9656 - val_loss: 0.6639 - val_acc: 0.7908
#
# Epoch 00030: val_loss improved from 0.66407 to 0.66386, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 31/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3284 - acc: 0.9688 - val_loss: 0.6618 - val_acc: 0.7918
#
# Epoch 00031: val_loss improved from 0.66386 to 0.66184, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 32/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3212 - acc: 0.9700 - val_loss: 0.6542 - val_acc: 0.7916
#
# Epoch 00032: val_loss improved from 0.66184 to 0.65418, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 33/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3118 - acc: 0.9722 - val_loss: 0.6522 - val_acc: 0.7902
#
# Epoch 00033: val_loss improved from 0.65418 to 0.65219, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 34/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.3016 - acc: 0.9744 - val_loss: 0.6443 - val_acc: 0.7970
#
# Epoch 00034: val_loss improved from 0.65219 to 0.64425, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 35/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2926 - acc: 0.9760 - val_loss: 0.6357 - val_acc: 0.7940
#
# Epoch 00035: val_loss improved from 0.64425 to 0.63574, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 36/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2843 - acc: 0.9780 - val_loss: 0.6405 - val_acc: 0.7916
#
# Epoch 00036: val_loss did not improve from 0.63574
# Epoch 37/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2768 - acc: 0.9803 - val_loss: 0.6312 - val_acc: 0.7990
#
# Epoch 00037: val_loss improved from 0.63574 to 0.63117, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 38/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2703 - acc: 0.9806 - val_loss: 0.6286 - val_acc: 0.7965
#
# Epoch 00038: val_loss improved from 0.63117 to 0.62856, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 39/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2637 - acc: 0.9819 - val_loss: 0.6296 - val_acc: 0.7988
#
# Epoch 00039: val_loss did not improve from 0.62856
# Epoch 40/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2548 - acc: 0.9827 - val_loss: 0.6264 - val_acc: 0.7958
#
# Epoch 00040: val_loss improved from 0.62856 to 0.62636, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 41/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2456 - acc: 0.9847 - val_loss: 0.6293 - val_acc: 0.7972
#
# Epoch 00041: val_loss did not improve from 0.62636
# Epoch 42/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2413 - acc: 0.9859 - val_loss: 0.6203 - val_acc: 0.7989
#
# Epoch 00042: val_loss improved from 0.62636 to 0.62029, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2342 - acc: 0.9864 - val_loss: 0.6101 - val_acc: 0.7948
#
# Epoch 00043: val_loss improved from 0.62029 to 0.61010, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 44/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2290 - acc: 0.9864 - val_loss: 0.6122 - val_acc: 0.7958
#
# Epoch 00044: val_loss did not improve from 0.61010
# Epoch 45/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2233 - acc: 0.9871 - val_loss: 0.6096 - val_acc: 0.7946
#
# Epoch 00045: val_loss improved from 0.61010 to 0.60960, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 46/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2162 - acc: 0.9883 - val_loss: 0.6055 - val_acc: 0.8017
#
# Epoch 00046: val_loss improved from 0.60960 to 0.60549, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 47/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2113 - acc: 0.9889 - val_loss: 0.6071 - val_acc: 0.7964
#
# Epoch 00047: val_loss did not improve from 0.60549
# Epoch 48/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2048 - acc: 0.9902 - val_loss: 0.6057 - val_acc: 0.7999
#
# Epoch 00048: val_loss did not improve from 0.60549
# Epoch 49/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2012 - acc: 0.9903 - val_loss: 0.6061 - val_acc: 0.7950
#
# Epoch 00049: val_loss did not improve from 0.60549
# Epoch 50/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1949 - acc: 0.9910 - val_loss: 0.6107 - val_acc: 0.7995
#
# Epoch 00050: val_loss did not improve from 0.60549
# Epoch 51/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1898 - acc: 0.9918 - val_loss: 0.5999 - val_acc: 0.8040
#
# Epoch 00051: val_loss improved from 0.60549 to 0.59988, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 52/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1863 - acc: 0.9913 - val_loss: 0.5991 - val_acc: 0.7978
#
# Epoch 00052: val_loss improved from 0.59988 to 0.59908, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 53/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1814 - acc: 0.9915 - val_loss: 0.6004 - val_acc: 0.7907
#
# Epoch 00053: val_loss did not improve from 0.59908
# Epoch 54/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1779 - acc: 0.9917 - val_loss: 0.6045 - val_acc: 0.7960
#
# Epoch 00054: val_loss did not improve from 0.59908
# Epoch 55/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1735 - acc: 0.9919 - val_loss: 0.6020 - val_acc: 0.8012
#
# Epoch 00055: val_loss did not improve from 0.59908
# Epoch 56/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1689 - acc: 0.9926 - val_loss: 0.5946 - val_acc: 0.7975
#
# Epoch 00056: val_loss improved from 0.59908 to 0.59457, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 57/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1631 - acc: 0.9939 - val_loss: 0.5948 - val_acc: 0.7984
#
# Epoch 00057: val_loss did not improve from 0.59457
# Epoch 58/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1600 - acc: 0.9939 - val_loss: 0.6026 - val_acc: 0.7966
#
# Epoch 00058: val_loss did not improve from 0.59457
# Epoch 59/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1581 - acc: 0.9938 - val_loss: 0.5964 - val_acc: 0.7990
#
# Epoch 00059: val_loss did not improve from 0.59457
# Epoch 60/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1551 - acc: 0.9937 - val_loss: 0.6012 - val_acc: 0.7948
#
# Epoch 00060: val_loss did not improve from 0.59457
# Epoch 61/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1497 - acc: 0.9942 - val_loss: 0.6061 - val_acc: 0.7989
#
# Epoch 00061: val_loss did not improve from 0.59457
# Epoch 62/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1438 - acc: 0.9956 - val_loss: 0.5956 - val_acc: 0.8000
#
# Epoch 00062: val_loss did not improve from 0.59457
# Epoch 63/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1436 - acc: 0.9945 - val_loss: 0.6003 - val_acc: 0.7963
#
# Epoch 00063: val_loss did not improve from 0.59457
# Epoch 64/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1377 - acc: 0.9957 - val_loss: 0.6072 - val_acc: 0.7982
#
# Epoch 00064: val_loss did not improve from 0.59457
# Epoch 65/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1373 - acc: 0.9954 - val_loss: 0.5901 - val_acc: 0.7977
#
# Epoch 00065: val_loss improved from 0.59457 to 0.59009, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 66/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1344 - acc: 0.9952 - val_loss: 0.6024 - val_acc: 0.7925
#
# Epoch 00066: val_loss did not improve from 0.59009
# Epoch 67/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1297 - acc: 0.9957 - val_loss: 0.5953 - val_acc: 0.8033
#
# Epoch 00067: val_loss did not improve from 0.59009
# Epoch 68/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1277 - acc: 0.9958 - val_loss: 0.5885 - val_acc: 0.7990
#
# Epoch 00068: val_loss improved from 0.59009 to 0.58846, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 69/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1240 - acc: 0.9961 - val_loss: 0.5958 - val_acc: 0.7970
#
# Epoch 00069: val_loss did not improve from 0.58846
# Epoch 70/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1218 - acc: 0.9963 - val_loss: 0.6025 - val_acc: 0.7903
#
# Epoch 00070: val_loss did not improve from 0.58846
# Epoch 71/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1188 - acc: 0.9962 - val_loss: 0.5999 - val_acc: 0.7928
#
# Epoch 00071: val_loss did not improve from 0.58846
# Epoch 72/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1159 - acc: 0.9967 - val_loss: 0.5923 - val_acc: 0.7931
#
# Epoch 00072: val_loss did not improve from 0.58846
# Epoch 73/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1124 - acc: 0.9964 - val_loss: 0.5884 - val_acc: 0.8039
#
# Epoch 00073: val_loss improved from 0.58846 to 0.58840, saving model to /content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 74/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1108 - acc: 0.9966 - val_loss: 0.5950 - val_acc: 0.7967
#
# Epoch 00074: val_loss did not improve from 0.58840
# Epoch 75/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1078 - acc: 0.9970 - val_loss: 0.5902 - val_acc: 0.7976
#
# Epoch 00075: val_loss did not improve from 0.58840
# Epoch 76/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1056 - acc: 0.9971 - val_loss: 0.5955 - val_acc: 0.8003
#
# Epoch 00076: val_loss did not improve from 0.58840
# ...
# Epoch 36/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2893 - acc: 0.9761 - val_loss: 0.5614 - val_acc: 0.8445
#
# Epoch 00036: val_loss improved from 0.56753 to 0.56139, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 37/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2823 - acc: 0.9780 - val_loss: 0.5569 - val_acc: 0.8434
#
# Epoch 00037: val_loss improved from 0.56139 to 0.55688, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 38/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2725 - acc: 0.9798 - val_loss: 0.5592 - val_acc: 0.8369
#
# Epoch 00038: val_loss did not improve from 0.55688
# Epoch 39/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2640 - acc: 0.9821 - val_loss: 0.5529 - val_acc: 0.8457
#
# Epoch 00039: val_loss improved from 0.55688 to 0.55288, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 40/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2587 - acc: 0.9819 - val_loss: 0.5550 - val_acc: 0.8378
#
# Epoch 00040: val_loss did not improve from 0.55288
# Epoch 41/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2506 - acc: 0.9832 - val_loss: 0.5430 - val_acc: 0.8438
#
# Epoch 00041: val_loss improved from 0.55288 to 0.54296, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 42/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2470 - acc: 0.9841 - val_loss: 0.5364 - val_acc: 0.8464
#
# Epoch 00042: val_loss improved from 0.54296 to 0.53644, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 43/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2365 - acc: 0.9857 - val_loss: 0.5394 - val_acc: 0.8431
#
# Epoch 00043: val_loss did not improve from 0.53644
# Epoch 44/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2321 - acc: 0.9855 - val_loss: 0.5356 - val_acc: 0.8411
#
# Epoch 00044: val_loss improved from 0.53644 to 0.53557, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 45/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2259 - acc: 0.9872 - val_loss: 0.5317 - val_acc: 0.8454
#
# Epoch 00045: val_loss improved from 0.53557 to 0.53175, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 46/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2199 - acc: 0.9880 - val_loss: 0.5322 - val_acc: 0.8411
#
# Epoch 00046: val_loss did not improve from 0.53175
# Epoch 47/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2152 - acc: 0.9877 - val_loss: 0.5269 - val_acc: 0.8427
#
# Epoch 00047: val_loss improved from 0.53175 to 0.52694, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 48/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2100 - acc: 0.9878 - val_loss: 0.5212 - val_acc: 0.8457
#
# Epoch 00048: val_loss improved from 0.52694 to 0.52116, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 49/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.2055 - acc: 0.9895 - val_loss: 0.5217 - val_acc: 0.8447
#
# Epoch 00049: val_loss did not improve from 0.52116
# Epoch 50/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1975 - acc: 0.9905 - val_loss: 0.5241 - val_acc: 0.8491
#
# Epoch 00050: val_loss did not improve from 0.52116
# Epoch 51/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1956 - acc: 0.9899 - val_loss: 0.5144 - val_acc: 0.8509
#
# Epoch 00051: val_loss improved from 0.52116 to 0.51441, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 52/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1897 - acc: 0.9906 - val_loss: 0.5083 - val_acc: 0.8563
#
# Epoch 00052: val_loss improved from 0.51441 to 0.50830, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 53/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1842 - acc: 0.9917 - val_loss: 0.5101 - val_acc: 0.8455
#
# Epoch 00053: val_loss did not improve from 0.50830
# Epoch 54/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1780 - acc: 0.9923 - val_loss: 0.5085 - val_acc: 0.8526
#
# Epoch 00054: val_loss did not improve from 0.50830
# Epoch 55/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1754 - acc: 0.9926 - val_loss: 0.5082 - val_acc: 0.8503
#
# Epoch 00055: val_loss improved from 0.50830 to 0.50817, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 56/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1698 - acc: 0.9927 - val_loss: 0.5000 - val_acc: 0.8516
#
# Epoch 00056: val_loss improved from 0.50817 to 0.50002, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 57/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1645 - acc: 0.9939 - val_loss: 0.5144 - val_acc: 0.8468
#
# Epoch 00057: val_loss did not improve from 0.50002
# Epoch 58/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1642 - acc: 0.9932 - val_loss: 0.5033 - val_acc: 0.8497
#
# Epoch 00058: val_loss did not improve from 0.50002
# Epoch 59/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1592 - acc: 0.9934 - val_loss: 0.4983 - val_acc: 0.8519
#
# Epoch 00059: val_loss improved from 0.50002 to 0.49829, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 60/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1537 - acc: 0.9939 - val_loss: 0.4971 - val_acc: 0.8544
#
# Epoch 00060: val_loss improved from 0.49829 to 0.49715, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 61/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1509 - acc: 0.9943 - val_loss: 0.4857 - val_acc: 0.8559
#
# Epoch 00061: val_loss improved from 0.49715 to 0.48568, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 62/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1461 - acc: 0.9942 - val_loss: 0.4896 - val_acc: 0.8526
#
# Epoch 00062: val_loss did not improve from 0.48568
# Epoch 63/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1435 - acc: 0.9944 - val_loss: 0.4983 - val_acc: 0.8478
#
# Epoch 00063: val_loss did not improve from 0.48568
# Epoch 64/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1415 - acc: 0.9944 - val_loss: 0.4878 - val_acc: 0.8554
#
# Epoch 00064: val_loss did not improve from 0.48568
# Epoch 65/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1373 - acc: 0.9952 - val_loss: 0.4870 - val_acc: 0.8518
#
# Epoch 00065: val_loss did not improve from 0.48568
# Epoch 66/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1342 - acc: 0.9957 - val_loss: 0.4956 - val_acc: 0.8500
#
# Epoch 00066: val_loss did not improve from 0.48568
# Epoch 67/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1302 - acc: 0.9955 - val_loss: 0.4783 - val_acc: 0.8547
#
# Epoch 00067: val_loss improved from 0.48568 to 0.47827, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 68/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1281 - acc: 0.9956 - val_loss: 0.4947 - val_acc: 0.8475
#
# Epoch 00068: val_loss did not improve from 0.47827
# Epoch 69/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1256 - acc: 0.9952 - val_loss: 0.4927 - val_acc: 0.8442
#
# Epoch 00069: val_loss did not improve from 0.47827
# Epoch 70/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1225 - acc: 0.9959 - val_loss: 0.4941 - val_acc: 0.8520
#
# Epoch 00070: val_loss did not improve from 0.47827
# Epoch 71/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1183 - acc: 0.9966 - val_loss: 0.4831 - val_acc: 0.8542
#
# Epoch 00071: val_loss did not improve from 0.47827
# Epoch 72/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1175 - acc: 0.9964 - val_loss: 0.4859 - val_acc: 0.8559
#
# Epoch 00072: val_loss did not improve from 0.47827
# Epoch 73/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1154 - acc: 0.9956 - val_loss: 0.4908 - val_acc: 0.8468
#
# Epoch 00073: val_loss did not improve from 0.47827
# Epoch 74/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1136 - acc: 0.9960 - val_loss: 0.4790 - val_acc: 0.8519
#
# Epoch 00074: val_loss did not improve from 0.47827
# Epoch 75/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1101 - acc: 0.9968 - val_loss: 0.4811 - val_acc: 0.8523
#
# Epoch 00075: val_loss did not improve from 0.47827
# Epoch 76/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1065 - acc: 0.9964 - val_loss: 0.4722 - val_acc: 0.8605
#
# Epoch 00076: val_loss improved from 0.47827 to 0.47217, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 77/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1044 - acc: 0.9969 - val_loss: 0.4770 - val_acc: 0.8572
#
# Epoch 00077: val_loss did not improve from 0.47217
# Epoch 78/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.1016 - acc: 0.9970 - val_loss: 0.4744 - val_acc: 0.8572
#
# Epoch 00078: val_loss did not improve from 0.47217
# Epoch 79/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0986 - acc: 0.9972 - val_loss: 0.4756 - val_acc: 0.8573
#
# Epoch 00079: val_loss did not improve from 0.47217
# Epoch 80/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0980 - acc: 0.9969 - val_loss: 0.4804 - val_acc: 0.8485
#
# Epoch 00080: val_loss did not improve from 0.47217
# Epoch 81/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0956 - acc: 0.9973 - val_loss: 0.4735 - val_acc: 0.8575
#
# Epoch 00081: val_loss did not improve from 0.47217
# Epoch 82/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0926 - acc: 0.9978 - val_loss: 0.4747 - val_acc: 0.8557
#
# Epoch 00082: val_loss did not improve from 0.47217
# Epoch 83/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0931 - acc: 0.9977 - val_loss: 0.4709 - val_acc: 0.8548
#
# Epoch 00083: val_loss improved from 0.47217 to 0.47088, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 84/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0908 - acc: 0.9980 - val_loss: 0.4736 - val_acc: 0.8576
#
# Epoch 00084: val_loss did not improve from 0.47088
# Epoch 85/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0910 - acc: 0.9975 - val_loss: 0.4740 - val_acc: 0.8588
#
# Epoch 00085: val_loss did not improve from 0.47088
# Epoch 86/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0919 - acc: 0.9978 - val_loss: 0.4723 - val_acc: 0.8627
#
# Epoch 00086: val_loss did not improve from 0.47088
# Epoch 87/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0899 - acc: 0.9981 - val_loss: 0.4726 - val_acc: 0.8576
#
# Epoch 00087: val_loss did not improve from 0.47088
# Epoch 88/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0896 - acc: 0.9982 - val_loss: 0.4713 - val_acc: 0.8572
#
# Epoch 00088: val_loss did not improve from 0.47088
# Epoch 89/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0897 - acc: 0.9979 - val_loss: 0.4705 - val_acc: 0.8595
#
# Epoch 00089: val_loss improved from 0.47088 to 0.47045, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 90/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0901 - acc: 0.9983 - val_loss: 0.4697 - val_acc: 0.8607
#
# Epoch 00090: val_loss improved from 0.47045 to 0.46967, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 91/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0894 - acc: 0.9983 - val_loss: 0.4690 - val_acc: 0.8574
#
# Epoch 00091: val_loss improved from 0.46967 to 0.46903, saving model to /content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5
# Epoch 92/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0890 - acc: 0.9983 - val_loss: 0.4718 - val_acc: 0.8574
#
# Epoch 00092: val_loss did not improve from 0.46903
# Epoch 93/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0901 - acc: 0.9981 - val_loss: 0.4728 - val_acc: 0.8579
#
# Epoch 00093: val_loss did not improve from 0.46903
# Epoch 94/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0904 - acc: 0.9977 - val_loss: 0.4732 - val_acc: 0.8546
#
# Epoch 00094: val_loss did not improve from 0.46903
# Epoch 95/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0883 - acc: 0.9984 - val_loss: 0.4747 - val_acc: 0.8542
#
# Epoch 00095: val_loss did not improve from 0.46903
# Epoch 96/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0883 - acc: 0.9979 - val_loss: 0.4720 - val_acc: 0.8584
#
# Epoch 00096: val_loss did not improve from 0.46903
# Epoch 97/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0895 - acc: 0.9978 - val_loss: 0.4751 - val_acc: 0.8560
#
# Epoch 00097: val_loss did not improve from 0.46903
# Epoch 98/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0873 - acc: 0.9980 - val_loss: 0.4732 - val_acc: 0.8580
#
# Epoch 00098: val_loss did not improve from 0.46903
# Epoch 99/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0884 - acc: 0.9979 - val_loss: 0.4749 - val_acc: 0.8564
#
# Epoch 00099: val_loss did not improve from 0.46903
# Epoch 100/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0882 - acc: 0.9983 - val_loss: 0.4750 - val_acc: 0.8579
#
# Epoch 00100: val_loss did not improve from 0.46903
# Epoch 101/600
# 1036/1036 [==============================] - 6s 6ms/step - loss: 0.0874 - acc: 0.9980 - val_loss: 0.4739 - val_acc: 0.8562
#
# Epoch 00101: val_loss did not improve from 0.46903
# results per 6-fold
# 340/340 [==============================] - 1s 3ms/step - loss: 0.4739 - acc: 0.8562
# [[2016   29    0   29  102]
#  [  92 1043   62  190  153]
#  [  15   58 2556  106   54]
#  [  25   72   65 2068  263]
#  [ 100   60   23   66 1631]]
#               precision    recall  f1-score   support
#
#           HC       0.90      0.93      0.91      2176
#          a_H       0.83      0.68      0.74      1540
#          a_K       0.94      0.92      0.93      2789
#          a_A       0.84      0.83      0.84      2493
#          a_C       0.74      0.87      0.80      1880
#
#     accuracy                           0.86     10878
#    macro avg       0.85      0.84      0.84     10878
# weighted avg       0.86      0.86      0.86     10878

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

mmscaler_LSTM.fit(test_COP_ML)
test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

test_x = np.concatenate([test_V[test_index], test_AP[test_index], test_ML[test_index], test_COP_AP[test_index]], axis=2)
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_54 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_55 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 128)               512
# _________________________________________________________________
# activation_57 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 64)                256
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_59 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1546   16   63   50   79]
#  [  23  894  338   73  123]
#  [  32  146 2240   33   68]
#  [  48  116  192 2383  250]
#  [  97  144   90  173 1661]]
#               precision    recall  f1-score   support
#
#           HC    0.88545   0.88141   0.88343      1754
#          a_H    0.67933   0.61613   0.64619      1451
#          a_K    0.76634   0.88924   0.82323      2519
#          a_A    0.87869   0.79726   0.83599      2989
#          a_C    0.76158   0.76721   0.76438      2165
#
#     accuracy                        0.80199     10878
#    macro avg    0.79428   0.79025   0.79064     10878
# weighted avg    0.80386   0.80199   0.80112     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/1fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_20 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_60 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_61 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_40 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_62 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 128)               512
# _________________________________________________________________
# activation_63 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 64)                256
# _________________________________________________________________
# activation_64 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_65 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1412   17   93   61  171]
#  [  46  838  356   99  112]
#  [  26  143 2237   62   51]
#  [ 109   55  234 2335  256]
#  [ 128  114  111  133 1679]]
#               precision    recall  f1-score   support
#
#           HC    0.82045   0.80502   0.81266      1754
#          a_H    0.71808   0.57753   0.64018      1451
#          a_K    0.73804   0.88805   0.80613      2519
#          a_A    0.86803   0.78120   0.82233      2989
#          a_C    0.73997   0.77552   0.75733      2165
#
#     accuracy                        0.78149     10878
#    macro avg    0.77692   0.76546   0.76773     10878
# weighted avg    0.78477   0.78149   0.77979     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_22 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_66 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_67 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_44 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_68 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 128)               512
# _________________________________________________________________
# activation_69 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 64)                256
# _________________________________________________________________
# activation_70 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_47 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_71 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1591   20   50   37   56]
#  [  35  792  354   63  207]
#  [  41   57 2338   19   64]
#  [  68   52  185 2331  353]
#  [ 126   85   71   79 1804]]
#               precision    recall  f1-score   support
#
#           HC    0.85492   0.90707   0.88022      1754
#          a_H    0.78728   0.54583   0.64469      1451
#          a_K    0.77985   0.92815   0.84756      2519
#          a_A    0.92171   0.77986   0.84487      2989
#          a_C    0.72625   0.83326   0.77608      2165
#
#     accuracy                        0.81412     10878
#    macro avg    0.81400   0.79883   0.79868     10878
# weighted avg    0.82126   0.81412   0.81080     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_24 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_72 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_72 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_73 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_73 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_74 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 128)               512
# _________________________________________________________________
# activation_75 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 64)                256
# _________________________________________________________________
# activation_76 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_51 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_77 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1611    0   20   38   85]
#  [  42  966  323    9  111]
#  [  58   65 2278   55   63]
#  [  50  123  169 2398  249]
#  [  94  122   37  104 1808]]
#               precision    recall  f1-score   support
#
#           HC    0.86846   0.91847   0.89277      1754
#          a_H    0.75705   0.66575   0.70847      1451
#          a_K    0.80580   0.90433   0.85223      2519
#          a_A    0.92089   0.80228   0.85750      2989
#          a_C    0.78066   0.83510   0.80696      2165
#
#     accuracy                        0.83297     10878
#    macro avg    0.82657   0.82519   0.82359     10878
# weighted avg    0.83602   0.83297   0.83203     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_26 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_78 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_78 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_79 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_79 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_80 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_80 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_81 (Batc (None, 128)               512
# _________________________________________________________________
# activation_81 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_82 (Batc (None, 64)                256
# _________________________________________________________________
# activation_82 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_83 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_83 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1546    8   57   51   92]
#  [  62  841  334   73  141]
#  [  29   74 2316   37   63]
#  [  99   54  213 2395  228]
#  [ 116   71  101  141 1736]]
#               precision    recall  f1-score   support
#
#           HC    0.83477   0.88141   0.85746      1754
#          a_H    0.80248   0.57960   0.67307      1451
#          a_K    0.76663   0.91941   0.83610      2519
#          a_A    0.88802   0.80127   0.84242      2989
#          a_C    0.76814   0.80185   0.78463      2165
#
#     accuracy                        0.81210     10878
#    macro avg    0.81201   0.79671   0.79874     10878
# weighted avg    0.81606   0.81210   0.80929     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_28 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_84 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_84 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_85 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_85 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_56 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_86 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_86 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 128)               512
# _________________________________________________________________
# activation_87 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_88 (Batc (None, 64)                256
# _________________________________________________________________
# activation_88 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_59 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_89 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1540    8   72   19  115]
#  [  23  989  299   10  130]
#  [  26  100 2328    0   65]
#  [  74  104  193 2321  297]
#  [  77  138  101   39 1810]]
#               precision    recall  f1-score   support
#
#           HC    0.88506   0.87799   0.88151      1754
#          a_H    0.73861   0.68160   0.70896      1451
#          a_K    0.77781   0.92418   0.84470      2519
#          a_A    0.97154   0.77651   0.86315      2989
#          a_C    0.74886   0.83603   0.79005      2165
#
#     accuracy                        0.82625     10878
#    macro avg    0.82438   0.81926   0.81767     10878
# weighted avg    0.83735   0.82625   0.82672     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_3DGRF_APCOP_1DCNN_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_30 (Conv1D)           (None, 101, 128)          1664
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 101, 128)          512
# _________________________________________________________________
# activation_90 (Activation)   (None, 101, 128)          0
# _________________________________________________________________
# max_pooling1d_30 (MaxPooling (None, 50, 128)           0
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 50, 256)           98560
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 50, 256)           1024
# _________________________________________________________________
# activation_91 (Activation)   (None, 50, 256)           0
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 25, 256)           0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_60 (Dense)             (None, 256)               1638656
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_92 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 128)               512
# _________________________________________________________________
# activation_93 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 64)                256
# _________________________________________________________________
# activation_94 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_95 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,783,705
# Trainable params: 1,782,031
# Non-trainable params: 1,674
# _________________________________________________________________
# [[1563   26   30   60   75]
#  [  38  894  305   41  173]
#  [  37   86 2330    7   59]
#  [  39  127  198 2331  294]
#  [  60  117   68  133 1787]]
#               precision    recall  f1-score   support
#
#           HC    0.89983   0.89111   0.89545      1754
#          a_H    0.71520   0.61613   0.66198      1451
#          a_K    0.79495   0.92497   0.85505      2519
#          a_A    0.90630   0.77986   0.83834      2989
#          a_C    0.74832   0.82540   0.78498      2165
#
#     accuracy                        0.81862     10878
#    macro avg    0.81292   0.80749   0.80716     10878
# weighted avg    0.82254   0.81862   0.81727     10878
