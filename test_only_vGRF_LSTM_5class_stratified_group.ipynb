# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_only_vGRF_LSTM_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# # Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# # StratifiedGroupKFoldの分割結果をpickle
import pickle

# test
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# trainig and validation
with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
   COP_ML = pickle.load(f)
f.close()

# label
with open("/content/drive/MyDrive/test_data/train_idx_list.pickle", mode="rb") as f:
   train_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   label = pickle.load(f)
f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    test_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    test_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()

# # trainig and validation
# with open("V_val_train.pickle", mode="rb") as f:
#    V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    COP_ML = pickle.load(f)
# f.close()

# # label
# with open("train_idx_list.pickle", mode="rb") as f:
#    train_index_list = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("label_val_train.pickle", mode="rb") as f:
#    label = pickle.load(f)
# f.close()

# with open("test_sub_ID.pickle", mode="rb") as f:
#    sub_ID=pickle.load(f)
# f.close()

# import pandas as pd

# with open("test_data_index.pickle", mode="rb") as f:
#    test_index = pickle.load(f)
# f.close()

# %%
import numpy as np
print(np.where(label==0)[0].shape)
print(np.where(label==1)[0].shape)
print(np.where(label==2)[0].shape)
print(np.where(label==3)[0].shape)
print(np.where(label==4)[0].shape)
# Out:
# (13756,)
# (11862,)
# (17630,)
# (18557,)
# (14341,)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(V)
V = mmscaler_LSTM.transform(V)
V = V.reshape(V.shape[0], V.shape[1], 1)

mmscaler_LSTM.fit(AP)
AP = mmscaler_LSTM.transform(AP)
AP = AP.reshape(AP.shape[0], AP.shape[1], 1)

mmscaler_LSTM.fit(ML)
ML = mmscaler_LSTM.transform(ML)
ML = ML.reshape(ML.shape[0], ML.shape[1], 1)

mmscaler_LSTM.fit(COP_AP)
COP_AP = mmscaler_LSTM.transform(COP_AP)
COP_AP = COP_AP.reshape(COP_AP.shape[0], COP_AP.shape[1], 1)

mmscaler_LSTM.fit(COP_ML)
COP_ML = mmscaler_LSTM.transform(COP_ML)
COP_ML = COP_ML.reshape(COP_ML.shape[0], COP_ML.shape[1], 1)

# %%
# !pip install keras-layer-normalization
# !pip install keras-self-attention
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=fdc3198257f9ebfe749126bb13026cb633e8bee5668288815ad475d2298fcdf3
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_vGRF_LSTM_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

initializer = he_normal()

classes_main = 5

#LSTM-----------------------------------------------------------------------------------------------------------------------
def build_model():
  # LSTM
  # 最初これだけだった
  model = Sequential()
  model.add(InputLayer(input_shape=(101, 1)))

  model.add(Bidirectional(LSTM(512, return_sequences=True)))
  # model.add(LSTM(256, return_sequences=True))
  model.add(LayerNormalization())
  model.add(Activation('tanh'))
  model.add(Dropout(0.5))
  
  model.add(Flatten())

  model.add(Dense(512, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#------------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

EPOCHS = 500

val_label_list = []
train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(7):
  train_index = train_index_list[i]
  train_LSTM_data = V[train_index]
  val_index = val_index_list[i]
  val_LSTM_data = V[val_index]
  
  # label
  train_label = label[train_index] 
  val_label= label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  # MAX = len(train_LSTM_data)

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)
# train_data (65268, 101, 1)
# val_data (10878, 101, 1)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )

  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# %%
i=2

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 76 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11736,)
# H (9990,)
# K (15491,)
# A (15652,)
# C (12399,)
# Epoch 1/400
# 1036/1036 [==============================] - 104s 68ms/step - loss: 0.3456 - acc: 0.9251 - val_loss: 0.7617 - val_acc: 0.7278
#
# Epoch 00001: val_loss improved from inf to 0.76174, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3439 - acc: 0.9252 - val_loss: 0.7613 - val_acc: 0.7310
#
# Epoch 00002: val_loss improved from 0.76174 to 0.76126, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
#  900/1036 [=========================>....] - ETA: 8s - loss: 0.3441 - acc: 0.9245

# %%
i=2

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 74 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11736,)
# H (9990,)
# K (15491,)
# A (15652,)
# C (12399,)
# Epoch 1/400
# 1036/1036 [==============================] - 103s 66ms/step - loss: 0.3429 - acc: 0.9262 - val_loss: 0.7631 - val_acc: 0.7281
#
# Epoch 00001: val_loss improved from inf to 0.76313, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3432 - acc: 0.9266 - val_loss: 0.7569 - val_acc: 0.7319
#
# Epoch 00002: val_loss improved from 0.76313 to 0.75694, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3409 - acc: 0.9260 - val_loss: 0.7604 - val_acc: 0.7290
#
# Epoch 00003: val_loss did not improve from 0.75694
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3393 - acc: 0.9251 - val_loss: 0.7567 - val_acc: 0.7284
#
# Epoch 00004: val_loss improved from 0.75694 to 0.75670, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3349 - acc: 0.9301 - val_loss: 0.7553 - val_acc: 0.7335
#
# Epoch 00005: val_loss improved from 0.75670 to 0.75532, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3354 - acc: 0.9289 - val_loss: 0.7583 - val_acc: 0.7315
#
# Epoch 00006: val_loss did not improve from 0.75532
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3335 - acc: 0.9302 - val_loss: 0.7587 - val_acc: 0.7309
#
# Epoch 00007: val_loss did not improve from 0.75532
# Epoch 8/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3338 - acc: 0.9290 - val_loss: 0.7603 - val_acc: 0.7347
#
# Epoch 00008: val_loss did not improve from 0.75532
# Epoch 9/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3345 - acc: 0.9289 - val_loss: 0.7617 - val_acc: 0.7333
#
# Epoch 00009: val_loss did not improve from 0.75532
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3339 - acc: 0.9275 - val_loss: 0.7556 - val_acc: 0.7320
#
# Epoch 00010: val_loss did not improve from 0.75532
# Epoch 11/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3323 - acc: 0.9299 - val_loss: 0.7592 - val_acc: 0.7351
#
# Epoch 00011: val_loss did not improve from 0.75532
# Epoch 12/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3303 - acc: 0.9311 - val_loss: 0.7545 - val_acc: 0.7329
#
# Epoch 00012: val_loss improved from 0.75532 to 0.75447, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3315 - acc: 0.9296 - val_loss: 0.7559 - val_acc: 0.7357
#
# Epoch 00013: val_loss did not improve from 0.75447
# Epoch 14/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3280 - acc: 0.9308 - val_loss: 0.7576 - val_acc: 0.7363
#
# Epoch 00014: val_loss did not improve from 0.75447
# Epoch 15/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3302 - acc: 0.9306 - val_loss: 0.7532 - val_acc: 0.7379
#
# Epoch 00015: val_loss improved from 0.75447 to 0.75323, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3310 - acc: 0.9295 - val_loss: 0.7573 - val_acc: 0.7356
#
# Epoch 00016: val_loss did not improve from 0.75323
# Epoch 17/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3295 - acc: 0.9296 - val_loss: 0.7578 - val_acc: 0.7381
#
# Epoch 00017: val_loss did not improve from 0.75323
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3304 - acc: 0.9303 - val_loss: 0.7551 - val_acc: 0.7352
#
# Epoch 00018: val_loss did not improve from 0.75323
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3245 - acc: 0.9322 - val_loss: 0.7524 - val_acc: 0.7398
#
# Epoch 00019: val_loss improved from 0.75323 to 0.75242, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3264 - acc: 0.9316 - val_loss: 0.7527 - val_acc: 0.7417
#
# Epoch 00020: val_loss did not improve from 0.75242
# Epoch 21/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3243 - acc: 0.9342 - val_loss: 0.7540 - val_acc: 0.7375
#
# Epoch 00021: val_loss did not improve from 0.75242
# Epoch 22/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3242 - acc: 0.9345 - val_loss: 0.7530 - val_acc: 0.7371
#
# Epoch 00022: val_loss did not improve from 0.75242
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3226 - acc: 0.9328 - val_loss: 0.7549 - val_acc: 0.7363
#
# Epoch 00023: val_loss did not improve from 0.75242
# Epoch 24/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3249 - acc: 0.9313 - val_loss: 0.7540 - val_acc: 0.7361
#
# Epoch 00024: val_loss did not improve from 0.75242
# Epoch 25/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3226 - acc: 0.9331 - val_loss: 0.7590 - val_acc: 0.7352
#
# Epoch 00025: val_loss did not improve from 0.75242
# Epoch 26/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3204 - acc: 0.9342 - val_loss: 0.7558 - val_acc: 0.7329
#
# Epoch 00026: val_loss did not improve from 0.75242
# Epoch 27/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3215 - acc: 0.9343 - val_loss: 0.7570 - val_acc: 0.7366
#
# Epoch 00027: val_loss did not improve from 0.75242
# Epoch 28/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3216 - acc: 0.9323 - val_loss: 0.7532 - val_acc: 0.7396
#
# Epoch 00028: val_loss did not improve from 0.75242
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3170 - acc: 0.9350 - val_loss: 0.7502 - val_acc: 0.7425
#
# Epoch 00029: val_loss improved from 0.75242 to 0.75018, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3196 - acc: 0.9328 - val_loss: 0.7533 - val_acc: 0.7369
#
# Epoch 00030: val_loss did not improve from 0.75018
# Epoch 31/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.3220 - acc: 0.9301 - val_loss: 0.7557 - val_acc: 0.7318
#
# Epoch 00031: val_loss did not improve from 0.75018
# Epoch 32/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3193 - acc: 0.9349 - val_loss: 0.7554 - val_acc: 0.7362
#
# Epoch 00032: val_loss did not improve from 0.75018
# Epoch 33/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3186 - acc: 0.9343 - val_loss: 0.7572 - val_acc: 0.7364
#
# Epoch 00033: val_loss did not improve from 0.75018
# Epoch 34/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3158 - acc: 0.9352 - val_loss: 0.7579 - val_acc: 0.7366
#
# Epoch 00034: val_loss did not improve from 0.75018
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3197 - acc: 0.9326 - val_loss: 0.7591 - val_acc: 0.7410
#
# Epoch 00035: val_loss did not improve from 0.75018
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3148 - acc: 0.9351 - val_loss: 0.7551 - val_acc: 0.7400
#
# Epoch 00036: val_loss did not improve from 0.75018
# Epoch 37/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3166 - acc: 0.9360 - val_loss: 0.7562 - val_acc: 0.7424
#
# Epoch 00037: val_loss did not improve from 0.75018
# Epoch 38/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3144 - acc: 0.9358 - val_loss: 0.7550 - val_acc: 0.7418
#
# Epoch 00038: val_loss did not improve from 0.75018
# Epoch 39/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3117 - acc: 0.9374 - val_loss: 0.7556 - val_acc: 0.7396
#
# Epoch 00039: val_loss did not improve from 0.75018
# results per 2-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.7556 - acc: 0.7396
# [[1743   80  131   39   27]
#  [ 125 1155  283  200  109]
#  [  17  109 1671  189  153]
#  [ 188   92  311 2117  197]
#  [  88  108  265  122 1359]]
#               precision    recall  f1-score   support
#
#           HC       0.81      0.86      0.83      2020
#          a_H       0.75      0.62      0.68      1872
#          a_K       0.63      0.78      0.70      2139
#          a_A       0.79      0.73      0.76      2905
#          a_C       0.74      0.70      0.72      1942
#
#     accuracy                           0.74     10878
#    macro avg       0.74      0.74      0.74     10878
# weighted avg       0.75      0.74      0.74     10878

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

for i in range(3, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )

  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (12396,)
# H (10200,)
# K (14405,)
# A (16112,)
# C (12155,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 68ms/step - loss: 1.7234 - acc: 0.2601 - val_loss: 1.5661 - val_acc: 0.2777
#
# Epoch 00001: val_loss improved from inf to 1.56606, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.5033 - acc: 0.3412 - val_loss: 1.5319 - val_acc: 0.3183
#
# Epoch 00002: val_loss improved from 1.56606 to 1.53187, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.4414 - acc: 0.3835 - val_loss: 1.4986 - val_acc: 0.3429
#
# Epoch 00003: val_loss improved from 1.53187 to 1.49857, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3863 - acc: 0.4154 - val_loss: 1.4578 - val_acc: 0.3744
#
# Epoch 00004: val_loss improved from 1.49857 to 1.45782, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.3358 - acc: 0.4435 - val_loss: 1.4439 - val_acc: 0.3870
#
# Epoch 00005: val_loss improved from 1.45782 to 1.44391, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2952 - acc: 0.4691 - val_loss: 1.4052 - val_acc: 0.4137
#
# Epoch 00006: val_loss improved from 1.44391 to 1.40517, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.2529 - acc: 0.4910 - val_loss: 1.3840 - val_acc: 0.4208
#
# Epoch 00007: val_loss improved from 1.40517 to 1.38399, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2170 - acc: 0.5134 - val_loss: 1.3560 - val_acc: 0.4352
#
# Epoch 00008: val_loss improved from 1.38399 to 1.35596, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1862 - acc: 0.5288 - val_loss: 1.3326 - val_acc: 0.4594
#
# Epoch 00009: val_loss improved from 1.35596 to 1.33258, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.1516 - acc: 0.5509 - val_loss: 1.3486 - val_acc: 0.4493
#
# Epoch 00010: val_loss did not improve from 1.33258
# Epoch 11/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.1261 - acc: 0.5629 - val_loss: 1.2966 - val_acc: 0.4893
#
# Epoch 00011: val_loss improved from 1.33258 to 1.29663, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.0971 - acc: 0.5802 - val_loss: 1.2976 - val_acc: 0.4842
#
# Epoch 00012: val_loss did not improve from 1.29663
# Epoch 13/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0748 - acc: 0.5928 - val_loss: 1.2953 - val_acc: 0.4767
#
# Epoch 00013: val_loss improved from 1.29663 to 1.29525, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0527 - acc: 0.6006 - val_loss: 1.2542 - val_acc: 0.4981
#
# Epoch 00014: val_loss improved from 1.29525 to 1.25419, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.0283 - acc: 0.6144 - val_loss: 1.2664 - val_acc: 0.4915
#
# Epoch 00015: val_loss did not improve from 1.25419
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.0098 - acc: 0.6245 - val_loss: 1.2232 - val_acc: 0.5144
#
# Epoch 00016: val_loss improved from 1.25419 to 1.22317, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9896 - acc: 0.6358 - val_loss: 1.2482 - val_acc: 0.5031
#
# Epoch 00017: val_loss did not improve from 1.22317
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.9680 - acc: 0.6482 - val_loss: 1.1984 - val_acc: 0.5199
#
# Epoch 00018: val_loss improved from 1.22317 to 1.19843, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9498 - acc: 0.6608 - val_loss: 1.1908 - val_acc: 0.5183
#
# Epoch 00019: val_loss improved from 1.19843 to 1.19076, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9319 - acc: 0.6677 - val_loss: 1.1920 - val_acc: 0.5298
#
# Epoch 00020: val_loss did not improve from 1.19076
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9151 - acc: 0.6772 - val_loss: 1.1774 - val_acc: 0.5349
#
# Epoch 00021: val_loss improved from 1.19076 to 1.17744, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8956 - acc: 0.6876 - val_loss: 1.1662 - val_acc: 0.5367
#
# Epoch 00022: val_loss improved from 1.17744 to 1.16617, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8796 - acc: 0.6984 - val_loss: 1.1529 - val_acc: 0.5454
#
# Epoch 00023: val_loss improved from 1.16617 to 1.15294, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8590 - acc: 0.7051 - val_loss: 1.1448 - val_acc: 0.5532
#
# Epoch 00024: val_loss improved from 1.15294 to 1.14481, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8472 - acc: 0.7112 - val_loss: 1.1315 - val_acc: 0.5710
#
# Epoch 00025: val_loss improved from 1.14481 to 1.13151, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8360 - acc: 0.7168 - val_loss: 1.1306 - val_acc: 0.5655
#
# Epoch 00026: val_loss improved from 1.13151 to 1.13063, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.8183 - acc: 0.7220 - val_loss: 1.1107 - val_acc: 0.5629
#
# Epoch 00027: val_loss improved from 1.13063 to 1.11075, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.8010 - acc: 0.7344 - val_loss: 1.0925 - val_acc: 0.5758
#
# Epoch 00028: val_loss improved from 1.11075 to 1.09251, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7900 - acc: 0.7380 - val_loss: 1.1036 - val_acc: 0.5850
#
# Epoch 00029: val_loss did not improve from 1.09251
# Epoch 30/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7777 - acc: 0.7450 - val_loss: 1.0866 - val_acc: 0.5895
#
# Epoch 00030: val_loss improved from 1.09251 to 1.08661, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7611 - acc: 0.7547 - val_loss: 1.0889 - val_acc: 0.5815
#
# Epoch 00031: val_loss did not improve from 1.08661
# Epoch 32/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7461 - acc: 0.7625 - val_loss: 1.0532 - val_acc: 0.5899
#
# Epoch 00032: val_loss improved from 1.08661 to 1.05321, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7357 - acc: 0.7673 - val_loss: 1.0598 - val_acc: 0.6000
#
# Epoch 00033: val_loss did not improve from 1.05321
# Epoch 34/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7294 - acc: 0.7692 - val_loss: 1.0635 - val_acc: 0.5978
#
# Epoch 00034: val_loss did not improve from 1.05321
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.7127 - acc: 0.7773 - val_loss: 1.0489 - val_acc: 0.6020
#
# Epoch 00035: val_loss improved from 1.05321 to 1.04893, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.7050 - acc: 0.7795 - val_loss: 1.0300 - val_acc: 0.6210
#
# Epoch 00036: val_loss improved from 1.04893 to 1.03003, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6925 - acc: 0.7860 - val_loss: 1.0346 - val_acc: 0.6214
#
# Epoch 00037: val_loss did not improve from 1.03003
# Epoch 38/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6795 - acc: 0.7934 - val_loss: 1.0309 - val_acc: 0.6186
#
# Epoch 00038: val_loss did not improve from 1.03003
# Epoch 39/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6695 - acc: 0.7950 - val_loss: 1.0201 - val_acc: 0.6158
#
# Epoch 00039: val_loss improved from 1.03003 to 1.02010, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6593 - acc: 0.8015 - val_loss: 1.0337 - val_acc: 0.6084
#
# Epoch 00040: val_loss did not improve from 1.02010
# Epoch 41/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6445 - acc: 0.8088 - val_loss: 1.0075 - val_acc: 0.6225
#
# Epoch 00041: val_loss improved from 1.02010 to 1.00747, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6344 - acc: 0.8115 - val_loss: 1.0114 - val_acc: 0.6254
#
# Epoch 00042: val_loss did not improve from 1.00747
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6280 - acc: 0.8146 - val_loss: 1.0114 - val_acc: 0.6211
#
# Epoch 00043: val_loss did not improve from 1.00747
# Epoch 44/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.6192 - acc: 0.8178 - val_loss: 0.9995 - val_acc: 0.6338
#
# Epoch 00044: val_loss improved from 1.00747 to 0.99951, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6049 - acc: 0.8258 - val_loss: 0.9849 - val_acc: 0.6392
#
# Epoch 00045: val_loss improved from 0.99951 to 0.98491, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5954 - acc: 0.8286 - val_loss: 1.0130 - val_acc: 0.6260
#
# Epoch 00046: val_loss did not improve from 0.98491
# Epoch 47/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5846 - acc: 0.8357 - val_loss: 0.9953 - val_acc: 0.6298
#
# Epoch 00047: val_loss did not improve from 0.98491
# Epoch 48/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5775 - acc: 0.8352 - val_loss: 0.9685 - val_acc: 0.6410
#
# Epoch 00048: val_loss improved from 0.98491 to 0.96855, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5698 - acc: 0.8372 - val_loss: 0.9646 - val_acc: 0.6408
#
# Epoch 00049: val_loss improved from 0.96855 to 0.96463, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5639 - acc: 0.8392 - val_loss: 0.9591 - val_acc: 0.6477
#
# Epoch 00050: val_loss improved from 0.96463 to 0.95910, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 51/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5481 - acc: 0.8485 - val_loss: 0.9533 - val_acc: 0.6482
#
# Epoch 00051: val_loss improved from 0.95910 to 0.95333, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5436 - acc: 0.8497 - val_loss: 0.9784 - val_acc: 0.6368
#
# Epoch 00052: val_loss did not improve from 0.95333
# Epoch 53/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5321 - acc: 0.8552 - val_loss: 0.9668 - val_acc: 0.6347
#
# Epoch 00053: val_loss did not improve from 0.95333
# Epoch 54/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5258 - acc: 0.8566 - val_loss: 0.9592 - val_acc: 0.6555
#
# Epoch 00054: val_loss did not improve from 0.95333
# Epoch 55/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5205 - acc: 0.8592 - val_loss: 0.9669 - val_acc: 0.6516
#
# Epoch 00055: val_loss did not improve from 0.95333
# Epoch 56/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.5079 - acc: 0.8632 - val_loss: 0.9592 - val_acc: 0.6552
#
# Epoch 00056: val_loss did not improve from 0.95333
# Epoch 57/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.5025 - acc: 0.8643 - val_loss: 0.9478 - val_acc: 0.6524
#
# Epoch 00057: val_loss improved from 0.95333 to 0.94777, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4930 - acc: 0.8692 - val_loss: 0.9475 - val_acc: 0.6496
#
# Epoch 00058: val_loss improved from 0.94777 to 0.94746, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 59/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4853 - acc: 0.8717 - val_loss: 0.9407 - val_acc: 0.6634
#
# Epoch 00059: val_loss improved from 0.94746 to 0.94072, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 60/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4794 - acc: 0.8735 - val_loss: 0.9523 - val_acc: 0.6536
#
# Epoch 00060: val_loss did not improve from 0.94072
# Epoch 61/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4721 - acc: 0.8782 - val_loss: 0.9682 - val_acc: 0.6466
#
# Epoch 00061: val_loss did not improve from 0.94072
# Epoch 62/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4653 - acc: 0.8790 - val_loss: 0.9406 - val_acc: 0.6621
#
# Epoch 00062: val_loss improved from 0.94072 to 0.94064, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 63/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.4558 - acc: 0.8833 - val_loss: 0.9320 - val_acc: 0.6587
#
# Epoch 00063: val_loss improved from 0.94064 to 0.93198, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 64/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4479 - acc: 0.8868 - val_loss: 0.9397 - val_acc: 0.6624
#
# Epoch 00064: val_loss did not improve from 0.93198
# Epoch 65/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4485 - acc: 0.8837 - val_loss: 0.9374 - val_acc: 0.6591
#
# Epoch 00065: val_loss did not improve from 0.93198
# Epoch 66/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4388 - acc: 0.8873 - val_loss: 0.9293 - val_acc: 0.6678
#
# Epoch 00066: val_loss improved from 0.93198 to 0.92932, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 67/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4323 - acc: 0.8910 - val_loss: 0.9209 - val_acc: 0.6602
#
# Epoch 00067: val_loss improved from 0.92932 to 0.92086, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 68/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.4252 - acc: 0.8944 - val_loss: 0.9501 - val_acc: 0.6511
#
# Epoch 00068: val_loss did not improve from 0.92086
# Epoch 69/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4158 - acc: 0.8959 - val_loss: 0.9288 - val_acc: 0.6632
#
# Epoch 00069: val_loss did not improve from 0.92086
# Epoch 70/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4096 - acc: 0.9009 - val_loss: 0.9277 - val_acc: 0.6665
#
# Epoch 00070: val_loss did not improve from 0.92086
# Epoch 71/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.4067 - acc: 0.8992 - val_loss: 0.9454 - val_acc: 0.6611
#
# Epoch 00071: val_loss did not improve from 0.92086
# Epoch 72/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3980 - acc: 0.9038 - val_loss: 0.9278 - val_acc: 0.6710
#
# Epoch 00072: val_loss did not improve from 0.92086
# Epoch 73/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3984 - acc: 0.9034 - val_loss: 0.9165 - val_acc: 0.6809
#
# Epoch 00073: val_loss improved from 0.92086 to 0.91650, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 74/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.3881 - acc: 0.9065 - val_loss: 0.9331 - val_acc: 0.6691
#
# Epoch 00074: val_loss did not improve from 0.91650
# Epoch 75/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3823 - acc: 0.9089 - val_loss: 0.9207 - val_acc: 0.6702
#
# Epoch 00075: val_loss did not improve from 0.91650
# Epoch 76/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3760 - acc: 0.9101 - val_loss: 0.9202 - val_acc: 0.6737
#
# Epoch 00076: val_loss did not improve from 0.91650
# Epoch 77/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3714 - acc: 0.9128 - val_loss: 0.9348 - val_acc: 0.6692
#
# Epoch 00077: val_loss did not improve from 0.91650
# Epoch 78/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3687 - acc: 0.9109 - val_loss: 0.9414 - val_acc: 0.6580
#
# Epoch 00078: val_loss did not improve from 0.91650
# Epoch 79/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3663 - acc: 0.9118 - val_loss: 0.9238 - val_acc: 0.6649
#
# Epoch 00079: val_loss did not improve from 0.91650
# Epoch 80/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3508 - acc: 0.9218 - val_loss: 0.9299 - val_acc: 0.6721
#
# Epoch 00080: val_loss did not improve from 0.91650
# Epoch 81/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3460 - acc: 0.9203 - val_loss: 0.9200 - val_acc: 0.6791
#
# Epoch 00081: val_loss did not improve from 0.91650
# Epoch 82/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3384 - acc: 0.9255 - val_loss: 0.9177 - val_acc: 0.6750
#
# Epoch 00082: val_loss did not improve from 0.91650
# Epoch 83/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3357 - acc: 0.9268 - val_loss: 0.9163 - val_acc: 0.6756
#
# Epoch 00083: val_loss improved from 0.91650 to 0.91634, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 84/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3323 - acc: 0.9279 - val_loss: 0.9149 - val_acc: 0.6757
#
# Epoch 00084: val_loss improved from 0.91634 to 0.91495, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 85/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3325 - acc: 0.9269 - val_loss: 0.9126 - val_acc: 0.6746
#
# Epoch 00085: val_loss improved from 0.91495 to 0.91265, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 86/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3274 - acc: 0.9306 - val_loss: 0.9148 - val_acc: 0.6702
#
# Epoch 00086: val_loss did not improve from 0.91265
# Epoch 87/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3289 - acc: 0.9283 - val_loss: 0.9099 - val_acc: 0.6713
#
# Epoch 00087: val_loss improved from 0.91265 to 0.90988, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 88/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3268 - acc: 0.9287 - val_loss: 0.9126 - val_acc: 0.6694
#
# Epoch 00088: val_loss did not improve from 0.90988
# Epoch 89/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3243 - acc: 0.9308 - val_loss: 0.9117 - val_acc: 0.6694
#
# Epoch 00089: val_loss did not improve from 0.90988
# Epoch 90/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3268 - acc: 0.9302 - val_loss: 0.9090 - val_acc: 0.6697
#
# Epoch 00090: val_loss improved from 0.90988 to 0.90903, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 91/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3244 - acc: 0.9319 - val_loss: 0.9097 - val_acc: 0.6752
#
# Epoch 00091: val_loss did not improve from 0.90903
# Epoch 92/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3234 - acc: 0.9312 - val_loss: 0.9125 - val_acc: 0.6669
#
# Epoch 00092: val_loss did not improve from 0.90903
# Epoch 93/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3245 - acc: 0.9295 - val_loss: 0.9113 - val_acc: 0.6737
#
# Epoch 00093: val_loss did not improve from 0.90903
# Epoch 94/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3213 - acc: 0.9322 - val_loss: 0.9068 - val_acc: 0.6761
#
# Epoch 00094: val_loss improved from 0.90903 to 0.90682, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 95/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3162 - acc: 0.9353 - val_loss: 0.9086 - val_acc: 0.6754
#
# Epoch 00095: val_loss did not improve from 0.90682
# Epoch 96/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3238 - acc: 0.9303 - val_loss: 0.9074 - val_acc: 0.6737
#
# Epoch 00096: val_loss did not improve from 0.90682
# Epoch 97/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3188 - acc: 0.9345 - val_loss: 0.9042 - val_acc: 0.6723
#
# Epoch 00097: val_loss improved from 0.90682 to 0.90425, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 98/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3209 - acc: 0.9318 - val_loss: 0.9092 - val_acc: 0.6766
#
# Epoch 00098: val_loss did not improve from 0.90425
# Epoch 99/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3213 - acc: 0.9317 - val_loss: 0.9095 - val_acc: 0.6732
#
# Epoch 00099: val_loss did not improve from 0.90425
# Epoch 100/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3191 - acc: 0.9343 - val_loss: 0.9100 - val_acc: 0.6763
#
# Epoch 00100: val_loss did not improve from 0.90425
# Epoch 101/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3170 - acc: 0.9341 - val_loss: 0.9043 - val_acc: 0.6825
#
# Epoch 00101: val_loss did not improve from 0.90425
# Epoch 102/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3177 - acc: 0.9343 - val_loss: 0.9006 - val_acc: 0.6820
#
# Epoch 00102: val_loss improved from 0.90425 to 0.90058, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 103/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3164 - acc: 0.9337 - val_loss: 0.9018 - val_acc: 0.6790
#
# Epoch 00103: val_loss did not improve from 0.90058
# Epoch 104/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3159 - acc: 0.9333 - val_loss: 0.9050 - val_acc: 0.6737
#
# Epoch 00104: val_loss did not improve from 0.90058
# Epoch 105/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3144 - acc: 0.9364 - val_loss: 0.9053 - val_acc: 0.6768
#
# Epoch 00105: val_loss did not improve from 0.90058
# Epoch 106/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3122 - acc: 0.9353 - val_loss: 0.9038 - val_acc: 0.6805
#
# Epoch 00106: val_loss did not improve from 0.90058
# Epoch 107/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3129 - acc: 0.9354 - val_loss: 0.9061 - val_acc: 0.6719
#
# Epoch 00107: val_loss did not improve from 0.90058
# Epoch 108/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3132 - acc: 0.9345 - val_loss: 0.9080 - val_acc: 0.6732
#
# Epoch 00108: val_loss did not improve from 0.90058
# Epoch 109/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.3133 - acc: 0.9339 - val_loss: 0.9063 - val_acc: 0.6735
#
# Epoch 00109: val_loss did not improve from 0.90058
# Epoch 110/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3130 - acc: 0.9350 - val_loss: 0.9026 - val_acc: 0.6726
#
# Epoch 00110: val_loss did not improve from 0.90058
# Epoch 111/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.3143 - acc: 0.9339 - val_loss: 0.9012 - val_acc: 0.6721
#
# Epoch 00111: val_loss did not improve from 0.90058
# Epoch 112/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.3084 - acc: 0.9367 - val_loss: 0.9056 - val_acc: 0.6666
#
# Epoch 00112: val_loss did not improve from 0.90058
# results per 3-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.9056 - acc: 0.6666
# [[1034    7   57  159  103]
#  [ 184  963  221  220   74]
#  [ 216  174 2247  375  213]
#  [ 113   66  380 1710  176]
#  [ 165  108  339  277 1297]]
#               precision    recall  f1-score   support
#
#           HC       0.60      0.76      0.67      1360
#          a_H       0.73      0.58      0.65      1662
#          a_K       0.69      0.70      0.69      3225
#          a_A       0.62      0.70      0.66      2445
#          a_C       0.70      0.59      0.64      2186
#
#     accuracy                           0.67     10878
#    macro avg       0.67      0.67      0.66     10878
# weighted avg       0.67      0.67      0.67     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11732,)
# H (10284,)
# K (15374,)
# A (15728,)
# C (12150,)
# Epoch 1/400
# 1036/1036 [==============================] - 74s 69ms/step - loss: 1.6904 - acc: 0.2579 - val_loss: 1.5885 - val_acc: 0.2861
#
# Epoch 00001: val_loss improved from inf to 1.58855, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.5055 - acc: 0.3416 - val_loss: 1.5039 - val_acc: 0.3596
#
# Epoch 00002: val_loss improved from 1.58855 to 1.50386, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.4397 - acc: 0.3770 - val_loss: 1.4695 - val_acc: 0.3638
#
# Epoch 00003: val_loss improved from 1.50386 to 1.46955, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3842 - acc: 0.4175 - val_loss: 1.4404 - val_acc: 0.3862
#
# Epoch 00004: val_loss improved from 1.46955 to 1.44035, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.3352 - acc: 0.4436 - val_loss: 1.4145 - val_acc: 0.4073
#
# Epoch 00005: val_loss improved from 1.44035 to 1.41452, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2915 - acc: 0.4667 - val_loss: 1.3747 - val_acc: 0.4425
#
# Epoch 00006: val_loss improved from 1.41452 to 1.37466, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2472 - acc: 0.4953 - val_loss: 1.3509 - val_acc: 0.4593
#
# Epoch 00007: val_loss improved from 1.37466 to 1.35094, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2142 - acc: 0.5112 - val_loss: 1.3232 - val_acc: 0.4709
#
# Epoch 00008: val_loss improved from 1.35094 to 1.32320, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1807 - acc: 0.5289 - val_loss: 1.3008 - val_acc: 0.4722
#
# Epoch 00009: val_loss improved from 1.32320 to 1.30081, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1540 - acc: 0.5454 - val_loss: 1.2951 - val_acc: 0.4730
#
# Epoch 00010: val_loss improved from 1.30081 to 1.29508, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1361 - acc: 0.5556 - val_loss: 1.2845 - val_acc: 0.4853
#
# Epoch 00011: val_loss improved from 1.29508 to 1.28451, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1026 - acc: 0.5738 - val_loss: 1.2593 - val_acc: 0.4928
#
# Epoch 00012: val_loss improved from 1.28451 to 1.25925, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0738 - acc: 0.5884 - val_loss: 1.2383 - val_acc: 0.5070
#
# Epoch 00013: val_loss improved from 1.25925 to 1.23825, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0521 - acc: 0.6012 - val_loss: 1.2226 - val_acc: 0.5181
#
# Epoch 00014: val_loss improved from 1.23825 to 1.22258, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.0285 - acc: 0.6157 - val_loss: 1.2072 - val_acc: 0.5356
#
# Epoch 00015: val_loss improved from 1.22258 to 1.20719, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0074 - acc: 0.6264 - val_loss: 1.1970 - val_acc: 0.5404
#
# Epoch 00016: val_loss improved from 1.20719 to 1.19700, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.9867 - acc: 0.6393 - val_loss: 1.1806 - val_acc: 0.5436
#
# Epoch 00017: val_loss improved from 1.19700 to 1.18062, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.9701 - acc: 0.6479 - val_loss: 1.1563 - val_acc: 0.5664
#
# Epoch 00018: val_loss improved from 1.18062 to 1.15626, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.9504 - acc: 0.6594 - val_loss: 1.1585 - val_acc: 0.5538
#
# Epoch 00019: val_loss did not improve from 1.15626
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9303 - acc: 0.6651 - val_loss: 1.1680 - val_acc: 0.5561
#
# Epoch 00020: val_loss did not improve from 1.15626
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9102 - acc: 0.6809 - val_loss: 1.1315 - val_acc: 0.5757
#
# Epoch 00021: val_loss improved from 1.15626 to 1.13146, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8964 - acc: 0.6848 - val_loss: 1.1281 - val_acc: 0.5711
#
# Epoch 00022: val_loss improved from 1.13146 to 1.12814, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8785 - acc: 0.6923 - val_loss: 1.1026 - val_acc: 0.5889
#
# Epoch 00023: val_loss improved from 1.12814 to 1.10263, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8594 - acc: 0.7049 - val_loss: 1.1013 - val_acc: 0.5879
#
# Epoch 00024: val_loss improved from 1.10263 to 1.10130, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8487 - acc: 0.7107 - val_loss: 1.0922 - val_acc: 0.6008
#
# Epoch 00025: val_loss improved from 1.10130 to 1.09221, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8310 - acc: 0.7184 - val_loss: 1.0728 - val_acc: 0.5989
#
# Epoch 00026: val_loss improved from 1.09221 to 1.07277, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8191 - acc: 0.7238 - val_loss: 1.0796 - val_acc: 0.5981
#
# Epoch 00027: val_loss did not improve from 1.07277
# Epoch 28/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7989 - acc: 0.7322 - val_loss: 1.0749 - val_acc: 0.5998
#
# Epoch 00028: val_loss did not improve from 1.07277
# Epoch 29/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7873 - acc: 0.7410 - val_loss: 1.0552 - val_acc: 0.6128
#
# Epoch 00029: val_loss improved from 1.07277 to 1.05518, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7724 - acc: 0.7491 - val_loss: 1.0561 - val_acc: 0.6088
#
# Epoch 00030: val_loss did not improve from 1.05518
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7506 - acc: 0.7616 - val_loss: 1.0445 - val_acc: 0.6211
#
# Epoch 00031: val_loss improved from 1.05518 to 1.04447, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7398 - acc: 0.7639 - val_loss: 1.0350 - val_acc: 0.6167
#
# Epoch 00032: val_loss improved from 1.04447 to 1.03501, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7346 - acc: 0.7672 - val_loss: 1.0323 - val_acc: 0.6206
#
# Epoch 00033: val_loss improved from 1.03501 to 1.03227, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7198 - acc: 0.7729 - val_loss: 1.0187 - val_acc: 0.6190
#
# Epoch 00034: val_loss improved from 1.03227 to 1.01873, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7101 - acc: 0.7787 - val_loss: 1.0345 - val_acc: 0.6199
#
# Epoch 00035: val_loss did not improve from 1.01873
# Epoch 36/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6949 - acc: 0.7851 - val_loss: 1.0261 - val_acc: 0.6177
#
# Epoch 00036: val_loss did not improve from 1.01873
# Epoch 37/400
# 1025/1036 [============================>.] - ETA: 0s - loss: 0.6836 - acc: 0.7913

# %%
i=4

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 43 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11732,)
# H (10284,)
# K (15374,)
# A (15728,)
# C (12150,)
# Epoch 1/400
# 1036/1036 [==============================] - 104s 67ms/step - loss: 0.6993 - acc: 0.7838 - val_loss: 1.0147 - val_acc: 0.6280
#
# Epoch 00001: val_loss improved from inf to 1.01475, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6926 - acc: 0.7879 - val_loss: 1.0083 - val_acc: 0.6293
#
# Epoch 00002: val_loss improved from 1.01475 to 1.00830, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6868 - acc: 0.7915 - val_loss: 1.0072 - val_acc: 0.6320
#
# Epoch 00003: val_loss improved from 1.00830 to 1.00725, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6866 - acc: 0.7919 - val_loss: 1.0071 - val_acc: 0.6337
#
# Epoch 00004: val_loss improved from 1.00725 to 1.00710, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6818 - acc: 0.7940 - val_loss: 1.0056 - val_acc: 0.6362
#
# Epoch 00005: val_loss improved from 1.00710 to 1.00558, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6771 - acc: 0.7996 - val_loss: 1.0088 - val_acc: 0.6407
#
# Epoch 00006: val_loss did not improve from 1.00558
# Epoch 7/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6793 - acc: 0.7948 - val_loss: 1.0026 - val_acc: 0.6404
#
# Epoch 00007: val_loss improved from 1.00558 to 1.00255, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6751 - acc: 0.7977 - val_loss: 1.0016 - val_acc: 0.6397
#
# Epoch 00008: val_loss improved from 1.00255 to 1.00156, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6752 - acc: 0.7970 - val_loss: 1.0023 - val_acc: 0.6401
#
# Epoch 00009: val_loss did not improve from 1.00156
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6729 - acc: 0.7981 - val_loss: 1.0025 - val_acc: 0.6339
#
# Epoch 00010: val_loss did not improve from 1.00156
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6739 - acc: 0.7974 - val_loss: 1.0013 - val_acc: 0.6400
#
# Epoch 00011: val_loss improved from 1.00156 to 1.00131, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6727 - acc: 0.7968 - val_loss: 0.9999 - val_acc: 0.6415
#
# Epoch 00012: val_loss improved from 1.00131 to 0.99994, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6707 - acc: 0.8003 - val_loss: 0.9967 - val_acc: 0.6376
#
# Epoch 00013: val_loss improved from 0.99994 to 0.99670, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6668 - acc: 0.8019 - val_loss: 1.0007 - val_acc: 0.6375
#
# Epoch 00014: val_loss did not improve from 0.99670
# Epoch 15/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6618 - acc: 0.8046 - val_loss: 0.9951 - val_acc: 0.6376
#
# Epoch 00015: val_loss improved from 0.99670 to 0.99509, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6619 - acc: 0.8045 - val_loss: 0.9970 - val_acc: 0.6394
#
# Epoch 00016: val_loss did not improve from 0.99509
# Epoch 17/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6612 - acc: 0.8065 - val_loss: 0.9963 - val_acc: 0.6402
#
# Epoch 00017: val_loss did not improve from 0.99509
# Epoch 18/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6586 - acc: 0.8057 - val_loss: 0.9918 - val_acc: 0.6381
#
# Epoch 00018: val_loss improved from 0.99509 to 0.99179, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6615 - acc: 0.8053 - val_loss: 0.9948 - val_acc: 0.6377
#
# Epoch 00019: val_loss did not improve from 0.99179
# Epoch 20/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6550 - acc: 0.8080 - val_loss: 0.9918 - val_acc: 0.6371
#
# Epoch 00020: val_loss did not improve from 0.99179
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6602 - acc: 0.8045 - val_loss: 0.9889 - val_acc: 0.6345
#
# Epoch 00021: val_loss improved from 0.99179 to 0.98885, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6541 - acc: 0.8080 - val_loss: 0.9886 - val_acc: 0.6410
#
# Epoch 00022: val_loss improved from 0.98885 to 0.98860, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6570 - acc: 0.8058 - val_loss: 0.9917 - val_acc: 0.6418
#
# Epoch 00023: val_loss did not improve from 0.98860
# Epoch 24/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6513 - acc: 0.8096 - val_loss: 0.9907 - val_acc: 0.6413
#
# Epoch 00024: val_loss did not improve from 0.98860
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6535 - acc: 0.8090 - val_loss: 0.9921 - val_acc: 0.6362
#
# Epoch 00025: val_loss did not improve from 0.98860
# Epoch 26/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6482 - acc: 0.8112 - val_loss: 0.9886 - val_acc: 0.6350
#
# Epoch 00026: val_loss improved from 0.98860 to 0.98856, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6521 - acc: 0.8101 - val_loss: 0.9883 - val_acc: 0.6395
#
# Epoch 00027: val_loss improved from 0.98856 to 0.98831, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6467 - acc: 0.8095 - val_loss: 0.9863 - val_acc: 0.6377
#
# Epoch 00028: val_loss improved from 0.98831 to 0.98626, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6382 - acc: 0.8167 - val_loss: 0.9841 - val_acc: 0.6342
#
# Epoch 00029: val_loss improved from 0.98626 to 0.98406, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6442 - acc: 0.8138 - val_loss: 0.9863 - val_acc: 0.6413
#
# Epoch 00030: val_loss did not improve from 0.98406
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6411 - acc: 0.8133 - val_loss: 0.9862 - val_acc: 0.6391
#
# Epoch 00031: val_loss did not improve from 0.98406
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6432 - acc: 0.8147 - val_loss: 0.9841 - val_acc: 0.6489
#
# Epoch 00032: val_loss did not improve from 0.98406
# Epoch 33/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6387 - acc: 0.8173 - val_loss: 0.9866 - val_acc: 0.6372
#
# Epoch 00033: val_loss did not improve from 0.98406
# Epoch 34/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6412 - acc: 0.8157 - val_loss: 0.9856 - val_acc: 0.6373
#
# Epoch 00034: val_loss did not improve from 0.98406
# Epoch 35/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6387 - acc: 0.8151 - val_loss: 0.9814 - val_acc: 0.6408
#
# Epoch 00035: val_loss improved from 0.98406 to 0.98144, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6373 - acc: 0.8192 - val_loss: 0.9811 - val_acc: 0.6435
#
# Epoch 00036: val_loss improved from 0.98144 to 0.98107, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6386 - acc: 0.8152 - val_loss: 0.9867 - val_acc: 0.6407
#
# Epoch 00037: val_loss did not improve from 0.98107
# Epoch 38/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6314 - acc: 0.8172 - val_loss: 0.9832 - val_acc: 0.6369
#
# Epoch 00038: val_loss did not improve from 0.98107
# Epoch 39/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6334 - acc: 0.8204 - val_loss: 0.9819 - val_acc: 0.6386
#
# Epoch 00039: val_loss did not improve from 0.98107
# Epoch 40/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6340 - acc: 0.8170 - val_loss: 0.9807 - val_acc: 0.6449
#
# Epoch 00040: val_loss improved from 0.98107 to 0.98068, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6317 - acc: 0.8186 - val_loss: 0.9809 - val_acc: 0.6428
#
# Epoch 00041: val_loss did not improve from 0.98068
# Epoch 42/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6329 - acc: 0.8159 - val_loss: 0.9761 - val_acc: 0.6471
#
# Epoch 00042: val_loss improved from 0.98068 to 0.97606, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6311 - acc: 0.8193 - val_loss: 0.9801 - val_acc: 0.6441
#
# Epoch 00043: val_loss did not improve from 0.97606
# Epoch 44/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6255 - acc: 0.8223 - val_loss: 0.9784 - val_acc: 0.6429
#
# Epoch 00044: val_loss did not improve from 0.97606
# Epoch 45/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6285 - acc: 0.8188 - val_loss: 0.9791 - val_acc: 0.6395
#
# Epoch 00045: val_loss did not improve from 0.97606
# Epoch 46/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6291 - acc: 0.8201 - val_loss: 0.9763 - val_acc: 0.6471
#
# Epoch 00046: val_loss did not improve from 0.97606
# Epoch 47/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6241 - acc: 0.8231 - val_loss: 0.9785 - val_acc: 0.6441
#
# Epoch 00047: val_loss did not improve from 0.97606
# Epoch 48/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6255 - acc: 0.8223 - val_loss: 0.9781 - val_acc: 0.6432
#
# Epoch 00048: val_loss did not improve from 0.97606
# Epoch 49/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6242 - acc: 0.8229 - val_loss: 0.9785 - val_acc: 0.6427
#
# Epoch 00049: val_loss did not improve from 0.97606
# Epoch 50/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6247 - acc: 0.8209 - val_loss: 0.9793 - val_acc: 0.6405
#
# Epoch 00050: val_loss did not improve from 0.97606
# Epoch 51/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6255 - acc: 0.8211 - val_loss: 0.9771 - val_acc: 0.6445
#
# Epoch 00051: val_loss did not improve from 0.97606
# Epoch 52/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6269 - acc: 0.8206 - val_loss: 0.9760 - val_acc: 0.6449
#
# Epoch 00052: val_loss improved from 0.97606 to 0.97598, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6259 - acc: 0.8205 - val_loss: 0.9786 - val_acc: 0.6433
#
# Epoch 00053: val_loss did not improve from 0.97598
# Epoch 54/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6231 - acc: 0.8230 - val_loss: 0.9787 - val_acc: 0.6464
#
# Epoch 00054: val_loss did not improve from 0.97598
# Epoch 55/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6240 - acc: 0.8224 - val_loss: 0.9779 - val_acc: 0.6450
#
# Epoch 00055: val_loss did not improve from 0.97598
# Epoch 56/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6246 - acc: 0.8229 - val_loss: 0.9767 - val_acc: 0.6452
#
# Epoch 00056: val_loss did not improve from 0.97598
# Epoch 57/400
# 1036/1036 [==============================] - 71s 69ms/step - loss: 0.6230 - acc: 0.8216 - val_loss: 0.9768 - val_acc: 0.6443
#
# Epoch 00057: val_loss did not improve from 0.97598
# Epoch 58/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6281 - acc: 0.8206 - val_loss: 0.9764 - val_acc: 0.6440
#
# Epoch 00058: val_loss did not improve from 0.97598
# Epoch 59/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6266 - acc: 0.8201 - val_loss: 0.9776 - val_acc: 0.6424
#
# Epoch 00059: val_loss did not improve from 0.97598
# Epoch 60/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6223 - acc: 0.8239 - val_loss: 0.9775 - val_acc: 0.6451
#
# Epoch 00060: val_loss did not improve from 0.97598
# Epoch 61/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6184 - acc: 0.8240 - val_loss: 0.9775 - val_acc: 0.6425
#
# Epoch 00061: val_loss did not improve from 0.97598
# Epoch 62/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6261 - acc: 0.8207 - val_loss: 0.9765 - val_acc: 0.6457
#
# Epoch 00062: val_loss did not improve from 0.97598
# results per 4-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.9765 - acc: 0.6457
# [[1378  156  169  176  145]
#  [ 110  929  294   95  150]
#  [ 219  141 1612  166  118]
#  [ 133  159  210 2020  307]
#  [ 141  269  467  229 1085]]
#               precision    recall  f1-score   support
#
#           HC       0.70      0.68      0.69      2024
#          a_H       0.56      0.59      0.57      1578
#          a_K       0.59      0.71      0.64      2256
#          a_A       0.75      0.71      0.73      2829
#          a_C       0.60      0.50      0.54      2191
#
#     accuracy                           0.65     10878
#    macro avg       0.64      0.64      0.64     10878
# weighted avg       0.65      0.65      0.64     10878

# %%
def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

for i in range(5, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )

  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  
  # class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
  #               np.argmax(train_label_list[i], axis=1)))) 

  # print("class_weights", class_weights)

  print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
  print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
  print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
  print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
  print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      # class_weight=class_weights,
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11496,)
# H (10032,)
# K (15224,)
# A (15958,)
# C (12558,)
# Epoch 1/400
# 1036/1036 [==============================] - 74s 69ms/step - loss: 1.7190 - acc: 0.2562 - val_loss: 1.5383 - val_acc: 0.3195
#
# Epoch 00001: val_loss improved from inf to 1.53834, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.5150 - acc: 0.3280 - val_loss: 1.4754 - val_acc: 0.3617
#
# Epoch 00002: val_loss improved from 1.53834 to 1.47536, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.4554 - acc: 0.3717 - val_loss: 1.4506 - val_acc: 0.3819
#
# Epoch 00003: val_loss improved from 1.47536 to 1.45059, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.3978 - acc: 0.4092 - val_loss: 1.4252 - val_acc: 0.3926
#
# Epoch 00004: val_loss improved from 1.45059 to 1.42524, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.3546 - acc: 0.4286 - val_loss: 1.3844 - val_acc: 0.4112
#
# Epoch 00005: val_loss improved from 1.42524 to 1.38443, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.3094 - acc: 0.4593 - val_loss: 1.3552 - val_acc: 0.4402
#
# Epoch 00006: val_loss improved from 1.38443 to 1.35521, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2647 - acc: 0.4874 - val_loss: 1.3416 - val_acc: 0.4464
#
# Epoch 00007: val_loss improved from 1.35521 to 1.34158, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2236 - acc: 0.5083 - val_loss: 1.3333 - val_acc: 0.4509
#
# Epoch 00008: val_loss improved from 1.34158 to 1.33325, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1894 - acc: 0.5271 - val_loss: 1.3196 - val_acc: 0.4485
#
# Epoch 00009: val_loss improved from 1.33325 to 1.31956, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1575 - acc: 0.5457 - val_loss: 1.3065 - val_acc: 0.4668
#
# Epoch 00010: val_loss improved from 1.31956 to 1.30646, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1292 - acc: 0.5615 - val_loss: 1.2817 - val_acc: 0.4907
#
# Epoch 00011: val_loss improved from 1.30646 to 1.28175, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1028 - acc: 0.5774 - val_loss: 1.2671 - val_acc: 0.5047
#
# Epoch 00012: val_loss improved from 1.28175 to 1.26706, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0777 - acc: 0.5943 - val_loss: 1.2714 - val_acc: 0.4980
#
# Epoch 00013: val_loss did not improve from 1.26706
# Epoch 14/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0497 - acc: 0.6031 - val_loss: 1.2648 - val_acc: 0.4983
#
# Epoch 00014: val_loss improved from 1.26706 to 1.26480, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.0278 - acc: 0.6173 - val_loss: 1.2515 - val_acc: 0.4930
#
# Epoch 00015: val_loss improved from 1.26480 to 1.25150, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.0042 - acc: 0.6295 - val_loss: 1.2353 - val_acc: 0.5260
#
# Epoch 00016: val_loss improved from 1.25150 to 1.23526, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.9807 - acc: 0.6434 - val_loss: 1.2291 - val_acc: 0.5170
#
# Epoch 00017: val_loss improved from 1.23526 to 1.22915, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.9699 - acc: 0.6486 - val_loss: 1.2243 - val_acc: 0.5231
#
# Epoch 00018: val_loss improved from 1.22915 to 1.22435, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.9400 - acc: 0.6659 - val_loss: 1.1978 - val_acc: 0.5385
#
# Epoch 00019: val_loss improved from 1.22435 to 1.19783, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.9289 - acc: 0.6711 - val_loss: 1.1986 - val_acc: 0.5307
#
# Epoch 00020: val_loss did not improve from 1.19783
# Epoch 21/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.9115 - acc: 0.6786 - val_loss: 1.1956 - val_acc: 0.5393
#
# Epoch 00021: val_loss improved from 1.19783 to 1.19557, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8895 - acc: 0.6919 - val_loss: 1.1765 - val_acc: 0.5542
#
# Epoch 00022: val_loss improved from 1.19557 to 1.17646, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8705 - acc: 0.7029 - val_loss: 1.1727 - val_acc: 0.5532
#
# Epoch 00023: val_loss improved from 1.17646 to 1.17272, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8587 - acc: 0.7088 - val_loss: 1.1613 - val_acc: 0.5656
#
# Epoch 00024: val_loss improved from 1.17272 to 1.16128, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8447 - acc: 0.7129 - val_loss: 1.1549 - val_acc: 0.5553
#
# Epoch 00025: val_loss improved from 1.16128 to 1.15493, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8257 - acc: 0.7260 - val_loss: 1.1335 - val_acc: 0.5719
#
# Epoch 00026: val_loss improved from 1.15493 to 1.13351, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.8083 - acc: 0.7343 - val_loss: 1.1460 - val_acc: 0.5743
#
# Epoch 00027: val_loss did not improve from 1.13351
# Epoch 28/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.8014 - acc: 0.7346 - val_loss: 1.1335 - val_acc: 0.5736
#
# Epoch 00028: val_loss did not improve from 1.13351
# Epoch 29/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7857 - acc: 0.7440 - val_loss: 1.1344 - val_acc: 0.5734
#
# Epoch 00029: val_loss did not improve from 1.13351
# Epoch 30/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7713 - acc: 0.7518 - val_loss: 1.1315 - val_acc: 0.5700
#
# Epoch 00030: val_loss improved from 1.13351 to 1.13150, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7566 - acc: 0.7582 - val_loss: 1.1085 - val_acc: 0.5971
#
# Epoch 00031: val_loss improved from 1.13150 to 1.10848, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.7438 - acc: 0.7596 - val_loss: 1.1139 - val_acc: 0.5854
#
# Epoch 00032: val_loss did not improve from 1.10848
# Epoch 33/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7353 - acc: 0.7656 - val_loss: 1.0938 - val_acc: 0.5918
#
# Epoch 00033: val_loss improved from 1.10848 to 1.09375, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7224 - acc: 0.7738 - val_loss: 1.1009 - val_acc: 0.5982
#
# Epoch 00034: val_loss did not improve from 1.09375
# Epoch 35/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.7040 - acc: 0.7844 - val_loss: 1.1051 - val_acc: 0.5888
#
# Epoch 00035: val_loss did not improve from 1.09375
# Epoch 36/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6956 - acc: 0.7839 - val_loss: 1.0804 - val_acc: 0.5925
#
# Epoch 00036: val_loss improved from 1.09375 to 1.08035, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6883 - acc: 0.7860 - val_loss: 1.0848 - val_acc: 0.5914
#
# Epoch 00037: val_loss did not improve from 1.08035
# Epoch 38/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6721 - acc: 0.7945 - val_loss: 1.0625 - val_acc: 0.6035
#
# Epoch 00038: val_loss improved from 1.08035 to 1.06245, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6617 - acc: 0.8012 - val_loss: 1.0658 - val_acc: 0.6086
#
# Epoch 00039: val_loss did not improve from 1.06245
# Epoch 40/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6519 - acc: 0.8042 - val_loss: 1.0661 - val_acc: 0.6075
#
# Epoch 00040: val_loss did not improve from 1.06245
# Epoch 41/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6390 - acc: 0.8121 - val_loss: 1.0511 - val_acc: 0.6078
#
# Epoch 00041: val_loss improved from 1.06245 to 1.05106, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6303 - acc: 0.8166 - val_loss: 1.0439 - val_acc: 0.6115
#
# Epoch 00042: val_loss improved from 1.05106 to 1.04386, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.6163 - acc: 0.8228 - val_loss: 1.0567 - val_acc: 0.6042
#
# Epoch 00043: val_loss did not improve from 1.04386
# Epoch 44/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 0.6104 - acc: 0.8223 - val_loss: 1.0459 - val_acc: 0.6121
#
# Epoch 00044: val_loss did not improve from 1.04386
# Epoch 45/400
#  681/1036 [==================>...........] - ETA: 23s - loss: 0.6066 - acc: 0.8226

# %%
i=5

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 36 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11496,)
# H (10032,)
# K (15224,)
# A (15958,)
# C (12558,)
# Epoch 1/400
# 1036/1036 [==============================] - 103s 67ms/step - loss: 0.6177 - acc: 0.8169 - val_loss: 1.0425 - val_acc: 0.6088
#
# Epoch 00001: val_loss improved from inf to 1.04245, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.6050 - acc: 0.8291 - val_loss: 1.0404 - val_acc: 0.6108
#
# Epoch 00002: val_loss improved from 1.04245 to 1.04043, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5991 - acc: 0.8303 - val_loss: 1.0423 - val_acc: 0.6065
#
# Epoch 00003: val_loss did not improve from 1.04043
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5985 - acc: 0.8301 - val_loss: 1.0375 - val_acc: 0.6098
#
# Epoch 00004: val_loss improved from 1.04043 to 1.03752, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5985 - acc: 0.8310 - val_loss: 1.0361 - val_acc: 0.6157
#
# Epoch 00005: val_loss improved from 1.03752 to 1.03606, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5920 - acc: 0.8363 - val_loss: 1.0310 - val_acc: 0.6180
#
# Epoch 00006: val_loss improved from 1.03606 to 1.03097, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5918 - acc: 0.8353 - val_loss: 1.0383 - val_acc: 0.6133
#
# Epoch 00007: val_loss did not improve from 1.03097
# Epoch 8/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5899 - acc: 0.8354 - val_loss: 1.0351 - val_acc: 0.6120
#
# Epoch 00008: val_loss did not improve from 1.03097
# Epoch 9/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5870 - acc: 0.8354 - val_loss: 1.0351 - val_acc: 0.6187
#
# Epoch 00009: val_loss did not improve from 1.03097
# Epoch 10/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 0.5852 - acc: 0.8389 - val_loss: 1.0328 - val_acc: 0.6188
#
# Epoch 00010: val_loss did not improve from 1.03097
# Epoch 11/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5829 - acc: 0.8413 - val_loss: 1.0311 - val_acc: 0.6179
#
# Epoch 00011: val_loss did not improve from 1.03097
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5822 - acc: 0.8402 - val_loss: 1.0336 - val_acc: 0.6178
#
# Epoch 00012: val_loss did not improve from 1.03097
# Epoch 13/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5846 - acc: 0.8368 - val_loss: 1.0327 - val_acc: 0.6186
#
# Epoch 00013: val_loss did not improve from 1.03097
# Epoch 14/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5819 - acc: 0.8367 - val_loss: 1.0271 - val_acc: 0.6169
#
# Epoch 00014: val_loss improved from 1.03097 to 1.02713, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5773 - acc: 0.8431 - val_loss: 1.0280 - val_acc: 0.6193
#
# Epoch 00015: val_loss did not improve from 1.02713
# Epoch 16/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5775 - acc: 0.8425 - val_loss: 1.0298 - val_acc: 0.6172
#
# Epoch 00016: val_loss did not improve from 1.02713
# Epoch 17/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5763 - acc: 0.8429 - val_loss: 1.0314 - val_acc: 0.6222
#
# Epoch 00017: val_loss did not improve from 1.02713
# Epoch 18/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5743 - acc: 0.8417 - val_loss: 1.0336 - val_acc: 0.6187
#
# Epoch 00018: val_loss did not improve from 1.02713
# Epoch 19/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5746 - acc: 0.8414 - val_loss: 1.0278 - val_acc: 0.6239
#
# Epoch 00019: val_loss did not improve from 1.02713
# Epoch 20/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5765 - acc: 0.8434 - val_loss: 1.0309 - val_acc: 0.6202
#
# Epoch 00020: val_loss did not improve from 1.02713
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5754 - acc: 0.8422 - val_loss: 1.0290 - val_acc: 0.6188
#
# Epoch 00021: val_loss did not improve from 1.02713
# Epoch 22/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5736 - acc: 0.8429 - val_loss: 1.0284 - val_acc: 0.6216
#
# Epoch 00022: val_loss did not improve from 1.02713
# Epoch 23/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 0.5677 - acc: 0.8475 - val_loss: 1.0297 - val_acc: 0.6242
#
# Epoch 00023: val_loss did not improve from 1.02713
# Epoch 24/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 0.5705 - acc: 0.8465 - val_loss: 1.0290 - val_acc: 0.6205
#
# Epoch 00024: val_loss did not improve from 1.02713
# results per 5-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 1.0290 - acc: 0.6205
# [[1714   35  310   79  122]
#  [ 121 1091  237  247  134]
#  [ 167  110 1567  332  230]
#  [  84  204  488 1630  193]
#  [ 193  200  245  397  748]]
#               precision    recall  f1-score   support
#
#           HC       0.75      0.76      0.76      2260
#          a_H       0.67      0.60      0.63      1830
#          a_K       0.55      0.65      0.60      2406
#          a_A       0.61      0.63      0.62      2599
#          a_C       0.52      0.42      0.47      1783
#
#     accuracy                           0.62     10878
#    macro avg       0.62      0.61      0.61     10878
# weighted avg       0.62      0.62      0.62     10878

# %%
i=6

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr
lr_scheduler = LearningRateScheduler(decay_schedule)

# checkpointの設定
checkpoint = ModelCheckpoint(
                    filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
# model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.Adam(lr=1e-6, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc']
          )

# class_weights = dict(zip(np.unique(np.argmax(train_label_list[i], axis=1)), class_weight.compute_class_weight('balanced', np.unique(np.argmax(train_label_list[i], axis=1)), 
#               np.argmax(train_label_list[i], axis=1)))) 

# print("class_weights", class_weights)

print("HC",np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
print("H",np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
print("K",np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
print("A",np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
print("C",np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    # class_weight=class_weights,
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "drive/MyDrive/saved_models/test/{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/StratifiedGroupFold/COP_LSTM_5class_with_both/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# HC (11580,)
# H (10322,)
# K (14841,)
# A (16064,)
# C (12461,)
# Epoch 1/400
# 1036/1036 [==============================] - 73s 68ms/step - loss: 1.8445 - acc: 0.2101 - val_loss: 1.6093 - val_acc: 0.2389
#
# Epoch 00001: val_loss improved from inf to 1.60926, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.6630 - acc: 0.2455 - val_loss: 1.5758 - val_acc: 0.2439
#
# Epoch 00002: val_loss improved from 1.60926 to 1.57583, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.6219 - acc: 0.2611 - val_loss: 1.5491 - val_acc: 0.2789
#
# Epoch 00003: val_loss improved from 1.57583 to 1.54909, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.5905 - acc: 0.2797 - val_loss: 1.5402 - val_acc: 0.2704
#
# Epoch 00004: val_loss improved from 1.54909 to 1.54016, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.5666 - acc: 0.2897 - val_loss: 1.5361 - val_acc: 0.2724
#
# Epoch 00005: val_loss improved from 1.54016 to 1.53607, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.5460 - acc: 0.3067 - val_loss: 1.5225 - val_acc: 0.2984
#
# Epoch 00006: val_loss improved from 1.53607 to 1.52252, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.5381 - acc: 0.3140 - val_loss: 1.5110 - val_acc: 0.3059
#
# Epoch 00007: val_loss improved from 1.52252 to 1.51096, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.5199 - acc: 0.3241 - val_loss: 1.4951 - val_acc: 0.3115
#
# Epoch 00008: val_loss improved from 1.51096 to 1.49506, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.5064 - acc: 0.3375 - val_loss: 1.4862 - val_acc: 0.3300
#
# Epoch 00009: val_loss improved from 1.49506 to 1.48624, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4941 - acc: 0.3455 - val_loss: 1.4760 - val_acc: 0.3338
#
# Epoch 00010: val_loss improved from 1.48624 to 1.47601, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.4855 - acc: 0.3493 - val_loss: 1.4719 - val_acc: 0.3336
#
# Epoch 00011: val_loss improved from 1.47601 to 1.47192, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4768 - acc: 0.3564 - val_loss: 1.4598 - val_acc: 0.3496
#
# Epoch 00012: val_loss improved from 1.47192 to 1.45985, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4682 - acc: 0.3628 - val_loss: 1.4520 - val_acc: 0.3574
#
# Epoch 00013: val_loss improved from 1.45985 to 1.45203, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4568 - acc: 0.3713 - val_loss: 1.4471 - val_acc: 0.3600
#
# Epoch 00014: val_loss improved from 1.45203 to 1.44713, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4511 - acc: 0.3772 - val_loss: 1.4396 - val_acc: 0.3520
#
# Epoch 00015: val_loss improved from 1.44713 to 1.43961, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.4322 - acc: 0.3857 - val_loss: 1.4410 - val_acc: 0.3657
#
# Epoch 00016: val_loss did not improve from 1.43961
# Epoch 17/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4265 - acc: 0.3928 - val_loss: 1.4347 - val_acc: 0.3653
#
# Epoch 00017: val_loss improved from 1.43961 to 1.43470, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4226 - acc: 0.3884 - val_loss: 1.4253 - val_acc: 0.3726
#
# Epoch 00018: val_loss improved from 1.43470 to 1.42525, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1036/1036 [==============================] - 69s 67ms/step - loss: 1.4121 - acc: 0.3997 - val_loss: 1.4247 - val_acc: 0.3740
#
# Epoch 00019: val_loss improved from 1.42525 to 1.42467, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.4078 - acc: 0.4048 - val_loss: 1.4160 - val_acc: 0.3826
#
# Epoch 00020: val_loss improved from 1.42467 to 1.41603, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3947 - acc: 0.4061 - val_loss: 1.4143 - val_acc: 0.3904
#
# Epoch 00021: val_loss improved from 1.41603 to 1.41428, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3888 - acc: 0.4151 - val_loss: 1.4090 - val_acc: 0.3855
#
# Epoch 00022: val_loss improved from 1.41428 to 1.40899, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3812 - acc: 0.4173 - val_loss: 1.3990 - val_acc: 0.3904
#
# Epoch 00023: val_loss improved from 1.40899 to 1.39897, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3749 - acc: 0.4204 - val_loss: 1.3998 - val_acc: 0.3843
#
# Epoch 00024: val_loss did not improve from 1.39897
# Epoch 25/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3714 - acc: 0.4223 - val_loss: 1.3939 - val_acc: 0.3885
#
# Epoch 00025: val_loss improved from 1.39897 to 1.39388, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3587 - acc: 0.4321 - val_loss: 1.3947 - val_acc: 0.3854
#
# Epoch 00026: val_loss did not improve from 1.39388
# Epoch 27/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3567 - acc: 0.4355 - val_loss: 1.3845 - val_acc: 0.4000
#
# Epoch 00027: val_loss improved from 1.39388 to 1.38450, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3462 - acc: 0.4384 - val_loss: 1.3800 - val_acc: 0.4033
#
# Epoch 00028: val_loss improved from 1.38450 to 1.38004, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3406 - acc: 0.4431 - val_loss: 1.3816 - val_acc: 0.3978
#
# Epoch 00029: val_loss did not improve from 1.38004
# Epoch 30/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3384 - acc: 0.4462 - val_loss: 1.3765 - val_acc: 0.3955
#
# Epoch 00030: val_loss improved from 1.38004 to 1.37652, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3295 - acc: 0.4501 - val_loss: 1.3699 - val_acc: 0.4032
#
# Epoch 00031: val_loss improved from 1.37652 to 1.36993, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3291 - acc: 0.4476 - val_loss: 1.3661 - val_acc: 0.4069
#
# Epoch 00032: val_loss improved from 1.36993 to 1.36606, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3221 - acc: 0.4511 - val_loss: 1.3641 - val_acc: 0.4065
#
# Epoch 00033: val_loss improved from 1.36606 to 1.36412, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3151 - acc: 0.4596 - val_loss: 1.3576 - val_acc: 0.4147
#
# Epoch 00034: val_loss improved from 1.36412 to 1.35765, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.3063 - acc: 0.4637 - val_loss: 1.3564 - val_acc: 0.4203
#
# Epoch 00035: val_loss improved from 1.35765 to 1.35645, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.3027 - acc: 0.4615 - val_loss: 1.3569 - val_acc: 0.4200
#
# Epoch 00036: val_loss did not improve from 1.35645
# Epoch 37/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2981 - acc: 0.4676 - val_loss: 1.3499 - val_acc: 0.4254
#
# Epoch 00037: val_loss improved from 1.35645 to 1.34987, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2898 - acc: 0.4712 - val_loss: 1.3436 - val_acc: 0.4183
#
# Epoch 00038: val_loss improved from 1.34987 to 1.34356, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2859 - acc: 0.4745 - val_loss: 1.3407 - val_acc: 0.4331
#
# Epoch 00039: val_loss improved from 1.34356 to 1.34071, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2834 - acc: 0.4749 - val_loss: 1.3381 - val_acc: 0.4333
#
# Epoch 00040: val_loss improved from 1.34071 to 1.33807, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.2793 - acc: 0.4742 - val_loss: 1.3334 - val_acc: 0.4384
#
# Epoch 00041: val_loss improved from 1.33807 to 1.33343, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2758 - acc: 0.4797 - val_loss: 1.3300 - val_acc: 0.4380
#
# Epoch 00042: val_loss improved from 1.33343 to 1.33002, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2678 - acc: 0.4857 - val_loss: 1.3275 - val_acc: 0.4383
#
# Epoch 00043: val_loss improved from 1.33002 to 1.32747, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2596 - acc: 0.4884 - val_loss: 1.3215 - val_acc: 0.4408
#
# Epoch 00044: val_loss improved from 1.32747 to 1.32151, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2623 - acc: 0.4877 - val_loss: 1.3201 - val_acc: 0.4511
#
# Epoch 00045: val_loss improved from 1.32151 to 1.32007, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2570 - acc: 0.4905 - val_loss: 1.3148 - val_acc: 0.4493
#
# Epoch 00046: val_loss improved from 1.32007 to 1.31475, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 47/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2477 - acc: 0.4939 - val_loss: 1.3095 - val_acc: 0.4491
#
# Epoch 00047: val_loss improved from 1.31475 to 1.30946, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2418 - acc: 0.5001 - val_loss: 1.3136 - val_acc: 0.4479
#
# Epoch 00048: val_loss did not improve from 1.30946
# Epoch 49/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2409 - acc: 0.4996 - val_loss: 1.3106 - val_acc: 0.4530
#
# Epoch 00049: val_loss did not improve from 1.30946
# Epoch 50/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2362 - acc: 0.5015 - val_loss: 1.3092 - val_acc: 0.4566
#
# Epoch 00050: val_loss improved from 1.30946 to 1.30920, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 51/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2343 - acc: 0.5014 - val_loss: 1.3039 - val_acc: 0.4671
#
# Epoch 00051: val_loss improved from 1.30920 to 1.30394, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2288 - acc: 0.5078 - val_loss: 1.2969 - val_acc: 0.4670
#
# Epoch 00052: val_loss improved from 1.30394 to 1.29695, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2265 - acc: 0.5086 - val_loss: 1.2975 - val_acc: 0.4617
#
# Epoch 00053: val_loss did not improve from 1.29695
# Epoch 54/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.2215 - acc: 0.5083 - val_loss: 1.2955 - val_acc: 0.4731
#
# Epoch 00054: val_loss improved from 1.29695 to 1.29546, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 55/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2186 - acc: 0.5123 - val_loss: 1.2906 - val_acc: 0.4651
#
# Epoch 00055: val_loss improved from 1.29546 to 1.29060, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2148 - acc: 0.5120 - val_loss: 1.2889 - val_acc: 0.4697
#
# Epoch 00056: val_loss improved from 1.29060 to 1.28887, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 57/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2078 - acc: 0.5186 - val_loss: 1.2884 - val_acc: 0.4673
#
# Epoch 00057: val_loss improved from 1.28887 to 1.28845, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2061 - acc: 0.5193 - val_loss: 1.2831 - val_acc: 0.4700
#
# Epoch 00058: val_loss improved from 1.28845 to 1.28312, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 59/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.2029 - acc: 0.5186 - val_loss: 1.2805 - val_acc: 0.4631
#
# Epoch 00059: val_loss improved from 1.28312 to 1.28049, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 60/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1972 - acc: 0.5213 - val_loss: 1.2811 - val_acc: 0.4739
#
# Epoch 00060: val_loss did not improve from 1.28049
# Epoch 61/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1906 - acc: 0.5262 - val_loss: 1.2775 - val_acc: 0.4742
#
# Epoch 00061: val_loss improved from 1.28049 to 1.27746, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 62/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1928 - acc: 0.5234 - val_loss: 1.2768 - val_acc: 0.4660
#
# Epoch 00062: val_loss improved from 1.27746 to 1.27682, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 63/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1836 - acc: 0.5273 - val_loss: 1.2704 - val_acc: 0.4768
#
# Epoch 00063: val_loss improved from 1.27682 to 1.27037, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 64/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1862 - acc: 0.5305 - val_loss: 1.2696 - val_acc: 0.4749
#
# Epoch 00064: val_loss improved from 1.27037 to 1.26959, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 65/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1814 - acc: 0.5325 - val_loss: 1.2686 - val_acc: 0.4738
#
# Epoch 00065: val_loss improved from 1.26959 to 1.26860, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 66/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1754 - acc: 0.5333 - val_loss: 1.2651 - val_acc: 0.4788
#
# Epoch 00066: val_loss improved from 1.26860 to 1.26514, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 67/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1714 - acc: 0.5398 - val_loss: 1.2657 - val_acc: 0.4801
#
# Epoch 00067: val_loss did not improve from 1.26514
# Epoch 68/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1655 - acc: 0.5427 - val_loss: 1.2617 - val_acc: 0.4810
#
# Epoch 00068: val_loss improved from 1.26514 to 1.26166, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 69/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1640 - acc: 0.5415 - val_loss: 1.2546 - val_acc: 0.4774
#
# Epoch 00069: val_loss improved from 1.26166 to 1.25459, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 70/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1646 - acc: 0.5388 - val_loss: 1.2611 - val_acc: 0.4816
#
# Epoch 00070: val_loss did not improve from 1.25459
# Epoch 71/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1574 - acc: 0.5425 - val_loss: 1.2557 - val_acc: 0.4790
#
# Epoch 00071: val_loss did not improve from 1.25459
# Epoch 72/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1547 - acc: 0.5456 - val_loss: 1.2500 - val_acc: 0.4863
#
# Epoch 00072: val_loss improved from 1.25459 to 1.24996, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 73/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1513 - acc: 0.5493 - val_loss: 1.2502 - val_acc: 0.4827
#
# Epoch 00073: val_loss did not improve from 1.24996
# Epoch 74/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1582 - acc: 0.5431 - val_loss: 1.2454 - val_acc: 0.4857
#
# Epoch 00074: val_loss improved from 1.24996 to 1.24536, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 75/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1464 - acc: 0.5491 - val_loss: 1.2460 - val_acc: 0.4827
#
# Epoch 00075: val_loss did not improve from 1.24536
# Epoch 76/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1468 - acc: 0.5479 - val_loss: 1.2456 - val_acc: 0.4896
#
# Epoch 00076: val_loss did not improve from 1.24536
# Epoch 77/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1413 - acc: 0.5533 - val_loss: 1.2445 - val_acc: 0.4794
#
# Epoch 00077: val_loss improved from 1.24536 to 1.24455, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 78/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1429 - acc: 0.5535 - val_loss: 1.2452 - val_acc: 0.4801
#
# Epoch 00078: val_loss did not improve from 1.24455
# Epoch 79/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1310 - acc: 0.5586 - val_loss: 1.2383 - val_acc: 0.4852
#
# Epoch 00079: val_loss improved from 1.24455 to 1.23825, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 80/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1310 - acc: 0.5565 - val_loss: 1.2425 - val_acc: 0.4915
#
# Epoch 00080: val_loss did not improve from 1.23825
# Epoch 81/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1311 - acc: 0.5580 - val_loss: 1.2416 - val_acc: 0.4881
#
# Epoch 00081: val_loss did not improve from 1.23825
# Epoch 82/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1283 - acc: 0.5603 - val_loss: 1.2434 - val_acc: 0.4847
#
# Epoch 00082: val_loss did not improve from 1.23825
# Epoch 83/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1242 - acc: 0.5645 - val_loss: 1.2413 - val_acc: 0.4877
#
# Epoch 00083: val_loss did not improve from 1.23825
# Epoch 84/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1214 - acc: 0.5634 - val_loss: 1.2405 - val_acc: 0.4892
#
# Epoch 00084: val_loss did not improve from 1.23825
# Epoch 85/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1277 - acc: 0.5605 - val_loss: 1.2388 - val_acc: 0.4864
#
# Epoch 00085: val_loss did not improve from 1.23825
# Epoch 86/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1238 - acc: 0.5634 - val_loss: 1.2388 - val_acc: 0.4901
#
# Epoch 00086: val_loss did not improve from 1.23825
# Epoch 87/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1234 - acc: 0.5627 - val_loss: 1.2366 - val_acc: 0.4893
#
# Epoch 00087: val_loss improved from 1.23825 to 1.23662, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 88/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1197 - acc: 0.5663 - val_loss: 1.2367 - val_acc: 0.4863
#
# Epoch 00088: val_loss did not improve from 1.23662
# Epoch 89/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1220 - acc: 0.5636 - val_loss: 1.2391 - val_acc: 0.4868
#
# Epoch 00089: val_loss did not improve from 1.23662
# Epoch 90/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1209 - acc: 0.5656 - val_loss: 1.2375 - val_acc: 0.4879
#
# Epoch 00090: val_loss did not improve from 1.23662
# Epoch 91/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1223 - acc: 0.5650 - val_loss: 1.2356 - val_acc: 0.4883
#
# Epoch 00091: val_loss improved from 1.23662 to 1.23564, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 92/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1200 - acc: 0.5632 - val_loss: 1.2380 - val_acc: 0.4906
#
# Epoch 00092: val_loss did not improve from 1.23564
# Epoch 93/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1232 - acc: 0.5642 - val_loss: 1.2363 - val_acc: 0.4914
#
# Epoch 00093: val_loss did not improve from 1.23564
# Epoch 94/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1202 - acc: 0.5654 - val_loss: 1.2360 - val_acc: 0.4895
#
# Epoch 00094: val_loss did not improve from 1.23564
# Epoch 95/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1230 - acc: 0.5623 - val_loss: 1.2366 - val_acc: 0.4936
#
# Epoch 00095: val_loss did not improve from 1.23564
# Epoch 96/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1166 - acc: 0.5684 - val_loss: 1.2358 - val_acc: 0.4913
#
# Epoch 00096: val_loss did not improve from 1.23564
# Epoch 97/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1164 - acc: 0.5700 - val_loss: 1.2338 - val_acc: 0.4895
#
# Epoch 00097: val_loss improved from 1.23564 to 1.23380, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 98/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1203 - acc: 0.5673 - val_loss: 1.2341 - val_acc: 0.4924
#
# Epoch 00098: val_loss did not improve from 1.23380
# Epoch 99/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1201 - acc: 0.5673 - val_loss: 1.2332 - val_acc: 0.4943
#
# Epoch 00099: val_loss improved from 1.23380 to 1.23322, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 100/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1205 - acc: 0.5659 - val_loss: 1.2347 - val_acc: 0.4897
#
# Epoch 00100: val_loss did not improve from 1.23322
# Epoch 101/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1166 - acc: 0.5675 - val_loss: 1.2349 - val_acc: 0.4925
#
# Epoch 00101: val_loss did not improve from 1.23322
# Epoch 102/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1217 - acc: 0.5648 - val_loss: 1.2330 - val_acc: 0.4913
#
# Epoch 00102: val_loss improved from 1.23322 to 1.23303, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 103/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1127 - acc: 0.5723 - val_loss: 1.2317 - val_acc: 0.4920
#
# Epoch 00103: val_loss improved from 1.23303 to 1.23170, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 104/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1142 - acc: 0.5715 - val_loss: 1.2314 - val_acc: 0.4951
#
# Epoch 00104: val_loss improved from 1.23170 to 1.23143, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 105/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1156 - acc: 0.5700 - val_loss: 1.2323 - val_acc: 0.4940
#
# Epoch 00105: val_loss did not improve from 1.23143
# Epoch 106/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1178 - acc: 0.5644 - val_loss: 1.2315 - val_acc: 0.4947
#
# Epoch 00106: val_loss did not improve from 1.23143
# Epoch 107/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1159 - acc: 0.5680 - val_loss: 1.2322 - val_acc: 0.4912
#
# Epoch 00107: val_loss did not improve from 1.23143
# Epoch 108/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1190 - acc: 0.5657 - val_loss: 1.2329 - val_acc: 0.4942
#
# Epoch 00108: val_loss did not improve from 1.23143
# Epoch 109/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1224 - acc: 0.5638 - val_loss: 1.2326 - val_acc: 0.4938
#
# Epoch 00109: val_loss did not improve from 1.23143
# Epoch 110/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1173 - acc: 0.5703 - val_loss: 1.2325 - val_acc: 0.4961
#
# Epoch 00110: val_loss did not improve from 1.23143
# Epoch 111/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1229 - acc: 0.5636 - val_loss: 1.2314 - val_acc: 0.4955
#
# Epoch 00111: val_loss did not improve from 1.23143
# Epoch 112/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1211 - acc: 0.5664 - val_loss: 1.2305 - val_acc: 0.4978
#
# Epoch 00112: val_loss improved from 1.23143 to 1.23054, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 113/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1163 - acc: 0.5665 - val_loss: 1.2289 - val_acc: 0.4921
#
# Epoch 00113: val_loss improved from 1.23054 to 1.22888, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 114/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1122 - acc: 0.5687 - val_loss: 1.2275 - val_acc: 0.4936
#
# Epoch 00114: val_loss improved from 1.22888 to 1.22747, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 115/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1108 - acc: 0.5697 - val_loss: 1.2286 - val_acc: 0.4964
#
# Epoch 00115: val_loss did not improve from 1.22747
# Epoch 116/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1143 - acc: 0.5679 - val_loss: 1.2295 - val_acc: 0.4929
#
# Epoch 00116: val_loss did not improve from 1.22747
# Epoch 117/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1136 - acc: 0.5710 - val_loss: 1.2279 - val_acc: 0.4960
#
# Epoch 00117: val_loss did not improve from 1.22747
# Epoch 118/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1111 - acc: 0.5696 - val_loss: 1.2277 - val_acc: 0.4966
#
# Epoch 00118: val_loss did not improve from 1.22747
# Epoch 119/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1108 - acc: 0.5739 - val_loss: 1.2309 - val_acc: 0.4947
#
# Epoch 00119: val_loss did not improve from 1.22747
# Epoch 120/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1133 - acc: 0.5711 - val_loss: 1.2290 - val_acc: 0.4942
#
# Epoch 00120: val_loss did not improve from 1.22747
# Epoch 121/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1067 - acc: 0.5749 - val_loss: 1.2272 - val_acc: 0.4952
#
# Epoch 00121: val_loss improved from 1.22747 to 1.22723, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 122/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1158 - acc: 0.5666 - val_loss: 1.2273 - val_acc: 0.4949
#
# Epoch 00122: val_loss did not improve from 1.22723
# Epoch 123/400
# 1036/1036 [==============================] - 70s 67ms/step - loss: 1.1081 - acc: 0.5741 - val_loss: 1.2269 - val_acc: 0.4983
#
# Epoch 00123: val_loss improved from 1.22723 to 1.22693, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 124/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1070 - acc: 0.5732 - val_loss: 1.2285 - val_acc: 0.4948
#
# Epoch 00124: val_loss did not improve from 1.22693
# Epoch 125/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1153 - acc: 0.5674 - val_loss: 1.2272 - val_acc: 0.4965
#
# Epoch 00125: val_loss did not improve from 1.22693
# Epoch 126/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1150 - acc: 0.5705 - val_loss: 1.2284 - val_acc: 0.4928
#
# Epoch 00126: val_loss did not improve from 1.22693
# Epoch 127/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1106 - acc: 0.5707 - val_loss: 1.2274 - val_acc: 0.4956
#
# Epoch 00127: val_loss did not improve from 1.22693
# Epoch 128/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1098 - acc: 0.5746 - val_loss: 1.2268 - val_acc: 0.4969
#
# Epoch 00128: val_loss improved from 1.22693 to 1.22681, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 129/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1121 - acc: 0.5698 - val_loss: 1.2268 - val_acc: 0.4938
#
# Epoch 00129: val_loss did not improve from 1.22681
# Epoch 130/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1056 - acc: 0.5716 - val_loss: 1.2286 - val_acc: 0.4948
#
# Epoch 00130: val_loss did not improve from 1.22681
# Epoch 131/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1113 - acc: 0.5709 - val_loss: 1.2264 - val_acc: 0.4949
#
# Epoch 00131: val_loss improved from 1.22681 to 1.22643, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 132/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1060 - acc: 0.5748 - val_loss: 1.2278 - val_acc: 0.4921
#
# Epoch 00132: val_loss did not improve from 1.22643
# Epoch 133/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1076 - acc: 0.5709 - val_loss: 1.2259 - val_acc: 0.4951
#
# Epoch 00133: val_loss improved from 1.22643 to 1.22589, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 134/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1113 - acc: 0.5726 - val_loss: 1.2274 - val_acc: 0.4924
#
# Epoch 00134: val_loss did not improve from 1.22589
# Epoch 135/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1089 - acc: 0.5711 - val_loss: 1.2261 - val_acc: 0.4946
#
# Epoch 00135: val_loss did not improve from 1.22589
# Epoch 136/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1027 - acc: 0.5742 - val_loss: 1.2260 - val_acc: 0.4954
#
# Epoch 00136: val_loss did not improve from 1.22589
# Epoch 137/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1114 - acc: 0.5694 - val_loss: 1.2273 - val_acc: 0.4903
#
# Epoch 00137: val_loss did not improve from 1.22589
# Epoch 138/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1025 - acc: 0.5756 - val_loss: 1.2255 - val_acc: 0.4951
#
# Epoch 00138: val_loss improved from 1.22589 to 1.22554, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 139/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1024 - acc: 0.5765 - val_loss: 1.2244 - val_acc: 0.4921
#
# Epoch 00139: val_loss improved from 1.22554 to 1.22436, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 140/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1070 - acc: 0.5712 - val_loss: 1.2252 - val_acc: 0.4949
#
# Epoch 00140: val_loss did not improve from 1.22436
# Epoch 141/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1026 - acc: 0.5761 - val_loss: 1.2230 - val_acc: 0.4983
#
# Epoch 00141: val_loss improved from 1.22436 to 1.22298, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 142/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1073 - acc: 0.5724 - val_loss: 1.2232 - val_acc: 0.4962
#
# Epoch 00142: val_loss did not improve from 1.22298
# Epoch 143/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1021 - acc: 0.5753 - val_loss: 1.2235 - val_acc: 0.4981
#
# Epoch 00143: val_loss did not improve from 1.22298
# Epoch 144/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1042 - acc: 0.5770 - val_loss: 1.2209 - val_acc: 0.4968
#
# Epoch 00144: val_loss improved from 1.22298 to 1.22095, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5
# Epoch 145/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1022 - acc: 0.5746 - val_loss: 1.2240 - val_acc: 0.4946
#
# Epoch 00145: val_loss did not improve from 1.22095
# Epoch 146/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.0973 - acc: 0.5821 - val_loss: 1.2226 - val_acc: 0.4926
#
# Epoch 00146: val_loss did not improve from 1.22095
# Epoch 147/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1114 - acc: 0.5687 - val_loss: 1.2223 - val_acc: 0.4941
#
# Epoch 00147: val_loss did not improve from 1.22095
# Epoch 148/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1021 - acc: 0.5771 - val_loss: 1.2239 - val_acc: 0.4932
#
# Epoch 00148: val_loss did not improve from 1.22095
# Epoch 149/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1088 - acc: 0.5726 - val_loss: 1.2230 - val_acc: 0.4925
#
# Epoch 00149: val_loss did not improve from 1.22095
# Epoch 150/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1003 - acc: 0.5776 - val_loss: 1.2219 - val_acc: 0.4936
#
# Epoch 00150: val_loss did not improve from 1.22095
# Epoch 151/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1004 - acc: 0.5779 - val_loss: 1.2231 - val_acc: 0.4923
#
# Epoch 00151: val_loss did not improve from 1.22095
# Epoch 152/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1030 - acc: 0.5738 - val_loss: 1.2211 - val_acc: 0.4944
#
# Epoch 00152: val_loss did not improve from 1.22095
# Epoch 153/400
# 1036/1036 [==============================] - 71s 68ms/step - loss: 1.1059 - acc: 0.5724 - val_loss: 1.2228 - val_acc: 0.4945
#
# Epoch 00153: val_loss did not improve from 1.22095
# Epoch 154/400
# 1036/1036 [==============================] - 70s 68ms/step - loss: 1.1010 - acc: 0.5800 - val_loss: 1.2216 - val_acc: 0.4952
#
# Epoch 00154: val_loss did not improve from 1.22095
# results per 6-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 1.2216 - acc: 0.4952
# [[1079  421  215  174  287]
#  [ 156  892  205  132  155]
#  [ 157  418 1358  416  440]
#  [ 137  373  508 1090  385]
#  [ 148  159  237  368  968]]
#               precision    recall  f1-score   support
#
#           HC       0.64      0.50      0.56      2176
#          a_H       0.39      0.58      0.47      1540
#          a_K       0.54      0.49      0.51      2789
#          a_A       0.50      0.44      0.47      2493
#          a_C       0.43      0.51      0.47      1880
#
#     accuracy                           0.50     10878
#    macro avg       0.50      0.50      0.50     10878
# weighted avg       0.51      0.50      0.50     10878

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

mmscaler_LSTM.fit(test_COP_ML)
test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

test_x = test_V[test_index]
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
loss, acc = model.evaluate(
    x=test_x, 
    y=test_y,
    verbose=1)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))

# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# 340/340 [==============================] - 6s 14ms/step - loss: 0.8931 - accuracy: 0.6862
# Restored model, accuracy: 70.85%
# [[1350   71   86   85  162]
#  [ 104  826  268   91  162]
#  [ 190  221 1592  390  126]
#  [  68  183  237 2251  250]
#  [ 124   92  116  145 1688]]
#               precision    recall  f1-score   support
#
#           HC   0.735294  0.769669  0.752089      1754
#          a_H   0.592965  0.569263  0.580872      1451
#          a_K   0.692475  0.631997  0.660855      2519
#          a_A   0.759959  0.753095  0.756512      2989
#          a_C   0.706868  0.779677  0.741489      2165
#
#     accuracy                       0.708494     10878
#    macro avg   0.697512  0.700740  0.698363     10878
# weighted avg   0.707513  0.708494  0.707229     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/1fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
loss, acc = model.evaluate(
    x=test_x, 
    y=test_y,
    verbose=1)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))

# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_24 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_25 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# activation_27 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# activation_28 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_29 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# 340/340 [==============================] - 6s 14ms/step - loss: 0.8611 - accuracy: 0.6916
# Restored model, accuracy: 70.12%
# [[1350   71   86   85  162]
#  [ 104  826  268   91  162]
#  [ 190  221 1592  390  126]
#  [  68  183  237 2251  250]
#  [ 124   92  116  145 1688]]
#               precision    recall  f1-score   support
#
#           HC   0.735294  0.769669  0.752089      1754
#          a_H   0.592965  0.569263  0.580872      1451
#          a_K   0.692475  0.631997  0.660855      2519
#          a_A   0.759959  0.753095  0.756512      2989
#          a_C   0.706868  0.779677  0.741489      2165
#
#     accuracy                       0.708494     10878
#    macro avg   0.697512  0.700740  0.698363     10878
# weighted avg   0.707513  0.708494  0.707229     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))

# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_30 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_31 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# activation_33 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# activation_34 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_35 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1535   21   86   54   58]
#  [ 135  799  244  105  168]
#  [ 191  172 1697  251  208]
#  [  77  184  281 2214  233]
#  [  78   59  206   89 1733]]
#               precision    recall  f1-score   support
#
#           HC   0.761409  0.875143  0.814324      1754
#          a_H   0.646964  0.550655  0.594937      1451
#          a_K   0.675020  0.673680  0.674349      2519
#          a_A   0.816071  0.740716  0.776570      2989
#          a_C   0.722083  0.800462  0.759255      2165
#
#     accuracy                       0.733407     10878
#    macro avg   0.724309  0.728131  0.723887     10878
# weighted avg   0.733331  0.733407  0.731312     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# loss, acc = model.evaluate(
#     x=test_x, 
#     y=test_y,
#     verbose=1)
# print("Restored model, accuracy: {:5.2f}%".format(100*acc))

# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1459   29  100   99   67]
#  [ 115  957  238   28  113]
#  [ 177  172 1766  270  134]
#  [  79  164  313 2215  218]
#  [  86   68  154   95 1762]]
#               precision    recall  f1-score   support
#
#           HC   0.761482  0.831813  0.795095      1754
#          a_H   0.688489  0.659545  0.673706      1451
#          a_K   0.686892  0.701072  0.693910      2519
#          a_A   0.818249  0.741051  0.777739      2989
#          a_C   0.768091  0.813857  0.790312      2165
#
#     accuracy                       0.750046     10878
#    macro avg   0.744641  0.749467  0.746152     10878
# weighted avg   0.751386  0.750046  0.749751     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_42 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_43 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 128)               512
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 64)                256
# _________________________________________________________________
# activation_46 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_47 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1395   35  121   81  122]
#  [ 164  869  227   84  107]
#  [ 163  209 1618  295  234]
#  [ 220  205  359 1917  288]
#  [ 118  218  187  124 1518]]
#               precision    recall  f1-score   support
#
#           HC   0.677184  0.795325  0.731515      1754
#          a_H   0.565755  0.598897  0.581855      1451
#          a_K   0.644108  0.642318  0.643212      2519
#          a_A   0.766493  0.641352  0.698361      2989
#          a_C   0.669017  0.701155  0.684709      2165
#
#     accuracy                       0.672642     10878
#    macro avg   0.664512  0.675809  0.667930     10878
# weighted avg   0.677576  0.672642  0.672678     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_8 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_48 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_49 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_50 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 128)               512
# _________________________________________________________________
# activation_51 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 64)                256
# _________________________________________________________________
# activation_52 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_53 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1433   78  115   85   43]
#  [ 218  716  248  133  136]
#  [ 210  158 1627  353  171]
#  [ 176  197  323 2113  180]
#  [ 167  141  198  241 1418]]
#               precision    recall  f1-score   support
#
#           HC   0.650181  0.816990  0.724103      1754
#          a_H   0.555039  0.493453  0.522437      1451
#          a_K   0.647949  0.645891  0.646918      2519
#          a_A   0.722393  0.706925  0.714576      2989
#          a_C   0.727926  0.654965  0.689521      2165
#
#     accuracy                       0.671723     10878
#    macro avg   0.660698  0.663645  0.659511     10878
# weighted avg   0.672289  0.671723  0.669829     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_vGRF_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits= 6)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_9 (Bidirection (None, 101, 1024)         2105344
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_54 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_45 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_55 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 128)               512
# _________________________________________________________________
# activation_57 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 64)                256
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_59 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,237,657
# Trainable params: 55,235,727
# Non-trainable params: 1,930
# _________________________________________________________________
# [[ 855  279  147  200  273]
#  [ 162  717  299   57  216]
#  [ 275  431 1255  273  285]
#  [ 184  456  512 1407  430]
#  [ 170  240  294  176 1285]]
#               precision    recall  f1-score   support
#
#           HC   0.519441  0.487457  0.502941      1754
#          a_H   0.337730  0.494142  0.401231      1451
#          a_K   0.500598  0.498214  0.499403      2519
#          a_A   0.665878  0.470726  0.551548      2989
#          a_C   0.516272  0.593533  0.552213      2165
#
#     accuracy                       0.507354     10878
#    macro avg   0.507984  0.508814  0.501467     10878
# weighted avg   0.530446  0.507354  0.511717     10878

# %%
import numpy as np
print("validation: samples / class")
print(np.where(np.argmax(val_label_list[0], axis=1)==0)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==1)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==2)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==3)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==4)[0].shape)
print("training: samples / class")
print(np.where(np.argmax(train_label_list[0], axis=1)==0)[0].shape)
print(np.where(np.argmax(train_label_list[0], axis=1)==1)[0].shape)
print(np.where(np.argmax(train_label_list[0], axis=1)==2)[0].shape)
print(np.where(np.argmax(train_label_list[0], axis=1)==3)[0].shape)
print(np.where(np.argmax(train_label_list[0], axis=1)==4)[0].shape)
print("test: samples / class")
print(np.where(np.argmax(test_y, axis=1)==0)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==1)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==2)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==3)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==4)[0].shape)
# Out:
# validation: samples / class
# (1804,)
# (1489,)
# (2478,)
# (2821,)
# (2286,)
# training: samples / class
# (11952,)
# (10373,)
# (15152,)
# (15736,)
# (12055,)
# test: samples / class
# (1754,)
# (1451,)
# (2519,)
# (2989,)
# (2165,)
