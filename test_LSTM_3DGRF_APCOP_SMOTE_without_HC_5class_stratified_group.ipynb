# %% [markdown]
# <a href="https://colab.research.google.com/github/is0280fp/Gait/blob/main/test_LSTM_3DGRF_APCOP_SMOTE_without_HC_5class_stratified_group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

# Baseline

# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# Out:
# Mounted at /content/drive

# %%
# StratifiedGroupKFoldの分割結果をpickle
import pickle

# test 
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   tes_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   tes_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
# with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()


# train
with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_V.pickle", mode="rb") as f:
   train_V_list = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_AP.pickle", mode="rb") as f:
   train_AP_list = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_ML.pickle", mode="rb") as f:
   train_ML_list = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_COP_AP.pickle", mode="rb") as f:
   train_COP_AP_list = pickle.load(f)
f.close()
# with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_COP_ML.pickle", mode="rb") as f:
#    train_COP_ML_list = pickle.load(f)
# f.close()
with open("/content/drive/MyDrive/test_data/Oversampling_smote_without_HC/oversampled_training_label.pickle", mode="rb") as f:
   train_label_list = pickle.load(f)
f.close()

# validation

with open("/content/drive/MyDrive/test_data/label_val_train.pickle", mode="rb") as f:
   val_train_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/val_idx_list.pickle", mode="rb") as f:
   val_index_list = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/V_val_train.pickle", mode="rb") as f:
   val_train_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_val_train.pickle", mode="rb") as f:
   val_train_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_val_train.pickle", mode="rb") as f:
   val_train_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_val_train.pickle", mode="rb") as f:
   val_train_COP_AP = pickle.load(f)
f.close()
# with open("/content/drive/MyDrive/test_data/COP_ML_val_train.pickle", mode="rb") as f:
#    val_train_COP_ML = pickle.load(f)
# f.close()

# %%
# import os
# print(os.getcwd())

# # os.chdir("C:\\Users\\clasi\\OneDrive\\デスクトップ\\test_data\\test_data\\")
# os.chdir("C:\\Users\\mm101\\Desktop\\test_data\\")

# %%
# # StratifiedGroupKFoldの分割結果をpickle
# import pickle

# # test 
# with open("V_test.pickle", mode="rb") as f:
#    test_V = pickle.load(f)
# f.close()
# with open("AP_test.pickle", mode="rb") as f:
#    tes_AP = pickle.load(f)
# f.close()
# with open("ML_test.pickle", mode="rb") as f:
#    tes_ML = pickle.load(f)
# f.close()

# with open("COP_AP_test.pickle", mode="rb") as f:
#    test_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_test.pickle", mode="rb") as f:
#    test_COP_ML = pickle.load(f)
# f.close()

# with open("label_test.pickle", mode="rb") as f:
#    test_label = pickle.load(f)
# f.close()


# # train
# with open("oversampled_V.pickle", mode="rb") as f:
#    train_V_list = pickle.load(f)
# f.close()
# with open("oversampled_AP.pickle", mode="rb") as f:
#    train_AP_list = pickle.load(f)
# f.close()
# with open("oversampled_ML.pickle", mode="rb") as f:
#    train_ML_list = pickle.load(f)
# f.close()
# with open("oversampled_COP_AP.pickle", mode="rb") as f:
#    train_COP_AP_list = pickle.load(f)
# f.close()
# with open("oversampled_COP_ML.pickle", mode="rb") as f:
#    train_COP_ML_list = pickle.load(f)
# f.close()
# with open("oversampled_training_label.pickle", mode="rb") as f:
#    train_label_list = pickle.load(f)
# f.close()

# # validation

# with open("label_val_train.pickle", mode="rb") as f:
#    val_train_label = pickle.load(f)
# f.close()

# with open("val_idx_list.pickle", mode="rb") as f:
#    val_index_list = pickle.load(f)
# f.close()

# with open("V_val_train.pickle", mode="rb") as f:
#    val_train_V = pickle.load(f)
# f.close()
# with open("AP_val_train.pickle", mode="rb") as f:
#    val_train_AP = pickle.load(f)
# f.close()
# with open("ML_val_train.pickle", mode="rb") as f:
#    val_train_ML = pickle.load(f)
# f.close()

# with open("COP_AP_val_train.pickle", mode="rb") as f:
#    val_train_COP_AP = pickle.load(f)
# f.close()
# with open("COP_ML_val_train.pickle", mode="rb") as f:
#    val_train_COP_ML = pickle.load(f)
# f.close()

# %%
# import sys

# print("{}{: >25}{}{: >10}{}".format('|','Variable Name','|','Memory','|'))
# print(" ------------------------------------ ")
# for var_name in dir():
#     if not var_name.startswith("_"):
#         print("{}{: >25}{}{: >10}{}".format('|',var_name,'|',sys.getsizeof(eval(var_name)),'|'))

# %%
import gc
gc.collect()
# Out:
# 198

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

mmscaler.fit(val_train_V)
val_train_V = mmscaler.transform(val_train_V)
val_train_V = val_train_V.reshape(val_train_V.shape[0], val_train_V.shape[1], 1)

mmscaler.fit(val_train_AP)
val_train_AP = mmscaler.transform(val_train_AP)
val_train_AP = val_train_AP.reshape(val_train_AP.shape[0], val_train_AP.shape[1], 1)

mmscaler.fit(val_train_ML)
val_train_ML = mmscaler.transform(val_train_ML)
val_train_ML = val_train_ML.reshape(val_train_ML.shape[0], val_train_ML.shape[1], 1)

mmscaler.fit(val_train_COP_AP)
val_train_COP_AP = mmscaler.transform(val_train_COP_AP)
val_train_COP_AP = val_train_COP_AP.reshape(val_train_COP_AP.shape[0], val_train_COP_AP.shape[1], 1)

# mmscaler.fit(val_train_COP_ML)
# val_train_COP_ML = mmscaler.transform(val_train_COP_ML)
# val_train_COP_ML = val_train_COP_ML.reshape(val_train_COP_ML.shape[0], val_train_COP_ML.shape[1], 1)

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

i = 0
for train_V in train_V_list:  
  mmscaler.fit(train_V)
  train_V = mmscaler.transform(train_V)
  train_V = train_V.reshape(train_V.shape[0], train_V.shape[1], 1)
  train_V_list[i] = train_V
  i = i+1

i = 0
for train_AP in train_AP_list:  
  mmscaler.fit(train_AP)
  train_AP = mmscaler.transform(train_AP)
  train_AP = train_AP.reshape(train_AP.shape[0], train_AP.shape[1], 1)
  train_AP_list[i] = train_AP
  i = i+1

i = 0
for train_ML in train_ML_list:  
  mmscaler.fit(train_ML)
  train_ML = mmscaler.transform(train_ML)
  train_ML = train_ML.reshape(train_ML.shape[0], train_ML.shape[1], 1)
  train_ML_list[i] = train_ML
  i = i+1

i = 0
for train_COP_AP in train_COP_AP_list:  
  mmscaler.fit(train_COP_AP)
  train_COP_AP = mmscaler.transform(train_COP_AP)
  train_COP_AP = train_COP_AP.reshape(train_COP_AP.shape[0], train_COP_AP.shape[1], 1)
  train_COP_AP_list[i] = train_COP_AP
  i = i+1

# i = 0
# for train_COP_ML in train_COP_ML_list:  
#   mmscaler.fit(train_COP_ML)
#   train_COP_ML = mmscaler.transform(train_COP_ML)
#   train_COP_ML = train_COP_ML.reshape(train_COP_ML.shape[0], train_COP_ML.shape[1], 1)
#   train_COP_ML_list[i] = train_COP_ML
#   i = i+1

# %%
# !pip install keras-layer-normalization
# Out:
# Collecting keras-layer-normalization
#   Downloading https://files.pythonhosted.org/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (1.19.5)
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras-layer-normalization) (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras-layer-normalization) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras-layer-normalization) (1.15.0)
# Building wheels for collected packages: keras-layer-normalization
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-cp37-none-any.whl size=5269 sha256=937b3b07035b2f9547396e17d4f3b66500580a3940e073573c6145b36b3cf683
#   Stored in directory: /root/.cache/pip/wheels/54/80/22/a638a7d406fd155e507aa33d703e3fa2612b9eb7bb4f4fe667
# Successfully built keras-layer-normalization
# Installing collected packages: keras-layer-normalization
# Successfully installed keras-layer-normalization-0.14.0

# %%
del train_AP
del train_ML
del train_V
del train_COP_AP
# del train_COP_ML
# del train_data
# del train_label

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

# %%
from keras import optimizers, regularizers
from keras.initializers import he_normal
from keras.layers import ELU, Conv2D, MaxPooling2D, LSTM, InputLayer, Dense, Dropout, Activation, Flatten, concatenate, Conv1D, MaxPooling1D, Input, Reshape, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.layers.advanced_activations import PReLU
from keras.models import Model, Sequential
from keras.callbacks import TensorBoard, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix
from keras.layers.normalization import BatchNormalization
from keras_layer_normalization import LayerNormalization
# from keras_self_attention import SeqSelfAttention
import numpy as np
import keras
from sklearn.utils import class_weight

import seaborn as sns
import matplotlib.pyplot as plt
import time
import math
import datetime

NAME = "test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group"
i = 0

# 共通
now = datetime.datetime.now()

# early stopping
early_stopping = EarlyStopping(
                        monitor='val_loss',
                        min_delta=0.0,
                        patience=10,
                )

def decay_schedule(epoch, lr):
    # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
    if (epoch % 80 == 0) and (epoch != 0):
        lr = lr * 0.1
    return lr

lr_scheduler = LearningRateScheduler(decay_schedule)

initializer = he_normal()

classes_main = 5

#LSTM-----------------------------------------------------------------------------------------------------------------------
def build_model():
  # LSTM
  # 最初これだけだった
  model = Sequential()
  model.add(InputLayer(input_shape=(101, 4)))

  model.add(Bidirectional(LSTM(512, return_sequences=True)))
  # model.add(LSTM(256, return_sequences=True))
  model.add(LayerNormalization())
  model.add(Activation('tanh'))
  model.add(Dropout(0.5))
  
  model.add(Flatten())

  model.add(Dense(512, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.5))

  model.add(Dense(256, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(128, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(64, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  # model.add(Dropout(0.5))

  model.add(Dense(classes_main, kernel_initializer=initializer))
  model.add(BatchNormalization())
  model.add(Activation('softmax'))

  model.summary()
  return model
#------------------------------------------------------------------------------------------------------------------------------------------------------

# k-fold目のモデルのval_accuracyとval_lossのログ
history = []
# 混合行列のログ
cmx_list = []
# F1などスコアのログ
report_list = []

val_label_list = []
used_train_label_list = []

val_LSTM_data_list = []
train_LSTM_data_list = []

i = 0
for i in range(0, 7):
  train_LSTM_data = np.concatenate([train_V_list[i], train_AP_list[i], train_ML_list[i], train_COP_AP_list[i]], axis=2)
  val_index = val_index_list[i]
  val_LSTM_data = np.concatenate([val_train_V[val_index], val_train_AP[val_index], val_train_ML[val_index], val_train_COP_AP[val_index]], axis=2)
  
  # label
  train_label = train_label_list[i] 
  val_label= val_train_label[val_index] 

  # シャッフル
  p = np.random.permutation(len(train_label))
  train_LSTM_data = train_LSTM_data[p]
  train_label = train_label[p]

  train_label = keras.utils.to_categorical(train_label, classes_main)
  val_label = keras.utils.to_categorical(val_label, classes_main)

  train_LSTM_data_list.append(train_LSTM_data)
  val_LSTM_data_list.append(val_LSTM_data)

  val_label_list.append(val_label)
  used_train_label_list.append(train_label)

  print("train_data", train_LSTM_data.shape)
  print("val_data", val_LSTM_data.shape)
  i = i+1
# Out:
# train_data (74896, 101, 4)
# val_data (10878, 101, 4)
# train_data (76012, 101, 4)
# val_data (10878, 101, 4)
# train_data (74344, 101, 4)
# val_data (10878, 101, 4)
# train_data (76844, 101, 4)
# val_data (10878, 101, 4)
# train_data (74644, 101, 4)
# val_data (10878, 101, 4)
# train_data (75328, 101, 4)
# val_data (10878, 101, 4)
# train_data (75836, 101, 4)
# val_data (10878, 101, 4)

# %%
for i in range(0, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  

  print("HC for train", np.where(np.argmax(train_label, axis=1)==0)[0].shape)
  print("H for train", np.where(np.argmax(train_label, axis=1)==1)[0].shape)
  print("K for train", np.where(np.argmax(train_label, axis=1)==2)[0].shape)
  print("A for train", np.where(np.argmax(train_label, axis=1)==3)[0].shape)
  print("C for train", np.where(np.argmax(train_label, axis=1)==4)[0].shape)

  print("HC for val", np.where(np.argmax(val_label, axis=1)==0)[0].shape)
  print("H for val", np.where(np.argmax(val_label, axis=1)==1)[0].shape)
  print("K for val", np.where(np.argmax(val_label, axis=1)==2)[0].shape)
  print("A for val", np.where(np.argmax(val_label, axis=1)==3)[0].shape)
  print("C for val", np.where(np.argmax(val_label, axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=used_train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# now = datetime.datetime.now()
# with open("/content/drive/MyDrive/saved_models/test/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/test/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

now = datetime.datetime.now()

with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(cmx_list, f)
f.close()

with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
   pickle.dump(report_list, f)
f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1189/1189 [==============================] - 113s 66ms/step - loss: 1.5332 - acc: 0.3547 - val_loss: 1.2811 - val_acc: 0.5066
#
# Epoch 00001: val_loss improved from inf to 1.28111, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 1.2050 - acc: 0.5160 - val_loss: 1.1729 - val_acc: 0.5500
#
# Epoch 00002: val_loss improved from 1.28111 to 1.17287, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 1.0772 - acc: 0.5962 - val_loss: 1.0745 - val_acc: 0.6092
#
# Epoch 00003: val_loss improved from 1.17287 to 1.07449, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.9915 - acc: 0.6453 - val_loss: 1.0055 - val_acc: 0.6586
#
# Epoch 00004: val_loss improved from 1.07449 to 1.00549, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.9134 - acc: 0.6913 - val_loss: 0.9582 - val_acc: 0.6685
#
# Epoch 00005: val_loss improved from 1.00549 to 0.95824, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.8498 - acc: 0.7287 - val_loss: 0.9166 - val_acc: 0.6908
#
# Epoch 00006: val_loss improved from 0.95824 to 0.91665, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.8027 - acc: 0.7556 - val_loss: 0.8694 - val_acc: 0.7065
#
# Epoch 00007: val_loss improved from 0.91665 to 0.86939, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.7620 - acc: 0.7785 - val_loss: 0.8454 - val_acc: 0.7248
#
# Epoch 00008: val_loss improved from 0.86939 to 0.84542, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.7254 - acc: 0.7960 - val_loss: 0.8099 - val_acc: 0.7446
#
# Epoch 00009: val_loss improved from 0.84542 to 0.80992, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.6895 - acc: 0.8134 - val_loss: 0.7685 - val_acc: 0.7624
#
# Epoch 00010: val_loss improved from 0.80992 to 0.76854, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.6522 - acc: 0.8356 - val_loss: 0.7528 - val_acc: 0.7560
#
# Epoch 00011: val_loss improved from 0.76854 to 0.75283, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.6282 - acc: 0.8444 - val_loss: 0.7431 - val_acc: 0.7584
#
# Epoch 00012: val_loss improved from 0.75283 to 0.74311, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.6025 - acc: 0.8593 - val_loss: 0.7253 - val_acc: 0.7805
#
# Epoch 00013: val_loss improved from 0.74311 to 0.72535, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.5740 - acc: 0.8731 - val_loss: 0.6987 - val_acc: 0.7842
#
# Epoch 00014: val_loss improved from 0.72535 to 0.69867, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.5546 - acc: 0.8813 - val_loss: 0.6918 - val_acc: 0.7824
#
# Epoch 00015: val_loss improved from 0.69867 to 0.69178, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.5334 - acc: 0.8901 - val_loss: 0.6731 - val_acc: 0.7984
#
# Epoch 00016: val_loss improved from 0.69178 to 0.67315, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.5141 - acc: 0.8963 - val_loss: 0.6695 - val_acc: 0.7968
#
# Epoch 00017: val_loss improved from 0.67315 to 0.66948, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.4902 - acc: 0.9078 - val_loss: 0.6474 - val_acc: 0.8058
#
# Epoch 00018: val_loss improved from 0.66948 to 0.64742, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.4755 - acc: 0.9117 - val_loss: 0.6477 - val_acc: 0.8018
#
# Epoch 00019: val_loss did not improve from 0.64742
# Epoch 20/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.4566 - acc: 0.9225 - val_loss: 0.6328 - val_acc: 0.8132
#
# Epoch 00020: val_loss improved from 0.64742 to 0.63282, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.4442 - acc: 0.9245 - val_loss: 0.6257 - val_acc: 0.8102
#
# Epoch 00021: val_loss improved from 0.63282 to 0.62575, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.4268 - acc: 0.9324 - val_loss: 0.6190 - val_acc: 0.8118
#
# Epoch 00022: val_loss improved from 0.62575 to 0.61895, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.4115 - acc: 0.9378 - val_loss: 0.6076 - val_acc: 0.8173
#
# Epoch 00023: val_loss improved from 0.61895 to 0.60762, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3957 - acc: 0.9438 - val_loss: 0.5884 - val_acc: 0.8209
#
# Epoch 00024: val_loss improved from 0.60762 to 0.58839, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.3828 - acc: 0.9468 - val_loss: 0.5813 - val_acc: 0.8247
#
# Epoch 00025: val_loss improved from 0.58839 to 0.58131, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3722 - acc: 0.9495 - val_loss: 0.5888 - val_acc: 0.8242
#
# Epoch 00026: val_loss did not improve from 0.58131
# Epoch 27/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3635 - acc: 0.9507 - val_loss: 0.5674 - val_acc: 0.8358
#
# Epoch 00027: val_loss improved from 0.58131 to 0.56738, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3470 - acc: 0.9572 - val_loss: 0.5649 - val_acc: 0.8289
#
# Epoch 00028: val_loss improved from 0.56738 to 0.56488, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3404 - acc: 0.9577 - val_loss: 0.5637 - val_acc: 0.8326
#
# Epoch 00029: val_loss improved from 0.56488 to 0.56367, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3277 - acc: 0.9624 - val_loss: 0.5443 - val_acc: 0.8403
#
# Epoch 00030: val_loss improved from 0.56367 to 0.54427, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3167 - acc: 0.9652 - val_loss: 0.5417 - val_acc: 0.8398
#
# Epoch 00031: val_loss improved from 0.54427 to 0.54165, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.3106 - acc: 0.9656 - val_loss: 0.5521 - val_acc: 0.8362
#
# Epoch 00032: val_loss did not improve from 0.54165
# Epoch 33/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.3028 - acc: 0.9673 - val_loss: 0.5400 - val_acc: 0.8326
#
# Epoch 00033: val_loss improved from 0.54165 to 0.54000, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2908 - acc: 0.9707 - val_loss: 0.5438 - val_acc: 0.8362
#
# Epoch 00034: val_loss did not improve from 0.54000
# Epoch 35/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2811 - acc: 0.9727 - val_loss: 0.5267 - val_acc: 0.8429
#
# Epoch 00035: val_loss improved from 0.54000 to 0.52674, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2717 - acc: 0.9756 - val_loss: 0.5235 - val_acc: 0.8337
#
# Epoch 00036: val_loss improved from 0.52674 to 0.52350, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2674 - acc: 0.9750 - val_loss: 0.5187 - val_acc: 0.8461
#
# Epoch 00037: val_loss improved from 0.52350 to 0.51869, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2600 - acc: 0.9766 - val_loss: 0.5300 - val_acc: 0.8341
#
# Epoch 00038: val_loss did not improve from 0.51869
# Epoch 39/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2496 - acc: 0.9795 - val_loss: 0.5109 - val_acc: 0.8400
#
# Epoch 00039: val_loss improved from 0.51869 to 0.51094, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2429 - acc: 0.9811 - val_loss: 0.5175 - val_acc: 0.8411
#
# Epoch 00040: val_loss did not improve from 0.51094
# Epoch 41/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2375 - acc: 0.9809 - val_loss: 0.5098 - val_acc: 0.8442
#
# Epoch 00041: val_loss improved from 0.51094 to 0.50983, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2304 - acc: 0.9823 - val_loss: 0.4983 - val_acc: 0.8537
#
# Epoch 00042: val_loss improved from 0.50983 to 0.49831, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 43/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2254 - acc: 0.9831 - val_loss: 0.5045 - val_acc: 0.8431
#
# Epoch 00043: val_loss did not improve from 0.49831
# Epoch 44/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2181 - acc: 0.9838 - val_loss: 0.4928 - val_acc: 0.8520
#
# Epoch 00044: val_loss improved from 0.49831 to 0.49281, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.2112 - acc: 0.9859 - val_loss: 0.4909 - val_acc: 0.8468
#
# Epoch 00045: val_loss improved from 0.49281 to 0.49087, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2065 - acc: 0.9857 - val_loss: 0.4924 - val_acc: 0.8514
#
# Epoch 00046: val_loss did not improve from 0.49087
# Epoch 47/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.2016 - acc: 0.9865 - val_loss: 0.4887 - val_acc: 0.8403
#
# Epoch 00047: val_loss improved from 0.49087 to 0.48866, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1946 - acc: 0.9876 - val_loss: 0.4822 - val_acc: 0.8488
#
# Epoch 00048: val_loss improved from 0.48866 to 0.48218, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1906 - acc: 0.9879 - val_loss: 0.4778 - val_acc: 0.8602
#
# Epoch 00049: val_loss improved from 0.48218 to 0.47779, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1874 - acc: 0.9882 - val_loss: 0.5015 - val_acc: 0.8371
#
# Epoch 00050: val_loss did not improve from 0.47779
# Epoch 51/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1802 - acc: 0.9891 - val_loss: 0.4708 - val_acc: 0.8581
#
# Epoch 00051: val_loss improved from 0.47779 to 0.47077, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1756 - acc: 0.9884 - val_loss: 0.4755 - val_acc: 0.8548
#
# Epoch 00052: val_loss did not improve from 0.47077
# Epoch 53/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1704 - acc: 0.9900 - val_loss: 0.4864 - val_acc: 0.8432
#
# Epoch 00053: val_loss did not improve from 0.47077
# Epoch 54/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1669 - acc: 0.9900 - val_loss: 0.4786 - val_acc: 0.8441
#
# Epoch 00054: val_loss did not improve from 0.47077
# Epoch 55/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1627 - acc: 0.9913 - val_loss: 0.4690 - val_acc: 0.8584
#
# Epoch 00055: val_loss improved from 0.47077 to 0.46896, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1591 - acc: 0.9917 - val_loss: 0.4641 - val_acc: 0.8603
#
# Epoch 00056: val_loss improved from 0.46896 to 0.46405, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 57/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1539 - acc: 0.9914 - val_loss: 0.4618 - val_acc: 0.8561
#
# Epoch 00057: val_loss improved from 0.46405 to 0.46182, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 58/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1499 - acc: 0.9916 - val_loss: 0.4673 - val_acc: 0.8495
#
# Epoch 00058: val_loss did not improve from 0.46182
# Epoch 59/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1453 - acc: 0.9930 - val_loss: 0.4614 - val_acc: 0.8603
#
# Epoch 00059: val_loss improved from 0.46182 to 0.46140, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 60/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1425 - acc: 0.9925 - val_loss: 0.4591 - val_acc: 0.8546
#
# Epoch 00060: val_loss improved from 0.46140 to 0.45907, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1403 - acc: 0.9932 - val_loss: 0.4715 - val_acc: 0.8466
#
# Epoch 00061: val_loss did not improve from 0.45907
# Epoch 62/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1354 - acc: 0.9938 - val_loss: 0.4691 - val_acc: 0.8474
#
# Epoch 00062: val_loss did not improve from 0.45907
# Epoch 63/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1322 - acc: 0.9936 - val_loss: 0.4544 - val_acc: 0.8609
#
# Epoch 00063: val_loss improved from 0.45907 to 0.45437, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 64/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1294 - acc: 0.9931 - val_loss: 0.4428 - val_acc: 0.8646
#
# Epoch 00064: val_loss improved from 0.45437 to 0.44282, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 65/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1255 - acc: 0.9943 - val_loss: 0.4468 - val_acc: 0.8622
#
# Epoch 00065: val_loss did not improve from 0.44282
# Epoch 66/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1232 - acc: 0.9941 - val_loss: 0.4623 - val_acc: 0.8537
#
# Epoch 00066: val_loss did not improve from 0.44282
# Epoch 67/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1194 - acc: 0.9942 - val_loss: 0.4526 - val_acc: 0.8506
#
# Epoch 00067: val_loss did not improve from 0.44282
# Epoch 68/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1163 - acc: 0.9944 - val_loss: 0.4598 - val_acc: 0.8522
#
# Epoch 00068: val_loss did not improve from 0.44282
# Epoch 69/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1122 - acc: 0.9953 - val_loss: 0.4493 - val_acc: 0.8563
#
# Epoch 00069: val_loss did not improve from 0.44282
# Epoch 70/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1095 - acc: 0.9957 - val_loss: 0.4390 - val_acc: 0.8653
#
# Epoch 00070: val_loss improved from 0.44282 to 0.43903, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 71/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1062 - acc: 0.9960 - val_loss: 0.4590 - val_acc: 0.8541
#
# Epoch 00071: val_loss did not improve from 0.43903
# Epoch 72/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.1072 - acc: 0.9947 - val_loss: 0.4460 - val_acc: 0.8553
#
# Epoch 00072: val_loss did not improve from 0.43903
# Epoch 73/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.1028 - acc: 0.9955 - val_loss: 0.4569 - val_acc: 0.8571
#
# Epoch 00073: val_loss did not improve from 0.43903
# Epoch 74/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0998 - acc: 0.9953 - val_loss: 0.4473 - val_acc: 0.8542
#
# Epoch 00074: val_loss did not improve from 0.43903
# Epoch 75/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0976 - acc: 0.9959 - val_loss: 0.4517 - val_acc: 0.8592
#
# Epoch 00075: val_loss did not improve from 0.43903
# Epoch 76/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0969 - acc: 0.9961 - val_loss: 0.4604 - val_acc: 0.8509
#
# Epoch 00076: val_loss did not improve from 0.43903
# Epoch 77/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0932 - acc: 0.9957 - val_loss: 0.4586 - val_acc: 0.8571
#
# Epoch 00077: val_loss did not improve from 0.43903
# Epoch 78/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0899 - acc: 0.9965 - val_loss: 0.4577 - val_acc: 0.8491
#
# Epoch 00078: val_loss did not improve from 0.43903
# Epoch 79/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0876 - acc: 0.9969 - val_loss: 0.4390 - val_acc: 0.8657
#
# Epoch 00079: val_loss improved from 0.43903 to 0.43897, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 80/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0848 - acc: 0.9971 - val_loss: 0.4509 - val_acc: 0.8565
#
# Epoch 00080: val_loss did not improve from 0.43897
# Epoch 81/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0830 - acc: 0.9970 - val_loss: 0.4421 - val_acc: 0.8623
#
# Epoch 00081: val_loss did not improve from 0.43897
# Epoch 82/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0807 - acc: 0.9973 - val_loss: 0.4418 - val_acc: 0.8623
#
# Epoch 00082: val_loss did not improve from 0.43897
# Epoch 83/400
# 1189/1189 [==============================] - 79s 67ms/step - loss: 0.0801 - acc: 0.9976 - val_loss: 0.4430 - val_acc: 0.8628
#
# Epoch 00083: val_loss did not improve from 0.43897
# Epoch 84/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0793 - acc: 0.9976 - val_loss: 0.4428 - val_acc: 0.8638
#
# Epoch 00084: val_loss did not improve from 0.43897
# Epoch 85/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0777 - acc: 0.9981 - val_loss: 0.4392 - val_acc: 0.8636
#
# Epoch 00085: val_loss did not improve from 0.43897
# Epoch 86/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0776 - acc: 0.9978 - val_loss: 0.4411 - val_acc: 0.8611
#
# Epoch 00086: val_loss did not improve from 0.43897
# Epoch 87/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0771 - acc: 0.9980 - val_loss: 0.4386 - val_acc: 0.8612
#
# Epoch 00087: val_loss improved from 0.43897 to 0.43864, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 88/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0767 - acc: 0.9981 - val_loss: 0.4423 - val_acc: 0.8632
#
# Epoch 00088: val_loss did not improve from 0.43864
# Epoch 89/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0765 - acc: 0.9977 - val_loss: 0.4391 - val_acc: 0.8617
#
# Epoch 00089: val_loss did not improve from 0.43864
# Epoch 90/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0765 - acc: 0.9977 - val_loss: 0.4375 - val_acc: 0.8610
#
# Epoch 00090: val_loss improved from 0.43864 to 0.43748, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 91/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0753 - acc: 0.9982 - val_loss: 0.4366 - val_acc: 0.8618
#
# Epoch 00091: val_loss improved from 0.43748 to 0.43659, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 92/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0760 - acc: 0.9978 - val_loss: 0.4390 - val_acc: 0.8621
#
# Epoch 00092: val_loss did not improve from 0.43659
# Epoch 93/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0767 - acc: 0.9978 - val_loss: 0.4433 - val_acc: 0.8603
#
# Epoch 00093: val_loss did not improve from 0.43659
# Epoch 94/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0750 - acc: 0.9982 - val_loss: 0.4397 - val_acc: 0.8610
#
# Epoch 00094: val_loss did not improve from 0.43659
# Epoch 95/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0749 - acc: 0.9980 - val_loss: 0.4385 - val_acc: 0.8607
#
# Epoch 00095: val_loss did not improve from 0.43659
# Epoch 96/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0755 - acc: 0.9978 - val_loss: 0.4398 - val_acc: 0.8588
#
# Epoch 00096: val_loss did not improve from 0.43659
# Epoch 97/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0744 - acc: 0.9978 - val_loss: 0.4359 - val_acc: 0.8619
#
# Epoch 00097: val_loss improved from 0.43659 to 0.43588, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 98/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0743 - acc: 0.9981 - val_loss: 0.4364 - val_acc: 0.8615
#
# Epoch 00098: val_loss did not improve from 0.43588
# Epoch 99/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0737 - acc: 0.9983 - val_loss: 0.4384 - val_acc: 0.8597
#
# Epoch 00099: val_loss did not improve from 0.43588
# Epoch 100/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0737 - acc: 0.9982 - val_loss: 0.4404 - val_acc: 0.8585
#
# Epoch 00100: val_loss did not improve from 0.43588
# Epoch 101/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0731 - acc: 0.9982 - val_loss: 0.4407 - val_acc: 0.8604
#
# Epoch 00101: val_loss did not improve from 0.43588
# Epoch 102/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0731 - acc: 0.9981 - val_loss: 0.4383 - val_acc: 0.8609
#
# Epoch 00102: val_loss did not improve from 0.43588
# Epoch 103/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0735 - acc: 0.9978 - val_loss: 0.4365 - val_acc: 0.8600
#
# Epoch 00103: val_loss did not improve from 0.43588
# Epoch 104/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0729 - acc: 0.9980 - val_loss: 0.4349 - val_acc: 0.8603
#
# Epoch 00104: val_loss improved from 0.43588 to 0.43495, saving model to drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 105/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0718 - acc: 0.9983 - val_loss: 0.4350 - val_acc: 0.8648
#
# Epoch 00105: val_loss did not improve from 0.43495
# Epoch 106/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0718 - acc: 0.9983 - val_loss: 0.4367 - val_acc: 0.8591
#
# Epoch 00106: val_loss did not improve from 0.43495
# Epoch 107/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0727 - acc: 0.9982 - val_loss: 0.4359 - val_acc: 0.8636
#
# Epoch 00107: val_loss did not improve from 0.43495
# Epoch 108/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0731 - acc: 0.9981 - val_loss: 0.4358 - val_acc: 0.8652
#
# Epoch 00108: val_loss did not improve from 0.43495
# Epoch 109/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0724 - acc: 0.9980 - val_loss: 0.4380 - val_acc: 0.8567
#
# Epoch 00109: val_loss did not improve from 0.43495
# Epoch 110/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0710 - acc: 0.9983 - val_loss: 0.4388 - val_acc: 0.8625
#
# Epoch 00110: val_loss did not improve from 0.43495
# Epoch 111/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0719 - acc: 0.9983 - val_loss: 0.4368 - val_acc: 0.8664
#
# Epoch 00111: val_loss did not improve from 0.43495
# Epoch 112/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0715 - acc: 0.9982 - val_loss: 0.4383 - val_acc: 0.8639
#
# Epoch 00112: val_loss did not improve from 0.43495
# Epoch 113/400
# 1189/1189 [==============================] - 78s 66ms/step - loss: 0.0713 - acc: 0.9982 - val_loss: 0.4370 - val_acc: 0.8649
#
# Epoch 00113: val_loss did not improve from 0.43495
# Epoch 114/400
# 1189/1189 [==============================] - 79s 66ms/step - loss: 0.0712 - acc: 0.9983 - val_loss: 0.4386 - val_acc: 0.8602
#
# Epoch 00114: val_loss did not improve from 0.43495
# results per 0-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4386 - acc: 0.8602
# [[1546   11   48   88  111]
#  [  11 1162  113  102  101]
#  [ 106   52 2059  175   86]
#  [  48   48   80 2576   69]
#  [  17   82    7  166 2014]]
#               precision    recall  f1-score   support
#
#           HC       0.89      0.86      0.88      1804
#          a_H       0.86      0.78      0.82      1489
#          a_K       0.89      0.83      0.86      2478
#          a_A       0.83      0.91      0.87      2821
#          a_C       0.85      0.88      0.86      2286
#
#     accuracy                           0.86     10878
#    macro avg       0.86      0.85      0.86     10878
# weighted avg       0.86      0.86      0.86     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1207/1207 [==============================] - 84s 67ms/step - loss: 1.5361 - acc: 0.3626 - val_loss: 1.2855 - val_acc: 0.5027
#
# Epoch 00001: val_loss improved from inf to 1.28546, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1207/1207 [==============================] - 79s 66ms/step - loss: 1.2155 - acc: 0.5139 - val_loss: 1.1721 - val_acc: 0.5494
#
# Epoch 00002: val_loss improved from 1.28546 to 1.17209, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 1.0781 - acc: 0.5931 - val_loss: 1.1200 - val_acc: 0.5826
#
# Epoch 00003: val_loss improved from 1.17209 to 1.12001, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.9849 - acc: 0.6492 - val_loss: 1.0612 - val_acc: 0.6133
#
# Epoch 00004: val_loss improved from 1.12001 to 1.06123, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.9167 - acc: 0.6895 - val_loss: 0.9985 - val_acc: 0.6424
#
# Epoch 00005: val_loss improved from 1.06123 to 0.99850, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.8594 - acc: 0.7237 - val_loss: 0.9676 - val_acc: 0.6593
#
# Epoch 00006: val_loss improved from 0.99850 to 0.96760, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.8089 - acc: 0.7500 - val_loss: 0.9197 - val_acc: 0.6824
#
# Epoch 00007: val_loss improved from 0.96760 to 0.91972, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.7665 - acc: 0.7727 - val_loss: 0.9058 - val_acc: 0.6820
#
# Epoch 00008: val_loss improved from 0.91972 to 0.90577, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.7261 - acc: 0.7955 - val_loss: 0.8938 - val_acc: 0.6967
#
# Epoch 00009: val_loss improved from 0.90577 to 0.89378, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.6921 - acc: 0.8119 - val_loss: 0.8568 - val_acc: 0.7138
#
# Epoch 00010: val_loss improved from 0.89378 to 0.85675, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.6584 - acc: 0.8287 - val_loss: 0.8338 - val_acc: 0.7263
#
# Epoch 00011: val_loss improved from 0.85675 to 0.83378, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.6305 - acc: 0.8437 - val_loss: 0.8124 - val_acc: 0.7238
#
# Epoch 00012: val_loss improved from 0.83378 to 0.81238, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.6034 - acc: 0.8570 - val_loss: 0.7937 - val_acc: 0.7401
#
# Epoch 00013: val_loss improved from 0.81238 to 0.79374, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.5759 - acc: 0.8716 - val_loss: 0.7676 - val_acc: 0.7550
#
# Epoch 00014: val_loss improved from 0.79374 to 0.76758, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.5538 - acc: 0.8785 - val_loss: 0.7509 - val_acc: 0.7546
#
# Epoch 00015: val_loss improved from 0.76758 to 0.75088, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.5321 - acc: 0.8884 - val_loss: 0.7495 - val_acc: 0.7627
#
# Epoch 00016: val_loss improved from 0.75088 to 0.74954, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.5093 - acc: 0.8987 - val_loss: 0.7308 - val_acc: 0.7573
#
# Epoch 00017: val_loss improved from 0.74954 to 0.73081, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4900 - acc: 0.9061 - val_loss: 0.7155 - val_acc: 0.7704
#
# Epoch 00018: val_loss improved from 0.73081 to 0.71549, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4705 - acc: 0.9154 - val_loss: 0.6973 - val_acc: 0.7785
#
# Epoch 00019: val_loss improved from 0.71549 to 0.69729, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4559 - acc: 0.9193 - val_loss: 0.7160 - val_acc: 0.7654
#
# Epoch 00020: val_loss did not improve from 0.69729
# Epoch 21/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4363 - acc: 0.9275 - val_loss: 0.6760 - val_acc: 0.7741
#
# Epoch 00021: val_loss improved from 0.69729 to 0.67597, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4262 - acc: 0.9305 - val_loss: 0.6843 - val_acc: 0.7762
#
# Epoch 00022: val_loss did not improve from 0.67597
# Epoch 23/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.4092 - acc: 0.9359 - val_loss: 0.6499 - val_acc: 0.7990
#
# Epoch 00023: val_loss improved from 0.67597 to 0.64992, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3950 - acc: 0.9398 - val_loss: 0.6475 - val_acc: 0.7925
#
# Epoch 00024: val_loss improved from 0.64992 to 0.64751, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.3808 - acc: 0.9459 - val_loss: 0.6561 - val_acc: 0.7870
#
# Epoch 00025: val_loss did not improve from 0.64751
# Epoch 26/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3665 - acc: 0.9509 - val_loss: 0.6269 - val_acc: 0.7939
#
# Epoch 00026: val_loss improved from 0.64751 to 0.62691, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3578 - acc: 0.9527 - val_loss: 0.6395 - val_acc: 0.7949
#
# Epoch 00027: val_loss did not improve from 0.62691
# Epoch 28/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3450 - acc: 0.9567 - val_loss: 0.6194 - val_acc: 0.8003
#
# Epoch 00028: val_loss improved from 0.62691 to 0.61942, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.3348 - acc: 0.9590 - val_loss: 0.6067 - val_acc: 0.8052
#
# Epoch 00029: val_loss improved from 0.61942 to 0.60666, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3218 - acc: 0.9630 - val_loss: 0.6124 - val_acc: 0.7896
#
# Epoch 00030: val_loss did not improve from 0.60666
# Epoch 31/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3126 - acc: 0.9657 - val_loss: 0.5967 - val_acc: 0.8050
#
# Epoch 00031: val_loss improved from 0.60666 to 0.59665, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.3038 - acc: 0.9671 - val_loss: 0.6099 - val_acc: 0.7925
#
# Epoch 00032: val_loss did not improve from 0.59665
# Epoch 33/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2957 - acc: 0.9684 - val_loss: 0.5924 - val_acc: 0.7961
#
# Epoch 00033: val_loss improved from 0.59665 to 0.59244, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2862 - acc: 0.9705 - val_loss: 0.5758 - val_acc: 0.8128
#
# Epoch 00034: val_loss improved from 0.59244 to 0.57584, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.2745 - acc: 0.9742 - val_loss: 0.5805 - val_acc: 0.8130
#
# Epoch 00035: val_loss did not improve from 0.57584
# Epoch 36/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2680 - acc: 0.9761 - val_loss: 0.5772 - val_acc: 0.8069
#
# Epoch 00036: val_loss did not improve from 0.57584
# Epoch 37/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2614 - acc: 0.9762 - val_loss: 0.5686 - val_acc: 0.8122
#
# Epoch 00037: val_loss improved from 0.57584 to 0.56858, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2506 - acc: 0.9779 - val_loss: 0.5744 - val_acc: 0.8169
#
# Epoch 00038: val_loss did not improve from 0.56858
# Epoch 39/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2449 - acc: 0.9789 - val_loss: 0.5677 - val_acc: 0.8163
#
# Epoch 00039: val_loss improved from 0.56858 to 0.56770, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2384 - acc: 0.9804 - val_loss: 0.5667 - val_acc: 0.8047
#
# Epoch 00040: val_loss improved from 0.56770 to 0.56665, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2290 - acc: 0.9818 - val_loss: 0.5560 - val_acc: 0.8131
#
# Epoch 00041: val_loss improved from 0.56665 to 0.55595, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2203 - acc: 0.9844 - val_loss: 0.5645 - val_acc: 0.8071
#
# Epoch 00042: val_loss did not improve from 0.55595
# Epoch 43/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.2177 - acc: 0.9839 - val_loss: 0.5604 - val_acc: 0.8141
#
# Epoch 00043: val_loss did not improve from 0.55595
# Epoch 44/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2115 - acc: 0.9848 - val_loss: 0.5490 - val_acc: 0.8131
#
# Epoch 00044: val_loss improved from 0.55595 to 0.54901, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.2087 - acc: 0.9840 - val_loss: 0.5472 - val_acc: 0.8224
#
# Epoch 00045: val_loss improved from 0.54901 to 0.54719, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 46/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.1995 - acc: 0.9869 - val_loss: 0.5703 - val_acc: 0.8069
#
# Epoch 00046: val_loss did not improve from 0.54719
# Epoch 47/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1949 - acc: 0.9862 - val_loss: 0.5524 - val_acc: 0.8103
#
# Epoch 00047: val_loss did not improve from 0.54719
# Epoch 48/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1898 - acc: 0.9879 - val_loss: 0.5392 - val_acc: 0.8251
#
# Epoch 00048: val_loss improved from 0.54719 to 0.53917, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1855 - acc: 0.9880 - val_loss: 0.5453 - val_acc: 0.8185
#
# Epoch 00049: val_loss did not improve from 0.53917
# Epoch 50/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1789 - acc: 0.9886 - val_loss: 0.5403 - val_acc: 0.8227
#
# Epoch 00050: val_loss did not improve from 0.53917
# Epoch 51/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1758 - acc: 0.9892 - val_loss: 0.5371 - val_acc: 0.8197
#
# Epoch 00051: val_loss improved from 0.53917 to 0.53707, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1710 - acc: 0.9896 - val_loss: 0.5311 - val_acc: 0.8275
#
# Epoch 00052: val_loss improved from 0.53707 to 0.53113, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 53/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1641 - acc: 0.9909 - val_loss: 0.5272 - val_acc: 0.8260
#
# Epoch 00053: val_loss improved from 0.53113 to 0.52722, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 54/400
# 1207/1207 [==============================] - 80s 67ms/step - loss: 0.1618 - acc: 0.9905 - val_loss: 0.5288 - val_acc: 0.8228
#
# Epoch 00054: val_loss did not improve from 0.52722
# Epoch 55/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1604 - acc: 0.9895 - val_loss: 0.5163 - val_acc: 0.8315
#
# Epoch 00055: val_loss improved from 0.52722 to 0.51632, saving model to drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1536 - acc: 0.9910 - val_loss: 0.5389 - val_acc: 0.8237
#
# Epoch 00056: val_loss did not improve from 0.51632
# Epoch 57/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1478 - acc: 0.9913 - val_loss: 0.5262 - val_acc: 0.8320
#
# Epoch 00057: val_loss did not improve from 0.51632
# Epoch 58/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1451 - acc: 0.9920 - val_loss: 0.5346 - val_acc: 0.8244
#
# Epoch 00058: val_loss did not improve from 0.51632
# Epoch 59/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1406 - acc: 0.9926 - val_loss: 0.5247 - val_acc: 0.8243
#
# Epoch 00059: val_loss did not improve from 0.51632
# Epoch 60/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1391 - acc: 0.9921 - val_loss: 0.5315 - val_acc: 0.8246
#
# Epoch 00060: val_loss did not improve from 0.51632
# Epoch 61/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1334 - acc: 0.9930 - val_loss: 0.5336 - val_acc: 0.8252
#
# Epoch 00061: val_loss did not improve from 0.51632
# Epoch 62/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1299 - acc: 0.9934 - val_loss: 0.5297 - val_acc: 0.8274
#
# Epoch 00062: val_loss did not improve from 0.51632
# Epoch 63/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1274 - acc: 0.9934 - val_loss: 0.5248 - val_acc: 0.8284
#
# Epoch 00063: val_loss did not improve from 0.51632
# Epoch 64/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1246 - acc: 0.9940 - val_loss: 0.5369 - val_acc: 0.8281
#
# Epoch 00064: val_loss did not improve from 0.51632
# Epoch 65/400
# 1207/1207 [==============================] - 80s 66ms/step - loss: 0.1211 - acc: 0.9938 - val_loss: 0.5250 - val_acc: 0.8260
#
# Epoch 00065: val_loss did not improve from 0.51632
# results per 1-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5250 - acc: 0.8260
# [[1748   46    0  104  214]
#  [  47 1497   88  185   74]
#  [  41   83 1919  142  152]
#  [  99   34   21 2259   52]
#  [ 265   52   34  160 1562]]
#               precision    recall  f1-score   support
#
#           HC       0.79      0.83      0.81      2112
#          a_H       0.87      0.79      0.83      1891
#          a_K       0.93      0.82      0.87      2337
#          a_A       0.79      0.92      0.85      2465
#          a_C       0.76      0.75      0.76      2073
#
#     accuracy                           0.83     10878
#    macro avg       0.83      0.82      0.82     10878
# weighted avg       0.83      0.83      0.83     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1181/1181 [==============================] - 82s 67ms/step - loss: 1.5694 - acc: 0.3503 - val_loss: 1.2394 - val_acc: 0.4908
#
# Epoch 00001: val_loss improved from inf to 1.23939, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 1.2410 - acc: 0.5010 - val_loss: 1.1022 - val_acc: 0.5932
#
# Epoch 00002: val_loss improved from 1.23939 to 1.10216, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 1.1061 - acc: 0.5765 - val_loss: 1.0404 - val_acc: 0.6214
#
# Epoch 00003: val_loss improved from 1.10216 to 1.04036, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 1.0159 - acc: 0.6295 - val_loss: 0.9791 - val_acc: 0.6630
#
# Epoch 00004: val_loss improved from 1.04036 to 0.97909, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.9457 - acc: 0.6721 - val_loss: 0.9317 - val_acc: 0.6698
#
# Epoch 00005: val_loss improved from 0.97909 to 0.93174, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.8971 - acc: 0.7008 - val_loss: 0.8874 - val_acc: 0.6885
#
# Epoch 00006: val_loss improved from 0.93174 to 0.88745, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.8371 - acc: 0.7355 - val_loss: 0.8664 - val_acc: 0.7119
#
# Epoch 00007: val_loss improved from 0.88745 to 0.86636, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.7961 - acc: 0.7568 - val_loss: 0.8205 - val_acc: 0.7177
#
# Epoch 00008: val_loss improved from 0.86636 to 0.82047, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.7657 - acc: 0.7728 - val_loss: 0.8052 - val_acc: 0.7318
#
# Epoch 00009: val_loss improved from 0.82047 to 0.80521, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.7301 - acc: 0.7929 - val_loss: 0.7798 - val_acc: 0.7496
#
# Epoch 00010: val_loss improved from 0.80521 to 0.77975, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1181/1181 [==============================] - 78s 66ms/step - loss: 0.6977 - acc: 0.8089 - val_loss: 0.7608 - val_acc: 0.7568
#
# Epoch 00011: val_loss improved from 0.77975 to 0.76077, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
#  807/1181 [===================>..........] - ETA: 24s - loss: 0.6688 - acc: 0.8222

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 69 == 0) and (epoch != 0) and (epoch % 149 == 0): #  間違いでも影響なし
      lr = lr * 0.1
  return lr

i = 2
# print("HC", np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
# print("H", np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
# print("K", np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
# print("A", np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
# print("C", np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

# checkpointの設定
checkpoint = ModelCheckpoint(
                  filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    # loss = custom_cross_entropy,
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc'],
    # class_weight=class_weight
          )

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=used_train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

# i = i + 1



# plt.plot(result.history['acc'])
# plt.plot(result.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# plt.plot(result.history['loss'])
# plt.plot(result.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# now = datetime.datetime.now()
# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# Epoch 1/400
# 1181/1181 [==============================] - 225s 163ms/step - loss: 0.6325 - acc: 0.8438 - val_loss: 0.7042 - val_acc: 0.7717
#
# Epoch 00001: val_loss improved from inf to 0.70421, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.6096 - acc: 0.8517 - val_loss: 0.7074 - val_acc: 0.7773
#
# Epoch 00002: val_loss did not improve from 0.70421
# Epoch 3/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.5858 - acc: 0.8638 - val_loss: 0.6781 - val_acc: 0.7833
#
# Epoch 00003: val_loss improved from 0.70421 to 0.67806, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.5677 - acc: 0.8716 - val_loss: 0.6561 - val_acc: 0.7969
#
# Epoch 00004: val_loss improved from 0.67806 to 0.65611, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.5402 - acc: 0.8872 - val_loss: 0.6556 - val_acc: 0.7912
#
# Epoch 00005: val_loss improved from 0.65611 to 0.65559, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.5298 - acc: 0.8885 - val_loss: 0.6344 - val_acc: 0.7955
#
# Epoch 00006: val_loss improved from 0.65559 to 0.63438, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.5024 - acc: 0.9012 - val_loss: 0.6388 - val_acc: 0.7918
#
# Epoch 00007: val_loss did not improve from 0.63438
# Epoch 8/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.4829 - acc: 0.9077 - val_loss: 0.6071 - val_acc: 0.8108
#
# Epoch 00008: val_loss improved from 0.63438 to 0.60706, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.4707 - acc: 0.9124 - val_loss: 0.6182 - val_acc: 0.8108
#
# Epoch 00009: val_loss did not improve from 0.60706
# Epoch 10/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.4577 - acc: 0.9171 - val_loss: 0.6016 - val_acc: 0.8092
#
# Epoch 00010: val_loss improved from 0.60706 to 0.60160, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.4487 - acc: 0.9202 - val_loss: 0.6033 - val_acc: 0.8124
#
# Epoch 00011: val_loss did not improve from 0.60160
# Epoch 12/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.4287 - acc: 0.9267 - val_loss: 0.5939 - val_acc: 0.8108
#
# Epoch 00012: val_loss improved from 0.60160 to 0.59390, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.4110 - acc: 0.9356 - val_loss: 0.5671 - val_acc: 0.8283
#
# Epoch 00013: val_loss improved from 0.59390 to 0.56715, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.4032 - acc: 0.9359 - val_loss: 0.5731 - val_acc: 0.8248
#
# Epoch 00014: val_loss did not improve from 0.56715
# Epoch 15/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3904 - acc: 0.9401 - val_loss: 0.5625 - val_acc: 0.8187
#
# Epoch 00015: val_loss improved from 0.56715 to 0.56246, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3808 - acc: 0.9435 - val_loss: 0.5514 - val_acc: 0.8356
#
# Epoch 00016: val_loss improved from 0.56246 to 0.55142, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3685 - acc: 0.9469 - val_loss: 0.5464 - val_acc: 0.8332
#
# Epoch 00017: val_loss improved from 0.55142 to 0.54636, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3577 - acc: 0.9509 - val_loss: 0.5633 - val_acc: 0.8206
#
# Epoch 00018: val_loss did not improve from 0.54636
# Epoch 19/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.3477 - acc: 0.9525 - val_loss: 0.5383 - val_acc: 0.8351
#
# Epoch 00019: val_loss improved from 0.54636 to 0.53831, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.3384 - acc: 0.9545 - val_loss: 0.5429 - val_acc: 0.8310
#
# Epoch 00020: val_loss did not improve from 0.53831
# Epoch 21/400
# 1181/1181 [==============================] - 191s 161ms/step - loss: 0.3225 - acc: 0.9608 - val_loss: 0.5471 - val_acc: 0.8274
#
# Epoch 00021: val_loss did not improve from 0.53831
# Epoch 22/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3147 - acc: 0.9630 - val_loss: 0.5391 - val_acc: 0.8365
#
# Epoch 00022: val_loss did not improve from 0.53831
# Epoch 23/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.3101 - acc: 0.9616 - val_loss: 0.5361 - val_acc: 0.8308
#
# Epoch 00023: val_loss improved from 0.53831 to 0.53614, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.3002 - acc: 0.9654 - val_loss: 0.5244 - val_acc: 0.8353
#
# Epoch 00024: val_loss improved from 0.53614 to 0.52441, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.2953 - acc: 0.9658 - val_loss: 0.5212 - val_acc: 0.8388
#
# Epoch 00025: val_loss improved from 0.52441 to 0.52116, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1181/1181 [==============================] - 192s 162ms/step - loss: 0.2800 - acc: 0.9700 - val_loss: 0.5119 - val_acc: 0.8380
#
# Epoch 00026: val_loss improved from 0.52116 to 0.51188, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1181/1181 [==============================] - 191s 162ms/step - loss: 0.2747 - acc: 0.9710 - val_loss: 0.5023 - val_acc: 0.8452
#
# Epoch 00027: val_loss improved from 0.51188 to 0.50233, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.2664 - acc: 0.9731 - val_loss: 0.5086 - val_acc: 0.8376
#
# Epoch 00028: val_loss did not improve from 0.50233
# Epoch 29/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.2638 - acc: 0.9728 - val_loss: 0.5005 - val_acc: 0.8427
#
# Epoch 00029: val_loss improved from 0.50233 to 0.50049, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1181/1181 [==============================] - 193s 163ms/step - loss: 0.2550 - acc: 0.9745 - val_loss: 0.4971 - val_acc: 0.8433
#
# Epoch 00030: val_loss improved from 0.50049 to 0.49707, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1181/1181 [==============================] - 193s 163ms/step - loss: 0.2503 - acc: 0.9748 - val_loss: 0.4874 - val_acc: 0.8447
#
# Epoch 00031: val_loss improved from 0.49707 to 0.48737, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1181/1181 [==============================] - 193s 163ms/step - loss: 0.2365 - acc: 0.9792 - val_loss: 0.5002 - val_acc: 0.8402
#
# Epoch 00032: val_loss did not improve from 0.48737
# Epoch 33/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.2296 - acc: 0.9818 - val_loss: 0.5061 - val_acc: 0.8404
#
# Epoch 00033: val_loss did not improve from 0.48737
# Epoch 34/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.2277 - acc: 0.9789 - val_loss: 0.5107 - val_acc: 0.8408
#
# Epoch 00034: val_loss did not improve from 0.48737
# Epoch 35/400
# 1181/1181 [==============================] - 192s 163ms/step - loss: 0.2213 - acc: 0.9810 - val_loss: 0.4965 - val_acc: 0.8400
#
# Epoch 00035: val_loss did not improve from 0.48737
# Epoch 36/400
# 1181/1181 [==============================] - 193s 164ms/step - loss: 0.2181 - acc: 0.9808 - val_loss: 0.4966 - val_acc: 0.8487
#
# Epoch 00036: val_loss did not improve from 0.48737
# Epoch 37/400
# 1181/1181 [==============================] - 193s 164ms/step - loss: 0.2105 - acc: 0.9814 - val_loss: 0.4874 - val_acc: 0.8478
#
# Epoch 00037: val_loss did not improve from 0.48737
# Epoch 38/400
# 1181/1181 [==============================] - 193s 163ms/step - loss: 0.2066 - acc: 0.9819 - val_loss: 0.4807 - val_acc: 0.8479
#
# Epoch 00038: val_loss improved from 0.48737 to 0.48069, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1181/1181 [==============================] - 194s 164ms/step - loss: 0.1977 - acc: 0.9855 - val_loss: 0.4893 - val_acc: 0.8488
#
# Epoch 00039: val_loss did not improve from 0.48069
# Epoch 40/400
# 1181/1181 [==============================] - 193s 164ms/step - loss: 0.1977 - acc: 0.9848 - val_loss: 0.4784 - val_acc: 0.8483
#
# Epoch 00040: val_loss improved from 0.48069 to 0.47840, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1181/1181 [==============================] - 193s 164ms/step - loss: 0.1899 - acc: 0.9864 - val_loss: 0.5028 - val_acc: 0.8363
#
# Epoch 00041: val_loss did not improve from 0.47840
# Epoch 42/400
# 1181/1181 [==============================] - 193s 164ms/step - loss: 0.1830 - acc: 0.9870 - val_loss: 0.4941 - val_acc: 0.8375
#
# Epoch 00042: val_loss did not improve from 0.47840
# Epoch 43/400
#  993/1181 [========================>.....] - ETA: 29s - loss: 0.1824 - acc: 0.9865

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 23 == 0) and (epoch != 0):
      lr = lr * 0.1
  return lr

i = 2
# print("HC", np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
# print("H", np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
# print("K", np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
# print("A", np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
# print("C", np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

# checkpointの設定
checkpoint = ModelCheckpoint(
                  filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    # loss = custom_cross_entropy,
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc'],
    # class_weight=class_weight
          )

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=used_train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

# i = i + 1



# plt.plot(result.history['acc'])
# plt.plot(result.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# plt.plot(result.history['loss'])
# plt.plot(result.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# now = datetime.datetime.now()
# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# Epoch 1/400
# 1181/1181 [==============================] - 84s 68ms/step - loss: 0.1512 - acc: 0.9900 - val_loss: 0.4749 - val_acc: 0.8499
#
# Epoch 00001: val_loss improved from inf to 0.47494, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1181/1181 [==============================] - 80s 67ms/step - loss: 0.1470 - acc: 0.9905 - val_loss: 0.4649 - val_acc: 0.8477
#
# Epoch 00002: val_loss improved from 0.47494 to 0.46494, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1181/1181 [==============================] - 80s 68ms/step - loss: 0.1467 - acc: 0.9905 - val_loss: 0.4490 - val_acc: 0.8543
#
# Epoch 00003: val_loss improved from 0.46494 to 0.44895, saving model to drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1181/1181 [==============================] - 80s 67ms/step - loss: 0.1407 - acc: 0.9906 - val_loss: 0.4608 - val_acc: 0.8501
#
# Epoch 00004: val_loss did not improve from 0.44895
# Epoch 5/400
# 1181/1181 [==============================] - 80s 67ms/step - loss: 0.1365 - acc: 0.9910 - val_loss: 0.4602 - val_acc: 0.8519
#
# Epoch 00005: val_loss did not improve from 0.44895
# Epoch 6/400
# 1181/1181 [==============================] - 80s 67ms/step - loss: 0.1342 - acc: 0.9919 - val_loss: 0.4591 - val_acc: 0.8505
#
# Epoch 00006: val_loss did not improve from 0.44895
# Epoch 7/400
# 1181/1181 [==============================] - 80s 67ms/step - loss: 0.1369 - acc: 0.9911 - val_loss: 0.4575 - val_acc: 0.8527
#
# Epoch 00007: val_loss did not improve from 0.44895
# Epoch 8/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1281 - acc: 0.9924 - val_loss: 0.4652 - val_acc: 0.8561
#
# Epoch 00008: val_loss did not improve from 0.44895
# Epoch 9/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1270 - acc: 0.9916 - val_loss: 0.4747 - val_acc: 0.8457
#
# Epoch 00009: val_loss did not improve from 0.44895
# Epoch 10/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1235 - acc: 0.9925 - val_loss: 0.4664 - val_acc: 0.8589
#
# Epoch 00010: val_loss did not improve from 0.44895
# Epoch 11/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1204 - acc: 0.9932 - val_loss: 0.4624 - val_acc: 0.8478
#
# Epoch 00011: val_loss did not improve from 0.44895
# Epoch 12/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1164 - acc: 0.9934 - val_loss: 0.4608 - val_acc: 0.8457
#
# Epoch 00012: val_loss did not improve from 0.44895
# Epoch 13/400
# 1181/1181 [==============================] - 79s 67ms/step - loss: 0.1155 - acc: 0.9934 - val_loss: 0.4668 - val_acc: 0.8487
#
# Epoch 00013: val_loss did not improve from 0.44895
# results per 2-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4668 - acc: 0.8487
# [[1843   67   31   68   11]
#  [  61 1478  224   89   20]
#  [  10   99 1948   69   13]
#  [  97  208   86 2306  208]
#  [  30   84   90   81 1657]]
#               precision    recall  f1-score   support
#
#           HC       0.90      0.91      0.91      2020
#          a_H       0.76      0.79      0.78      1872
#          a_K       0.82      0.91      0.86      2139
#          a_A       0.88      0.79      0.84      2905
#          a_C       0.87      0.85      0.86      1942
#
#     accuracy                           0.85     10878
#    macro avg       0.85      0.85      0.85     10878
# weighted avg       0.85      0.85      0.85     10878

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 80 == 0) and (epoch != 0):
      lr = lr * 0.1
  return lr

for i in range(3, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  

  print("HC for train", np.where(np.argmax(train_label, axis=1)==0)[0].shape)
  print("H for train", np.where(np.argmax(train_label, axis=1)==1)[0].shape)
  print("K for train", np.where(np.argmax(train_label, axis=1)==2)[0].shape)
  print("A for train", np.where(np.argmax(train_label, axis=1)==3)[0].shape)
  print("C for train", np.where(np.argmax(train_label, axis=1)==4)[0].shape)

  print("HC for val", np.where(np.argmax(val_label, axis=1)==0)[0].shape)
  print("H for val", np.where(np.argmax(val_label, axis=1)==1)[0].shape)
  print("K for val", np.where(np.argmax(val_label, axis=1)==2)[0].shape)
  print("A for val", np.where(np.argmax(val_label, axis=1)==3)[0].shape)
  print("C for val", np.where(np.argmax(val_label, axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=used_train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# now = datetime.datetime.now()
# with open("/content/drive/MyDrive/saved_models/test/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/test/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1220/1220 [==============================] - 86s 68ms/step - loss: 1.5410 - acc: 0.3620 - val_loss: 1.2057 - val_acc: 0.5132
#
# Epoch 00001: val_loss improved from inf to 1.20567, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 1.2061 - acc: 0.5143 - val_loss: 1.1009 - val_acc: 0.5773
#
# Epoch 00002: val_loss improved from 1.20567 to 1.10092, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 1.0759 - acc: 0.5913 - val_loss: 1.0280 - val_acc: 0.6218
#
# Epoch 00003: val_loss improved from 1.10092 to 1.02804, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.9846 - acc: 0.6474 - val_loss: 0.9669 - val_acc: 0.6452
#
# Epoch 00004: val_loss improved from 1.02804 to 0.96687, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.9121 - acc: 0.6918 - val_loss: 0.9273 - val_acc: 0.6643
#
# Epoch 00005: val_loss improved from 0.96687 to 0.92727, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.8548 - acc: 0.7258 - val_loss: 0.8937 - val_acc: 0.6834
#
# Epoch 00006: val_loss improved from 0.92727 to 0.89367, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.8004 - acc: 0.7553 - val_loss: 0.8701 - val_acc: 0.7008
#
# Epoch 00007: val_loss improved from 0.89367 to 0.87014, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.7584 - acc: 0.7777 - val_loss: 0.8454 - val_acc: 0.7154
#
# Epoch 00008: val_loss improved from 0.87014 to 0.84537, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.7181 - acc: 0.8005 - val_loss: 0.8182 - val_acc: 0.7291
#
# Epoch 00009: val_loss improved from 0.84537 to 0.81815, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.6831 - acc: 0.8186 - val_loss: 0.7989 - val_acc: 0.7430
#
# Epoch 00010: val_loss improved from 0.81815 to 0.79895, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.6485 - acc: 0.8373 - val_loss: 0.7772 - val_acc: 0.7524
#
# Epoch 00011: val_loss improved from 0.79895 to 0.77716, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.6209 - acc: 0.8509 - val_loss: 0.7633 - val_acc: 0.7505
#
# Epoch 00012: val_loss improved from 0.77716 to 0.76335, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.5956 - acc: 0.8599 - val_loss: 0.7337 - val_acc: 0.7735
#
# Epoch 00013: val_loss improved from 0.76335 to 0.73369, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.5717 - acc: 0.8728 - val_loss: 0.7208 - val_acc: 0.7698
#
# Epoch 00014: val_loss improved from 0.73369 to 0.72077, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.5447 - acc: 0.8851 - val_loss: 0.7090 - val_acc: 0.7846
#
# Epoch 00015: val_loss improved from 0.72077 to 0.70898, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.5246 - acc: 0.8953 - val_loss: 0.6957 - val_acc: 0.7778
#
# Epoch 00016: val_loss improved from 0.70898 to 0.69571, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.5023 - acc: 0.9033 - val_loss: 0.6819 - val_acc: 0.7925
#
# Epoch 00017: val_loss improved from 0.69571 to 0.68194, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.4880 - acc: 0.9088 - val_loss: 0.6781 - val_acc: 0.7875
#
# Epoch 00018: val_loss improved from 0.68194 to 0.67814, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.4676 - acc: 0.9162 - val_loss: 0.6657 - val_acc: 0.8030
#
# Epoch 00019: val_loss improved from 0.67814 to 0.66573, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.4501 - acc: 0.9252 - val_loss: 0.6453 - val_acc: 0.8103
#
# Epoch 00020: val_loss improved from 0.66573 to 0.64534, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.4336 - acc: 0.9294 - val_loss: 0.6551 - val_acc: 0.7990
#
# Epoch 00021: val_loss did not improve from 0.64534
# Epoch 22/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.4188 - acc: 0.9356 - val_loss: 0.6278 - val_acc: 0.8179
#
# Epoch 00022: val_loss improved from 0.64534 to 0.62777, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.4039 - acc: 0.9405 - val_loss: 0.6382 - val_acc: 0.8086
#
# Epoch 00023: val_loss did not improve from 0.62777
# Epoch 24/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.3935 - acc: 0.9425 - val_loss: 0.6187 - val_acc: 0.8181
#
# Epoch 00024: val_loss improved from 0.62777 to 0.61869, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1220/1220 [==============================] - 82s 67ms/step - loss: 0.3765 - acc: 0.9494 - val_loss: 0.6011 - val_acc: 0.8212
#
# Epoch 00025: val_loss improved from 0.61869 to 0.60108, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3632 - acc: 0.9537 - val_loss: 0.5978 - val_acc: 0.8171
#
# Epoch 00026: val_loss improved from 0.60108 to 0.59776, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 27/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3540 - acc: 0.9563 - val_loss: 0.5933 - val_acc: 0.8195
#
# Epoch 00027: val_loss improved from 0.59776 to 0.59330, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.3401 - acc: 0.9598 - val_loss: 0.5925 - val_acc: 0.8239
#
# Epoch 00028: val_loss improved from 0.59330 to 0.59247, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3307 - acc: 0.9614 - val_loss: 0.5764 - val_acc: 0.8309
#
# Epoch 00029: val_loss improved from 0.59247 to 0.57643, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3236 - acc: 0.9629 - val_loss: 0.5728 - val_acc: 0.8265
#
# Epoch 00030: val_loss improved from 0.57643 to 0.57278, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3124 - acc: 0.9657 - val_loss: 0.5715 - val_acc: 0.8296
#
# Epoch 00031: val_loss improved from 0.57278 to 0.57150, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.3023 - acc: 0.9679 - val_loss: 0.5816 - val_acc: 0.8217
#
# Epoch 00032: val_loss did not improve from 0.57150
# Epoch 33/400
# 1220/1220 [==============================] - 82s 68ms/step - loss: 0.2897 - acc: 0.9720 - val_loss: 0.5609 - val_acc: 0.8361
#
# Epoch 00033: val_loss improved from 0.57150 to 0.56091, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 34/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2810 - acc: 0.9747 - val_loss: 0.5577 - val_acc: 0.8299
#
# Epoch 00034: val_loss improved from 0.56091 to 0.55766, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2745 - acc: 0.9749 - val_loss: 0.5494 - val_acc: 0.8293
#
# Epoch 00035: val_loss improved from 0.55766 to 0.54936, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2700 - acc: 0.9750 - val_loss: 0.5411 - val_acc: 0.8295
#
# Epoch 00036: val_loss improved from 0.54936 to 0.54105, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2610 - acc: 0.9761 - val_loss: 0.5386 - val_acc: 0.8391
#
# Epoch 00037: val_loss improved from 0.54105 to 0.53857, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 38/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2534 - acc: 0.9786 - val_loss: 0.5373 - val_acc: 0.8338
#
# Epoch 00038: val_loss improved from 0.53857 to 0.53728, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2438 - acc: 0.9798 - val_loss: 0.5309 - val_acc: 0.8312
#
# Epoch 00039: val_loss improved from 0.53728 to 0.53094, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2390 - acc: 0.9817 - val_loss: 0.5390 - val_acc: 0.8311
#
# Epoch 00040: val_loss did not improve from 0.53094
# Epoch 41/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2346 - acc: 0.9814 - val_loss: 0.5170 - val_acc: 0.8298
#
# Epoch 00041: val_loss improved from 0.53094 to 0.51704, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1220/1220 [==============================] - 83s 68ms/step - loss: 0.2245 - acc: 0.9830 - val_loss: 0.5175 - val_acc: 0.8363
#
# Epoch 00042: val_loss did not improve from 0.51704
# Epoch 43/400
# 1199/1220 [============================>.] - ETA: 1s - loss: 0.2189 - acc: 0.9839

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 38 == 0) and (epoch != 0):
      lr = lr * 0.1
  return lr

i = 3
# print("HC", np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
# print("H", np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
# print("K", np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
# print("A", np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
# print("C", np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

# checkpointの設定
checkpoint = ModelCheckpoint(
                  filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    # loss = custom_cross_entropy,
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc'],
    # class_weight=class_weight
          )

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=used_train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

# i = i + 1



# plt.plot(result.history['acc'])
# plt.plot(result.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# plt.plot(result.history['loss'])
# plt.plot(result.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# now = datetime.datetime.now()
# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# Epoch 1/400
# 1220/1220 [==============================] - 115s 66ms/step - loss: 0.2142 - acc: 0.9840 - val_loss: 0.5167 - val_acc: 0.8332
#
# Epoch 00001: val_loss improved from inf to 0.51665, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.2062 - acc: 0.9862 - val_loss: 0.5246 - val_acc: 0.8354
#
# Epoch 00002: val_loss did not improve from 0.51665
# Epoch 3/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.2023 - acc: 0.9860 - val_loss: 0.5109 - val_acc: 0.8360
#
# Epoch 00003: val_loss improved from 0.51665 to 0.51091, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1921 - acc: 0.9887 - val_loss: 0.5217 - val_acc: 0.8341
#
# Epoch 00004: val_loss did not improve from 0.51091
# Epoch 5/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1882 - acc: 0.9883 - val_loss: 0.5119 - val_acc: 0.8359
#
# Epoch 00005: val_loss did not improve from 0.51091
# Epoch 6/400
# 1220/1220 [==============================] - 80s 65ms/step - loss: 0.1828 - acc: 0.9897 - val_loss: 0.5001 - val_acc: 0.8367
#
# Epoch 00006: val_loss improved from 0.51091 to 0.50013, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1798 - acc: 0.9887 - val_loss: 0.4968 - val_acc: 0.8414
#
# Epoch 00007: val_loss improved from 0.50013 to 0.49681, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1747 - acc: 0.9900 - val_loss: 0.4916 - val_acc: 0.8441
#
# Epoch 00008: val_loss improved from 0.49681 to 0.49159, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1708 - acc: 0.9897 - val_loss: 0.4966 - val_acc: 0.8375
#
# Epoch 00009: val_loss did not improve from 0.49159
# Epoch 10/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1643 - acc: 0.9913 - val_loss: 0.4971 - val_acc: 0.8368
#
# Epoch 00010: val_loss did not improve from 0.49159
# Epoch 11/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1609 - acc: 0.9914 - val_loss: 0.5008 - val_acc: 0.8349
#
# Epoch 00011: val_loss did not improve from 0.49159
# Epoch 12/400
# 1220/1220 [==============================] - 81s 67ms/step - loss: 0.1569 - acc: 0.9915 - val_loss: 0.4936 - val_acc: 0.8366
#
# Epoch 00012: val_loss did not improve from 0.49159
# Epoch 13/400
# 1220/1220 [==============================] - 81s 67ms/step - loss: 0.1522 - acc: 0.9921 - val_loss: 0.4932 - val_acc: 0.8386
#
# Epoch 00013: val_loss did not improve from 0.49159
# Epoch 14/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1499 - acc: 0.9916 - val_loss: 0.4969 - val_acc: 0.8381
#
# Epoch 00014: val_loss did not improve from 0.49159
# Epoch 15/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1461 - acc: 0.9918 - val_loss: 0.4962 - val_acc: 0.8418
#
# Epoch 00015: val_loss did not improve from 0.49159
# Epoch 16/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1417 - acc: 0.9930 - val_loss: 0.4786 - val_acc: 0.8486
#
# Epoch 00016: val_loss improved from 0.49159 to 0.47857, saving model to drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1369 - acc: 0.9937 - val_loss: 0.4924 - val_acc: 0.8411
#
# Epoch 00017: val_loss did not improve from 0.47857
# Epoch 18/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1337 - acc: 0.9936 - val_loss: 0.5060 - val_acc: 0.8318
#
# Epoch 00018: val_loss did not improve from 0.47857
# Epoch 19/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1318 - acc: 0.9927 - val_loss: 0.4890 - val_acc: 0.8492
#
# Epoch 00019: val_loss did not improve from 0.47857
# Epoch 20/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1268 - acc: 0.9943 - val_loss: 0.4851 - val_acc: 0.8451
#
# Epoch 00020: val_loss did not improve from 0.47857
# Epoch 21/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1239 - acc: 0.9945 - val_loss: 0.4811 - val_acc: 0.8451
#
# Epoch 00021: val_loss did not improve from 0.47857
# Epoch 22/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1223 - acc: 0.9939 - val_loss: 0.4837 - val_acc: 0.8434
#
# Epoch 00022: val_loss did not improve from 0.47857
# Epoch 23/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1170 - acc: 0.9944 - val_loss: 0.4873 - val_acc: 0.8401
#
# Epoch 00023: val_loss did not improve from 0.47857
# Epoch 24/400
# 1220/1220 [==============================] - 81s 66ms/step - loss: 0.1153 - acc: 0.9951 - val_loss: 0.4871 - val_acc: 0.8444
#
# Epoch 00024: val_loss did not improve from 0.47857
# Epoch 25/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1116 - acc: 0.9955 - val_loss: 0.4793 - val_acc: 0.8449
#
# Epoch 00025: val_loss did not improve from 0.47857
# Epoch 26/400
# 1220/1220 [==============================] - 80s 66ms/step - loss: 0.1086 - acc: 0.9955 - val_loss: 0.4814 - val_acc: 0.8460
#
# Epoch 00026: val_loss did not improve from 0.47857
# results per 3-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4814 - acc: 0.8460
# [[1167   20   21  108   44]
#  [  20 1353   81  121   87]
#  [  19  109 2953  124   20]
#  [  48   64  189 1958  186]
#  [  31   78   90  215 1772]]
#               precision    recall  f1-score   support
#
#           HC       0.91      0.86      0.88      1360
#          a_H       0.83      0.81      0.82      1662
#          a_K       0.89      0.92      0.90      3225
#          a_A       0.78      0.80      0.79      2445
#          a_C       0.84      0.81      0.83      2186
#
#     accuracy                           0.85     10878
#    macro avg       0.85      0.84      0.84     10878
# weighted avg       0.85      0.85      0.85     10878

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 80 == 0) and (epoch != 0):
      lr = lr * 0.1
  return lr

for i in range(4, 7):
  # checkpointの設定
  checkpoint = ModelCheckpoint(
                      filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                      monitor='val_loss',
                      save_best_only=True,
                      period=1,
                      verbose=1
                  )
  model = build_model()
  model.compile(
      loss='categorical_crossentropy',
      optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
      metrics=['acc']
            )
  

  print("HC for train", np.where(np.argmax(train_label, axis=1)==0)[0].shape)
  print("H for train", np.where(np.argmax(train_label, axis=1)==1)[0].shape)
  print("K for train", np.where(np.argmax(train_label, axis=1)==2)[0].shape)
  print("A for train", np.where(np.argmax(train_label, axis=1)==3)[0].shape)
  print("C for train", np.where(np.argmax(train_label, axis=1)==4)[0].shape)

  print("HC for val", np.where(np.argmax(val_label, axis=1)==0)[0].shape)
  print("H for val", np.where(np.argmax(val_label, axis=1)==1)[0].shape)
  print("K for val", np.where(np.argmax(val_label, axis=1)==2)[0].shape)
  print("A for val", np.where(np.argmax(val_label, axis=1)==3)[0].shape)
  print("C for val", np.where(np.argmax(val_label, axis=1)==4)[0].shape)

  result = model.fit(
      x=train_LSTM_data_list[i], 
      y=used_train_label_list[i], 
      batch_size=63, 
      epochs=400, 
      verbose=1,
      validation_data=(
          val_LSTM_data_list[i], 
          val_label_list[i]
            ),
      callbacks=[early_stopping, checkpoint, lr_scheduler]
      )
  
  print("results per {}-fold".format(i))
  history.append(model.evaluate(
      x=val_LSTM_data_list[i], 
      y=val_label_list[i], 
      verbose=1))
  # save weights
  # file_name = "{}fold_{}".format(i, NAME)
  # model.save(file_name+'.h5')

    # 混合行列
  predict_prob = model.predict(val_LSTM_data_list[i])
  predict_classes=np.argmax(predict_prob,axis=1)
  true_classes = val_label_list[i]
  true_classes=np.argmax(true_classes, axis=1)
  cmx = confusion_matrix(true_classes, predict_classes)
  cmx_list.append(cmx)
  print(cmx)

  index = ["HC", "a_H", "a_K", "a_A", "a_C"]

  report = classification_report(true_classes, predict_classes, target_names=index)
  report_list.append(report)
  print(report)

  cmx_data = []
  for i in range(len(cmx)):
    for j in range(len(cmx)): 
      cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

  cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

  ax= plt.subplot()
  sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix') 
  ax.xaxis.set_ticklabels(index) 
  ax.yaxis.set_ticklabels(index)
  plt.show()

  i = i + 1



plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# now = datetime.datetime.now()
# with open("/content/drive/MyDrive/saved_models/test/cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("/content/drive/MyDrive/saved_models/test/classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()

# now = datetime.datetime.now()

# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_1 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 101, 1024)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1185/1185 [==============================] - 83s 67ms/step - loss: 1.5842 - acc: 0.3449 - val_loss: 1.2197 - val_acc: 0.5078
#
# Epoch 00001: val_loss improved from inf to 1.21970, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 1.2247 - acc: 0.5102 - val_loss: 1.1070 - val_acc: 0.5764
#
# Epoch 00002: val_loss improved from 1.21970 to 1.10701, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 1.0865 - acc: 0.5875 - val_loss: 1.0338 - val_acc: 0.6253
#
# Epoch 00003: val_loss improved from 1.10701 to 1.03383, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.9931 - acc: 0.6409 - val_loss: 0.9959 - val_acc: 0.6426
#
# Epoch 00004: val_loss improved from 1.03383 to 0.99595, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.9288 - acc: 0.6789 - val_loss: 0.9445 - val_acc: 0.6711
#
# Epoch 00005: val_loss improved from 0.99595 to 0.94448, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.8687 - acc: 0.7139 - val_loss: 0.9116 - val_acc: 0.6777
#
# Epoch 00006: val_loss improved from 0.94448 to 0.91162, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.8200 - acc: 0.7401 - val_loss: 0.8689 - val_acc: 0.7082
#
# Epoch 00007: val_loss improved from 0.91162 to 0.86894, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.7756 - acc: 0.7663 - val_loss: 0.8542 - val_acc: 0.7122
#
# Epoch 00008: val_loss improved from 0.86894 to 0.85415, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.7355 - acc: 0.7884 - val_loss: 0.8212 - val_acc: 0.7314
#
# Epoch 00009: val_loss improved from 0.85415 to 0.82117, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.7008 - acc: 0.8061 - val_loss: 0.7881 - val_acc: 0.7364
#
# Epoch 00010: val_loss improved from 0.82117 to 0.78814, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.6694 - acc: 0.8217 - val_loss: 0.7696 - val_acc: 0.7510
#
# Epoch 00011: val_loss improved from 0.78814 to 0.76965, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.6371 - acc: 0.8403 - val_loss: 0.7653 - val_acc: 0.7505
#
# Epoch 00012: val_loss improved from 0.76965 to 0.76527, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.6170 - acc: 0.8506 - val_loss: 0.7414 - val_acc: 0.7716
#
# Epoch 00013: val_loss improved from 0.76527 to 0.74137, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.5863 - acc: 0.8653 - val_loss: 0.7209 - val_acc: 0.7670
#
# Epoch 00014: val_loss improved from 0.74137 to 0.72093, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.5584 - acc: 0.8808 - val_loss: 0.6823 - val_acc: 0.7796
#
# Epoch 00015: val_loss improved from 0.72093 to 0.68233, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.5404 - acc: 0.8832 - val_loss: 0.6762 - val_acc: 0.7864
#
# Epoch 00016: val_loss improved from 0.68233 to 0.67617, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.5173 - acc: 0.8976 - val_loss: 0.6665 - val_acc: 0.7916
#
# Epoch 00017: val_loss improved from 0.67617 to 0.66653, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4968 - acc: 0.9048 - val_loss: 0.6569 - val_acc: 0.7936
#
# Epoch 00018: val_loss improved from 0.66653 to 0.65694, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4807 - acc: 0.9116 - val_loss: 0.6514 - val_acc: 0.7968
#
# Epoch 00019: val_loss improved from 0.65694 to 0.65144, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4628 - acc: 0.9190 - val_loss: 0.6294 - val_acc: 0.8043
#
# Epoch 00020: val_loss improved from 0.65144 to 0.62937, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4481 - acc: 0.9236 - val_loss: 0.6173 - val_acc: 0.8130
#
# Epoch 00021: val_loss improved from 0.62937 to 0.61727, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4335 - acc: 0.9279 - val_loss: 0.5979 - val_acc: 0.8114
#
# Epoch 00022: val_loss improved from 0.61727 to 0.59785, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4151 - acc: 0.9358 - val_loss: 0.5957 - val_acc: 0.8126
#
# Epoch 00023: val_loss improved from 0.59785 to 0.59572, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.4016 - acc: 0.9398 - val_loss: 0.5747 - val_acc: 0.8269
#
# Epoch 00024: val_loss improved from 0.59572 to 0.57472, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.3914 - acc: 0.9430 - val_loss: 0.5814 - val_acc: 0.8251
#
# Epoch 00025: val_loss did not improve from 0.57472
# Epoch 26/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.3783 - acc: 0.9480 - val_loss: 0.5756 - val_acc: 0.8271
#
# Epoch 00026: val_loss did not improve from 0.57472
# Epoch 27/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.3652 - acc: 0.9501 - val_loss: 0.5670 - val_acc: 0.8240
#
# Epoch 00027: val_loss improved from 0.57472 to 0.56700, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 28/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.3511 - acc: 0.9552 - val_loss: 0.5390 - val_acc: 0.8374
#
# Epoch 00028: val_loss improved from 0.56700 to 0.53901, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 29/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.3423 - acc: 0.9574 - val_loss: 0.5307 - val_acc: 0.8427
#
# Epoch 00029: val_loss improved from 0.53901 to 0.53072, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.3317 - acc: 0.9598 - val_loss: 0.5483 - val_acc: 0.8344
#
# Epoch 00030: val_loss did not improve from 0.53072
# Epoch 31/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.3200 - acc: 0.9644 - val_loss: 0.5375 - val_acc: 0.8371
#
# Epoch 00031: val_loss did not improve from 0.53072
# Epoch 32/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.3121 - acc: 0.9636 - val_loss: 0.5192 - val_acc: 0.8435
#
# Epoch 00032: val_loss improved from 0.53072 to 0.51916, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.3044 - acc: 0.9676 - val_loss: 0.5238 - val_acc: 0.8379
#
# Epoch 00033: val_loss did not improve from 0.51916
# Epoch 34/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.2932 - acc: 0.9704 - val_loss: 0.5161 - val_acc: 0.8461
#
# Epoch 00034: val_loss improved from 0.51916 to 0.51606, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2826 - acc: 0.9733 - val_loss: 0.5164 - val_acc: 0.8357
#
# Epoch 00035: val_loss did not improve from 0.51606
# Epoch 36/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.2771 - acc: 0.9733 - val_loss: 0.5132 - val_acc: 0.8356
#
# Epoch 00036: val_loss improved from 0.51606 to 0.51316, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.2706 - acc: 0.9736 - val_loss: 0.5202 - val_acc: 0.8366
#
# Epoch 00037: val_loss did not improve from 0.51316
# Epoch 38/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.2609 - acc: 0.9760 - val_loss: 0.5073 - val_acc: 0.8395
#
# Epoch 00038: val_loss improved from 0.51316 to 0.50728, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2535 - acc: 0.9782 - val_loss: 0.5052 - val_acc: 0.8468
#
# Epoch 00039: val_loss improved from 0.50728 to 0.50525, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 40/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2470 - acc: 0.9782 - val_loss: 0.4995 - val_acc: 0.8418
#
# Epoch 00040: val_loss improved from 0.50525 to 0.49950, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2384 - acc: 0.9803 - val_loss: 0.4886 - val_acc: 0.8449
#
# Epoch 00041: val_loss improved from 0.49950 to 0.48857, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.2321 - acc: 0.9820 - val_loss: 0.4993 - val_acc: 0.8321
#
# Epoch 00042: val_loss did not improve from 0.48857
# Epoch 43/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2271 - acc: 0.9822 - val_loss: 0.4771 - val_acc: 0.8394
#
# Epoch 00043: val_loss improved from 0.48857 to 0.47708, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2199 - acc: 0.9836 - val_loss: 0.4753 - val_acc: 0.8484
#
# Epoch 00044: val_loss improved from 0.47708 to 0.47530, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.2137 - acc: 0.9845 - val_loss: 0.4863 - val_acc: 0.8487
#
# Epoch 00045: val_loss did not improve from 0.47530
# Epoch 46/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2068 - acc: 0.9853 - val_loss: 0.4788 - val_acc: 0.8400
#
# Epoch 00046: val_loss did not improve from 0.47530
# Epoch 47/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.2021 - acc: 0.9859 - val_loss: 0.4799 - val_acc: 0.8439
#
# Epoch 00047: val_loss did not improve from 0.47530
# Epoch 48/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1964 - acc: 0.9861 - val_loss: 0.4651 - val_acc: 0.8479
#
# Epoch 00048: val_loss improved from 0.47530 to 0.46512, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1927 - acc: 0.9863 - val_loss: 0.4836 - val_acc: 0.8412
#
# Epoch 00049: val_loss did not improve from 0.46512
# Epoch 50/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1867 - acc: 0.9876 - val_loss: 0.4700 - val_acc: 0.8470
#
# Epoch 00050: val_loss did not improve from 0.46512
# Epoch 51/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.1829 - acc: 0.9885 - val_loss: 0.4639 - val_acc: 0.8483
#
# Epoch 00051: val_loss improved from 0.46512 to 0.46388, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1773 - acc: 0.9880 - val_loss: 0.4778 - val_acc: 0.8440
#
# Epoch 00052: val_loss did not improve from 0.46388
# Epoch 53/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.1735 - acc: 0.9892 - val_loss: 0.4633 - val_acc: 0.8516
#
# Epoch 00053: val_loss improved from 0.46388 to 0.46328, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 54/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1679 - acc: 0.9903 - val_loss: 0.4662 - val_acc: 0.8486
#
# Epoch 00054: val_loss did not improve from 0.46328
# Epoch 55/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1628 - acc: 0.9908 - val_loss: 0.4450 - val_acc: 0.8547
#
# Epoch 00055: val_loss improved from 0.46328 to 0.44496, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 56/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1591 - acc: 0.9909 - val_loss: 0.4580 - val_acc: 0.8521
#
# Epoch 00056: val_loss did not improve from 0.44496
# Epoch 57/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1559 - acc: 0.9909 - val_loss: 0.4654 - val_acc: 0.8379
#
# Epoch 00057: val_loss did not improve from 0.44496
# Epoch 58/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.1507 - acc: 0.9914 - val_loss: 0.4625 - val_acc: 0.8488
#
# Epoch 00058: val_loss did not improve from 0.44496
# Epoch 59/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1490 - acc: 0.9914 - val_loss: 0.4615 - val_acc: 0.8522
#
# Epoch 00059: val_loss did not improve from 0.44496
# Epoch 60/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1431 - acc: 0.9921 - val_loss: 0.4403 - val_acc: 0.8557
#
# Epoch 00060: val_loss improved from 0.44496 to 0.44030, saving model to drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1391 - acc: 0.9935 - val_loss: 0.4541 - val_acc: 0.8559
#
# Epoch 00061: val_loss did not improve from 0.44030
# Epoch 62/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1377 - acc: 0.9932 - val_loss: 0.4584 - val_acc: 0.8491
#
# Epoch 00062: val_loss did not improve from 0.44030
# Epoch 63/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1331 - acc: 0.9935 - val_loss: 0.4482 - val_acc: 0.8474
#
# Epoch 00063: val_loss did not improve from 0.44030
# Epoch 64/400
# 1185/1185 [==============================] - 78s 66ms/step - loss: 0.1288 - acc: 0.9934 - val_loss: 0.4608 - val_acc: 0.8468
#
# Epoch 00064: val_loss did not improve from 0.44030
# Epoch 65/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1279 - acc: 0.9933 - val_loss: 0.4628 - val_acc: 0.8482
#
# Epoch 00065: val_loss did not improve from 0.44030
# Epoch 66/400
# 1185/1185 [==============================] - 79s 66ms/step - loss: 0.1250 - acc: 0.9933 - val_loss: 0.4559 - val_acc: 0.8518
#
# Epoch 00066: val_loss did not improve from 0.44030
# Epoch 67/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.1212 - acc: 0.9939 - val_loss: 0.4522 - val_acc: 0.8480
#
# Epoch 00067: val_loss did not improve from 0.44030
# Epoch 68/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.1174 - acc: 0.9943 - val_loss: 0.4522 - val_acc: 0.8461
#
# Epoch 00068: val_loss did not improve from 0.44030
# Epoch 69/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.1171 - acc: 0.9939 - val_loss: 0.4540 - val_acc: 0.8451
#
# Epoch 00069: val_loss did not improve from 0.44030
# Epoch 70/400
# 1185/1185 [==============================] - 79s 67ms/step - loss: 0.1122 - acc: 0.9948 - val_loss: 0.4523 - val_acc: 0.8436
#
# Epoch 00070: val_loss did not improve from 0.44030
# results per 4-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.4523 - acc: 0.8436
# [[1897    8    0   81   38]
#  [  24 1186  190  125   53]
#  [  29   72 1983  121   51]
#  [  68   58   15 2563  125]
#  [  45  120   54  424 1548]]
#               precision    recall  f1-score   support
#
#           HC       0.92      0.94      0.93      2024
#          a_H       0.82      0.75      0.78      1578
#          a_K       0.88      0.88      0.88      2256
#          a_A       0.77      0.91      0.83      2829
#          a_C       0.85      0.71      0.77      2191
#
#     accuracy                           0.84     10878
#    macro avg       0.85      0.84      0.84     10878
# weighted avg       0.85      0.84      0.84     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1196/1196 [==============================] - 84s 67ms/step - loss: 1.5450 - acc: 0.3567 - val_loss: 1.2330 - val_acc: 0.5041
#
# Epoch 00001: val_loss improved from inf to 1.23303, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 1.2090 - acc: 0.5219 - val_loss: 1.1283 - val_acc: 0.5745
#
# Epoch 00002: val_loss improved from 1.23303 to 1.12830, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 1.0739 - acc: 0.5946 - val_loss: 1.0274 - val_acc: 0.6222
#
# Epoch 00003: val_loss improved from 1.12830 to 1.02737, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.9791 - acc: 0.6506 - val_loss: 0.9651 - val_acc: 0.6477
#
# Epoch 00004: val_loss improved from 1.02737 to 0.96509, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.9113 - acc: 0.6904 - val_loss: 0.9313 - val_acc: 0.6664
#
# Epoch 00005: val_loss improved from 0.96509 to 0.93130, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.8518 - acc: 0.7223 - val_loss: 0.8880 - val_acc: 0.6968
#
# Epoch 00006: val_loss improved from 0.93130 to 0.88800, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.8011 - acc: 0.7540 - val_loss: 0.8675 - val_acc: 0.7044
#
# Epoch 00007: val_loss improved from 0.88800 to 0.86751, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.7549 - acc: 0.7803 - val_loss: 0.8370 - val_acc: 0.7284
#
# Epoch 00008: val_loss improved from 0.86751 to 0.83695, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.7238 - acc: 0.7979 - val_loss: 0.8153 - val_acc: 0.7389
#
# Epoch 00009: val_loss improved from 0.83695 to 0.81527, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1196/1196 [==============================] - 80s 66ms/step - loss: 0.6853 - acc: 0.8186 - val_loss: 0.7915 - val_acc: 0.7461
#
# Epoch 00010: val_loss improved from 0.81527 to 0.79145, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.6582 - acc: 0.8281 - val_loss: 0.7859 - val_acc: 0.7516
#
# Epoch 00011: val_loss improved from 0.79145 to 0.78593, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.6297 - acc: 0.8470 - val_loss: 0.7572 - val_acc: 0.7610
#
# Epoch 00012: val_loss improved from 0.78593 to 0.75720, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.6006 - acc: 0.8599 - val_loss: 0.7413 - val_acc: 0.7689
#
# Epoch 00013: val_loss improved from 0.75720 to 0.74131, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.5745 - acc: 0.8711 - val_loss: 0.7516 - val_acc: 0.7535
#
# Epoch 00014: val_loss did not improve from 0.74131
# Epoch 15/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.5517 - acc: 0.8827 - val_loss: 0.7152 - val_acc: 0.7768
#
# Epoch 00015: val_loss improved from 0.74131 to 0.71521, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.5298 - acc: 0.8897 - val_loss: 0.6996 - val_acc: 0.7769
#
# Epoch 00016: val_loss improved from 0.71521 to 0.69959, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1196/1196 [==============================] - 80s 66ms/step - loss: 0.5082 - acc: 0.9020 - val_loss: 0.7079 - val_acc: 0.7789
#
# Epoch 00017: val_loss did not improve from 0.69959
# Epoch 18/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.4898 - acc: 0.9099 - val_loss: 0.6951 - val_acc: 0.7739
#
# Epoch 00018: val_loss improved from 0.69959 to 0.69510, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.4733 - acc: 0.9152 - val_loss: 0.6813 - val_acc: 0.7836
#
# Epoch 00019: val_loss improved from 0.69510 to 0.68125, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.4553 - acc: 0.9203 - val_loss: 0.6816 - val_acc: 0.7857
#
# Epoch 00020: val_loss did not improve from 0.68125
# Epoch 21/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.4351 - acc: 0.9294 - val_loss: 0.6536 - val_acc: 0.7987
#
# Epoch 00021: val_loss improved from 0.68125 to 0.65359, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.4217 - acc: 0.9333 - val_loss: 0.6705 - val_acc: 0.7939
#
# Epoch 00022: val_loss did not improve from 0.65359
# Epoch 23/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.4081 - acc: 0.9381 - val_loss: 0.6433 - val_acc: 0.8008
#
# Epoch 00023: val_loss improved from 0.65359 to 0.64332, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.3927 - acc: 0.9440 - val_loss: 0.6211 - val_acc: 0.8140
#
# Epoch 00024: val_loss improved from 0.64332 to 0.62112, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3814 - acc: 0.9463 - val_loss: 0.6195 - val_acc: 0.8031
#
# Epoch 00025: val_loss improved from 0.62112 to 0.61949, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3664 - acc: 0.9525 - val_loss: 0.6284 - val_acc: 0.8114
#
# Epoch 00026: val_loss did not improve from 0.61949
# Epoch 27/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3542 - acc: 0.9561 - val_loss: 0.6215 - val_acc: 0.8069
#
# Epoch 00027: val_loss did not improve from 0.61949
# Epoch 28/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3422 - acc: 0.9596 - val_loss: 0.6407 - val_acc: 0.7927
#
# Epoch 00028: val_loss did not improve from 0.61949
# Epoch 29/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3319 - acc: 0.9627 - val_loss: 0.6146 - val_acc: 0.8085
#
# Epoch 00029: val_loss improved from 0.61949 to 0.61456, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 30/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3226 - acc: 0.9638 - val_loss: 0.5979 - val_acc: 0.8132
#
# Epoch 00030: val_loss improved from 0.61456 to 0.59786, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 31/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3088 - acc: 0.9691 - val_loss: 0.6015 - val_acc: 0.8118
#
# Epoch 00031: val_loss did not improve from 0.59786
# Epoch 32/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.3029 - acc: 0.9689 - val_loss: 0.5950 - val_acc: 0.8086
#
# Epoch 00032: val_loss improved from 0.59786 to 0.59500, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 33/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2928 - acc: 0.9705 - val_loss: 0.5972 - val_acc: 0.8102
#
# Epoch 00033: val_loss did not improve from 0.59500
# Epoch 34/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2843 - acc: 0.9728 - val_loss: 0.5794 - val_acc: 0.8156
#
# Epoch 00034: val_loss improved from 0.59500 to 0.57941, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2774 - acc: 0.9737 - val_loss: 0.5774 - val_acc: 0.8204
#
# Epoch 00035: val_loss improved from 0.57941 to 0.57737, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2694 - acc: 0.9755 - val_loss: 0.5694 - val_acc: 0.8258
#
# Epoch 00036: val_loss improved from 0.57737 to 0.56936, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2622 - acc: 0.9778 - val_loss: 0.5814 - val_acc: 0.8185
#
# Epoch 00037: val_loss did not improve from 0.56936
# Epoch 38/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2516 - acc: 0.9796 - val_loss: 0.5635 - val_acc: 0.8276
#
# Epoch 00038: val_loss improved from 0.56936 to 0.56347, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 39/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2453 - acc: 0.9802 - val_loss: 0.5655 - val_acc: 0.8187
#
# Epoch 00039: val_loss did not improve from 0.56347
# Epoch 40/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2389 - acc: 0.9820 - val_loss: 0.5556 - val_acc: 0.8214
#
# Epoch 00040: val_loss improved from 0.56347 to 0.55564, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 41/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2319 - acc: 0.9830 - val_loss: 0.5685 - val_acc: 0.8150
#
# Epoch 00041: val_loss did not improve from 0.55564
# Epoch 42/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2246 - acc: 0.9836 - val_loss: 0.5680 - val_acc: 0.8185
#
# Epoch 00042: val_loss did not improve from 0.55564
# Epoch 43/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2189 - acc: 0.9854 - val_loss: 0.5410 - val_acc: 0.8274
#
# Epoch 00043: val_loss improved from 0.55564 to 0.54105, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 44/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2107 - acc: 0.9859 - val_loss: 0.5380 - val_acc: 0.8355
#
# Epoch 00044: val_loss improved from 0.54105 to 0.53801, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2098 - acc: 0.9854 - val_loss: 0.5456 - val_acc: 0.8217
#
# Epoch 00045: val_loss did not improve from 0.53801
# Epoch 46/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.2024 - acc: 0.9864 - val_loss: 0.5538 - val_acc: 0.8195
#
# Epoch 00046: val_loss did not improve from 0.53801
# Epoch 47/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1967 - acc: 0.9878 - val_loss: 0.5602 - val_acc: 0.8215
#
# Epoch 00047: val_loss did not improve from 0.53801
# Epoch 48/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1919 - acc: 0.9874 - val_loss: 0.5331 - val_acc: 0.8304
#
# Epoch 00048: val_loss improved from 0.53801 to 0.53309, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 49/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1851 - acc: 0.9897 - val_loss: 0.5332 - val_acc: 0.8305
#
# Epoch 00049: val_loss did not improve from 0.53309
# Epoch 50/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1804 - acc: 0.9894 - val_loss: 0.5324 - val_acc: 0.8316
#
# Epoch 00050: val_loss improved from 0.53309 to 0.53238, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 51/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1783 - acc: 0.9887 - val_loss: 0.5219 - val_acc: 0.8377
#
# Epoch 00051: val_loss improved from 0.53238 to 0.52187, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 52/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.1691 - acc: 0.9919 - val_loss: 0.5316 - val_acc: 0.8320
#
# Epoch 00052: val_loss did not improve from 0.52187
# Epoch 53/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.1677 - acc: 0.9909 - val_loss: 0.5236 - val_acc: 0.8389
#
# Epoch 00053: val_loss did not improve from 0.52187
# Epoch 54/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.1635 - acc: 0.9904 - val_loss: 0.5249 - val_acc: 0.8390
#
# Epoch 00054: val_loss did not improve from 0.52187
# Epoch 55/400
# 1196/1196 [==============================] - 80s 67ms/step - loss: 0.1585 - acc: 0.9913 - val_loss: 0.5458 - val_acc: 0.8235
#
# Epoch 00055: val_loss did not improve from 0.52187
# Epoch 56/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1538 - acc: 0.9927 - val_loss: 0.5469 - val_acc: 0.8204
#
# Epoch 00056: val_loss did not improve from 0.52187
# Epoch 57/400
# 1196/1196 [==============================] - 80s 66ms/step - loss: 0.1501 - acc: 0.9924 - val_loss: 0.5328 - val_acc: 0.8278
#
# Epoch 00057: val_loss did not improve from 0.52187
# Epoch 58/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1466 - acc: 0.9922 - val_loss: 0.5125 - val_acc: 0.8425
#
# Epoch 00058: val_loss improved from 0.52187 to 0.51246, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 59/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1429 - acc: 0.9927 - val_loss: 0.5317 - val_acc: 0.8310
#
# Epoch 00059: val_loss did not improve from 0.51246
# Epoch 60/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1384 - acc: 0.9932 - val_loss: 0.5054 - val_acc: 0.8398
#
# Epoch 00060: val_loss improved from 0.51246 to 0.50542, saving model to drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 61/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1351 - acc: 0.9941 - val_loss: 0.5126 - val_acc: 0.8370
#
# Epoch 00061: val_loss did not improve from 0.50542
# Epoch 62/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1337 - acc: 0.9927 - val_loss: 0.5214 - val_acc: 0.8367
#
# Epoch 00062: val_loss did not improve from 0.50542
# Epoch 63/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1303 - acc: 0.9932 - val_loss: 0.5147 - val_acc: 0.8284
#
# Epoch 00063: val_loss did not improve from 0.50542
# Epoch 64/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1266 - acc: 0.9936 - val_loss: 0.5316 - val_acc: 0.8304
#
# Epoch 00064: val_loss did not improve from 0.50542
# Epoch 65/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1234 - acc: 0.9941 - val_loss: 0.5201 - val_acc: 0.8321
#
# Epoch 00065: val_loss did not improve from 0.50542
# Epoch 66/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1192 - acc: 0.9946 - val_loss: 0.5153 - val_acc: 0.8336
#
# Epoch 00066: val_loss did not improve from 0.50542
# Epoch 67/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1152 - acc: 0.9948 - val_loss: 0.5075 - val_acc: 0.8374
#
# Epoch 00067: val_loss did not improve from 0.50542
# Epoch 68/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1130 - acc: 0.9954 - val_loss: 0.5201 - val_acc: 0.8279
#
# Epoch 00068: val_loss did not improve from 0.50542
# Epoch 69/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1106 - acc: 0.9952 - val_loss: 0.5216 - val_acc: 0.8299
#
# Epoch 00069: val_loss did not improve from 0.50542
# Epoch 70/400
# 1196/1196 [==============================] - 79s 66ms/step - loss: 0.1074 - acc: 0.9955 - val_loss: 0.5154 - val_acc: 0.8416
#
# Epoch 00070: val_loss did not improve from 0.50542
# results per 5-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.5154 - acc: 0.8416
# [[1967    0   48  132  113]
#  [  14 1506  128  153   29]
#  [  15   15 2106  176   94]
#  [   0   53   33 2457   56]
#  [ 154  104   73  333 1119]]
#               precision    recall  f1-score   support
#
#           HC       0.91      0.87      0.89      2260
#          a_H       0.90      0.82      0.86      1830
#          a_K       0.88      0.88      0.88      2406
#          a_A       0.76      0.95      0.84      2599
#          a_C       0.79      0.63      0.70      1783
#
#     accuracy                           0.84     10878
#    macro avg       0.85      0.83      0.83     10878
# weighted avg       0.85      0.84      0.84     10878
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# HC for train (11580,)
# H for train (16064,)
# K for train (16064,)
# A for train (16064,)
# C for train (16064,)
# HC for val (2176,)
# H for val (1540,)
# K for val (2789,)
# A for val (2493,)
# C for val (1880,)
# Epoch 1/400
# 1204/1204 [==============================] - 83s 66ms/step - loss: 1.5458 - acc: 0.3580 - val_loss: 1.2068 - val_acc: 0.4990
#
# Epoch 00001: val_loss improved from inf to 1.20681, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 1.2018 - acc: 0.5213 - val_loss: 1.0756 - val_acc: 0.5894
#
# Epoch 00002: val_loss improved from 1.20681 to 1.07555, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 3/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 1.0689 - acc: 0.6011 - val_loss: 1.0006 - val_acc: 0.6380
#
# Epoch 00003: val_loss improved from 1.07555 to 1.00061, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.9794 - acc: 0.6511 - val_loss: 0.9601 - val_acc: 0.6554
#
# Epoch 00004: val_loss improved from 1.00061 to 0.96006, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.9099 - acc: 0.6896 - val_loss: 0.9025 - val_acc: 0.6905
#
# Epoch 00005: val_loss improved from 0.96006 to 0.90247, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.8583 - acc: 0.7202 - val_loss: 0.8599 - val_acc: 0.7135
#
# Epoch 00006: val_loss improved from 0.90247 to 0.85991, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.8073 - acc: 0.7496 - val_loss: 0.8290 - val_acc: 0.7158
#
# Epoch 00007: val_loss improved from 0.85991 to 0.82897, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.7698 - acc: 0.7706 - val_loss: 0.8008 - val_acc: 0.7291
#
# Epoch 00008: val_loss improved from 0.82897 to 0.80076, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.7255 - acc: 0.7937 - val_loss: 0.7568 - val_acc: 0.7466
#
# Epoch 00009: val_loss improved from 0.80076 to 0.75682, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.6911 - acc: 0.8149 - val_loss: 0.7337 - val_acc: 0.7605
#
# Epoch 00010: val_loss improved from 0.75682 to 0.73372, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.6601 - acc: 0.8284 - val_loss: 0.7106 - val_acc: 0.7702
#
# Epoch 00011: val_loss improved from 0.73372 to 0.71061, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.6341 - acc: 0.8415 - val_loss: 0.6861 - val_acc: 0.7765
#
# Epoch 00012: val_loss improved from 0.71061 to 0.68606, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 13/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.6045 - acc: 0.8577 - val_loss: 0.6715 - val_acc: 0.7807
#
# Epoch 00013: val_loss improved from 0.68606 to 0.67148, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.5818 - acc: 0.8690 - val_loss: 0.6411 - val_acc: 0.7958
#
# Epoch 00014: val_loss improved from 0.67148 to 0.64115, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 15/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.5570 - acc: 0.8779 - val_loss: 0.6286 - val_acc: 0.7985
#
# Epoch 00015: val_loss improved from 0.64115 to 0.62864, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.5347 - acc: 0.8881 - val_loss: 0.6147 - val_acc: 0.8079
#
# Epoch 00016: val_loss improved from 0.62864 to 0.61474, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.5168 - acc: 0.8975 - val_loss: 0.6008 - val_acc: 0.8048
#
# Epoch 00017: val_loss improved from 0.61474 to 0.60082, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 18/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4986 - acc: 0.9040 - val_loss: 0.5920 - val_acc: 0.8188
#
# Epoch 00018: val_loss improved from 0.60082 to 0.59205, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4795 - acc: 0.9096 - val_loss: 0.5654 - val_acc: 0.8295
#
# Epoch 00019: val_loss improved from 0.59205 to 0.56535, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 20/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4624 - acc: 0.9175 - val_loss: 0.5456 - val_acc: 0.8341
#
# Epoch 00020: val_loss improved from 0.56535 to 0.54557, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 21/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4446 - acc: 0.9250 - val_loss: 0.5465 - val_acc: 0.8243
#
# Epoch 00021: val_loss did not improve from 0.54557
# Epoch 22/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.4300 - acc: 0.9289 - val_loss: 0.5306 - val_acc: 0.8366
#
# Epoch 00022: val_loss improved from 0.54557 to 0.53058, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4187 - acc: 0.9329 - val_loss: 0.5195 - val_acc: 0.8443
#
# Epoch 00023: val_loss improved from 0.53058 to 0.51945, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.4031 - acc: 0.9380 - val_loss: 0.5089 - val_acc: 0.8385
#
# Epoch 00024: val_loss improved from 0.51945 to 0.50887, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 25/400
#  377/1204 [========>.....................] - ETA: 52s - loss: 0.3937 - acc: 0.9410

# %%
#  続き 1fold 22 epoch finished
def decay_schedule(epoch, lr):
  # decay by 0.1 every 5 epochs; use `% 1` to decay after each epoch
  if (epoch % 56 == 0) and (epoch != 0):
      lr = lr * 0.1
  return lr

i = 6
# print("HC", np.where(np.argmax(train_label_list[i], axis=1)==0)[0].shape)
# print("H", np.where(np.argmax(train_label_list[i], axis=1)==1)[0].shape)
# print("K", np.where(np.argmax(train_label_list[i], axis=1)==2)[0].shape)
# print("A", np.where(np.argmax(train_label_list[i], axis=1)==3)[0].shape)
# print("C", np.where(np.argmax(train_label_list[i], axis=1)==4)[0].shape)

# checkpointの設定
checkpoint = ModelCheckpoint(
                  filepath="drive/MyDrive/saved_models/checkpoints/{}fold_{}.h5".format(i, NAME),
                    monitor='val_loss',
                    save_best_only=True,
                    period=1,
                    verbose=1
                )

model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(
    loss='categorical_crossentropy',
    # loss = custom_cross_entropy,
    optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
    metrics=['acc'],
    # class_weight=class_weight
          )

result = model.fit(
    x=train_LSTM_data_list[i], 
    y=used_train_label_list[i], 
    batch_size=63, 
    epochs=400, 
    verbose=1,
    validation_data=(
        val_LSTM_data_list[i], 
        val_label_list[i]
          ),
    callbacks=[early_stopping, checkpoint, lr_scheduler]
    )

print("results per {}-fold".format(i))
history.append(model.evaluate(
    x=val_LSTM_data_list[i], 
    y=val_label_list[i], 
    verbose=1))
# save weights
# file_name = "{}fold_{}".format(i, NAME)
# model.save(file_name+'.h5')

  # 混合行列
predict_prob = model.predict(val_LSTM_data_list[i])
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = val_label_list[i]
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data, annot=True, ax = ax, fmt="1.3f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()

# i = i + 1



# plt.plot(result.history['acc'])
# plt.plot(result.history['val_acc'])
# plt.title('Model accuracy')
# plt.ylabel('Accuracy')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# plt.plot(result.history['loss'])
# plt.plot(result.history['val_loss'])
# plt.title('Model loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.grid()
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()

# now = datetime.datetime.now()
# with open("cmx_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(cmx_list, f)
# f.close()

# with open("classification_report_{}_{}.pickle".format(NAME, now.strftime('%Y%m%d_%H%M%S')), mode="wb") as f:
#    pickle.dump(report_list, f)
# f.close()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization (LayerNo (None, 101, 1024)         2048
# _________________________________________________________________
# activation (Activation)      (None, 101, 1024)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 101, 1024)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 103424)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               52953600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5)                 20
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# Epoch 1/400
# 1204/1204 [==============================] - 113s 65ms/step - loss: 0.3894 - acc: 0.9419 - val_loss: 0.4946 - val_acc: 0.8479
#
# Epoch 00001: val_loss improved from inf to 0.49460, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 2/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3737 - acc: 0.9471 - val_loss: 0.4972 - val_acc: 0.8480
#
# Epoch 00002: val_loss did not improve from 0.49460
# Epoch 3/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.3646 - acc: 0.9502 - val_loss: 0.4743 - val_acc: 0.8575
#
# Epoch 00003: val_loss improved from 0.49460 to 0.47433, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 4/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3532 - acc: 0.9532 - val_loss: 0.4731 - val_acc: 0.8554
#
# Epoch 00004: val_loss improved from 0.47433 to 0.47314, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 5/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3431 - acc: 0.9555 - val_loss: 0.4698 - val_acc: 0.8523
#
# Epoch 00005: val_loss improved from 0.47314 to 0.46978, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 6/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3324 - acc: 0.9597 - val_loss: 0.4623 - val_acc: 0.8552
#
# Epoch 00006: val_loss improved from 0.46978 to 0.46230, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 7/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3225 - acc: 0.9623 - val_loss: 0.4593 - val_acc: 0.8566
#
# Epoch 00007: val_loss improved from 0.46230 to 0.45927, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 8/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3100 - acc: 0.9657 - val_loss: 0.4405 - val_acc: 0.8634
#
# Epoch 00008: val_loss improved from 0.45927 to 0.44052, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 9/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.3019 - acc: 0.9683 - val_loss: 0.4368 - val_acc: 0.8718
#
# Epoch 00009: val_loss improved from 0.44052 to 0.43684, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 10/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2910 - acc: 0.9708 - val_loss: 0.4329 - val_acc: 0.8668
#
# Epoch 00010: val_loss improved from 0.43684 to 0.43288, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 11/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2853 - acc: 0.9707 - val_loss: 0.4299 - val_acc: 0.8710
#
# Epoch 00011: val_loss improved from 0.43288 to 0.42990, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 12/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2764 - acc: 0.9727 - val_loss: 0.4317 - val_acc: 0.8725
#
# Epoch 00012: val_loss did not improve from 0.42990
# Epoch 13/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2690 - acc: 0.9739 - val_loss: 0.4220 - val_acc: 0.8810
#
# Epoch 00013: val_loss improved from 0.42990 to 0.42196, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 14/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2606 - acc: 0.9766 - val_loss: 0.4230 - val_acc: 0.8810
#
# Epoch 00014: val_loss did not improve from 0.42196
# Epoch 15/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2551 - acc: 0.9757 - val_loss: 0.4179 - val_acc: 0.8769
#
# Epoch 00015: val_loss improved from 0.42196 to 0.41792, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 16/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2468 - acc: 0.9783 - val_loss: 0.4099 - val_acc: 0.8748
#
# Epoch 00016: val_loss improved from 0.41792 to 0.40990, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 17/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2388 - acc: 0.9802 - val_loss: 0.4149 - val_acc: 0.8749
#
# Epoch 00017: val_loss did not improve from 0.40990
# Epoch 18/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2319 - acc: 0.9818 - val_loss: 0.3972 - val_acc: 0.8833
#
# Epoch 00018: val_loss improved from 0.40990 to 0.39719, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 19/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2236 - acc: 0.9823 - val_loss: 0.4130 - val_acc: 0.8734
#
# Epoch 00019: val_loss did not improve from 0.39719
# Epoch 20/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2202 - acc: 0.9824 - val_loss: 0.4021 - val_acc: 0.8799
#
# Epoch 00020: val_loss did not improve from 0.39719
# Epoch 21/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.2124 - acc: 0.9849 - val_loss: 0.3933 - val_acc: 0.8783
#
# Epoch 00021: val_loss improved from 0.39719 to 0.39332, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 22/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2079 - acc: 0.9847 - val_loss: 0.3903 - val_acc: 0.8780
#
# Epoch 00022: val_loss improved from 0.39332 to 0.39035, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 23/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.2030 - acc: 0.9857 - val_loss: 0.3897 - val_acc: 0.8789
#
# Epoch 00023: val_loss improved from 0.39035 to 0.38971, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 24/400
# 1204/1204 [==============================] - 80s 67ms/step - loss: 0.1973 - acc: 0.9861 - val_loss: 0.3911 - val_acc: 0.8757
#
# Epoch 00024: val_loss did not improve from 0.38971
# Epoch 25/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1918 - acc: 0.9872 - val_loss: 0.3738 - val_acc: 0.8828
#
# Epoch 00025: val_loss improved from 0.38971 to 0.37381, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 26/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1861 - acc: 0.9884 - val_loss: 0.3791 - val_acc: 0.8793
#
# Epoch 00026: val_loss did not improve from 0.37381
# Epoch 27/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1816 - acc: 0.9893 - val_loss: 0.3819 - val_acc: 0.8825
#
# Epoch 00027: val_loss did not improve from 0.37381
# Epoch 28/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1775 - acc: 0.9892 - val_loss: 0.3746 - val_acc: 0.8836
#
# Epoch 00028: val_loss did not improve from 0.37381
# Epoch 29/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1712 - acc: 0.9901 - val_loss: 0.3764 - val_acc: 0.8778
#
# Epoch 00029: val_loss did not improve from 0.37381
# Epoch 30/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1687 - acc: 0.9897 - val_loss: 0.3794 - val_acc: 0.8842
#
# Epoch 00030: val_loss did not improve from 0.37381
# Epoch 31/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1622 - acc: 0.9909 - val_loss: 0.3664 - val_acc: 0.8877
#
# Epoch 00031: val_loss improved from 0.37381 to 0.36640, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 32/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1584 - acc: 0.9911 - val_loss: 0.3680 - val_acc: 0.8844
#
# Epoch 00032: val_loss did not improve from 0.36640
# Epoch 33/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1545 - acc: 0.9919 - val_loss: 0.3698 - val_acc: 0.8883
#
# Epoch 00033: val_loss did not improve from 0.36640
# Epoch 34/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1508 - acc: 0.9918 - val_loss: 0.3614 - val_acc: 0.8852
#
# Epoch 00034: val_loss improved from 0.36640 to 0.36140, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 35/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1476 - acc: 0.9914 - val_loss: 0.3565 - val_acc: 0.8899
#
# Epoch 00035: val_loss improved from 0.36140 to 0.35651, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 36/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1422 - acc: 0.9928 - val_loss: 0.3526 - val_acc: 0.8936
#
# Epoch 00036: val_loss improved from 0.35651 to 0.35262, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 37/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1411 - acc: 0.9916 - val_loss: 0.3574 - val_acc: 0.8868
#
# Epoch 00037: val_loss did not improve from 0.35262
# Epoch 38/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1368 - acc: 0.9928 - val_loss: 0.3560 - val_acc: 0.8858
#
# Epoch 00038: val_loss did not improve from 0.35262
# Epoch 39/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1331 - acc: 0.9932 - val_loss: 0.3549 - val_acc: 0.8932
#
# Epoch 00039: val_loss did not improve from 0.35262
# Epoch 40/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1288 - acc: 0.9938 - val_loss: 0.3533 - val_acc: 0.8928
#
# Epoch 00040: val_loss did not improve from 0.35262
# Epoch 41/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1278 - acc: 0.9939 - val_loss: 0.3519 - val_acc: 0.8914
#
# Epoch 00041: val_loss improved from 0.35262 to 0.35189, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 42/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1229 - acc: 0.9942 - val_loss: 0.3565 - val_acc: 0.8879
#
# Epoch 00042: val_loss did not improve from 0.35189
# Epoch 43/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1196 - acc: 0.9941 - val_loss: 0.3527 - val_acc: 0.8949
#
# Epoch 00043: val_loss did not improve from 0.35189
# Epoch 44/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1176 - acc: 0.9941 - val_loss: 0.3453 - val_acc: 0.8863
#
# Epoch 00044: val_loss improved from 0.35189 to 0.34531, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 45/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1145 - acc: 0.9949 - val_loss: 0.3453 - val_acc: 0.8873
#
# Epoch 00045: val_loss did not improve from 0.34531
# Epoch 46/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1104 - acc: 0.9952 - val_loss: 0.3482 - val_acc: 0.8926
#
# Epoch 00046: val_loss did not improve from 0.34531
# Epoch 47/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1056 - acc: 0.9960 - val_loss: 0.3442 - val_acc: 0.8928
#
# Epoch 00047: val_loss improved from 0.34531 to 0.34425, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 48/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.1062 - acc: 0.9946 - val_loss: 0.3456 - val_acc: 0.8894
#
# Epoch 00048: val_loss did not improve from 0.34425
# Epoch 49/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1015 - acc: 0.9957 - val_loss: 0.3336 - val_acc: 0.8937
#
# Epoch 00049: val_loss improved from 0.34425 to 0.33355, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 50/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.1001 - acc: 0.9961 - val_loss: 0.3531 - val_acc: 0.8933
#
# Epoch 00050: val_loss did not improve from 0.33355
# Epoch 51/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0994 - acc: 0.9951 - val_loss: 0.3475 - val_acc: 0.8942
#
# Epoch 00051: val_loss did not improve from 0.33355
# Epoch 52/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0965 - acc: 0.9957 - val_loss: 0.3398 - val_acc: 0.8919
#
# Epoch 00052: val_loss did not improve from 0.33355
# Epoch 53/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0933 - acc: 0.9961 - val_loss: 0.3373 - val_acc: 0.8921
#
# Epoch 00053: val_loss did not improve from 0.33355
# Epoch 54/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0912 - acc: 0.9961 - val_loss: 0.3307 - val_acc: 0.9007
#
# Epoch 00054: val_loss improved from 0.33355 to 0.33066, saving model to drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5
# Epoch 55/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.0908 - acc: 0.9953 - val_loss: 0.3432 - val_acc: 0.8911
#
# Epoch 00055: val_loss did not improve from 0.33066
# Epoch 56/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0855 - acc: 0.9972 - val_loss: 0.3488 - val_acc: 0.8916
#
# Epoch 00056: val_loss did not improve from 0.33066
# Epoch 57/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0844 - acc: 0.9966 - val_loss: 0.3387 - val_acc: 0.8953
#
# Epoch 00057: val_loss did not improve from 0.33066
# Epoch 58/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0836 - acc: 0.9963 - val_loss: 0.3491 - val_acc: 0.9032
#
# Epoch 00058: val_loss did not improve from 0.33066
# Epoch 59/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0816 - acc: 0.9961 - val_loss: 0.3355 - val_acc: 0.8894
#
# Epoch 00059: val_loss did not improve from 0.33066
# Epoch 60/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0799 - acc: 0.9963 - val_loss: 0.3474 - val_acc: 0.8951
#
# Epoch 00060: val_loss did not improve from 0.33066
# Epoch 61/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0792 - acc: 0.9965 - val_loss: 0.3367 - val_acc: 0.8978
#
# Epoch 00061: val_loss did not improve from 0.33066
# Epoch 62/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.0752 - acc: 0.9972 - val_loss: 0.3460 - val_acc: 0.8935
#
# Epoch 00062: val_loss did not improve from 0.33066
# Epoch 63/400
# 1204/1204 [==============================] - 80s 66ms/step - loss: 0.0743 - acc: 0.9970 - val_loss: 0.3545 - val_acc: 0.8885
#
# Epoch 00063: val_loss did not improve from 0.33066
# Epoch 64/400
# 1204/1204 [==============================] - 79s 66ms/step - loss: 0.0725 - acc: 0.9966 - val_loss: 0.3614 - val_acc: 0.8944
#
# Epoch 00064: val_loss did not improve from 0.33066
# results per 6-fold
# 340/340 [==============================] - 5s 14ms/step - loss: 0.3614 - acc: 0.8944
# [[2089    8    0   29   50]
#  [  94 1162   30  212   42]
#  [  16   78 2567  103   25]
#  [   6   24  104 2187  172]
#  [  67    8   11   70 1724]]
#               precision    recall  f1-score   support
#
#           HC       0.92      0.96      0.94      2176
#          a_H       0.91      0.75      0.82      1540
#          a_K       0.95      0.92      0.93      2789
#          a_A       0.84      0.88      0.86      2493
#          a_C       0.86      0.92      0.89      1880
#
#     accuracy                           0.89     10878
#    macro avg       0.89      0.89      0.89     10878
# weighted avg       0.90      0.89      0.89     10878

# %%
import gc 
gc.collect()
# Out:
# 1227

# %%
# test 
with open("/content/drive/MyDrive/test_data/V_test.pickle", mode="rb") as f:
   test_V = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/AP_test.pickle", mode="rb") as f:
   test_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/ML_test.pickle", mode="rb") as f:
   test_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/COP_AP_test.pickle", mode="rb") as f:
   test_COP_AP = pickle.load(f)
f.close()
with open("/content/drive/MyDrive/test_data/COP_ML_test.pickle", mode="rb") as f:
   test_COP_ML = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/label_test.pickle", mode="rb") as f:
   test_label = pickle.load(f)
f.close()

with open("/content/drive/MyDrive/test_data/test_data_index.pickle", mode="rb") as f:
   test_index = pickle.load(f)
f.close()

# %%
# min_max normalizationする場合
from sklearn import preprocessing
mmscaler_LSTM = preprocessing.MinMaxScaler(feature_range=(-1, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1) 
# mmscaler_CNN = preprocessing.MinMaxScaler(feature_range=(0, 1), copy=True) # インスタンスの作成、活性化関数でtanhを使うのでfeature_range=(-1,1)

# LSTM
mmscaler_LSTM.fit(test_V)
test_V = mmscaler_LSTM.transform(test_V)
test_V = test_V.reshape(test_V.shape[0], test_V.shape[1], 1)

mmscaler_LSTM.fit(test_AP)
test_AP = mmscaler_LSTM.transform(test_AP)
test_AP = test_AP.reshape(test_AP.shape[0], test_AP.shape[1], 1)

mmscaler_LSTM.fit(test_ML)
test_ML = mmscaler_LSTM.transform(test_ML)
test_ML = test_ML.reshape(test_ML.shape[0], test_ML.shape[1], 1)

mmscaler_LSTM.fit(test_COP_AP)
test_COP_AP = mmscaler_LSTM.transform(test_COP_AP)
test_COP_AP = test_COP_AP.reshape(test_COP_AP.shape[0], test_COP_AP.shape[1], 1)

# mmscaler_LSTM.fit(test_COP_ML)
# test_COP_ML = mmscaler_LSTM.transform(test_COP_ML)
# test_COP_ML = test_COP_ML.reshape(test_COP_ML.shape[0], test_COP_ML.shape[1], 1)

test_x = np.concatenate([test_V[test_index], test_AP[test_index], test_ML[test_index], test_COP_AP[test_index]], axis=2)
test_y = test_label[test_index]
test_y = keras.utils.to_categorical(test_y, classes_main)

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/0fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_2 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 64)                256
# _________________________________________________________________
# activation_16 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_17 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1530    9   17   86  112]
#  [  19  907  270  106  149]
#  [  19   60 2248   98   94]
#  [   0   33   67 2770  119]
#  [  25   65   11  185 1879]]
#               precision    recall  f1-score   support
#
#           HC    0.96045   0.87229   0.91425      1754
#          a_H    0.84451   0.62509   0.71842      1451
#          a_K    0.86031   0.89242   0.87607      2519
#          a_A    0.85362   0.92673   0.88868      2989
#          a_C    0.79856   0.86790   0.83178      2165
#
#     accuracy                        0.85806     10878
#    macro avg    0.86349   0.83689   0.84584     10878
# weighted avg    0.86022   0.85806   0.85585     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/1fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_3 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_18 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_20 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# activation_22 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_23 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1575   26    0   28  125]
#  [  17 1014  176   81  163]
#  [  61  136 2136  117   69]
#  [  93   36   52 2575  233]
#  [ 116   97   20  182 1750]]
#               precision    recall  f1-score   support
#
#           HC    0.84586   0.89795   0.87113      1754
#          a_H    0.77464   0.69883   0.73478      1451
#          a_K    0.89597   0.84796   0.87130      2519
#          a_A    0.86322   0.86149   0.86236      2989
#          a_C    0.74786   0.80831   0.77691      2165
#
#     accuracy                        0.83195     10878
#    macro avg    0.82551   0.82291   0.82330     10878
# weighted avg    0.83323   0.83195   0.83182     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_4 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_24 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 101, 1024)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_25 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 128)               512
# _________________________________________________________________
# activation_27 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 64)                256
# _________________________________________________________________
# activation_28 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_29 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1662   10   33   11   38]
#  [  15 1086  251   30   69]
#  [  40   71 2370   28   10]
#  [ 132   68  103 2519  167]
#  [  74  173   74  150 1694]]
#               precision    recall  f1-score   support
#
#           HC    0.86427   0.94755   0.90400      1754
#          a_H    0.77131   0.74845   0.75971      1451
#          a_K    0.83716   0.94085   0.88598      2519
#          a_A    0.92001   0.84276   0.87969      2989
#          a_C    0.85642   0.78245   0.81776      2165
#
#     accuracy                        0.85779     10878
#    macro avg    0.84984   0.85241   0.84943     10878
# weighted avg    0.85935   0.85779   0.85674     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/2fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_5 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_30 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_31 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# activation_33 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 64)                256
# _________________________________________________________________
# activation_34 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_35 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1662   10   33   11   38]
#  [  15 1086  251   30   69]
#  [  40   71 2370   28   10]
#  [ 132   68  103 2519  167]
#  [  74  173   74  150 1694]]
#               precision    recall  f1-score   support
#
#           HC    0.86427   0.94755   0.90400      1754
#          a_H    0.77131   0.74845   0.75971      1451
#          a_K    0.83716   0.94085   0.88598      2519
#          a_A    0.92001   0.84276   0.87969      2989
#          a_C    0.85642   0.78245   0.81776      2165
#
#     accuracy                        0.85779     10878
#    macro avg    0.84984   0.85241   0.84943     10878
# weighted avg    0.85935   0.85779   0.85674     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/3fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_6 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_38 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 128)               512
# _________________________________________________________________
# activation_39 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 64)                256
# _________________________________________________________________
# activation_40 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_41 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1568    8   47   72   59]
#  [   9 1120  234   17   71]
#  [   9   55 2378   77    0]
#  [  32  113  181 2497  166]
#  [  86   91   94   97 1797]]
#               precision    recall  f1-score   support
#
#           HC    0.92019   0.89396   0.90688      1754
#          a_H    0.80750   0.77188   0.78929      1451
#          a_K    0.81050   0.94403   0.87218      2519
#          a_A    0.90471   0.83540   0.86867      2989
#          a_C    0.85858   0.83002   0.84406      2165
#
#     accuracy                        0.86045     10878
#    macro avg    0.86029   0.85506   0.85622     10878
# weighted avg    0.86324   0.86045   0.86016     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/4fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_7 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_42 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_35 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_43 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 128)               512
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 64)                256
# _________________________________________________________________
# activation_46 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_39 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_47 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1671    0    0   19   64]
#  [  74  990  220   74   93]
#  [  39   97 2180  128   75]
#  [  98   19   49 2675  148]
#  [  45   70    0  180 1870]]
#               precision    recall  f1-score   support
#
#           HC    0.86715   0.95268   0.90791      1754
#          a_H    0.84184   0.68229   0.75371      1451
#          a_K    0.89016   0.86542   0.87762      2519
#          a_A    0.86964   0.89495   0.88211      2989
#          a_C    0.83111   0.86374   0.84711      2165
#
#     accuracy                        0.86284     10878
#    macro avg    0.85998   0.85182   0.85369     10878
# weighted avg    0.86261   0.86284   0.86114     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/5fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_8 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_8 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_48 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_49 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_50 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 128)               512
# _________________________________________________________________
# activation_51 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 64)                256
# _________________________________________________________________
# activation_52 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_53 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1625    8   36   19   66]
#  [  28  984  278   45  116]
#  [  30   96 2274   41   78]
#  [  45   65  100 2621  158]
#  [  54   96   40  182 1793]]
#               precision    recall  f1-score   support
#
#           HC    0.91190   0.92645   0.91912      1754
#          a_H    0.78783   0.67815   0.72889      1451
#          a_K    0.83358   0.90274   0.86678      2519
#          a_A    0.90131   0.87688   0.88893      2989
#          a_C    0.81095   0.82818   0.81947      2165
#
#     accuracy                        0.85466     10878
#    macro avg    0.84911   0.84248   0.84464     10878
# weighted avg    0.85421   0.85466   0.85350     10878

# %%
# test 
model = build_model()
model.load_weights('/content/drive/MyDrive/saved_models/checkpoints/6fold_test_SMOTE_without_HC_3DGRF_APCOP_LSTM_5class_stratified_group.h5')
model.compile(loss='categorical_crossentropy', 
          optimizer= optimizers.Adam(lr=1e-5, beta_1= 0.9, beta_2= 0.999),
          metrics=['accuracy']
          )
# history.append(model.evaluate(
#       x=test_x, 
#       y=test_y, 
#       verbose=1))
#   # save weights

  # 混合行列
predict_prob = model.predict(test_x)
predict_classes=np.argmax(predict_prob,axis=1)
true_classes = test_y
true_classes=np.argmax(true_classes, axis=1)
cmx = confusion_matrix(true_classes, predict_classes)
cmx_list.append(cmx)
print(cmx)

index = ["HC", "a_H", "a_K", "a_A", "a_C"]

report = classification_report(true_classes, predict_classes, target_names=index, digits=5)
report_list.append(report)
print(report)

cmx_data = []
for i in range(len(cmx)):
  for j in range(len(cmx)): 
    cmx_data.append((cmx[j, i] / np.sum(cmx[i])))

cmx_data = np.array(cmx_data).reshape(classes_main, classes_main)

ax= plt.subplot()
sns.heatmap(cmx_data*100, annot=True, ax = ax, fmt="1.2f", cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix') 
ax.xaxis.set_ticklabels(index) 
ax.yaxis.set_ticklabels(index)
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_9 (Bidirection (None, 101, 1024)         2117632
# _________________________________________________________________
# layer_normalization_9 (Layer (None, 101, 1024)         2048
# _________________________________________________________________
# activation_54 (Activation)   (None, 101, 1024)         0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 101, 1024)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 103424)            0
# _________________________________________________________________
# dense_45 (Dense)             (None, 512)               52953600
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_55 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_56 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_47 (Dense)             (None, 128)               32896
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 128)               512
# _________________________________________________________________
# activation_57 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 64)                256
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 325
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 5)                 20
# _________________________________________________________________
# activation_59 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 55,249,945
# Trainable params: 55,248,015
# Non-trainable params: 1,930
# _________________________________________________________________
# [[1681   28   16   10   19]
#  [  48 1034  228   39  102]
#  [  19  119 2274   54   53]
#  [  20   65   68 2647  189]
#  [  80  141   19   68 1857]]
#               precision    recall  f1-score   support
#
#           HC    0.90963   0.95838   0.93337      1754
#          a_H    0.74549   0.71261   0.72868      1451
#          a_K    0.87294   0.90274   0.88759      2519
#          a_A    0.93932   0.88558   0.91166      2989
#          a_C    0.83649   0.85774   0.84698      2165
#
#     accuracy                        0.87268     10878
#    macro avg    0.86077   0.86341   0.86166     10878
# weighted avg    0.87284   0.87268   0.87231     10878

# %%
import numpy as np
print("validation: samples / class")
print(np.where(np.argmax(val_label_list[0], axis=1)==0)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==1)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==2)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==3)[0].shape)
print(np.where(np.argmax(val_label_list[0], axis=1)==4)[0].shape)
print("training: samples / class")
print(np.where(np.argmax(used_train_label_list[0], axis=1)==0)[0].shape)
print(np.where(np.argmax(used_train_label_list[0], axis=1)==1)[0].shape)
print(np.where(np.argmax(used_train_label_list[0], axis=1)==2)[0].shape)
print(np.where(np.argmax(used_train_label_list[0], axis=1)==3)[0].shape)
print(np.where(np.argmax(used_train_label_list[0], axis=1)==4)[0].shape)
print("test: samples / class")
print(np.where(np.argmax(test_y, axis=1)==0)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==1)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==2)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==3)[0].shape)
print(np.where(np.argmax(test_y, axis=1)==4)[0].shape)
# Out:
# validation: samples / class
# (1804,)
# (1489,)
# (2478,)
# (2821,)
# (2286,)
# training: samples / class
# (11952,)
# (15736,)
# (15736,)
# (15736,)
# (15736,)
# test: samples / class
# (1754,)
# (1451,)
# (2519,)
# (2989,)
# (2165,)
